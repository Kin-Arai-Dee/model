# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd

df = pd.read_json('../data/final_ingredient_data.json')

# %%
import sys
from pathlib import Path

# in jupyter (lab / notebook), based on notebook path
module_path = str(Path.cwd().parents[0])

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import re
from dictionary.regex_util import number_with_special_character_regex
from dictionary.protein_carbo import protein_carbo_list
from dictionary.ingredient_merg import ingredient_merg
from dictionary.calories_list import calories_list
from dictionary.ingredient_dict import ingredient_dict
from dictionary.unit_dict import measure, amount_for_uncount_unit

# %%
def set_amount(ingredient):
  if ingredient['unit'] in measure:
    return ingredient['amount']*measure[ingredient['unit']] 
  elif ingredient['unit'] in amount_for_uncount_unit[ingredient['ingredientName']]:
    return ingredient['amount']*amount_for_uncount_unit[ingredient['ingredientName']][ingredient['unit']]
  if ingredient['amount'] > 0:
    return ingredient['amount']
  else: return 0

# %%
def merge_food_ingredient(ingredients):
  new_ingre = {}
  for ingre in ingredients:
    for m in ingredient_merg:
      if ingre['ingredientName'] in ingredient_merg[m]:
        if m not in new_ingre:
          new_ingre[m] = 0
        new_ingre[m]+= set_amount(ingre)
  return new_ingre

# %%
df['ingredients'][0]
# Out:
# [{'ingredientName': 'วุ้นเส้น', 'amount': 1, 'unit': 'ซอง'},
#  {'ingredientName': 'หมูกรอบ', 'amount': 1, 'unit': 'cup'},
#  {'ingredientName': 'ใบกะเพรา', 'amount': 1, 'unit': 'cup'},
#  {'ingredientName': 'พริก', 'amount': 4, 'unit': 'เม็ด'},
#  {'ingredientName': 'กระเทียม', 'amount': 4, 'unit': 'lobe'},
#  {'ingredientName': 'ซีอิ๊วขาว', 'amount': 0.5, 'unit': 'table_spoon'},
#  {'ingredientName': 'น้ำตาล', 'amount': 1, 'unit': 'table_spoon'},
#  {'ingredientName': 'ผงปรุงรส', 'amount': 0.5, 'unit': 'table_spoon'},
#  {'ingredientName': 'น้ำเปล่า', 'amount': 2.125, 'unit': 'table_spoon'},
#  {'ingredientName': 'น้ำมัน', 'amount': 1, 'unit': 'table_spoon'}]

# %%
df['mergeIngredients'] = df['ingredients'].apply(merge_food_ingredient)

# %%
def calulate_ingredient_cal(ingredients):
  cal = 0
  for ingre in ingredients:
    if ingre in calories_list:
      cal += calories_list[ingre]* ingredients[ingre]
  return cal

# %%
df['calories'] = df['mergeIngredients'].apply(calulate_ingredient_cal)

# %%
df[df['calories'] > 1500]
# Out:
#                         title  \
# 15          ก๋วยเตี๋ยวไก่ตุ๋น
# 31          ยำหมูยอไข่แดงเค็ม
# 36        หมูปิ้งสูตรนุ๊มนุ่ม
# 43        หมี่เหลืองผัดซีอิ๊ว
# 47     ผัดซีอิ๊วเส้นเหลืองหมู
# ...                       ...
# 2775        ข้าวต้มแห้งหมูสับ
# 2776        สปาเกตตี้มิลานเนส
# 2778  ข้าวราดแกงกะหรี่ญี่ปุ่น
# 2780  ข้าวไรซ์เบอรรี่คลุกกะปิ
# 2785     สปาเก็ตตี้ขี้เมาเห็ด
#
#                                                     url  allTimeScore    view  \
# 15    https://www.wongnai.com/recipes/ugc/0724e57bd8...          2027    1897
# 31    https://www.wongnai.com/recipes/ugc/fddf94d916...          1118    1118
# 36    https://www.wongnai.com/recipes/ugc/535006fbd1...        101866  101376
# 43    https://www.wongnai.com/recipes/ugc/32277f99cd...         68578   68238
# 47    https://www.wongnai.com/recipes/ugc/87725ee94e...          1312    1182
# ...                                                 ...           ...     ...
# 2775  https://www.wongnai.com/recipes/ugc/9861529d06...          4699    4599
# 2776  https://www.wongnai.com/recipes/ugc/6752503858...           504     494
# 2778  https://www.wongnai.com/recipes/ugc/b951b197dd...          4323    3923
# 2780  https://www.wongnai.com/recipes/ugc/9cb3c02985...           879     839
# 2785  https://www.wongnai.com/recipes/ugc/95804aa0df...           877     817
#
#       totalLike                                             photos  \
# 15            4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 31            0  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 36           37  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 43           11  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 47            4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# ...         ...                                                ...
# 2775          4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2776          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2778         11  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2780          4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2785          6  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 15    [{'ingredientName': 'เนื้อไก่', 'amount': 6, '...
# 31    [{'ingredientName': 'หมูยอ', 'amount': 10, 'un...
# 36    [{'ingredientName': 'เนื้อหมู', 'amount': 1, '...
# 43    [{'ingredientName': 'บะหมี่', 'amount': 0.5, '...
# 47    [{'ingredientName': 'บะหมี่', 'amount': 1, 'un...
# ...                                                 ...
# 2775  [{'ingredientName': 'เนื้อหมู', 'amount': 3, '...
# 2776  [{'ingredientName': 'เส้นสปาเก็ตตี้', 'amount'...
# 2778  [{'ingredientName': 'เนื้อหมู', 'amount': 1, '...
# 2780  [{'ingredientName': 'ข้าวไรซ์เบอรี่', 'amount'...
# 2785  [{'ingredientName': 'เส้นสปาเก็ตตี้', 'amount'...
#
#                                                    tags  is_has_amoungs  \
# 15    [{'externalId': 'chicken-recipes', 'primaryNam...        1.000000
# 31    [{'externalId': 'main-dish-recipes', 'primaryN...        1.000000
# 36    [{'externalId': 'pork-recipes', 'primaryName':...        1.000000
# 43    [{'externalId': 'pork-recipes', 'primaryName':...        1.000000
# 47    [{'externalId': 'pork-recipes', 'primaryName':...        1.000000
# ...                                                 ...             ...
# 2775  [{'externalId': 'pork-recipes', 'primaryName':...        0.555556
# 2776  [{'externalId': 'pork-recipes', 'primaryName':...        0.545455
# 2778  [{'externalId': 'pork-recipes', 'primaryName':...        0.545455
# 2780  [{'externalId': 'main-dish-recipes', 'primaryN...        0.545455
# 2785  [{'externalId': 'main-dish-recipes', 'primaryN...        0.533333
#
#                                        mergeIngredients   calories
# 15    {'chicken': 600.0, 'offal': 400.0, 'vegetable'...  2369.5000
# 31    {'pork': 1000.0, 'egg': 750.0, 'smell_flavor':...  3821.5000
# 36    {'pork': 1000, 'salty_flavor': 115.0, 'milk': ...  2552.0000
# 43    {'noodle': 500.0, 'pork': 500.0, 'vegetable': ...  2498.8000
# 47    {'noodle': 1000, 'pork': 400, 'vegetable': 300...  2963.0000
# ...                                                 ...        ...
# 2775                     {'pork': 800.0, 'rice': 500.0}  2586.0000
# 2776  {'noodle': 700.0, 'pork': 220, 'salty_flavor':...  1820.1875
# 2778  {'pork': 1000, 'vegetable': 279.0, 'smell_flav...  3063.3500
# 2780  {'rice': 660, 'salty_flavor': 15, 'smell_flavo...  2263.8000
# 2785  {'noodle': 2000, 'vegetable': 5600.0, 'smell_f...  7966.0000
#
# [314 rows x 11 columns]

# %%
df.iloc[2719]['url']
# Out:
# 'https://www.wongnai.com/recipes/ugc/36cb20f8ab6d42bc98e1703335f1d1a4'

# %%
df_yield = pd.read_json('../data/0.recipe_data_ugc.json')

# %%
def remove_leading_zeros(s: str):
    parts = s.split('.')
    if len(parts) == 2:
        left, right = parts
        if left == '0':
            left = ''
        return f"{left}.{right}"
    else:
        return s.lstrip('0') or '0'

def recur_change_to_number(number_list):
  if not number_list:
    return 0
  if '-' in number_list:
    dash_index = number_list.index('-')
    return (recur_change_to_number(number_list[:dash_index]) + recur_change_to_number(number_list[dash_index+1:]))/2
  number_list2 = []
  for num in number_list:
    try:
      number_list2.append(remove_leading_zeros(str(eval(num))))
    except:
      number_list2.append(num.strip())
  try:
    return eval(''.join(number_list2))
  except:
    # print(number_list2)


    if '+' == number_list2[-1]:
      recur_change_to_number(number_list2[:-1])
    else:
      # print('+'.join(number_list2))
      return eval('+'.join(number_list2))

def check_recur(num_list):
  a = recur_change_to_number(num_list)
  if a:
    return a
  return 1

# %%
df_yield['yield_num'] = df_yield['yield'].apply(lambda x: check_recur(re.findall(number_with_special_character_regex,x)))

# %%
df_yield['url'] = df_yield['url'].apply(lambda x: 'https://www.wongnai.com/'+ x)

# %%
df_yield = df_yield[['url','yield_num']]

# %%
merged_df = pd.merge(df, df_yield, on='url')

# %%
merged_df['calories2'] = merged_df['calories']/ merged_df['yield_num']

# %%
def merge_food_ingredient(ingredients):
  new_ingre = {}
  for ingre in ingredients:
    for m in ingredient_merg:
      if ingre['ingredientName'] in ingredient_merg[m]:
        if m not in new_ingre:
          new_ingre[m] = 0
        new_ingre[m]+= set_amount(ingre)
  return new_ingre

# %%
def merge_food_nutrients(ingredients):
  new_ingre = {}
  for ingre in ingredients:
    for m in protein_carbo_list:
      if ingre in protein_carbo_list[m]:
        if m not in new_ingre:
          new_ingre[m] = 0
        new_ingre[m]+= ingredients[ingre]
  return new_ingre

# %%
def cal_nutrients_percen(di):
  d = {**di}
  sumary = sum(d.values())
  if sumary:
    for x in d:
      d[x] = d[x]/sumary
  return d

# %%
merged_df['nutrients'] = merged_df['mergeIngredients'].apply(merge_food_nutrients)
merged_df['sum_nutrients'] = merged_df['nutrients'].apply(lambda x: sum(x.values()))
merged_df['nutrients_percen'] = merged_df['nutrients'].apply(cal_nutrients_percen)

# %%
merged_df.iloc[1]['ingredients']
# Out:
# [{'ingredientName': 'ไข่ไก่', 'amount': 2, 'unit': 'buble'},
#  {'ingredientName': 'บะหมี่กึ่งสำเร็จรูป', 'amount': 1, 'unit': 'ก้อน'},
#  {'ingredientName': 'นม', 'amount': 0.5, 'unit': 'กล่อง'},
#  {'ingredientName': 'แครอท', 'amount': -1, 'unit': 'avg'},
#  {'ingredientName': 'กระดูกหมู', 'amount': -1, 'unit': 'avg'},
#  {'ingredientName': 'น้ำปลา', 'amount': 2, 'unit': 'tea_spoon'},
#  {'ingredientName': 'พริกไทย', 'amount': 1, 'unit': 'tea_spoon'}]

# %%
def cal_spicy(x):
  if 'spicy_flavor' in x:
    return 3
  if 'mediumspicy_flavor' in x:
    return 2
  if 'little_spicy' in x:
    return 1
  return 0

# %%
merged_df['spicyLevel'] = merged_df['mergeIngredients'].apply(cal_spicy)

# %%
merged_df[merged_df['spicyLevel'] ==1].sample(3)
# Out:
#                          title  \
# 1701  ต้นกระเทียมผัดหมูสามชั้น
# 205                 สุกี้อกไก่
# 1271              อกไก่ทอดกรอบ
#
#                                                     url  allTimeScore  view  \
# 1701  https://www.wongnai.com/recipes/ugc/d266ae762d...           673   663
# 205   https://www.wongnai.com/recipes/ugc/e475eefa44...          1633  1493
# 1271  https://www.wongnai.com/recipes/ugc/d8f22083de...          8558  8478
#
#       totalLike                                             photos  \
# 1701          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 205           5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 1271          8  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 1701  [{'ingredientName': 'เนื้อหมู', 'amount': 300,...
# 205   [{'ingredientName': 'เนื้อไก่', 'amount': 200,...
# 1271  [{'ingredientName': 'เนื้อไก่', 'amount': 200,...
#
#                                                    tags  is_has_amoungs  \
# 1701  [{'externalId': 'pork-recipes', 'primaryName':...             1.0
# 205   [{'externalId': 'chicken-recipes', 'primaryNam...             1.0
# 1271  [{'externalId': 'chicken-recipes', 'primaryNam...             1.0
#
#                                        mergeIngredients  calories  yield_num  \
# 1701  {'pork': 300, 'salty_flavor': 22.5, 'vegetable...    726.00        1.0
# 205   {'chicken': 200, 'vegetable': 155.0, 'salty_fl...    656.25        2.0
# 1271  {'chicken': 200, 'salty_flavor': 5, 'little_sp...    478.00        1.0
#
#       calories2                           nutrients  sum_nutrients  \
# 1701    726.000      {'protein': 300, 'mineral': 0}          300.0
# 205     328.125  {'protein': 250, 'mineral': 155.0}          405.0
# 1271    478.000                    {'protein': 200}          200.0
#
#                                        nutrients_percen  spicyLevel
# 1701                   {'protein': 1.0, 'mineral': 0.0}           1
# 205   {'protein': 0.6172839506172839, 'mineral': 0.3...           1
# 1271                                   {'protein': 1.0}           1

# %%
merged_df['calories'] = merged_df['calories2']
merged_df.drop('calories2',axis=1)
# Out:
#                           title  \
# 0     ผัดวุ้นเส้นกระเพราหมูกรอบ
# 1                  ไข่ตุ๋นมาม่า
# 2       เกี่ยมอี๋คั่วไส้หมูก้อน
# 3       ออรินจิคั่วเกลือพริกไทย
# 4           กระหล่ำปลีทอดน้ำปลา
# ...                         ...
# 2782         สุกี้น้ำกระดูกอ่อน
# 2783              ผัดผักรวมมิตร
# 2784              ผัดมาม่าต้มยำ
# 2785       สปาเก็ตตี้ขี้เมาเห็ด
# 2786       เบอร์เกอร์หมูชุ่มฉ่ำ
#
#                                                     url  allTimeScore   view  \
# 0     https://www.wongnai.com/recipes/ugc/273249a788...          1939   1939
# 1     https://www.wongnai.com/recipes/ugc/d2ca1bdc51...          1519   1179
# 2     https://www.wongnai.com/recipes/ugc/ffbd2984f0...           946    826
# 3     https://www.wongnai.com/recipes/ugc/66e7abffe9...          1862   1792
# 4     https://www.wongnai.com/recipes/ugc/f0e49ced08...          1365   1305
# ...                                                 ...           ...    ...
# 2782  https://www.wongnai.com/recipes/ugc/7087159c34...           628    398
# 2783  https://www.wongnai.com/recipes/ugc/5887aa7205...           987    947
# 2784  https://www.wongnai.com/recipes/ugc/b30648906c...           397    377
# 2785  https://www.wongnai.com/recipes/ugc/95804aa0df...           877    817
# 2786  https://www.wongnai.com/recipes/ugc/ea691bb354...         99441  99191
#
#       totalLike                                             photos  \
# 0             0  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 1             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2             6  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 3             4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4             3  [{'contentUrl': 'https://img.wongnai.com/p/196...
# ...         ...                                                ...
# 2782          8  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2783          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2784          2  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2785          6  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2786         10  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 0     [{'ingredientName': 'วุ้นเส้น', 'amount': 1, '...
# 1     [{'ingredientName': 'ไข่ไก่', 'amount': 2, 'un...
# 2     [{'ingredientName': 'เกี่ยมอี๋ลวก', 'amount': ...
# 3     [{'ingredientName': 'เห็ด', 'amount': 3, 'unit...
# 4     [{'ingredientName': 'กะหล่ำปลี', 'amount': 10,...
# ...                                                 ...
# 2782  [{'ingredientName': 'กระดูกอ่อน', 'amount': 0....
# 2783  [{'ingredientName': 'ดอกกะหล่ำ', 'amount': 1, ...
# 2784  [{'ingredientName': 'กุ้ง', 'amount': 6, 'unit...
# 2785  [{'ingredientName': 'เส้นสปาเก็ตตี้', 'amount'...
# 2786  [{'ingredientName': 'เนื้อหมู', 'amount': 400,...
#
#                                                    tags  is_has_amoungs  \
# 0     [{'externalId': 'pork-recipes', 'primaryName':...        1.000000
# 1     [{'externalId': 'egg-recipes', 'primaryName': ...        1.000000
# 2     [{'externalId': 'main-dish-recipes', 'primaryN...        1.000000
# 3     [{'externalId': 'chicken-recipes', 'primaryNam...        1.000000
# 4     [{'externalId': 'vegetable-recipes', 'primaryN...        1.000000
# ...                                                 ...             ...
# 2782  [{'externalId': 'vegetable-recipes', 'primaryN...        0.545455
# 2783  [{'externalId': 'vegetable-recipes', 'primaryN...        0.538462
# 2784  [{'externalId': 'noodle-recipes', 'primaryName...        0.538462
# 2785  [{'externalId': 'main-dish-recipes', 'primaryN...        0.533333
# 2786  [{'externalId': 'pork-recipes', 'primaryName':...        0.533333
#
#                                        mergeIngredients    calories  \
# 0     {'noodle': 50.0, 'pork': 220, 'smell_flavor': ...  622.400000
# 1     {'egg': 100, 'noodle': 60.0, 'milk': 50.0, 've...  293.000000
# 2     {'pork': 200.0, 'egg': 100, 'smell_flavor': 39...  639.000000
# 3     {'vegetable': 300, 'chicken': 200, 'salty_flav...  336.500000
# 4     {'vegetable': 100.0, 'salty_flavor': 20, 'smel...   32.500000
# ...                                                 ...         ...
# 2782  {'vegetable': 61.0, 'egg': 50, 'smell_flavor':...  117.150000
# 2783  {'vegetable': 793.0, 'bean': 150.0, 'process_m...  810.633333
# 2784  {'shrimp': 300.0, 'egg': 50, 'noodle': 60.0, '...  482.500000
# 2785  {'noodle': 2000, 'vegetable': 5600.0, 'smell_f...  265.533333
# 2786  {'pork': 400, 'smell_flavor': 100.0, 'salty_fl...  261.375000
#
#       yield_num                                          nutrients  \
# 0           1.0                    {'carbo': 50.0, 'protein': 220}
# 1           1.0     {'protein': 100, 'carbo': 110.0, 'mineral': 0}
# 2           1.0                                 {'protein': 300.0}
# 3           2.0                   {'mineral': 300, 'protein': 200}
# 4           2.0                                 {'mineral': 100.0}
# ...         ...                                                ...
# 2782        1.0                   {'mineral': 61.0, 'protein': 50}
# 2783        1.5  {'mineral': 793.0, 'carbo': 150.0, 'protein': ...
# 2784        1.0    {'protein': 350.0, 'carbo': 60.0, 'mineral': 0}
# 2785       30.0  {'carbo': 2000, 'mineral': 5600.0, 'protein': ...
# 2786        4.0                                   {'protein': 450}
#
#       sum_nutrients                                   nutrients_percen  \
# 0             270.0  {'carbo': 0.18518518518518517, 'protein': 0.81...
# 1             210.0  {'protein': 0.47619047619047616, 'carbo': 0.52...
# 2             300.0                                   {'protein': 1.0}
# 3             500.0                   {'mineral': 0.6, 'protein': 0.4}
# 4             100.0                                   {'mineral': 1.0}
# ...             ...                                                ...
# 2782          111.0  {'mineral': 0.5495495495495496, 'protein': 0.4...
# 2783         1033.0  {'mineral': 0.7676669893514037, 'carbo': 0.145...
# 2784          410.0  {'protein': 0.8536585365853658, 'carbo': 0.146...
# 2785         7900.0  {'carbo': 0.25316455696202533, 'mineral': 0.70...
# 2786          450.0                                   {'protein': 1.0}
#
#       spicyLevel
# 0              3
# 1              1
# 2              0
# 3              1
# 4              0
# ...          ...
# 2782           0
# 2783           0
# 2784           0
# 2785           0
# 2786           1
#
# [2787 rows x 16 columns]

# %%
db_df = merged_df.copy(deep=False)

# %%
db_df = db_df[['url','calories','spicyLevel']]

# %%
with open('../data/addition_data.json','w',encoding='utf8')as file:
  db_df.to_json(file,orient='records', force_ascii=False)

# %%
merged_df[['title','tags','mergeIngredients','nutrients_percen','spicyLevel']]
# Out:
#                           title  \
# 0     ผัดวุ้นเส้นกระเพราหมูกรอบ
# 1                  ไข่ตุ๋นมาม่า
# 2       เกี่ยมอี๋คั่วไส้หมูก้อน
# 3       ออรินจิคั่วเกลือพริกไทย
# 4           กระหล่ำปลีทอดน้ำปลา
# ...                         ...
# 2782         สุกี้น้ำกระดูกอ่อน
# 2783              ผัดผักรวมมิตร
# 2784              ผัดมาม่าต้มยำ
# 2785       สปาเก็ตตี้ขี้เมาเห็ด
# 2786       เบอร์เกอร์หมูชุ่มฉ่ำ
#
#                                                    tags  \
# 0     [{'externalId': 'pork-recipes', 'primaryName':...
# 1     [{'externalId': 'egg-recipes', 'primaryName': ...
# 2     [{'externalId': 'main-dish-recipes', 'primaryN...
# 3     [{'externalId': 'chicken-recipes', 'primaryNam...
# 4     [{'externalId': 'vegetable-recipes', 'primaryN...
# ...                                                 ...
# 2782  [{'externalId': 'vegetable-recipes', 'primaryN...
# 2783  [{'externalId': 'vegetable-recipes', 'primaryN...
# 2784  [{'externalId': 'noodle-recipes', 'primaryName...
# 2785  [{'externalId': 'main-dish-recipes', 'primaryN...
# 2786  [{'externalId': 'pork-recipes', 'primaryName':...
#
#                                        mergeIngredients  \
# 0     {'noodle': 50.0, 'pork': 220, 'smell_flavor': ...
# 1     {'egg': 100, 'noodle': 60.0, 'milk': 50.0, 've...
# 2     {'pork': 200.0, 'egg': 100, 'smell_flavor': 39...
# 3     {'vegetable': 300, 'chicken': 200, 'salty_flav...
# 4     {'vegetable': 100.0, 'salty_flavor': 20, 'smel...
# ...                                                 ...
# 2782  {'vegetable': 61.0, 'egg': 50, 'smell_flavor':...
# 2783  {'vegetable': 793.0, 'bean': 150.0, 'process_m...
# 2784  {'shrimp': 300.0, 'egg': 50, 'noodle': 60.0, '...
# 2785  {'noodle': 2000, 'vegetable': 5600.0, 'smell_f...
# 2786  {'pork': 400, 'smell_flavor': 100.0, 'salty_fl...
#
#                                        nutrients_percen  spicyLevel
# 0     {'carbo': 0.18518518518518517, 'protein': 0.81...           3
# 1     {'protein': 0.47619047619047616, 'carbo': 0.52...           1
# 2                                      {'protein': 1.0}           0
# 3                      {'mineral': 0.6, 'protein': 0.4}           1
# 4                                      {'mineral': 1.0}           0
# ...                                                 ...         ...
# 2782  {'mineral': 0.5495495495495496, 'protein': 0.4...           0
# 2783  {'mineral': 0.7676669893514037, 'carbo': 0.145...           0
# 2784  {'protein': 0.8536585365853658, 'carbo': 0.146...           0
# 2785  {'carbo': 0.25316455696202533, 'mineral': 0.70...           0
# 2786                                   {'protein': 1.0}           1
#
# [2787 rows x 5 columns]

# %%
model_df = merged_df[['title','tags','mergeIngredients','nutrients_percen','spicyLevel']]

# %%
from dictionary.tag_category import tag_category

# %%
tc = tag_category
del tc['ประเภทอาหาร']

# %%
all_tag = sum(list(tc.values()),[])

# %%
def is_external_id_in_list(external_ids, check_external_id):
  if(check_external_id in external_ids):
    return 1
  else:
    return 0

for external_id in all_tag:
  model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# Out:
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_97210/1419923048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df[external_id] = model_df['tags'].apply(lambda tags : is_external_id_in_list([tag['externalId'] for tag in tags] ,external_id))

# %%
for ingre in ingredient_merg:
  model_df[ingre] = model_df['mergeIngredients'].apply(lambda mergeIngredients : is_external_id_in_list(list(mergeIngredients.keys()) ,ingre))

# %%
def is_in_dict(n,k):
  if k in n:
    return n[k]
  else :
    return 0

# %%
for protein_carbo in protein_carbo_list:
  model_df[protein_carbo] = model_df['nutrients_percen'].apply(lambda nutrients : is_in_dict(nutrients,protein_carbo))

# %%
model_df = model_df.drop(['tags','mergeIngredients','nutrients_percen'],axis=1)

# %%
model_df.to_csv('../data/data_for_model2.csv')
