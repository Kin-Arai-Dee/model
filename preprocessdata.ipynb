# %%
import pandas as pd

# Read JSON file into a Pandas DataFrame
df = pd.read_json('clean_recipe_data_ugc.json')

# %%
import re
import ftfy

def remove_emoji(title):
    return ftfy.fix_text(title, fix_entities=True, remove_unknown_chars=True)

df['title'] = df['title'].apply(remove_emoji)

df

# %%
import re
def remove_emojis(data):
    emoji = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoji, '', data)

# %%
df['title'] = df['title'].apply(remove_emoji)
df

# %%
df
# Out:
#                                               title  \
# 0                        ผัดโหระพาไก่สับเป็ดสับคีโต
# 1                                         กุ้งอบเนย
# 2                        สปาเกตตี ผัดปลาหมึกไข่เค็ม
# 3                              มาม่าผัดขี้เมากุ้ง 🦐
# 4     แกงกะหรี่ญี่ปุ่น\n{แกงกระหรี่สูตรHoney Apple}
# ...                                             ...
# 4502                               ไข่เจียววุ้นเส้น
# 4503                             พริกหยวกผัดพริกเผา
# 4504                           สเต็กแซลมอนพริกไทยดำ
# 4505                      ผัดเผ็ดปลาดุก น้ำขลุกขลิก
# 4506                      ผัดวุ้นเส้นกระเพราหมูกรอบ
#
#                                                url  allTimeScore  view  \
# 0     recipes/ugc/0f3a82d664274df380f802495e5c0d8c           750   680
# 1     recipes/ugc/d19b99c83bbf49bf89c2d31279c5ce28          1188   948
# 2     recipes/ugc/1398926e639148469a2326af3e14918a           751   641
# ...
