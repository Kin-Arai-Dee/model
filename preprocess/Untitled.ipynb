# %%
import re
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('../data/non.csv').sort_values(by=['frequency'], ascending=False).reset_index()
list_df = []
for i in range(len(df)):
    list_df.append([ df.loc[i]['ingredients'] , df.loc[i]['frequency'] ])

# %%
all_facility_unique = [[i[0],i[1],0] for i in list_df if i[1] >= 1]

# %%
def search_fsc(all_facility_unique, ch_regex):
    list_exam = []
    for i in range (len(all_facility_unique)) : 
        if re.search(ch_regex, all_facility_unique[i][0]):
            if all_facility_unique[i][1] > 1:
                print(all_facility_unique[i][0],all_facility_unique[i][1])
            all_facility_unique[i][2] = 1
            if all_facility_unique[i][1] > 1:
                list_exam.append(all_facility_unique[i][0])
    example = ', '.join(list_exam)
#     print(example)
    return all_facility_unique,example

def make_table(name,ch_regex,example):
    global df_name
    global df_ch_regex
    global df_example
    df_name.append(name)
    df_ch_regex.append(ch_regex)
    df_example.append(example)

df_name = []
df_ch_regex = []
df_example = []

# %%
all_facility_unique
# Out:
# [['น้ำปลา', 736, 0],
#  ['กระเทียม', 633, 0],
#  ['ไข่ไก่', 627, 0],
#  ['น้ำตาลทราย', 619, 0],
#  ['น้ำตาล', 584, 0],
#  ['น้ำมันหอย', 575, 0],
#  ['น้ำมันพืช', 423, 0],
#  ['เกลือ', 417, 0],
#  ['ซอสปรุงรส', 338, 0],
#  ['น้ำมัน', 328, 0],
#  ['น้ำเปล่า', 306, 0],
#  ['ซีอิ๊วขาว', 294, 0],
#  ['ซีอิ้วขาว', 289, 0],
#  ['กระเทียมสับ', 276, 0],
#  ['พริกไทย', 274, 0],
#  ['ต้นหอม', 228, 0],
#  ['แครอท', 224, 0],
#  ['ซอสหอยนางรม', 213, 0],
#  ['หมูสับ', 197, 0],
#  ['ข้าวสวย', 197, 0],
#  ['ผงปรุงรส', 193, 0],
#  ['มะนาว', 191, 0],
#  ['พริกไทยป่น', 163, 0],
#  ['พริกขี้หนู', 158, 0],
#  ['กุ้ง', 152, 0],
#  ['มะเขือเทศ', 139, 0],
#  ['หอมใหญ่', 135, 0],
#  ['เนื้อหมู', 123, 0],
#  ['น้ำสะอาด', 113, 0],
#  ['รากผักชี', 111, 0],
#  ['เกลือป่น', 108, 0],
#  ['น้ำมันมะกอก', 103, 0],
#  ['ซอสมะเขือเทศ', 103, 0],
#  ['หอมแดง', 100, 0],
#  ['พริกแห้ง', 100, 0],
#  ['พริกป่น', 99, 0],
#  ['ผักชี', 97, 0],
#  ['ใบมะกรูด', 94, 0],
#  ['น้ำมันงา', 93, 0],
#  ['น้ำตาลปี๊บ', 90, 0],
#  ['พริก', 89, 0],
#  ['ใบโหระพา', 89, 0],
#  ['ต้นหอมซอย', 88, 0],
#  ['ถั่วฝักยาว', 84, 0],
#  ['หอมหัวใหญ่', 83, 0],
#  ['ใบกะเพรา', 82, 0],
#  ['ใบกระเพรา', 82, 0],
#  ['อกไก่', 81, 0],
#  ['ซีอิ๊วดำ', 77, 0],
#  ['ถั่วงอก', 76, 0],
#  ['หมูบด', 76, 0],
#  ['พริกไทยดำ', 75, 0],
#  ['คะน้า', 74, 0],
#  ['ข้าวโพดอ่อน', 74, 0],
#  ['ไข่', 73, 0],
#  ['เนย', 70, 0],
#  ['น้ำมันรำข้าว', 67, 0],
#  ['น้ำมะนาว', 67, 0],
#  ['น้ำพริกเผา', 67, 0],
#  ['ซีอิ้วดำ', 62, 0],
#  ['แป้งทอดกรอบ', 59, 0],
#  ['แป้งมัน', 56, 0],
#  ['เห็ดหอม', 56, 0],
#  ['กระเทียมเจียว', 55, 0],
#  ['เส้นสปาเก็ตตี้', 55, 0],
#  ['เนื้อไก่', 54, 0],
#  ['โชยุ', 53, 0],
#  ['เต้าเจี้ยว', 53, 0],
#  ['ตะไคร้', 52, 0],
#  ['ปลาหมึก', 52, 0],
#  ['เบคอน', 52, 0],
#  ['โหระพา', 52, 0],
#  ['ไส้กรอก', 50, 0],
#  ['หัวหอมใหญ่', 49, 0],
#  ['นมสด', 49, 0],
#  ['กุ้งสด', 48, 0],
#  ['ซอสพริก', 48, 0],
#  ['วุ้นเส้น', 47, 0],
#  ['น้ำซุป', 46, 0],
#  ['น้ำมันสำหรับผัด', 45, 0],
#  ['หอมแดงซอย', 45, 0],
#  ['กระเทียมไทย', 45, 0],
#  ['ผักกาดขาว', 43, 0],
#  ['กะปิ', 43, 0],
#  ['พริกชี้ฟ้าแดง', 43, 0],
#  ['พริกสด', 42, 0],
#  ['กะทิ', 42, 0],
#  ['เส้นใหญ่', 42, 0],
#  ['กะหล่ำปลี', 40, 0],
#  ['พริกแกงเผ็ด', 39, 0],
#  ['พริกขี้หนูสวน', 39, 0],
#  ['ผักบุ้ง', 39, 0],
#  ['แฮม', 39, 0],
#  ['หมูยอ', 37, 0],
#  ['หมูสามชั้น', 36, 0],
#  ['แตงกวา', 36, 0],
#  ['กุ้งแห้ง', 35, 0],
#  ['พริกจินดา', 35, 0],
#  ['มิริน', 35, 0],
#  ['น้ำมะขามเปียก', 35, 0],
#  ['ข้าว', 35, 0],
#  ['เส้นสปาเกตตี้', 34, 0],
#  ['ผงปรุงรสคนอร์', 34, 0],
#  ['ขึ้นฉ่าย', 34, 0],
#  ['เห็ดเข็มทอง', 34, 0],
#  ['น้ำมันสำหรับทอด', 33, 0],
#  ['ผักคะน้า', 33, 0],
#  ['มันฝรั่ง', 33, 0],
#  ['แป้งข้าวโพด', 32, 0],
#  ['พริกไท', 32, 0],
#  ['กระเทียมจีน', 32, 0],
#  ['ซอสปรุงรสฝาเขียว', 32, 0],
#  ['น้ำส้มสายชู', 31, 0],
#  ['ข่า', 31, 0],
#  ['ผักชีฝรั่ง', 30, 0],
#  ['มาม่า', 29, 0],
#  ['ซอสถั่วเหลือง', 29, 0],
#  ['ซีอิ๋วขาว', 28, 0],
#  ['แครอทหั่นเต๋า', 28, 0],
#  ['ซีอิ้วปรุงรส', 28, 0],
#  ['น้ำผึ้ง', 28, 0],
#  ['พริกแกง', 28, 0],
#  ['รสดี', 28, 0],
#  ['คนอร์', 27, 0],
#  ['น้ำตาลทรายแดง', 26, 0],
#  ['พริกชี้ฟ้า', 26, 0],
#  ['พริกไทยอ่อน', 26, 0],
#  ['ซีอิ้วดำหวาน', 26, 0],
#  ['ซอสเห็ดหอม', 26, 0],
#  ['พริกไทยดำป่น', 25, 0],
#  ['กระเทียมสับละเอียด', 25, 0],
#  ['ไข่ต้ม', 25, 0],
#  ['พริกแดง', 25, 0],
#  ['หัวไชเท้า', 24, 0],
#  ['กุนเชียง', 24, 0],
#  ['ผงปรุงรสหมู', 24, 0],
#  ['น้ำมันถั่วเหลือง', 24, 0],
#  ['ข้าวคั่ว', 24, 0],
#  ['เนื้ออกไก่', 24, 0],
#  ['ผักกวางตุ้ง', 24, 0],
#  ['พริกขี้หนูซอย', 24, 0],
#  ['ลูกชิ้นปลา', 24, 0],
#  ['ไข่เป็ด', 24, 0],
#  ['ปลากระป๋อง', 23, 0],
#  ['ผักสลัด', 23, 0],
#  ['พริกไทป่น', 23, 0],
#  ['หมู', 23, 0],
#  ['กระดูกหมู', 23, 0],
#  ['ปูอัด', 23, 0],
#  ['หัวหอม', 22, 0],
#  ['เนื้อหมูสับ', 22, 0],
#  ['เนยจืด', 22, 0],
#  ['เกล็ดขนมปัง', 22, 0],
#  ['เต้าหู้ไข่', 22, 0],
#  ['หมูหมัก', 22, 0],
#  ['ใบมะกรูดซอย', 22, 0],
#  ['ตะไคร้ซอย', 22, 0],
#  ['บะหมี่กึ่งสำเร็จรูป', 21, 0],
#  ['กระหล่ำปลี', 21, 0],
#  ['สันในไก่', 21, 0],
#  ['น้ำปลาร้า', 20, 0],
#  ['หมูสันใน', 20, 0],
#  ['งาขาว', 20, 0],
#  ['ถั่วลันเตา', 20, 0],
#  ['กระเทียมทุบ', 20, 0],
#  ['ไข่เค็ม', 20, 0],
#  ['งาขาวคั่ว', 20, 0],
#  ['กระชาย', 20, 0],
#  ['สันคอหมู', 20, 0],
#  ['ผงชูรส', 19, 0],
#  ['เนยเค็ม', 19, 0],
#  ['ขนมจีน', 19, 0],
#  ['กระเพรา', 19, 0],
#  ['ชีส', 19, 0],
#  ['พริกจินดาแดง', 19, 0],
#  ['เห็ดออรินจิ', 19, 0],
#  ['พริกไทยเม็ด', 19, 0],
#  ['คะน้าฮ่องกง', 19, 0],
#  ['พริกหยวก', 18, 0],
#  ['เห็ดหอมสด', 18, 0],
#  ['เส้นหมี่', 18, 0],
#  ['น้ำตาลทรายขาว', 18, 0],
#  ['น้ำมันปาล์ม', 18, 0],
#  ['นมจืด', 18, 0],
#  ['มะเขือเทศราชินี', 18, 0],
#  ['มะเขือเปราะ', 17, 0],
#  ['ผักกาดหอม', 17, 0],
#  ['สะโพกไก่', 17, 0],
#  ['สี่อิ๋วขาวสูตร1', 17, 0],
#  ['พริกเผา', 17, 0],
#  ['ลูกชิ้นหมู', 17, 0],
#  ['ต้นหอมหั่นท่อน', 17, 0],
#  ['น้ำตาลมะพร้าว', 17, 0],
#  ['ซี่โครงหมู', 17, 0],
#  ['ใบมะกรูดฉีก', 16, 0],
#  ['เห็ดฟาง', 16, 0],
#  ['เหล้าจีน', 16, 0],
#  ['ลูกชิ้น', 16, 0],
#  ['เห็ด', 16, 0],
#  ['แหนม', 16, 0],
#  ['ยอดคะน้า', 16, 0],
#  ['คนอร์อร่อยชัวร์', 16, 0],
#  ['กิมจิ', 16, 0],
#  ['กระเทียมไท', 16, 0],
#  ['ออริกาโน่', 16, 0],
#  ['พริกไทยขาวป่น', 16, 0],
#  ['ซีอิ๊วดำหวาน', 16, 0],
#  ['เนยสด', 16, 0],
#  ['กระเทียมสับหยาบ', 15, 0],
#  ['ผักชีซอย', 15, 0],
#  ['ต้นหอมผักชี', 15, 0],
#  ['พริกขี้หนูแดง', 15, 0],
#  ['มายองเนส', 15, 0],
#  ['เส้นหมี่ขาว', 15, 0],
#  ['น้ำจิ้มสุกี้', 15, 0],
#  ['น้ำต้มสุก', 15, 0],
#  ['ขิงซอย', 15, 0],
#  ['ชะอม', 14, 0],
#  ['ไข่แดง', 14, 0],
#  ['หมูสไลด์', 14, 0],
#  ['น้ำตาลปี๊ป', 14, 0],
#  ['ผัก', 14, 0],
#  ['นมข้นจืด', 14, 0],
#  ['ข้าวกล้อง', 14, 0],
#  ['มักกะโรนี', 14, 0],
#  ['ผงคนอร์', 14, 0],
#  ['น้ำตาลปีบ', 14, 0],
#  ['เนื้อหมูบด', 14, 0],
#  ['อบเชย', 14, 0],
#  ['พริกใหญ่', 14, 0],
#  ['หอมเจียว', 14, 0],
#  ['น้ำ', 14, 0],
#  ['พริกไทยขาว', 14, 0],
#  ['ตับหมู', 13, 0],
#  ['พริกขี้หนูตำ', 13, 0],
#  ['กระเทียมกลีบใหญ่', 13, 0],
#  ['หมูกรอบ', 13, 0],
#  ['ซอสน้ำมันหอย', 13, 0],
#  ['ไก่', 13, 0],
#  ['หมูชิ้น', 13, 0],
#  ['ผักโขม', 13, 0],
#  ['ซอสฝาเขียว', 13, 0],
#  ['อร่อยชัวร์', 13, 0],
#  ['โคชูจัง', 12, 0],
#  ['ซีอิ๊วเห็ดหอม', 12, 0],
#  ['หัวกะทิ', 12, 0],
#  ['ไข่กุ้ง', 12, 0],
#  ['พริกแดงจินดา', 12, 0],
#  ['ปลาทู', 12, 0],
#  ['ซอยหอยนางรม', 12, 0],
#  ['พริกขี้หนูสด', 12, 0],
#  ['กระเทียมตำ', 12, 0],
#  ['มันกุ้ง', 12, 0],
#  ['เห็ดหูหนู', 12, 0],
#  ['เต้าหู้', 12, 0],
#  ['ทูน่าในน้ำแร่', 12, 0],
#  ['ไก่สับ', 12, 0],
#  ['น้ำปลาอย่างดี', 12, 0],
#  ['คื่นช่าย', 12, 0],
#  ['น้ำตาลปิ๊บ', 12, 0],
#  ['เบค่อน', 12, 0],
#  ['ซอสฝาเหลือง', 11, 0],
#  ['กะเพรา', 11, 0],
#  ['อกไก่สับ', 11, 0],
#  ['ผักกระเฉด', 11, 0],
#  ['แผ่นเกี๊ยว', 11, 0],
#  ['กระเทียมซอย', 11, 0],
#  ['เห็ดชิเมจิ', 11, 0],
#  ['ไข่ขาว', 11, 0],
#  ['น้ำเย็น', 11, 0],
#  ['สะตอ', 11, 0],
#  ['ซอสหอย', 11, 0],
#  ['ถั่วลิสงคั่ว', 11, 0],
#  ['พริกขี้หนูสับ', 11, 0],
#  ['พริกไทยดำบด', 11, 0],
#  ['แครอทหั่น', 11, 0],
#  ['เส้นเล็ก', 11, 0],
#  ['ซอสเทริยากิ', 11, 0],
#  ['น่องไก่', 11, 0],
#  ['กวางตุ้ง', 10, 0],
#  ['เลือดไก่', 10, 0],
#  ['น้ำมันพืชสำหรับผัด', 10, 0],
#  ['ต้นหอมหั่น', 10, 0],
#  ['น้ำมันหมู', 10, 0],
#  ['กระชายซอย', 10, 0],
#  ['ฟักทอง', 10, 0],
#  ['เห็ดหอมแห้ง', 10, 0],
#  ['ใบกระวาน', 10, 0],
#  ['หอมแขก', 10, 0],
#  ['ซอสเทอริยากิ', 10, 0],
#  ['กุยช่าย', 10, 0],
#  ['หอมใหญ่สับ', 10, 0],
#  ['วุ้นเส้นสด', 10, 0],
#  ['เครื่องปรุงรส', 10, 0],
#  ['ข้าวสาร', 10, 0],
#  ['มะเขือเทศหั่นเต๋า', 10, 0],
#  ['ผงกะหรี่', 10, 0],
#  ['มะเขือพวง', 10, 0],
#  ['มะเขือยาว', 10, 0],
#  ['ซีอิ๊ว', 10, 0],
#  ['ผักชีต้นหอม', 9, 0],
#  ['เชดด้าชีส', 9, 0],
#  ['น้ำตาลกรวด', 9, 0],
#  ['เต้าหู้เหลือง', 9, 0],
#  ['ข้าวเปล่า', 9, 0],
#  ['มะเขือเทศสีดา', 9, 0],
#  ['เห็ดแชมปิญอง', 9, 0],
#  ['พริกแกงใต้', 9, 0],
#  ['ขิง', 9, 0],
#  ['น้ำตาลหญ้าหวาน', 9, 0],
#  ['สาเก', 9, 0],
#  ['เส้นก๋วยเตี๋ยว', 9, 0],
#  ['ถั่วลิสง', 9, 0],
#  ['กระเทียมโทน', 9, 0],
#  ['สปาเก็ตตี้', 9, 0],
#  ['พริกจินดาสีแดง', 9, 0],
#  ['น้ำพริกกะปิ', 9, 0],
#  ['หัวหอมแดง', 9, 0],
#  ['เส้นหมี่เหลือง', 9, 0],
#  ['พริกแกงเขียวหวาน', 9, 0],
#  ['หอมใหญ่หั่นเต๋า', 9, 0],
#  ['ผักสามสี', 9, 0],
#  ['พริกไทยสด', 9, 0],
#  ['พริกสับ', 9, 0],
#  ['น้ำมันคาโนล่า', 8, 0],
#  ['หมูหั่นชิ้น', 8, 0],
#  ['เม็ดมะม่วงหิมพานต์', 8, 0],
#  ['กระเทียมจีนสับ', 8, 0],
#  ['ซีอิ๊วหวาน', 8, 0],
#  ['กุ้งแม่น้ำ', 8, 0],
#  ['เต้าหู้ทอด', 8, 0],
#  ['ข้าวโพด', 8, 0],
#  ['ผงกระหรี่', 8, 0],
#  ['บะหมี่', 8, 0],
#  ['ไก่น่องสะโพก', 8, 0],
#  ['มะขามเปียก', 8, 0],
#  ['ปีกไก่', 8, 0],
#  ['หน่อไม้ดอง', 8, 0],
#  ['บะหมี่ผัก', 8, 0],
#  ['แป้งอเนกประสงค์', 8, 0],
#  ['ตั้งฉ่าย', 8, 0],
#  ['กะเทียม', 8, 0],
#  ['น้ำปลาดี', 8, 0],
#  ['ดอกกะหล่ำ', 8, 0],
#  ['น้ำมันมะพร้าว', 8, 0],
#  ['มอสซาเรลล่าชีส', 8, 0],
#  ['แป้งมันฮ่องกง', 8, 0],
#  ['เส้นพาสต้า', 8, 0],
#  ['ซอสแมคกี้', 8, 0],
#  ['ชีสแผ่น', 8, 0],
#  ['ขนมปัง', 8, 0],
#  ['ข้าวหอมมะลิ', 8, 0],
#  ['สันในหมู', 8, 0],
#  ['ไข่ดาว', 8, 0],
#  ['เส้นหมี่ข้าวกล้อง', 8, 0],
#  ['บล็อคโคลี่', 8, 0],
#  ['กุ้งขาว', 8, 0],
#  ['น้ำเชื่อม', 8, 0],
#  ['ปลาหมึกสด', 8, 0],
#  ['น้ำจิ้มไก่', 8, 0],
#  ['พริกแห้งทอด', 8, 0],
#  ['เนื้อหมูสามชั้น', 8, 0],
#  ['น้ำพริกตาแดง', 8, 0],
#  ['ต้นหอมญี่ปุ่น', 8, 0],
#  ['ซีอิ๋วดำ', 8, 0],
#  ['อกไก่หั่น', 7, 0],
#  ['ไส้กรอกรมควัน', 7, 0],
#  ['ผงปรุงรสไก่', 7, 0],
#  ['หมี่ซั่ว', 7, 0],
#  ['น้ำเย็นจัด', 7, 0],
#  ['โป๊ยกั๊ก', 7, 0],
#  ['เส้นสปาเก็ตตี้ต้มสุก', 7, 0],
#  ['หมูเด้ง', 7, 0],
#  ['แป้งสาลีอเนกประสงค์', 7, 0],
#  ['น้ำกระเทียมดอง', 7, 0],
#  ['ผงปรุงรสรสหมู', 7, 0],
#  ['มะละกอ', 7, 0],
#  ['สันคอหมูสไลด์', 7, 0],
#  ['มะพร้าวคั่ว', 7, 0],
#  ['คึ่นช่าย', 7, 0],
#  ['มะนาวแป้น', 7, 0],
#  ['หน่อไม้', 7, 0],
#  ['เนื้อปู', 7, 0],
#  ['ผงพะโล้', 7, 0],
#  ['พริกชี้ฟ้าซอย', 7, 0],
#  ['มะเขือเทศลูกเล็ก', 7, 0],
#  ['เต้าหู้ขาว', 7, 0],
#  ['กระเทียบสับ', 7, 0],
#  ['เห็ดนางฟ้า', 7, 0],
#  ['สปาเกตตี้', 7, 0],
#  ['เห็ดหูหนูดำ', 7, 0],
#  ['ข้าวกล้องหุงสุก', 7, 0],
#  ['น้ำสต๊อกหมู', 7, 0],
#  ['สตอ', 7, 0],
#  ['คนอร์ผงรสหมู', 7, 0],
#  ['หมูหยอง', 7, 0],
#  ['ผงกระเทียม', 7, 0],
#  ['หมี่เหลือง', 7, 0],
#  ['เส้นสปาเกตตี', 7, 0],
#  ['ข้าวสวยแช่เย็น', 7, 0],
#  ['ไข่แดงเค็ม', 7, 0],
#  ['ตีนไก่', 7, 0],
#  ['ข้าวโพดหวาน', 7, 0],
#  ['สับปะรด', 7, 0],
#  ['เกลือเม็ด', 7, 0],
#  ['พริกอ่อน', 7, 0],
#  ['ต้นหอม ผักชี', 6, 0],
#  ['ถั่วลิสงป่น', 6, 0],
#  ['ใบมะกูด', 6, 0],
#  ['ไส้กรอกไก่', 6, 0],
#  ['ทูน่ากระป๋อง', 6, 0],
#  ['ซีอิ้วขาวโลว์โซเดียม', 6, 0],
#  ['ซี๊อิ๋วขาว', 6, 0],
#  ['น้ำมันพริกเผา', 6, 0],
#  ['นมสดจืด', 6, 0],
#  ['แครอทซอย', 6, 0],
#  ['ผงปรุงรสเห็ดหอม', 6, 0],
#  ['น้ำปลาไส้ตัน', 6, 0],
#  ['ขิงแก่', 6, 0],
#  ['คนอร์ผง', 6, 0],
#  ['ปลาทูน่าในน้ำแร่', 6, 0],
#  ['บะหมี่ไข่', 6, 0],
#  ['เกลือชมพู', 6, 0],
#  ['อาริกาโน', 6, 0],
#  ['ฟองเต้าหู้', 6, 0],
#  ['กระเทียมกลีบเล็ก', 6, 0],
#  ['ใบมะกรูดหั่นฝอย', 6, 0],
#  ['ซอสพริกศรีราชา', 6, 0],
#  ['กระเทียมดอง', 6, 0],
#  ['ผักกาดแก้ว', 6, 0],
#  ['น้ำสลัด', 6, 0],
#  ['หมูสามชั้นสไลด์', 6, 0],
#  ['หมูสันนอก', 6, 0],
#  ['แป้งชุบทอด', 6, 0],
#  ['คนอร์รสหมู', 6, 0],
#  ['หางกะทิ', 6, 0],
#  ['มัสตาร์ด', 6, 0],
#  ['แป้งสาลี', 6, 0],
#  ['พริกหวาน', 6, 0],
#  ['ซุปก้อน', 6, 0],
#  ['น้ำกะทิ', 6, 0],
#  ['ข้าวสวยหอมมะลิ', 6, 0],
#  ['แหนมหมู', 6, 0],
#  ['พริกชี้ฟ้าแห้ง', 6, 0],
#  ['ปลาสลิด', 6, 0],
#  ['ผงซุปก้อนหมู', 6, 0],
#  ['มะระ', 6, 0],
#  ['น้ำตาลดอกมะพร้าว', 6, 0],
#  ['แครรอท', 6, 0],
#  ['หน่อไม้ฝรั่ง', 6, 0],
#  ['เนื้อสะโพกไก่', 6, 0],
#  ['กระเทียมบุบ', 6, 0],
#  ['เก๋ากี้', 6, 0],
#  ['ขิงอ่อน', 6, 0],
#  ['น้ำมันกระเทียมเจียว', 6, 0],
#  ['ต้มหอม', 6, 0],
#  ['นม', 6, 0],
#  ['น้ำมันพืชสำหรับทอด', 6, 0],
#  ['หอยเชลล์', 6, 0],
#  ['ผักกาดดอง', 6, 0],
#  ['น้ำตาลโตนด', 6, 0],
#  ['เส้นอุด้ง', 6, 0],
#  ['มะม่วงเปรี้ยว', 6, 0],
#  ['เกลือแกง', 6, 0],
#  ['โครงไก่', 6, 0],
#  ['ปลาทูนึ่ง', 6, 0],
#  ['กุ้งสับ', 6, 0],
#  ['ซีอิ้ว ขาว', 6, 0],
#  ['ข้าวไรซ์เบอรี่', 5, 0],
#  ['งาคั่ว', 5, 0],
#  ['หมูแดง', 5, 0],
#  ['โรสแมรี่', 5, 0],
#  ['ต้นอ่อนทานตะวัน', 5, 0],
#  ['ข้าวสวยเก่า', 5, 0],
#  ['ผงซุปหมูก้อน', 5, 0],
#  ['น้ำสต๊อก', 5, 0],
#  ['ปลาอินทรีย์เค็ม', 5, 0],
#  ['ตั้งโอ๋', 5, 0],
#  ['ตะใคร้', 5, 0],
#  ['เห็ดหอมแช่น้ำ', 5, 0],
#  ['ซีอิ้วเห็ดหอม', 5, 0],
#  ['เส้นยากิโซบะ', 5, 0],
#  ['ทูน่า', 5, 0],
#  ['กุนเชียงหมู', 5, 0],
#  ['ผักชีฝรั่งซอย', 5, 0],
#  ['ไข่ไก่สด', 5, 0],
#  ['ต้นหอมผักชีซอย', 5, 0],
#  ['หอมใหญ่หั่นเสี้ยว', 5, 0],
#  ['ดอกเกลือ', 5, 0],
#  ['ใบกระเพา', 5, 0],
#  ['กระดูกเล้ง', 5, 0],
#  ['ข้าวเย็น', 5, 0],
#  ['มะเขือเทศลูกใหญ่', 5, 0],
#  ['หอยลาย', 5, 0],
#  ['ออริกาโน', 5, 0],
#  ['พาสต้าดิบ', 5, 0],
#  ['น้ำปลาแท้', 5, 0],
#  ['ลูกผักชี', 5, 0],
#  ['ใบกระเพราแดง', 5, 0],
#  ['เนื้อหมูสันใน', 5, 0],
#  ['ซอสพริกไทยดำ', 5, 0],
#  ['พริกหยวกหั่น', 5, 0],
#  ['ชูรส', 5, 0],
#  ['พริกขี้หนูแห้ง', 5, 0],
#  ['น้ำร้อน', 5, 0],
#  ['ปลากระพง', 5, 0],
#  ['ถั่วฟักยาว', 5, 0],
#  ['ไส้อั่ว', 5, 0],
#  ['ผงปรุงรสตราคนอร์', 5, 0],
#  ['ซอสโชยุ', 5, 0],
#  ['ต้นหอม ผักชีซอย', 5, 0],
#  ['กระเทียม ไท', 5, 0],
#  ['ซีอิ๊วขาวเห็ดหอม', 5, 0],
#  ['มาม่าเกาหลี', 5, 0],
#  ['บล๊อคโคลี่', 5, 0],
#  ['เนื้อหมูสันนอก', 5, 0],
#  ['ใบสะระแหน่', 5, 0],
#  ['เส้นก๋วยจั๊บ', 5, 0],
#  ['ข้าวหุงสุก', 5, 0],
#  ['หอยแมลงภู่', 5, 0],
#  ['พริกเหลือง', 5, 0],
#  ['ผงฟู', 5, 0],
#  ['เม็ดพริกไทย', 5, 0],
#  ['คนอร์ก้อน', 5, 0],
#  ['ข้าวญี่ปุ่น', 5, 0],
#  ['พริกแกงแดง', 5, 0],
#  ['ผงปรุงรสคนอร์อร่อยชัวร์', 5, 0],
#  ['เห็ดนางรมหลวง', 5, 0],
#  ['ปลาหมึกกรอบ', 5, 0],
#  ['พาร์เมซานชีส', 5, 0],
#  ['กระเทียมตำละเอียด', 5, 0],
#  ['ไชเท้า', 5, 0],
#  ['หมูสันคอ', 5, 0],
#  ['แครอทฝอย', 5, 0],
#  ['สามเกลอ', 5, 0],
#  ['ใบโหรพา', 5, 0],
#  ['แป้งโกกิ', 5, 0],
#  ['ผงซุป', 5, 0],
#  ['ผงเติมทิพ', 5, 0],
#  ['ซอสโคชูจัง', 5, 0],
#  ['ฮอตดอก', 5, 0],
#  ['มันกุ้งเสวย', 5, 0],
#  ['ซอสแม็กกี้', 5, 0],
#  ['เนื้อสับ', 4, 0],
#  ['ถั่วลิสงบด', 4, 0],
#  ['พริกหวานหั่นเต๋า', 4, 0],
#  ['แป้ง', 4, 0],
#  ['กระเทียมฝาน', 4, 0],
#  ['olive oil', 4, 0],
#  ['เครื่องพะโล้', 4, 0],
#  ['หมูหั่น', 4, 0],
#  ['ซอสเย็นตาโฟ', 4, 0],
#  ['ตับ', 4, 0],
#  ['ผักต่างๆ', 4, 0],
#  ['เต้าหู้แข็ง', 4, 0],
#  ['ซอสเห็ด หอม', 4, 0],
#  ['ขิงสับละเอียด', 4, 0],
#  ['มะเขือเทศเชอร์รี่', 4, 0],
#  ['เส้นหมี่ซั่ว', 4, 0],
#  ['ก๋วยเตี๋ยวเส้นใหญ่', 4, 0],
#  ['เนื้อ', 4, 0],
#  ['ผงดาชิ', 4, 0],
#  ['ผักชีใบเลื่อย', 4, 0],
#  ['ผงปาปริก้า', 4, 0],
#  ['ผักสด', 4, 0],
#  ['ข้าวไรซ์เบอร์รี่', 4, 0],
#  ['ซีอิ๊วญี่ปุ่น', 4, 0],
#  ['กะปิดี', 4, 0],
#  ['หอมหัวใหญ่สับละเอียด', 4, 0],
#  ['ข้าวโพดต้ม', 4, 0],
#  ['น้ำมันทอด', 4, 0],
#  ['ใบผักชี', 4, 0],
#  ['เบคอนหั่น', 4, 0],
#  ['น้ำจิ้มซีฟู้ด', 4, 0],
#  ['ตับไก่', 4, 0],
#  ['แตงร้าน', 4, 0],
#  ['มะเขือม่วง', 4, 0],
#  ['กุ้งลายเสือ', 4, 0],
#  ['ซีอิ้ว', 4, 0],
#  ['ตังฉ่าย', 4, 0],
#  ['กระดูกอ่อน', 4, 0],
#  ['คนอร์ผง รสหมู', 4, 0],
#  ['คนอร์ซุปก้อนรสหมู', 4, 0],
#  ['ปลาร้าต้มสุก', 4, 0],
#  ['น้ำตาลปิ้บ', 4, 0],
#  ['ข้าวสุก', 4, 0],
#  ['โยเกิร์ตรสธรรมชาติ', 4, 0],
#  ['ซอสข้นปรุงรสคนอร์', 4, 0],
#  ['แป้งข้าวเจ้า', 4, 0],
#  ['หัวหอมใหญ่สับ', 4, 0],
#  ['ข้าวสวยหุงสุก', 4, 0],
#  ['สาหร่าย', 4, 0],
#  ['หมี่ฮ่องกง', 4, 0],
#  ['ขิงสับ', 4, 0],
#  ['ข้าวโพดต้มสุก', 4, 0],
#  ['เส้นมาม่า', 4, 0],
#  ['สันนอกหมู', 4, 0],
#  ['เนื้อสัตว์', 4, 0],
#  ['น่องไก่ติดสะโพก', 4, 0],
#  ['ปลาแซลมอน', 4, 0],
#  ['กระเพาะปลา', 4, 0],
#  ['เต้าหู้หลอด', 4, 0],
#  ['ผักกะเฉด', 4, 0],
#  ['ผงขมิ้น', 4, 0],
#  ['น้ำตาลปี้บ', 4, 0],
#  ['น้ำซุปไก่', 4, 0],
#  ['พริกหนุ่ม', 4, 0],
#  ['ก้านพลู', 4, 0],
#  ['เส้นบุก', 4, 0],
#  ['น้ำตาลปึก', 4, 0],
#  ['ซอสภูเขา', 4, 0],
#  ['ขึ้นช่าย', 4, 0],
#  ['เห็ดออริจิน', 4, 0],
#  ['เส้นมักกะโรนี', 4, 0],
#  ['ผักแขนง', 4, 0],
#  ['เกลือ พริกไทย', 4, 0],
#  ['นำ้มันหอย', 4, 0],
#  ['เส้นบะหมี่กึ่งสำเร็จรูป', 4, 0],
#  ['ข้าวสวยญี่ปุ่น', 4, 0],
#  ['ดาชิ', 4, 0],
#  ['กะหล่ำดอก', 4, 0],
#  ['เครื่องในไก่', 4, 0],
#  ['หอมหัวใหญ่สับ', 4, 0],
#  ['เนื้อหมูหั่น', 4, 0],
#  ['ยี่หร่าป่น', 4, 0],
#  ['เนื้อปลา', 4, 0],
#  ['โบโลน่า', 4, 0],
#  ['หัวปลี', 4, 0],
#  ['รากผักชีสับ', 4, 0],
#  ['เนื้อวัว', 4, 0],
#  ['กุ้งแห้งฝอย', 4, 0],
#  ['ครีม', 4, 0],
#  ['กะหล่ำปลีหั่น', 4, 0],
#  ['ปลาเค็ม', 4, 0],
#  ['ไวน์ขาว', 4, 0],
#  ['ข่าซอย', 4, 0],
#  ['ถั่วงอกลวก', 4, 0],
#  ['ปูม้า', 4, 0],
#  ['กระเทียมกลีบ', 4, 0],
#  ['ดอกกระหล่ำ', 4, 0],
#  ['ขึ้นฉ่ายซอย', 4, 0],
#  ['มอสซาเรลลาชีส', 4, 0],
#  ['ปลาซาบะ', 4, 0],
#  ['แซลมอน', 4, 0],
#  ['ผักสลัดตามชอบ', 4, 0],
#  ['พาเมซานชีส', 4, 0],
#  ['ปลานิล', 4, 0],
#  ['กากหมู', 4, 0],
#  ['ข้าวสวยหุงค้างคืน', 4, 0],
#  ['ปลาหมึกแห้ง', 4, 0],
#  ['ยี่หร่า', 4, 0],
#  ['พริกซอย', 4, 0],
#  ['แครอทหั่นเต๋าเล็ก', 4, 0],
#  ['น้ำดื่ม', 4, 0],
#  ['เนื้อปลาแซลมอน', 4, 0],
#  ['รสดีเมนู', 4, 0],
#  ['พาสต้า', 4, 0],
#  ['พริกตำ', 4, 0],
#  ['กุ้งสดแกะเปลือก', 4, 0],
#  ['ผักบุ้งจีน', 4, 0],
#  ['อกไก่หั่นชิ้น', 4, 0],
#  ['แป้งเอนกประสงค์', 4, 0],
#  ['แป้งมันละลายน้ำ', 4, 0],
#  ['แม๊กกี้', 4, 0],
#  ['ใบกระเพราเด็ด', 4, 0],
#  ['มะม่วงเบา', 4, 0],
#  ['กุ้งแห้งป่น', 4, 0],
#  ['ขิงอ่อนซอย', 4, 0],
#  ['ปาปริก้า', 4, 0],
#  ['ทูน่ากระป๋องในน้ำแร่', 4, 0],
#  ['แป้งท้าวยายม่อม', 4, 0],
#  ['ผงปรุงรส คนอร์', 3, 0],
#  ['เต้าหู้พวง', 3, 0],
#  ['รสดีหมู', 3, 0],
#  ['กุ้ง ปลาหมึก', 3, 0],
#  ['สี่อิ๋วดำสูตรเค็ม', 3, 0],
#  ['มะกะโรนีต้มสุก', 3, 0],
#  ['ไข่ออนเซน', 3, 0],
#  ['คนอร์ขวดสูตรเข้มข้น', 3, 0],
#  ['ถั่วหวาน', 3, 0],
#  ['พริกชี้ฟ้าแดงหั่นแฉลบ', 3, 0],
#  ['เกลือหิมาลายัน', 3, 0],
#  ['หมี่กรอบ', 3, 0],
#  ['กระเทียม สับ', 3, 0],
#  ['ผักชีหั่น', 3, 0],
#  ['เส้นมาม่าลวก', 3, 0],
#  ['กระเทียมแกะเปลือก', 3, 0],
#  ['พริกทอด', 3, 0],
#  ['กระเทียวเจียว', 3, 0],
#  ['ตำลึง', 3, 0],
#  ['หอมแดงเจียว', 3, 0],
#  ['ออริกาโน่แห้ง', 3, 0],
#  ['ซอสภูเขาทอง', 3, 0],
#  ['เนื้ออกไก่สับ', 3, 0],
#  ['น้ำสลัดงาญี่ปุ่น', 3, 0],
#  ['ซอสเพสโต้', 3, 0],
#  ['น้ำซุปหรือน้ำเปล่า', 3, 0],
#  ['พริกไทยดำเม็ด', 3, 0],
#  ['เครื่องแกงเขียวหวาน', 3, 0],
#  ['Mozzarella cheese', 3, 0],
#  ['หนำเลี๊ยบ', 3, 0],
#  ['ซีอิ้วหวาน', 3, 0],
#  ['น้ำมันสำหรับทอดปลา', 3, 0],
#  ['ข้าวสวยร้อนๆ', 3, 0],
#  ['เครื่องปรุง', 3, 0],
#  ['เส้นเหลือง', 3, 0],
#  ['ข้าวเหนียว', 3, 0],
#  ['ผงเติมทิพ.', 3, 0],
#  ['หมูบดติดมัน', 3, 0],
#  ['ซอลหอยนางรม', 3, 0],
#  ['ถั่วฝักยาวหั่น', 3, 0],
#  ['กะหล่ำ', 3, 0],
#  ['หอมแดงสับละเอียด', 3, 0],
#  ['ถั่วฝักยาวซอย', 3, 0],
#  ['กุนเชียงทอด', 3, 0],
#  ['ซอสมะเขือเทศเข้มข้น', 3, 0],
#  ['กุ้ยช่าย', 3, 0],
#  ['แครอทหั่นชิ้น', 3, 0],
#  ['กะเพราแดง', 3, 0],
#  ['ดอกหอม', 3, 0],
#  ['สัปปะรด', 3, 0],
#  ['เนื้อปลาดอลลี่', 3, 0],
#  ['เนื้อหมูสไลด์', 3, 0],
#  ['โซดา', 3, 0],
#  ['ไวไว', 3, 0],
#  ['ถั่วพู', 3, 0],
#  ['หอมหัวใหญ่หั่นเต๋า', 3, 0],
#  ['สี่อิ๋วหวาน', 3, 0],
#  ['พริกแกงพะแนง', 3, 0],
#  ['ยอดข้าวโพดอ่อน', 3, 0],
#  ['เนื้อวัวสับ', 3, 0],
#  ['น้ำสต็อก', 3, 0],
#  ['น้ำตาลทรายเล็กน้อย', 3, 0],
#  ['คนอร์อร่อยชัว', 3, 0],
#  ['พริกขี้หนูตำละเอียด', 3, 0],
#  ['เส้นแก้ว', 3, 0],
#  ['ผักชีสับ', 3, 0],
#  ['น้ำส้มสายชูข้าว', 3, 0],
#  ['แป้งทอดกรอบคนอร์', 3, 0],
#  ['กระเทียมสด', 3, 0],
#  ['เส้นสปาเก็ตตี้โฮลวีท', 3, 0],
#  ['เครื่องต้มยำ', 3, 0],
#  ['ต้นหอม ผักชี ซอย', 3, 0],
#  ['ใบยี่หร่า', 3, 0],
#  ['เส้นหมี่ฮกเกี้ยน', 3, 0],
#  ['กระเทียมตำหยาบ', 3, 0],
#  ['แครอทหั่นเส้น', 3, 0],
#  ['ปลาสลิดทอด', 3, 0],
#  ['เผือก', 3, 0],
#  ['ซอส', 3, 0],
#  ['ต้นหอมผักชีหั่น', 3, 0],
#  ['ไส้กรอกหมู', 3, 0],
#  ['กุ้งแกะเปลือก', 3, 0],
#  ['ไข่เยี่ยวม้า', 3, 0],
#  ['พริกไทเม็ด', 3, 0],
#  ['เต้าเจี๊ยว', 3, 0],
#  ['ก้อนแกงกะหรี่ญี่ปุ่น', 3, 0],
#  ['หัวหอมสับ', 3, 0],
#  ['โปรตีนเกษตร', 3, 0],
#  ['ใบกุยช่าย', 3, 0],
#  ['เห็ดโคนญี่ปุ่น', 3, 0],
#  ['กระเทียมปอกเปลือก', 3, 0],
#  ['สี่อิ๋วดำสูตรหวาน', 3, 0],
#  ['ข้าวเสาไห้', 3, 0],
#  ['กระหล่ำปลีซอย', 3, 0],
#  ['แคร์รอต', 3, 0],
#  ['กุ่ยช่าย', 3, 0],
#  ['ผงปาปริกา', 3, 0],
#  ['ชีอิ้วขาว', 3, 0],
#  ['บ๊วยดอง', 3, 0],
#  ['นมสดรสจืด', 3, 0],
#  ['ปลาหมึกกล้วย', 3, 0],
#  ['หัวหอมซอย', 3, 0],
#  ['น้ำปลาร้าต้มสุก', 3, 0],
#  ['พริกขี้หนูบุบ', 3, 0],
#  ['มะนาวฝาน', 3, 0],
#  ['มักกะโรนีต้มสุก', 3, 0],
#  ['ไชโป๊ว', 3, 0],
#  ['หน่อไม้ต้ม', 3, 0],
#  ['น้ำซุปดาชิ', 3, 0],
#  ['ผักกาด', 3, 0],
#  ['น้ำมันสำหรับผัดเล็กน้อย', 3, 0],
#  ['คอหมูย่าง', 3, 0],
#  ['ผักชี/ต้นหอม', 3, 0],
#  ['พริกไทยป่นเล็กน้อย', 3, 0],
#  ['ข้าวสารหอมมะลิ', 3, 0],
#  ['คนอร์ต้มยำ', 3, 0],
#  ['พริกสดหั่น', 3, 0],
#  ['คื่นไช้', 3, 0],
#  ['ไข่เจียวหั่นฝอย', 3, 0],
#  ['เต้าเจียว', 3, 0],
#  ['รากผักชีทุบ', 3, 0],
#  ['แครอทหั่นแว่น', 3, 0],
#  ['วิปครีม', 3, 0],
#  ['แครอทขูด', 3, 0],
#  ['ใบโหระพาสับ', 3, 0],
#  ['เนื้อบด', 3, 0],
#  ['ไก่หมัก', 3, 0],
#  ['แป้งสาลีเอนกประสงค์', 3, 0],
#  ['แคปหมู', 3, 0],
#  ['แครอทสับ', 3, 0],
#  ['กุ้งกุลาดำ', 3, 0],
#  ['ปลากรอบ', 3, 0],
#  ['เนื้อหมูหั่นชิ้น', 3, 0],
#  ['เต้าหู้นิ่ม', 3, 0],
#  ['หอมหัวใหญ่สับหยาบ', 3, 0],
#  ['พาร์สลีย์', 3, 0],
#  ['เนยแท้', 3, 0],
#  ['น้ำเปล่าหรือน้ำซุป', 3, 0],
#  ['แม็กกี้', 3, 0],
#  ['เนยสดเค็ม', 3, 0],
#  ['บวบ', 3, 0],
#  ['ใบเตย', 3, 0],
#  ['ใบแมงลัก', 3, 0],
#  ['หมูนุ่ม', 3, 0],
#  ['โหรพา', 3, 0],
#  ['กระเทียมขูด', 3, 0],
#  ['เต้าหู้อ่อน', 3, 0],
#  ['เต้าหู้ปลา', 3, 0],
#  ['ขิงขูด', 3, 0],
#  ['เนื้อหอยแมลงภู่', 3, 0],
#  ['ผักคอส', 3, 0],
#  ['คนอร์ซอสข้นปรุงรสหมู', 3, 0],
#  ['ยอดมะพร้าวอ่อน', 3, 0],
#  ['กระเทียมตบ', 3, 0],
#  ['มะกะโรนี', 3, 0],
#  ['ปลาไข่', 3, 0],
#  ['เนื้อปลาอินทรีย์', 3, 0],
#  ['น้ำมันงาเกาหลี', 3, 0],
#  ['ซอสภูเขาฝาเขียว', 3, 0],
#  ['เนื้อหอยลาย', 3, 0],
#  ['ปีกบนไก่', 3, 0],
#  ['ซอสมะเขือเทศโรซ่า', 3, 0],
#  ['ถั่วงอกหัวโต', 3, 0],
#  ['มะละกอสับ', 3, 0],
#  ['คนอร์เห็ดหอม', 3, 0],
#  ['พริกแกงน้ำยา', 3, 0],
#  ['เส้นบะหมี่', 3, 0],
#  ['หมึก', 3, 0],
#  ['กะหล่ำปลีซอย', 3, 0],
#  ['ซี้อิ้วขาว', 3, 0],
#  ['พริกไทย ป่น', 3, 0],
#  ['ผัดกาดขาว', 3, 0],
#  ['วุ้นเส้นห่อเล็ก', 3, 0],
#  ['พริกแกงส้ม', 3, 0],
#  ['ใบเหลียง', 3, 0],
#  ['กะทิกล่อง', 3, 0],
#  ['พริกป่นตามชอบ', 3, 0],
#  ['black pepper', 3, 0],
#  ['ข้าวสวยเย็น', 3, 0],
#  ['เบคกิ้งโซดา', 3, 0],
#  ['คื่นไฉ่', 3, 0],
#  ['พริกแกงคั่ว', 3, 0],
#  ['น้ำปลาทิพรส', 3, 0],
#  ['แครอทหั่นฝอย', 3, 0],
#  ['ซอสพิซซ่า', 3, 0],
#  ['เส้นหมี่ไวไว', 3, 0],
#  ['หอยแมลงภู่นิวซีแลนด์', 3, 0],
#  ['เห็ดหอมแห้งแช่น้ำจนนิ่ม', 3, 0],
#  ['ยอดมะพร้าว', 3, 0],
#  ['พริกป่นเกาหลี', 3, 0],
#  ['พริกไทดำ', 3, 0],
#  ['salt', 3, 0],
#  ['เป็ดย่าง', 3, 0],
#  ['ข้าวบาสมาติ', 3, 0],
#  ['หอมใหญ่ซอย', 3, 0],
#  ['เต้าหู้ไข่ไก่', 3, 0],
#  ['ข้าวไรซ์เบอร์รี่หุงสุก', 3, 0],
#  ['น้ำตาลทราย ขาว', 3, 0],
#  ['เห็ดหูหนูขาว', 3, 0],
#  ['ถั่วป่น', 3, 0],
#  ['ข้าวหอมมะลิหุงสุก', 3, 0],
#  ['แป้งท้าว', 3, 0],
#  ['มันฝรั่งหั่นเต๋า', 3, 0],
#  ['หอมหัวใหญ่ซอย', 3, 0],
#  ['สะโพกไก่เลาะกระดูก', 3, 0],
#  ['งาดำ', 3, 0],
#  ['เลือดหมู', 3, 0],
#  ['หมี่กึง', 3, 0],
#  ['วิปปิ้งครีม', 3, 0],
#  ['มะเขือ', 3, 0],
#  ['แครอท หั่นเต๋า', 3, 0],
#  ['ปลาซุกิ', 3, 0],
#  ['เกลือพริกไทย', 2, 0],
#  ['บะหมี่กึ่งสำเร็จรูปรสต้มยำ', 2, 0],
#  ['พริกแดงซอย', 2, 0],
#  ['ซีอี๊วขาว', 2, 0],
#  ['มะกรูด', 2, 0],
#  ['หอยแมลงภู่ต้มสุก', 2, 0],
#  ['ถั่วลิสงตำ', 2, 0],
#  ['พริกสดซอย', 2, 0],
#  ['หมูสับลวก', 2, 0],
#  ['แครอท หั่นเป็นลูกเต๋า', 2, 0],
#  ['บล็อคโครี่', 2, 0],
#  ['น้ำสลัดงาคั่วญี่ปุ่น', 2, 0],
#  ['เส้น', 2, 0],
#  ['ถั่ว', 2, 0],
#  ['ไข่ลวก', 2, 0],
#  ['เนื้ออกไก่ลอกหนัง', 2, 0],
#  ['ไก่จ๊อ', 2, 0],
#  ['เนยละลาย', 2, 0],
#  ['พริกชี้ฟ้าเหลือง', 2, 0],
#  ['เนื้อหมูส่วนสันคอ', 2, 0],
#  ['ไข่ไก่เบอร์ 0', 2, 0],
#  ['น้ำมะขาวเปียก', 2, 0],
#  ['ข่าสับละเอียด', 2, 0],
#  ['ชีอิ๊วขาว', 2, 0],
#  ['เป็ด', 2, 0],
#  ['หอมใหญ่ซอยบางๆ', 2, 0],
#  ['ต้นหอม-ผักชีซอย', 2, 0],
#  ['ซ้อสปรุงรส', 2, 0],
#  ['ต้นกุยช่าย', 2, 0],
#  ['เบค่อนตามชอบ', 2, 0],
#  ['บะหมี่ลวก', 2, 0],
#  ['ถั่วแดง', 2, 0],
#  ['น้ำพริกหนุ่ม', 2, 0],
#  ['ไก่หั่น', 2, 0],
#  ['หอมใหญ่หั่นชิ้นเล็ก', 2, 0],
#  ['แครอทขูดฝอย', 2, 0],
#  ['แผ่นเกี้ยว', 2, 0],
#  ['ปลาช่อนหั่น', 2, 0],
#  ['ซอสปรุงรสเห็ดหอม', 2, 0],
#  ['คะน้ายอด', 2, 0],
#  ['หอมใหญ่หั่น', 2, 0],
#  ['มะเขือเทศสับละเอียด', 2, 0],
#  ['เส้นหมี่แช่น้ำ', 2, 0],
#  ['โรสแมรี่อบแห้ง', 2, 0],
#  ['หมี่หยก', 2, 0],
#  ['Angel Hair', 2, 0],
#  ['น้ำซุบ', 2, 0],
#  ['ข้าวแช่เย็น', 2, 0],
#  ['กะปิอย่างดี', 2, 0],
#  ['ขิงขูดละเอียด', 2, 0],
#  ['มะเขือเทศหั่นลูกเต๋า', 2, 0],
#  ['แครอทหั่นเต๋าเล็กๆ', 2, 0],
#  ['ปลาทูทอด', 2, 0],
#  ['เส้นมักกะโรนีต้มสุก', 2, 0],
#  ['ไส้กรอกหมูรมควัน', 2, 0],
#  ['แป้งพิซซ่าสำเร็จ', 2, 0],
#  ['มะละกอขูด', 2, 0],
#  ['เป็ดพะโล้', 2, 0],
#  ['พริกไทยนิดหน่อย', 2, 0],
#  ['ผิวมะกรูด', 2, 0],
#  ['ถั่วลิสงคั่วบด', 2, 0],
#  ['พริกหยวกสีเหลือง', 2, 0],
#  ['ซอสข้นคนอร์', 2, 0],
#  ['กระเทียมทุบหยาบ', 2, 0],
#  ['พริกน้ำส้ม', 2, 0],
#  ['พริกแกงเผ็ดใต้', 2, 0],
#  ['เส้นสปาเกตตี้ ต้มสุก', 2, 0],
#  ['ลูกผักชีป่น', 2, 0],
#  ['หมี่ขาว', 2, 0],
#  ['มะเขือเทศสับ', 2, 0],
#  ['เนยสดจืด', 2, 0],
#  ['กระทิ', 2, 0],
#  ['มาม่าลวก', 2, 0],
#  ['ปีกกลางไก่', 2, 0],
#  ['พาสลี่', 2, 0],
#  ['มาการีน', 2, 0],
#  ['แป้งสำหรับทอด', 2, 0],
#  ['เนยรสจืด', 2, 0],
#  ['กุ้งขาวขนาดกลาง', 2, 0],
#  ['น้ำมะนาวสด', 2, 0],
#  ['พริกแดงสับ', 2, 0],
#  ['แหนมตุ้มจิ๋ว', 2, 0],
#  ['ดอกไม้กวาด', 2, 0],
#  ['น้ำซุปกระดูกหมู', 2, 0],
#  ['กิมจิสับละเอียด', 2, 0],
#  ['ผงปรุงรสผัดคนอร์', 2, 0],
#  ['น้ำตาลเล็กน้อย', 2, 0],
#  ['กระเทียมเจียวกากหมู', 2, 0],
#  ['กระเทียม+พริก', 2, 0],
#  ['แครอท หั่นชิ้นเล็ก', 2, 0],
#  ['ผักกะหล่ำ', 2, 0],
#  ['น้ำมันมะกอกแคลอรี่0', 2, 0],
#  ['italian seasoning', 2, 0],
#  ['ซีอิ้ว ดำ', 2, 0],
#  ['ข้าวโพดอ่อนหั่นแฉลบ', 2, 0],
#  ['ไส้กรอกหั่นชิ้น', 2, 0],
#  ['กระหล่ำปลีหั่น', 2, 0],
#  ['พริกหวานสีแดง', 2, 0],
#  ['Red Pepper Flakes', 2, 0],
#  ['พริกแดง-พริกเขียว', 2, 0],
#  ['พริกแห้งจินดา', 2, 0],
#  ['ผักชีลาว', 2, 0],
#  ['เต้าหู้ขาวแข็ง', 2, 0],
#  ['น้ำมันพืช สำหรับทอด', 2, 0],
#  ['ขิงแก่ซอย', 2, 0],
#  ['คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส', 2, 0],
#  ['ปีกไก่บน', 2, 0],
#  ['ซอสภูเขาทองฝาเขียว', 2, 0],
#  ['หน่อไม้ฝอย', 2, 0],
#  ['ไข่ขาวพาสเจอร์ไรซ์', 2, 0],
#  ['พริกขี้หนูแห้งซอย', 2, 0],
#  ['น้ำมัน พืช', 2, 0],
#  ['ซีอิ๋ว', 2, 0],
#  ['ซี่โครงไก่', 2, 0],
#  ['น้ำเลม่อน', 2, 0],
#  ['ถั่วลิสงคั่วป่น', 2, 0],
#  ['ปีกไก่กลาง', 2, 0],
#  ...]

# %%
ch_regex = "น้ำปลา(?!ร้า)"
name = "น้ำปลา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำปลา 736
# น้ำปลาอย่างดี 12
# น้ำปลาดี 8
# น้ำปลาไส้ตัน 6
# น้ำปลาแท้ 5
# น้ำปลาทิพรส 3
# น้ำปลา Low Sodium 2
# น้ำปลาพริก 2
# น้ำปลาเมกะเชฟ 2
# เกลือ หรือ น้ำปลา 2

# %%
ch_regex = "^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม"
name = "กระเทียม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระเทียม 633
# กระเทียมสับ 276
# กระเทียมเจียว 55
# กระเทียมไทย 45
# กระเทียมจีน 32
# กระเทียมสับละเอียด 25
# กระเทียมทุบ 20
# กระเทียมไท 16
# กระเทียมสับหยาบ 15
# กระเทียมกลีบใหญ่ 13
# กระเทียมตำ 12
# กระเทียมซอย 11
# กระเทียมโทน 9
# กระเทียมจีนสับ 8
# กะเทียม 8
# กระเทียบสับ 7
# ผงกระเทียม 7
# กระเทียมกลีบเล็ก 6
# กระเทียมดอง 6
# กระเทียมบุบ 6
# กระเทียม ไท 5
# กระเทียมตำละเอียด 5
# กระเทียมฝาน 4
# กระเทียมกลีบ 4
# กระเทียม สับ 3
# กระเทียมแกะเปลือก 3
# กระเทียมสด 3
# กระเทียมตำหยาบ 3
# กระเทียมปอกเปลือก 3
# กระเทียมขูด 3
# กระเทียมตบ 3
# กระเทียมทุบหยาบ 2
# กระเทียมเจียวกากหมู 2
# กระเทียม+พริก 2
# กระเทียมจีนหั่น 2
# กระเทียมหั่นละเอียด 2
# เกลือผสมผงกระเทียม 2
# กระเทียมหั่น 2
# กระเทียมทุบพอแตก 2
# กระเทียมหัวใหญ่ 2
# กะเทียมสับ 2
# กระเทียมโขลกละเอียด 2
# กระเทียมสำหรับเจียว 2
# กระเทียมเผา 2
# กระเทียมโขลกหยาบๆ 2
# กระเทียมจีนซอย 2
# กระเทียมสไลด์ 2

# %%
ch_regex = "^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))"
name = "ไข่ไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่ไก่ 627
# ไข่ 73
# ไข่ต้ม 25
# ไข่เค็ม 20
# ไข่แดง 14
# ไข่ขาว 11
# ไข่ดาว 8
# ไข่แดงเค็ม 7
# ไข่ไก่สด 5
# ไข่ออนเซน 3
# ไข่เยี่ยวม้า 3
# ไข่เจียวหั่นฝอย 3
# ไข่ลวก 2
# ไข่ไก่เบอร์ 0 2
# ไข่ขาวพาสเจอร์ไรซ์ 2
# ไข่ไก่ต้ม 2
# ไข่ไก่เบอร์ 1 2
# ไข่เจียว 2
# ไข่ไก่2 2
# ไข่ไก่เต็มใบ 2
# ไข่ฝอย 2
# ไข่ไก่เบอร์0 2
# ไข่ไก 2
# ไข่ออนเซ็น 2
# ไข่ไก่เบอร์1 2
# ไข่เค็มต้ม 2

# %%
ch_regex = "น้ำตาล"
name = "น้ำตาล"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำตาลทราย 619
# น้ำตาล 584
# น้ำตาลปี๊บ 90
# น้ำตาลทรายแดง 26
# น้ำตาลทรายขาว 18
# น้ำตาลมะพร้าว 17
# น้ำตาลปี๊ป 14
# น้ำตาลปีบ 14
# น้ำตาลปิ๊บ 12
# น้ำตาลกรวด 9
# น้ำตาลหญ้าหวาน 9
# น้ำตาลดอกมะพร้าว 6
# น้ำตาลโตนด 6
# น้ำตาลปิ้บ 4
# น้ำตาลปี้บ 4
# น้ำตาลปึก 4
# น้ำตาลทรายเล็กน้อย 3
# น้ำตาลทราย ขาว 3
# น้ำตาลเล็กน้อย 2
# น้ำตาลปิ๊ป 2
# น้ำตาลปีป 2
# เกลือ น้ำตาล 2
# น้ำตาลทราย. 2
# น้ำตาล ทราย 2

# %%
ch_regex = "เกลือ"
name = "เกลือ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เกลือ 417
# เกลือป่น 108
# เกลือเม็ด 7
# เกลือชมพู 6
# เกลือแกง 6
# ดอกเกลือ 5
# เกลือ พริกไทย 4
# เกลือหิมาลายัน 3
# เกลือพริกไทย 2
# เกลือ Low Sodium 2
# เกลือสำหรับต้มเส้น 2
# เกลือผสมผงกระเทียม 2
# เกลือหิมาลัย 2
# เกลือ น้ำตาล 2
# เกลือและพริกไทย สำหรับปรุงรส 2
# เกลือสมุทร 2
# เกลือ/พริกไทย 2
# เกลือ หรือ น้ำปลา 2
# เกลือป่นหยาบ 2

# %%
ch_regex = "ซอสปรุงรส|ซอสฝาเขียว|ซอสฝาเหลือง|ซอสแมคกี้|ซอสแม็กกี้"
name = "ซอสปรุงรส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสปรุงรส 338
# ซอสปรุงรสฝาเขียว 32
# ซอสฝาเขียว 13
# ซอสฝาเหลือง 11
# ซอสแมคกี้ 8
# ซอสแม็กกี้ 5
# ซอสปรุงรสเห็ดหอม 2
# ซอสปรุงรสไก่ 2

# %%
ch_regex = "น้ำมันหอย|ซอสหอย|ซอยหอยนางรม"
name = "น้ำมันหอย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมันหอย 575
# ซอสหอยนางรม 213
# ซอสน้ำมันหอย 13
# ซอยหอยนางรม 12
# ซอสหอย 11
# น้ำมันหอย low sodium 2
# ซอสหอยนางรมตราแม่ครัว 2
# ซอสหอยนางรส 2

# %%
ch_regex = "น้ำมัน(?!(หอย|พริกเผา|งา))"
name = "น้ำมัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมันพืช 423
# น้ำมัน 328
# น้ำมันมะกอก 103
# น้ำมันรำข้าว 67
# น้ำมันสำหรับผัด 45
# น้ำมันสำหรับทอด 33
# น้ำมันถั่วเหลือง 24
# น้ำมันปาล์ม 18
# น้ำมันพืชสำหรับผัด 10
# น้ำมันหมู 10
# น้ำมันคาโนล่า 8
# น้ำมันมะพร้าว 8
# น้ำมันกระเทียมเจียว 6
# น้ำมันพืชสำหรับทอด 6
# น้ำมันทอด 4
# น้ำมันสำหรับทอดปลา 3
# น้ำมันสำหรับผัดเล็กน้อย 3
# น้ำมันมะกอกแคลอรี่0 2
# น้ำมันพืช สำหรับทอด 2
# น้ำมัน พืช 2
# น้ำมันพิช 2
# น้ำมัน หอย 2
# น้ำมันพืช. 2
# น้ำมันสำหรับทอดไก่ 2
# น้ำมันมะพร้าวสำหรับผัด 2
# น้ำมันสำหรับทอดและผัด 2
# น้ำมันมะกรอก 2
# น้ำมันมะกอกสเปรย์ 2
# น้ำมันสำหรับทอดไข่ 2
# น้ำมัน ถั่วเหลือง 2

# %%
ch_regex = "น้ำเปล่า|น้ำสะอาด|น้ำต้มสุก|^น้ำ$|น้ำเย็น|น้ำร้อน"
name = "น้ำเปล่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำเปล่า 306
# น้ำสะอาด 113
# น้ำต้มสุก 15
# น้ำ 14
# น้ำเย็น 11
# น้ำเย็นจัด 7
# น้ำร้อน 5
# น้ำซุปหรือน้ำเปล่า 3
# น้ำเปล่าหรือน้ำซุป 3
# น้ำสะอาดสำหรับต้มเส้น 2
# น้ำเปล่า/น้ำซุป 2

# %%
ch_regex = "ซีอิ๊วขาว|ซีอิ้วขาว|ซอสถั่วเหลือง|ซีอิ๋วขาว|สี่อิ๋วขาวสูตร1|ซีอิ้วปรุงรส|^ซีอิ๊ว$|ซี๊อิ๋วขาว|ซีอิ้ว ขาว"
name = "ซีอิ๊วขาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ๊วขาว 294
# ซีอิ้วขาว 289
# ซอสถั่วเหลือง 29
# ซีอิ๋วขาว 28
# ซีอิ้วปรุงรส 28
# สี่อิ๋วขาวสูตร1 17
# ซีอิ๊ว 10
# ซีอิ้วขาวโลว์โซเดียม 6
# ซี๊อิ๋วขาว 6
# ซีอิ้ว ขาว 6
# ซีอิ๊วขาวเห็ดหอม 5
# ซีอิ้วขาวเห็ดหอม 2
# ซีอิ๊วขาว. 2

# %%
ch_regex = "^(?!.*ซอส|หมู).*พริกไทย.*|พริกไท"
name = "พริกไทย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกไทย 274
# พริกไทยป่น 163
# พริกไทยดำ 75
# พริกไท 32
# พริกไทยอ่อน 26
# พริกไทยดำป่น 25
# พริกไทป่น 23
# พริกไทยเม็ด 19
# พริกไทยขาวป่น 16
# พริกไทยขาว 14
# พริกไทยดำบด 11
# พริกไทยสด 9
# ซอสพริกไทยดำ 5
# เม็ดพริกไทย 5
# เกลือ พริกไทย 4
# พริกไทยดำเม็ด 3
# พริกไทเม็ด 3
# พริกไทยป่นเล็กน้อย 3
# พริกไทย ป่น 3
# พริกไทดำ 3
# เกลือพริกไทย 2
# พริกไทยนิดหน่อย 2
# หมูหมักพริกไทยดำ 2
# พริกไทยขาวเม็ด 2
# พริกไทยดำบดหยาบ 2
# เกลือและพริกไทย สำหรับปรุงรส 2
# พริกไทยบด 2
# พริกไทยเม็ดตำละเอียด 2
# เกลือ/พริกไทย 2
# พริกไทยป่นสำหรับโรยหน้า 2
# พริกไทขาวเม็ด 2
# รากผักชี+กระเทียม+พริกไทย 2
# พริกไทยป่นตามชอบ 2

# %%
ch_regex = "ต้นหอม|ต้มหอม"
name = "ต้นหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ต้นหอม 228
# ต้นหอมซอย 88
# ต้นหอมหั่นท่อน 17
# ต้นหอมผักชี 15
# ต้นหอมหั่น 10
# ผักชีต้นหอม 9
# ต้นหอมญี่ปุ่น 8
# ต้นหอม ผักชี 6
# ต้มหอม 6
# ต้นหอมผักชีซอย 5
# ต้นหอม ผักชีซอย 5
# ต้นหอม ผักชี ซอย 3
# ต้นหอมผักชีหั่น 3
# ผักชี/ต้นหอม 3
# ต้นหอม-ผักชีซอย 2
# ผักชี ต้นหอม 2
# ต้มหอมซอย 2
# ต้นหอมหั่นฝอย 2
# ต้นหอม/ผักชี 2

# %%
ch_regex = "แครอท"
name = "แครอท"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แครอท 224
# แครอทหั่นเต๋า 28
# แครอทหั่น 11
# แครอทซอย 6
# แครอทฝอย 5
# แครอทหั่นเต๋าเล็ก 4
# แครอทหั่นชิ้น 3
# แครอทหั่นเส้น 3
# แครอทหั่นแว่น 3
# แครอทขูด 3
# แครอทสับ 3
# แครอทหั่นฝอย 3
# แครอท หั่นเต๋า 3
# แครอท หั่นเป็นลูกเต๋า 2
# แครอทขูดฝอย 2
# แครอทหั่นเต๋าเล็กๆ 2
# แครอท หั่นชิ้นเล็ก 2
# แครอทหั่นยาว 2
# แครอทหั่นละเอียด 2
# แครอทหั่นท่อน 2
# แครอทสไลด์ 2

# %%
ch_regex = "^(?!.*บะหมี่|ผง|กระดูก|ลูกชิ้น|ซี่โครง|ตับ|น้ำมัน|น้ำสต๊อก|คนอร์|แหนม|กุนเชียง|กาก|รสดี|ซุป|น้ำ|แคป|ซอส|มัน|กระเทียม|ไส้กรอก|เลือด|แฮม).*หมู(?!ยอ|กรอบ|หยอง|แดง|แฮม).*"
name = "เนื้อหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูสับ 197
# เนื้อหมู 123
# หมูบด 76
# หมูสามชั้น 36
# หมู 23
# เนื้อหมูสับ 22
# หมูหมัก 22
# หมูสันใน 20
# สันคอหมู 20
# หมูสไลด์ 14
# เนื้อหมูบด 14
# หมูชิ้น 13
# หมูหั่นชิ้น 8
# สันในหมู 8
# เนื้อหมูสามชั้น 8
# หมูเด้ง 7
# สันคอหมูสไลด์ 7
# หมูสามชั้นสไลด์ 6
# หมูสันนอก 6
# เนื้อหมูสันใน 5
# เนื้อหมูสันนอก 5
# หมูสันคอ 5
# หมูหั่น 4
# สันนอกหมู 4
# เนื้อหมูหั่น 4
# หมูบดติดมัน 3
# เนื้อหมูสไลด์ 3
# คอหมูย่าง 3
# เนื้อหมูหั่นชิ้น 3
# หมูนุ่ม 3
# หมูสับลวก 2
# เนื้อหมูส่วนสันคอ 2
# หมูหมักพริกไทยดำ 2
# หมูปิ้ง 2
# เนื้อหมูหมัก 2
# หมูหวาน 2
# หมูสับปรุงรส 2
# หมูสับหยาบ 2
# หมูเนื้อแดง 2
# เนื้อสันคอหมู 2

# %%
ch_regex = "^(?!.*เส้น)(.*ข้าวสวย|^ข้าว$|ข้าวกล้อง.*|ข้าวสาร|ข้าวเปล่า|ข้าวหอมมะลิ|ข้าวเย็น|ข้าวหุงสุก|ข้าวญี่ปุ่น)"
name = "ข้าวสวย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวสวย 197
# ข้าว 35
# ข้าวกล้อง 14
# ข้าวสาร 10
# ข้าวเปล่า 9
# ข้าวหอมมะลิ 8
# ข้าวกล้องหุงสุก 7
# ข้าวสวยแช่เย็น 7
# ข้าวสวยหอมมะลิ 6
# ข้าวสวยเก่า 5
# ข้าวเย็น 5
# ข้าวหุงสุก 5
# ข้าวญี่ปุ่น 5
# ข้าวสวยหุงสุก 4
# ข้าวสวยญี่ปุ่น 4
# ข้าวสวยหุงค้างคืน 4
# ข้าวสวยร้อนๆ 3
# ข้าวสารหอมมะลิ 3
# ข้าวสวยเย็น 3
# ข้าวหอมมะลิหุงสุก 3
# ข้าวเปล่าหุงสุก 2
# ข้าวสวยหอมมะลิหุงค้างคืน 2
# ข้าวสวยหุงแห้ง 2
# ข้าวหอมมะลิเก่า 2
# ข้าวสวย มากน้อยตามชอบค่ะ 2
# ข้าวญี่ปุ่นหุงสุก 2
# ข้าวสวยเย็นๆ 2

# %%
ch_regex = "มะนาว"
name = "น้ำมะนาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะนาว 191
# น้ำมะนาว 67
# มะนาวแป้น 7
# มะนาวฝาน 3
# น้ำมะนาวสด 2
# มะนาวผ่าซีก 2
# น้ำจิ้ม มะนาว 2

# %%
ch_regex = "พริกขี้หนู"
name = "พริกขี้หนู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกขี้หนู 158
# พริกขี้หนูสวน 39
# พริกขี้หนูซอย 24
# พริกขี้หนูแดง 15
# พริกขี้หนูตำ 13
# พริกขี้หนูสด 12
# พริกขี้หนูสับ 11
# พริกขี้หนูแห้ง 5
# พริกขี้หนูตำละเอียด 3
# พริกขี้หนูบุบ 3
# พริกขี้หนูแห้งซอย 2
# พริกขี้หนูสับหยาบ 2
# พริกขี้หนูหั่น 2
# พริกขี้หนูแห้งทอด 2
# พริกขี้หนูทอด 2

# %%
ch_regex = "^(?!.*ไข่|มัน|มาม่า).*กุ้ง(?!แห้ง).*"
name = "กุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุ้ง 152
# กุ้งสด 48
# กุ้งแม่น้ำ 8
# กุ้งขาว 8
# กุ้งสับ 6
# กุ้งลายเสือ 4
# กุ้งสดแกะเปลือก 4
# กุ้ง ปลาหมึก 3
# กุ้งแกะเปลือก 3
# กุ้งกุลาดำ 3
# กุ้งขาวขนาดกลาง 2
# กุ้งสดปอกเปลือกผ่าหลัง 2
# กุ้งก้ามกราม 2
# น้ำพริกมันกุ้ง 2
# เนื้อกุ้ง 2
# กุ้งแกะเปลือกผ่าหลัง 2
# กุ้งแชบ๊วย 2

# %%
ch_regex = "^(?!.*ซอส|ซ้อส).*มะเขือเทศ.*"
name = "มะเขือเทศ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือเทศ 139
# มะเขือเทศราชินี 18
# มะเขือเทศหั่นเต๋า 10
# มะเขือเทศสีดา 9
# มะเขือเทศลูกเล็ก 7
# มะเขือเทศลูกใหญ่ 5
# มะเขือเทศเชอร์รี่ 4
# มะเขือเทศสับละเอียด 2
# มะเขือเทศหั่นลูกเต๋า 2
# มะเขือเทศสับ 2
# มะเขือเทศหั่น 2
# มะเขือเทศเข้มข้น 2
# มะเขือเทศราชินีผ่าครึ่ง 2

# %%
ch_regex = "หอมใหญ่|หอมหัวใหญ่|หัวหอม|หอมแขก"
name = "หอมใหญ่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หอมใหญ่ 135
# หอมหัวใหญ่ 83
# หัวหอมใหญ่ 49
# หัวหอม 22
# หอมแขก 10
# หอมใหญ่สับ 10
# หัวหอมแดง 9
# หอมใหญ่หั่นเต๋า 9
# หอมใหญ่หั่นเสี้ยว 5
# หอมหัวใหญ่สับละเอียด 4
# หัวหอมใหญ่สับ 4
# หอมหัวใหญ่สับ 4
# หอมหัวใหญ่หั่นเต๋า 3
# หัวหอมสับ 3
# หัวหอมซอย 3
# หอมหัวใหญ่สับหยาบ 3
# หอมใหญ่ซอย 3
# หอมหัวใหญ่ซอย 3
# หอมใหญ่ซอยบางๆ 2
# หอมใหญ่หั่นชิ้นเล็ก 2
# หอมใหญ่หั่น 2
# หัวหอมหั่น 2
# หัวหอมใหญ่หั่น 2
# หอมใหญ่สับละเอียด 2
# หัวหอมแดงสับ 2
# หัวหอมใหญ่หั่นเต๋า 2
# หอมหัวใหญ่ หั่น 2

# %%
ch_regex = "รากผักชี"
name = "รากผักชี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# รากผักชี 111
# รากผักชีสับ 4
# รากผักชีทุบ 3
# รากผักชี+กระเทียม+พริกไทย 2

# %%
ch_regex = "หอมแดง|หอมเจียว"
name = "หอมแดง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หอมแดง 100
# หอมแดงซอย 45
# หอมเจียว 14
# หัวหอมแดง 9
# หอมแดงเจียว 3
# หอมแดงสับละเอียด 3
# หอมแดงเล็กซอย 2
# หอมแดงสับ 2
# หัวหอมแดงสับ 2
# หอมแดงเผา 2

# %%
ch_regex = "พริกแห้ง"
name = "พริกแห้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกแห้ง 100
# พริกแห้งทอด 8
# พริกแห้งจินดา 2
# พริกแห้งคั่ว 2
# พริกแห้งเม็ดเล็ก 2

# %%
ch_regex = "พริกป่น"
name = "พริกป่น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกป่น 99
# พริกป่นตามชอบ 3
# พริกป่นเกาหลี 3
# พริกป่นละเอียด 2

# %%
ch_regex = "^(?!.*ราก|ลูก).*ผักชี.*"
name = "ผักชี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักชี 97
# ผักชีฝรั่ง 30
# ผักชีซอย 15
# ต้นหอมผักชี 15
# ผักชีต้นหอม 9
# ต้นหอม ผักชี 6
# ผักชีฝรั่งซอย 5
# ต้นหอมผักชีซอย 5
# ต้นหอม ผักชีซอย 5
# ผักชีใบเลื่อย 4
# ใบผักชี 4
# ผักชีหั่น 3
# ผักชีสับ 3
# ต้นหอม ผักชี ซอย 3
# ต้นหอมผักชีหั่น 3
# ผักชี/ต้นหอม 3
# ต้นหอม-ผักชีซอย 2
# ผักชีลาว 2
# เม็ดผักชี 2
# ผักชี ต้นหอม 2
# ต้นหอม/ผักชี 2

# %%
ch_regex = "ซอสมะเขือเทศ"
name = "ซอสมะเขือเทศ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสมะเขือเทศ 103
# ซอสมะเขือเทศเข้มข้น 3
# ซอสมะเขือเทศโรซ่า 3

# %%
ch_regex = "ใบมะกรูด|ใบมะกูด"
name = "ใบมะกรูด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบมะกรูด 94
# ใบมะกรูดซอย 22
# ใบมะกรูดฉีก 16
# ใบมะกูด 6
# ใบมะกรูดหั่นฝอย 6
# ใบมะกรูดฝอย 2

# %%
ch_regex = "น้ำมันงา"
name = "น้ำมันงา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมันงา 93
# น้ำมันงาเกาหลี 3
# น้ำมันงาลีกุมกี่ 2

# %%
ch_regex = "^พริก$|พริกสด|พริกจินดา|พริกแดง|พริกใหญ่|พริกสับ|พริกอ่อน"
name = "พริก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริก 89
# พริกสด 42
# พริกจินดา 35
# พริกแดง 25
# พริกจินดาแดง 19
# พริกใหญ่ 14
# พริกแดงจินดา 12
# พริกจินดาสีแดง 9
# พริกสับ 9
# พริกอ่อน 7
# พริกสดหั่น 3
# พริกแดงซอย 2
# พริกสดซอย 2
# พริกแดงสับ 2
# พริกแดง-พริกเขียว 2
# ผงพริกแดง 2
# พริกใหญ่แดง 2

# %%
ch_regex = "โหระพา|ใบโหรพา"
name = "ใบโหระพา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบโหระพา 89
# โหระพา 52
# ใบโหรพา 5
# ใบโหระพาสับ 3
# ใบโหระพาเด็ด 2
# โหระพาเด็ด 2

# %%
ch_regex = "ถั่วฝักยาว|ถั่วฟักยาว"
name = "ถั่วฝักยาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วฝักยาว 84
# ถั่วฟักยาว 5
# ถั่วฝักยาวหั่น 3
# ถั่วฝักยาวซอย 3

# %%
ch_regex = "ใบกะเพรา|ใบกระเพรา|กระเพรา|กะเพรา|ใบกระเพา"
name = "ใบกะเพรา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบกะเพรา 82
# ใบกระเพรา 82
# กระเพรา 19
# กะเพรา 11
# ใบกระเพา 5
# ใบกระเพราแดง 5
# ใบกระเพราเด็ด 4
# กะเพราแดง 3
# กระเพราขาว 2

# %%
ch_regex = "^(?!.*ไส้กรอก|ไข่|เลือด|น้ำ|ผง|โครง|ตีน|เครื่องใน|เต้าหู้|ซี่โครง|ขา|ซอส|ตับ).*ไก่(?!จ๊อ|ไข่).*"
name = "เนื้อไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# อกไก่ 81
# เนื้อไก่ 54
# เนื้ออกไก่ 24
# สันในไก่ 21
# สะโพกไก่ 17
# ไก่ 13
# ไก่สับ 12
# อกไก่สับ 11
# น่องไก่ 11
# ไก่น่องสะโพก 8
# ปีกไก่ 8
# อกไก่หั่น 7
# เนื้อสะโพกไก่ 6
# น่องไก่ติดสะโพก 4
# อกไก่หั่นชิ้น 4
# เนื้ออกไก่สับ 3
# ไก่หมัก 3
# ปีกบนไก่ 3
# สะโพกไก่เลาะกระดูก 3
# เนื้ออกไก่ลอกหนัง 2
# ไก่หั่น 2
# ปีกกลางไก่ 2
# ปีกไก่บน 2
# ปีกไก่กลาง 2
# น่องไก่เล็ก 2
# อกไก่ลอกหนัง 2
# อกไก่ ไม่ติดหนัง 2
# เนื้อสันในไก่ 2
# ไก่บด 2
# เนื้ออกไก่หั่น 2
# เนื้อไก่บด 2
# อกไก่หมัก 2
# เนื้อไก่สับ 2
# ไก่ทอด 2
# ไก่สับละเอียด 2
# ไก่ชิ้น 2
# เนื้อไก่หั่นเต๋า 2
# อกไก่ต้ม 2
# อกไก่บด 2

# %%
ch_regex = "^ซีอิ๊วดำ$|^ซีอิ้วดำ$|ซีอิ๋วดำ(?!หวาน)"
name = "ซีอิ๊วดำ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ๊วดำ 77
# ซีอิ้วดำ 62
# ซีอิ๋วดำ 8

# %%
ch_regex = "ถั่วงอก"
name = "ถั่วงอก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วงอก 76
# ถั่วงอกลวก 4
# ถั่วงอกหัวโต 3
# ถั่วงอกดิบ 2
# ถั่วงอกเด็ดหาง 2

# %%
ch_regex = "คะน้า"
name = "คะน้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# คะน้า 74
# ผักคะน้า 33
# คะน้าฮ่องกง 19
# ยอดคะน้า 16
# คะน้ายอด 2
# ก้านคะน้าฮ่องกง 2

# %%
ch_regex = "ข้าวโพดอ่อน"
name = "ข้าวโพดอ่อน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวโพดอ่อน 74
# ยอดข้าวโพดอ่อน 3
# ข้าวโพดอ่อนหั่นแฉลบ 2
# ข้าวโพดอ่อนผ่าครึ่ง 2
# ข้าวโพดอ่อนแพคเล็ก 2
# ข้าวโพดอ่อนซอย 2
# ข้าวโพดอ่อนหั่น 2

# %%
ch_regex = "เนย"
name = "เนย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เนย 70
# เนยจืด 22
# เนยเค็ม 19
# เนยสด 16
# เนยแท้ 3
# เนยสดเค็ม 3
# เนยละลาย 2
# เนยสดจืด 2
# เนยรสจืด 2
# เนยมาการีน 2

# %%
ch_regex = "แป้งทอดกรอบ|แป้งชุบทอด|แป้งโกกิ"
name = "แป้งทอดกรอบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งทอดกรอบ 59
# แป้งชุบทอด 6
# แป้งโกกิ 5
# แป้งทอดกรอบคนอร์ 3

# %%
ch_regex = "แป้งมัน"
name = "แป้งมัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งมัน 56
# แป้งมันฮ่องกง 8
# แป้งมันละลายน้ำ 4

# %%
ch_regex = "^(?!.*ซอส|ซีอิ๊ว|ผงปรุงรส|ซีอิ้ว|คนอร์).*เห็ด.*"
name = "เห็ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เห็ดหอม 56
# เห็ดเข็มทอง 34
# เห็ดออรินจิ 19
# เห็ดหอมสด 18
# เห็ดฟาง 16
# เห็ด 16
# เห็ดหูหนู 12
# เห็ดชิเมจิ 11
# เห็ดหอมแห้ง 10
# เห็ดแชมปิญอง 9
# เห็ดนางฟ้า 7
# เห็ดหูหนูดำ 7
# เห็ดหอมแช่น้ำ 5
# เห็ดนางรมหลวง 5
# เห็ดออริจิน 4
# เห็ดโคนญี่ปุ่น 3
# เห็ดหอมแห้งแช่น้ำจนนิ่ม 3
# เห็ดหูหนูขาว 3
# เห็ดหอมดอกใหญ่ 2
# เห็ดออริจิ 2
# เห็ดแชมปิยอง 2
# เห็ดหอมซอย 2

# %%
ch_regex = "เส้นสปาเก็ตตี้|เส้นสปาเกตตี้|สปาเก็ตตี้|สปาเกตตี้|เส้นสปาเกตตี"
name = "เส้นสปาเก็ตตี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นสปาเก็ตตี้ 55
# เส้นสปาเกตตี้ 34
# สปาเก็ตตี้ 9
# เส้นสปาเก็ตตี้ต้มสุก 7
# สปาเกตตี้ 7
# เส้นสปาเกตตี 7
# เส้นสปาเก็ตตี้โฮลวีท 3
# เส้นสปาเกตตี้ ต้มสุก 2
# เส้นสปาเกตตี้ลวก 2

# %%
ch_regex = "เต้าเจี้ยว"
name = "เต้าเจี้ยว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เต้าเจี้ยว 53

# %%
ch_regex = "โชยุ"
name = "โชยุ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โชยุ 53
# ซอสโชยุ 5
# โชยุญี่ปุ่น 2

# %%
ch_regex = "ตะไคร้|ตะใคร้"
name = "ตะไคร้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตะไคร้ 52
# ตะไคร้ซอย 22
# ตะใคร้ 5
# ตะไคร้หั่นฝอย 2
# ตะไคร้ ซอย 2

# %%
ch_regex = "^(?!.*ไข่).*ปลาหมึก.*"
name = "ปลาหมึก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาหมึก 52
# ปลาหมึกสด 8
# ปลาหมึกกรอบ 5
# ปลาหมึกแห้ง 4
# กุ้ง ปลาหมึก 3
# ปลาหมึกกล้วย 3
# ปลาหมึกหั่นแว่น 2

# %%
ch_regex = "น้ำพริกเผา"
name = "น้ำพริกเผา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำพริกเผา 67
# น้ำพริกเผาผัด 2
# น้ำพริกเผาต้มยำ 2

# %%
ch_regex = "เบคอน"
name = "เบคอน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เบคอน 52
# เบคอนหั่น 4

# %%
ch_regex = "ไส้กรอก"
name = "ไส้กรอก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไส้กรอก 50
# ไส้กรอกรมควัน 7
# ไส้กรอกไก่ 6
# ไส้กรอกหมู 3
# ไส้กรอกหมูรมควัน 2
# ไส้กรอกหั่นชิ้น 2
# ไส้กรอกหั่นแว่น 2
# ไส้กรอกมินิคอกเทล 2
# ไส้กรอกไก่รมควัน 2

# %%
ch_regex = "^นม(?!ข้น)"
name = "นม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# นมสด 49
# นมจืด 18
# นมสดจืด 6
# นม 6
# นมสดรสจืด 3

# %%
ch_regex = "ซอสพริก"
name = "ซอสพริก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสพริก 48
# ซอสพริกศรีราชา 6
# ซอสพริกไทยดำ 5

# %%
ch_regex = "วุ้นเส้น"
name = "วุ้นเส้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# วุ้นเส้น 47
# วุ้นเส้นสด 10
# วุ้นเส้นห่อเล็ก 3
# วุ้นเส้นแช่น้ำ 2
# วุ้นเส้นเกาหลี 2

# %%
ch_regex = "น้ำซุป"
name = "น้ำซุป"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำซุป 46
# น้ำซุปไก่ 4
# น้ำซุปหรือน้ำเปล่า 3
# น้ำซุปดาชิ 3
# น้ำเปล่าหรือน้ำซุป 3
# น้ำซุปกระดูกหมู 2
# ส่วนผสมน้ำซุป 2
# น้ำเปล่า/น้ำซุป 2

# %%
ch_regex = "ผักกาด"
name = "ผักกาด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักกาดขาว 43
# ผักกาดหอม 17
# ผักกาดแก้ว 6
# ผักกาดดอง 6
# ผักกาด 3
# ผักกาดดองเค็ม 2
# ใบผักกาดขาว 2

# %%
ch_regex = "^กะปิ"
name = "กะปิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กะปิ 43
# กะปิดี 4
# กะปิอย่างดี 2

# %%
ch_regex = "พริกชี้ฟ้า|พริกเหลือง"
name = "พริกชี้ฟ้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกชี้ฟ้าแดง 43
# พริกชี้ฟ้า 26
# พริกชี้ฟ้าซอย 7
# พริกชี้ฟ้าแห้ง 6
# พริกเหลือง 5
# พริกชี้ฟ้าแดงหั่นแฉลบ 3
# พริกชี้ฟ้าเหลือง 2
# พริกชี้ฟ้าแดง เขียว 2
# พริกชี้ฟ้าหั่นเฉียง 2
# พริกชี้ฟ้าเขียว แดง 2
# พริกชี้ฟ้าส้ม 2
# พริกชี้ฟ้าตำละเอียด 2
# พริกชี้ฟ้าแดงซอย 2

# %%
ch_regex = "กะทิ"
name = "กะทิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กะทิ 42
# หัวกะทิ 12
# หางกะทิ 6
# น้ำกะทิ 6
# กะทิกล่อง 3
# กะทิสด 2
# พริกแกงกะทิ 2

# %%
ch_regex = "เส้นใหญ่"
name = "เส้นใหญ่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นใหญ่ 42
# ก๋วยเตี๋ยวเส้นใหญ่ 4

# %%
ch_regex = "กะหล่ำปลี|กระหล่ำปลี"
name = "กะหล่ำปลี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กะหล่ำปลี 40
# กระหล่ำปลี 21
# กะหล่ำปลีหั่น 4
# กระหล่ำปลีซอย 3
# กะหล่ำปลีซอย 3
# กระหล่ำปลีหั่น 2
# กะหล่ำปลีม่วงซอย 2
# กะหล่ำปลีฝอย 2
# กะหล่ำปลีหั่นฝอย 2

# %%
ch_regex = "ผักบุ้ง"
name = "ผักบุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักบุ้ง 39
# ผักบุ้งจีน 4
# ผักบุ้งไทย 2

# %%
ch_regex = "แฮม"
name = "แฮม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แฮม 39
# แฮมหมู 2
# แฮมหั่นเต๋า 2
# หมูแฮม 2

# %%
ch_regex = "หมูยอ"
name = "หมูยอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูยอ 37

# %%
ch_regex = "แตงกวา"
name = "แตงกวา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แตงกวา 36
# แตงกวาเล็ก 2
# แตงกวาญี่ปุ่น 2
# แตงกวาหั่น 2

# %%
ch_regex = "กุ้งแห้ง"
name = "กุ้งแห้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุ้งแห้ง 35
# กุ้งแห้งฝอย 4
# กุ้งแห้งป่น 4

# %%
ch_regex = "มิริน"
name = "มิริน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มิริน 35

# %%
ch_regex = "น้ำมะขามเปียก"
name = "น้ำมะขามเปียก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมะขามเปียก 35

# %%
ch_regex = "ขึ้นฉ่าย|คื่นช่าย|คึ่นช่าย"
name = "ขึ้นฉ่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขึ้นฉ่าย 34
# คื่นช่าย 12
# คึ่นช่าย 7
# ขึ้นฉ่ายซอย 4
# คื่นช่ายหั่น 2
# ขึ้นฉ่ายหั่น 2

# %%
ch_regex = "มันฝรั่ง"
name = "มันฝรั่ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มันฝรั่ง 33
# มันฝรั่งหั่นเต๋า 3

# %%
ch_regex = "น้ำส้มสายชู"
name = "น้ำส้มสายชู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำส้มสายชู 31
# น้ำส้มสายชูข้าว 3

# %%
ch_regex = "ข่า"
name = "ข่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข่า 31
# ข่าซอย 4
# ข่าสับละเอียด 2
# ข่าอ่อนหั่นแว่น 2
# ข่าหั่น 2
# ข่าอ่อน 2
# ข่าหั่นแว่น 2

# %%
ch_regex = "มาม่า|บะหมี่กึ่งสำเร็จรูป|เส้นหมี่ไวไว"
name = "บะหมี่กึ่งสำเร็จรูป"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มาม่า 29
# บะหมี่กึ่งสำเร็จรูป 21
# มาม่าเกาหลี 5
# เส้นมาม่า 4
# เส้นบะหมี่กึ่งสำเร็จรูป 4
# เส้นมาม่าลวก 3
# เส้นหมี่ไวไว 3
# บะหมี่กึ่งสำเร็จรูปรสต้มยำ 2
# มาม่าลวก 2
# มาม่าต้มยำเจ 2
# มาม่ารสต้มยำ 2
# มาม่าต้มยำกุ้งน้ำใส 2
# บะหมี่กึ่งสำเร็จรูปรสหมูสับ 2
# มาม่าลวกสุก 2
# มาม่าต้มยำกุ้งน้ำข้น 2
# มาม่าต้มยำ 2

# %%
ch_regex = "น้ำผึ้ง"
name = "น้ำผึ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำผึ้ง 28

# %%
ch_regex = "^(?!.*ซอส|แป้งทอด).*(คนอร์|รสดี).*|อร่อยชัวร์|ผงปรุงรส|เครื่องปรุงรส|ซุปก้อน|ผงซุปหมูก้อน|ชูรส|ผงซุป|ผงเติมทิพ"
name = "ผงปรุงรส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงปรุงรส 193
# ผงปรุงรสคนอร์ 34
# รสดี 28
# คนอร์ 27
# ผงปรุงรสหมู 24
# ผงชูรส 19
# คนอร์อร่อยชัวร์ 16
# ผงคนอร์ 14
# อร่อยชัวร์ 13
# เครื่องปรุงรส 10
# ผงปรุงรสไก่ 7
# ผงปรุงรสรสหมู 7
# คนอร์ผงรสหมู 7
# ผงปรุงรสเห็ดหอม 6
# คนอร์ผง 6
# คนอร์รสหมู 6
# ซุปก้อน 6
# ผงซุปก้อนหมู 6
# ผงซุปหมูก้อน 5
# ชูรส 5
# ผงปรุงรสตราคนอร์ 5
# คนอร์ก้อน 5
# ผงปรุงรสคนอร์อร่อยชัวร์ 5
# ผงซุป 5
# ผงเติมทิพ 5
# คนอร์ผง รสหมู 4
# คนอร์ซุปก้อนรสหมู 4
# รสดีเมนู 4
# ผงปรุงรส คนอร์ 3
# รสดีหมู 3
# คนอร์ขวดสูตรเข้มข้น 3
# ผงเติมทิพ. 3
# คนอร์อร่อยชัว 3
# คนอร์ต้มยำ 3
# คนอร์เห็ดหอม 3
# ผงปรุงรสผัดคนอร์ 2
# คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส 2
# รสดีรสหมู 2
# คนอร์อร่อยชัวร์รสหมู 2
# ผงชูรสเจ 2
# คนอร์ซุปก้อน 2
# ซุปหมูก้อนคนอร์ 2
# ซุปก้อนรสหมู 2
# ผงคนอร์รสหมู 2
# คนอร์ต้มยำก้อน 2
# คนอร์ขวดรสหมู 2

# %%
ch_regex = "ซอสเห็ดหอม"
name = "ซอสเห็ดหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสเห็ดหอม 26

# %%
ch_regex = "ไชเท้า"
name = "หัวไชเท้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หัวไชเท้า 24
# ไชเท้า 5

# %%
ch_regex = "พริกแกง"
name = "พริกแกง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกแกงเผ็ด 39
# พริกแกง 28
# พริกแกงใต้ 9
# พริกแกงเขียวหวาน 9
# พริกแกงแดง 5
# พริกแกงพะแนง 3
# พริกแกงน้ำยา 3
# พริกแกงส้ม 3
# พริกแกงคั่ว 3
# พริกแกงเผ็ดใต้ 2
# พริกแกงมัสมั่น 2
# พริกแกงกะทิ 2
# พริกแกงฉู่ฉี่ 2
# พริกแกงคั่วกลิ้ง 2

# %%
ch_regex = "แป้งข้าวโพด"
name = "แป้งข้าวโพด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งข้าวโพด 32

# %%
ch_regex = "ซีอิ้วดำหวาน|ซีอิ๊วดำหวาน|ซีอิ๊วหวาน"
name = "ซีอิ๊วหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ้วดำหวาน 26
# ซีอิ๊วดำหวาน 16
# ซีอิ๊วหวาน 8

# %%
ch_regex = "กุนเชียง"
name = "กุนเชียง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุนเชียง 24
# กุนเชียงหมู 5
# กุนเชียงทอด 3
# กุนเชียงอย่างดี 2

# %%
ch_regex = "ข้าวคั่ว"
name = "ข้าวคั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวคั่ว 24

# %%
ch_regex = "กวางตุ้ง"
name = "ผักกวางตุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักกวางตุ้ง 24
# กวางตุ้ง 10

# %%
ch_regex = "ลูกชิ้น"
name = "ลูกชิ้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ลูกชิ้นปลา 24
# ลูกชิ้นหมู 17
# ลูกชิ้น 16
# ลูกชิ้นปลากราย 2
# ลูกชิ้นเอ็นหมู 2
# ลูกชิ้นเนื้อ 2

# %%
ch_regex = "ไข่เป็ด"
name = "ไข่เป็ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่เป็ด 24

# %%
ch_regex = "ปลากระป๋อง"
name = "ปลากระป๋อง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลากระป๋อง 23

# %%
ch_regex = "ผักสลัด"
name = "ผักสลัด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักสลัด 23
# ผักสลัดตามชอบ 4

# %%
ch_regex = "^กระดูกหมู$|กระดูกเล้ง"
name = "กระดูกหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระดูกหมู 23
# กระดูกเล้ง 5

# %%
ch_regex = "ปูอัด"
name = "ปูอัด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปูอัด 23

# %%
ch_regex = "เกล็ดขนมปัง"
name = "เกล็ดขนมปัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เกล็ดขนมปัง 22

# %%
ch_regex = "เต้าหู้ไข่"
name = "เต้าหู้ไข่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เต้าหู้ไข่ 22
# เต้าหู้ไข่ไก่ 3

# %%
ch_regex = "น้ำปลาร้า"
name = "น้ำปลาร้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำปลาร้า 20
# น้ำปลาร้าต้มสุก 3

# %%
ch_regex = "^(?!.*น้ำ).*งา.*"
name = "งา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# งาขาว 20
# งาขาวคั่ว 20
# งาคั่ว 5
# งาดำ 3

# %%
ch_regex = "ถั่วลันเตา"
name = "ถั่วลันเตา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วลันเตา 20

# %%
ch_regex = "ถั่วลันเตา"
name = "ถั่วลันเตา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วลันเตา 20

# %%
ch_regex = "กระชาย"
name = "กระชาย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระชาย 20
# กระชายซอย 10
# กระชายหั่นฝอย 2
# กระชายหั่นเส้น 2

# %%
ch_regex = "ผงชูรส"
name = "ผงชูรส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงชูรส 19
# คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส 2
# ผงชูรสเจ 2

# %%
ch_regex = "ขนมจีน"
name = "ขนมจีน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขนมจีน 19
# เส้นขนมจีน 2

# %%
ch_regex = "^(?!.*ผัก).*ชีส.*"
name = "ชีส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ชีส 19
# เชดด้าชีส 9
# มอสซาเรลล่าชีส 8
# ชีสแผ่น 8
# พาร์เมซานชีส 5
# มอสซาเรลลาชีส 4
# พาเมซานชีส 4
# ชีสขูด 2

# %%
ch_regex = "พริกหยวก"
name = "พริกหยวก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกหยวก 18
# พริกหยวกหั่น 5
# พริกหยวกสีเหลือง 2
# พริกหยวกแดง 2
# พริกหยวกสีเขียว 2

# %%
ch_regex = "เส้นหมี่(?!ซั่ว|ฮกเกี้ยน|เหลือง|ไวไว)"
name = "เส้นหมี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นหมี่ 18
# เส้นหมี่ขาว 15
# เส้นหมี่ข้าวกล้อง 8
# เส้นหมี่แช่น้ำ 2
# เส้นหมี่สด 2

# %%
ch_regex = "มะเขือเปราะ"
name = "มะเขือเปราะ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือเปราะ 17

# %%
ch_regex = "พริกเผา"
name = "พริกเผา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำพริกเผา 67
# พริกเผา 17
# น้ำมันพริกเผา 6
# น้ำพริกเผาผัด 2
# น้ำพริกเผาต้มยำ 2

# %%
ch_regex = "ซี่โครงหมู"
name = "ซี่โครงหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซี่โครงหมู 17

# %%
ch_regex = "เหล้า|สาเก"
name = "เหล้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เหล้าจีน 16
# สาเก 9

# %%
ch_regex = "กิมจิ"
name = "กิมจิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กิมจิ 16
# กิมจิสับละเอียด 2

# %%
ch_regex = "ออริกาโน่|อาริกาโน|ออริกาโน"
name = "ออริกาโน่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ออริกาโน่ 16
# อาริกาโน 6
# ออริกาโน 5
# ออริกาโน่แห้ง 3
# ออริกาโนป่น 2
# ออริกาโน่อบแห้ง 2

# %%
ch_regex = "มายองเนส"
name = "มายองเนส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มายองเนส 15
# คิวพี มายองเนส ศรีราชา 2

# %%
ch_regex = "น้ำจิ้มสุกี้"
name = "น้ำจิ้มสุกี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มสุกี้ 15

# %%
ch_regex = "ขิง"
name = "ขิง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขิงซอย 15
# ขิง 9
# ขิงแก่ 6
# ขิงอ่อน 6
# ขิงสับละเอียด 4
# ขิงสับ 4
# ขิงอ่อนซอย 4
# ขิงขูด 3
# ขิงขูดละเอียด 2
# ขิงแก่ซอย 2
# ขิงหั่นแว่น 2

# %%
ch_regex = "ชะอม"
name = "ชะอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ชะอม 14

# %%
ch_regex = "^ผัก$"
name = "ผัก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผัก 14

# %%
ch_regex = "^ผัก$"
name = "ผัก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผัก 14

# %%
ch_regex = "แหนม"
name = "แหนม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แหนม 16
# แหนมหมู 6
# แหนมตุ้มจิ๋ว 2
# แหนมสด 2

# %%
ch_regex = "นมข้น"
name = "นมข้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# นมข้นจืด 14

# %%
ch_regex = "มักกะโรนี"
name = "มักกะโรนี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มักกะโรนี 14
# เส้นมักกะโรนี 4
# มักกะโรนีต้มสุก 3
# เส้นมักกะโรนีต้มสุก 2

# %%
ch_regex = "อบเชย"
name = "อบเชย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# อบเชย 14

# %%
ch_regex = "ตับ"
name = "ตับ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตับหมู 13
# ตับ 4
# ตับไก่ 4

# %%
ch_regex = "หมูกรอบ"
name = "หมูกรอบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูกรอบ 13

# %%
ch_regex = "ผักโขม"
name = "ผักโขม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักโขม 13

# %%
ch_regex = "โคชูจัง"
name = "โคชูจัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โคชูจัง 12
# ซอสโคชูจัง 5

# %%
ch_regex = "ซีอิ๊วเห็ดหอม|ซีอิ้วเห็ดหอม"
name = "ซีอิ๊วเห็ดหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ๊วเห็ดหอม 12
# ซีอิ้วเห็ดหอม 5

# %%
ch_regex = "ไข่กุ้ง"
name = "ไข่กุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่กุ้ง 12

# %%
ch_regex = "^ปลาทู(?!น่า)"
name = "ปลาทู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาทู 12
# ปลาทูนึ่ง 6
# ปลาทูทอด 2
# ปลาทูมัน 2

# %%
ch_regex = "^(?!.*น้ำพริก).*มันกุ้ง.*"
name = "มันกุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มันกุ้ง 12
# มันกุ้งเสวย 5

# %%
ch_regex = "^เต้าหู้(?!ไข่)"
name = "เต้าหู้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เต้าหู้ 12
# เต้าหู้เหลือง 9
# เต้าหู้ทอด 8
# เต้าหู้ขาว 7
# เต้าหู้แข็ง 4
# เต้าหู้หลอด 4
# เต้าหู้พวง 3
# เต้าหู้นิ่ม 3
# เต้าหู้อ่อน 3
# เต้าหู้ปลา 3
# เต้าหู้ขาวแข็ง 2
# เต้าหู้โมเมน 2

# %%
ch_regex = "ทูน่า"
name = "ทูน่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ทูน่าในน้ำแร่ 12
# ทูน่ากระป๋อง 6
# ปลาทูน่าในน้ำแร่ 6
# ทูน่า 5
# ทูน่ากระป๋องในน้ำแร่ 4
# ปลาทูน่า 2

# %%
ch_regex = "เบค่อน"
name = "เบค่อน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เบค่อน 12
# เบค่อนตามชอบ 2

# %%
ch_regex = "กระเฉด"
name = "กระเฉด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักกระเฉด 11

# %%
ch_regex = "แผ่นเกี๊ยว"
name = "แผ่นเกี๊ยว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แผ่นเกี๊ยว 11

# %%
ch_regex = "สะตอ|สตอ"
name = "สะตอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# สะตอ 11
# สตอ 7

# %%
ch_regex = "ถั่วลิสง"
name = "ถั่วลิสง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วลิสงคั่ว 11
# ถั่วลิสง 9
# ถั่วลิสงป่น 6
# ถั่วลิสงบด 4
# ถั่วลิสงตำ 2
# ถั่วลิสงคั่วบด 2
# ถั่วลิสงคั่วป่น 2

# %%
ch_regex = "เส้นเล็ก"
name = "เส้นเล็ก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นเล็ก 11

# %%
ch_regex = "ซอสเทริยากิ|ซอสเทอริยากิ"
name = "ซอสเทริยากิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสเทริยากิ 11
# ซอสเทอริยากิ 10

# %%
ch_regex = "เลือด"
name = "เลือด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เลือดไก่ 10
# เลือดหมู 3

# %%
ch_regex = "ฟักทอง"
name = "ฟักทอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ฟักทอง 10

# %%
ch_regex = "ใบกระวาน"
name = "ใบกระวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบกระวาน 10

# %%
ch_regex = "กุยช่าย"
name = "กุยช่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุยช่าย 10
# ใบกุยช่าย 3
# ต้นกุยช่าย 2
# ใบกุยช่ายหั่นท่อน 2

# %%
ch_regex = "ผงกะหรี่|ผงกระหรี่"
name = "ผงกะหรี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงกะหรี่ 10
# ผงกระหรี่ 8

# %%
ch_regex = "มะเขือพวง"
name = "มะเขือพวง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือพวง 10

# %%
ch_regex = "มะเขือยาว"
name = "มะเขือยาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือยาว 10

# %%
ch_regex = "เส้นก๋วยเตี๋ยว"
name = "เส้นก๋วยเตี๋ยว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นก๋วยเตี๋ยว 9
# เส้นก๋วยเตี๋ยวหลอด 2
# เส้นก๋วยเตี๋ยวเล็ก 2

# %%
ch_regex = "น้ำพริก(?!เผา)"
name = "น้ำพริก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำพริกกะปิ 9
# น้ำพริกตาแดง 8
# น้ำพริกหนุ่ม 2
# น้ำพริก 2
# น้ำพริกมันกุ้ง 2

# %%
ch_regex = "เม็ดมะม่วง"
name = "เม็ดมะม่วงหิมพานต์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เม็ดมะม่วงหิมพานต์ 8
# เม็ดมะม่วงหิมพานต์อบ 2
# เม็ดมะม่วงหิมพาน 2
# เม็ดมะม่วง 2

# %%
ch_regex = "^ข้าวโพด(?!อ่อน)"
name = "ข้าวโพด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวโพด 8
# ข้าวโพดหวาน 7
# ข้าวโพดต้ม 4
# ข้าวโพดต้มสุก 4

# %%
ch_regex = "บะหมี่(?!กึ่ง)|หมี่เหลือง|เส้นหมี่ฮกเกี้ยน|เส้นหมี่เหลือง"
name = "บะหมี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นหมี่เหลือง 9
# บะหมี่ 8
# บะหมี่ผัก 8
# หมี่เหลือง 7
# บะหมี่ไข่ 6
# เส้นหมี่ฮกเกี้ยน 3
# เส้นบะหมี่ 3
# บะหมี่ลวก 2
# บะหมี่หยก 2
# บะหมี่เหลือง 2

# %%
ch_regex = "หน่อไม้"
name = "หน่อไม้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หน่อไม้ดอง 8
# หน่อไม้ 7
# หน่อไม้ฝรั่ง 6
# หน่อไม้ต้ม 3
# หน่อไม้ฝอย 2
# หน่อไม้สด 2

# %%
ch_regex = "มะขามเปียก"
name = "มะขามเปียก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมะขามเปียก 35
# มะขามเปียก 8

# %%
ch_regex = "แป้งอเนกประสงค์|แป้งสาลีอเนกประสงค์|แป้งสาลี"
name = "แป้งอเนกประสงค์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งอเนกประสงค์ 8
# แป้งสาลีอเนกประสงค์ 7
# แป้งสาลี 6
# แป้งสาลีเอนกประสงค์ 3

# %%
ch_regex = "ตั้งฉ่าย"
name = "ตั้งฉ่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตั้งฉ่าย 8

# %%
ch_regex = "ตั้งฉ่าย"
name = "ตั้งฉ่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตั้งฉ่าย 8

# %%
ch_regex = "ดอกกะหล่ำ"
name = "ดอกกะหล่ำ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดอกกะหล่ำ 8

# %%
ch_regex = "พาสต้า"
name = "เส้นพาสต้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นพาสต้า 8
# พาสต้าดิบ 5
# พาสต้า 4
# พาสต้าเอลิเก 2

# %%
ch_regex = "^ขนมปัง$"
name = "ขนมปัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขนมปัง 8

# %%
ch_regex = "บล็อคโคลี่|บล๊อคโคลี่"
name = "บล็อคโคลี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# บล็อคโคลี่ 8
# บล๊อคโคลี่ 5

# %%
ch_regex = "น้ำเชื่อม"
name = "น้ำเชื่อม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำเชื่อม 8

# %%
ch_regex = "น้ำจิ้มไก่"
name = "น้ำจิ้มไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มไก่ 8

# %%
ch_regex = "น้ำจิ้มไก่"
name = "น้ำจิ้มไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มไก่ 8

# %%
ch_regex = "หมี่ซั่ว"
name = "หมี่ซั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมี่ซั่ว 7
# เส้นหมี่ซั่ว 4

# %%
ch_regex = "โป๊ยกั๊ก"
name = "โป๊ยกั๊ก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โป๊ยกั๊ก 7

# %%
ch_regex = "น้ำกระเทียมดอง"
name = "น้ำกระเทียมดอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำกระเทียมดอง 7

# %%
ch_regex = "มะละกอ"
name = "มะละกอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะละกอ 7
# มะละกอสับ 3
# มะละกอขูด 2

# %%
ch_regex = "^(?!.*น้ำ).*มะพร้าว.*"
name = "มะพร้าว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะพร้าวคั่ว 7
# ยอดมะพร้าวอ่อน 3
# ยอดมะพร้าว 3

# %%
ch_regex = "ปู(?!อัด)"
name = "เนื้อปู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เนื้อปู 7
# ปูม้า 4
# ปูม้าสด 2
# เนื้อปูก้อน 2

# %%
ch_regex = "ผงพะโล้"
name = "ผงพะโล้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงพะโล้ 7

# %%
ch_regex = "น้ำสต๊อก"
name = "น้ำสต๊อก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำสต๊อกหมู 7
# น้ำสต๊อก 5

# %%
ch_regex = "หมูหยอง"
name = "หมูหยอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูหยอง 7

# %%
ch_regex = "ตีนไก่"
name = "ตีนไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตีนไก่ 7

# %%
ch_regex = "สับปะรด"
name = "สับปะรด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# สับปะรด 7

# %%
ch_regex = "ฟองเต้าหู้"
name = "ฟองเต้าหู้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ฟองเต้าหู้ 6
# ฟองเต้าหู้ทอดกรอบ 2

# %%
ch_regex = "น้ำสลัด"
name = "น้ำสลัด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำสลัด 6
# น้ำสลัดงาญี่ปุ่น 3
# น้ำสลัดงาคั่วญี่ปุ่น 2
# น้ำสลัดญี่ปุ่น 2

# %%
ch_regex = "มัสตาร์ด"
name = "มัสตาร์ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มัสตาร์ด 6

# %%
ch_regex = "พริกหวาน"
name = "พริกหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกหวาน 6
# พริกหวานหั่นเต๋า 4
# พริกหวานสีแดง 2

# %%
ch_regex = "ปลาสลิด"
name = "ปลาสลิด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาสลิด 6
# ปลาสลิดทอด 3
# ปลาสลิดแดดเดียว 2

# %%
ch_regex = "มะระ"
name = "มะระ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะระ 6

# %%
ch_regex = "แครรอท"
name = "แครรอท"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แครรอท 6

# %%
ch_regex = "เก๋ากี้"
name = "เก๋ากี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เก๋ากี้ 6

# %%
ch_regex = "^(?!.*น้ำ|ซอส|ซอย|นำ้|ซอล|ไวไว|นํ้ามัน).*หอย.*"
name = "หอย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หอยเชลล์ 6
# หอยลาย 5
# หอยแมลงภู่ 5
# เนื้อหอยแมลงภู่ 3
# เนื้อหอยลาย 3
# หอยแมลงภู่นิวซีแลนด์ 3
# หอยแมลงภู่ต้มสุก 2
# หอยลายกระป๋อง 2
# หอยแครงลวก 2

# %%
ch_regex = "อุด้ง"
name = "เส้นอุด้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นอุด้ง 6

# %%
ch_regex = "^มะม่วง"
name = "มะม่วงดิบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะม่วงเปรี้ยว 6
# มะม่วงเบา 4
# มะม่วงแก้วขมิ้น 2
# มะม่วงสับ 2

# %%
ch_regex = "โครงไก่"
name = "โครงไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โครงไก่ 6
# ซี่โครงไก่ 2

# %%
ch_regex = "ข้าวไรซ์เบอรี่"
name = "ข้าวไรซ์เบอรี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวไรซ์เบอรี่ 5

# %%
ch_regex = "หมูแดง"
name = "หมูแดง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูแดง 5

# %%
ch_regex = "โรสแมรี่"
name = "โรสแมรี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โรสแมรี่ 5
# โรสแมรี่อบแห้ง 2
# โรสแมรี่แห้ง 2

# %%
ch_regex = "ต้นอ่อนทานตะวัน"
name = "ต้นอ่อนทานตะวัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ต้นอ่อนทานตะวัน 5

# %%
ch_regex = "ปลาอินทรีย์"
name = "ปลาอินทรีย์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาอินทรีย์เค็ม 5
# เนื้อปลาอินทรีย์ 3

# %%
ch_regex = "ตั้งโอ๋"
name = "ตั้งโอ๋"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตั้งโอ๋ 5
# ตั้งโอ๋หั่นท่อน 2

# %%
ch_regex = "เส้นยากิโซบะ"
name = "เส้นยากิโซบะ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นยากิโซบะ 5

# %%
ch_regex = "ลูกผักชี"
name = "ลูกผักชี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ลูกผักชี 5
# ลูกผักชีป่น 2

# %%
ch_regex = "ปลากระพง"
name = "ปลากระพง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลากระพง 5

# %%
ch_regex = "ไส้อั่ว"
name = "ไส้อั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไส้อั่ว 5

# %%
ch_regex = "สะระแหน่"
name = "ใบสะระแหน่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบสะระแหน่ 5
# สะระแหน่ 2

# %%
ch_regex = "เส้นก๋วยจั๊บ"
name = "เส้นก๋วยจั๊บ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นก๋วยจั๊บ 5

# %%
ch_regex = "ผงฟู"
name = "ผงฟู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงฟู 5

# %%
print(sum([1 for i in all_facility_unique if i[2] == 0]))
for i in all_facility_unique:
    if i[2] == 0 and i[1] > 1:
        print(i[0],i[1])
# Out:
# 1669
# ผักสามสี 9
# สามเกลอ 5
# ฮอตดอก 5
# เนื้อสับ 4
# แป้ง 4
# olive oil 4
# เครื่องพะโล้ 4
# ซอสเย็นตาโฟ 4
# ผักต่างๆ 4
# ซอสเห็ด หอม 4
# เนื้อ 4
# ผงดาชิ 4
# ผงปาปริก้า 4
# ผักสด 4
# ข้าวไรซ์เบอร์รี่ 4
# ซีอิ๊วญี่ปุ่น 4
# น้ำจิ้มซีฟู้ด 4
# แตงร้าน 4
# มะเขือม่วง 4
# ซีอิ้ว 4
# ตังฉ่าย 4
# กระดูกอ่อน 4
# ปลาร้าต้มสุก 4
# ข้าวสุก 4
# โยเกิร์ตรสธรรมชาติ 4
# ซอสข้นปรุงรสคนอร์ 4
# แป้งข้าวเจ้า 4
# สาหร่าย 4
# หมี่ฮ่องกง 4
# เนื้อสัตว์ 4
# ปลาแซลมอน 4
# กระเพาะปลา 4
# ผักกะเฉด 4
# ผงขมิ้น 4
# พริกหนุ่ม 4
# ก้านพลู 4
# เส้นบุก 4
# ซอสภูเขา 4
# ขึ้นช่าย 4
# ผักแขนง 4
# นำ้มันหอย 4
# ดาชิ 4
# กะหล่ำดอก 4
# เครื่องในไก่ 4
# ยี่หร่าป่น 4
# เนื้อปลา 4
# โบโลน่า 4
# หัวปลี 4
# เนื้อวัว 4
# ครีม 4
# ปลาเค็ม 4
# ไวน์ขาว 4
# ดอกกระหล่ำ 4
# ปลาซาบะ 4
# แซลมอน 4
# ปลานิล 4
# กากหมู 4
# ยี่หร่า 4
# พริกซอย 4
# น้ำดื่ม 4
# เนื้อปลาแซลมอน 4
# พริกตำ 4
# แป้งเอนกประสงค์ 4
# แม๊กกี้ 4
# ปาปริก้า 4
# แป้งท้าวยายม่อม 4
# สี่อิ๋วดำสูตรเค็ม 3
# มะกะโรนีต้มสุก 3
# ถั่วหวาน 3
# หมี่กรอบ 3
# พริกทอด 3
# กระเทียวเจียว 3
# ตำลึง 3
# ซอสภูเขาทอง 3
# ซอสเพสโต้ 3
# เครื่องแกงเขียวหวาน 3
# Mozzarella cheese 3
# หนำเลี๊ยบ 3
# ซีอิ้วหวาน 3
# เครื่องปรุง 3
# เส้นเหลือง 3
# ข้าวเหนียว 3
# ซอลหอยนางรม 3
# กะหล่ำ 3
# กุ้ยช่าย 3
# ดอกหอม 3
# สัปปะรด 3
# เนื้อปลาดอลลี่ 3
# โซดา 3
# ไวไว 3
# ถั่วพู 3
# สี่อิ๋วหวาน 3
# เนื้อวัวสับ 3
# น้ำสต็อก 3
# เส้นแก้ว 3
# เครื่องต้มยำ 3
# ใบยี่หร่า 3
# เผือก 3
# ซอส 3
# เต้าเจี๊ยว 3
# ก้อนแกงกะหรี่ญี่ปุ่น 3
# โปรตีนเกษตร 3
# สี่อิ๋วดำสูตรหวาน 3
# ข้าวเสาไห้ 3
# แคร์รอต 3
# กุ่ยช่าย 3
# ผงปาปริกา 3
# ชีอิ้วขาว 3
# บ๊วยดอง 3
# ไชโป๊ว 3
# คื่นไช้ 3
# เต้าเจียว 3
# วิปครีม 3
# เนื้อบด 3
# แคปหมู 3
# ปลากรอบ 3
# พาร์สลีย์ 3
# แม็กกี้ 3
# บวบ 3
# ใบเตย 3
# ใบแมงลัก 3
# โหรพา 3
# ผักคอส 3
# คนอร์ซอสข้นปรุงรสหมู 3
# มะกะโรนี 3
# ปลาไข่ 3
# ซอสภูเขาฝาเขียว 3
# หมึก 3
# ซี้อิ้วขาว 3
# ผัดกาดขาว 3
# ใบเหลียง 3
# black pepper 3
# เบคกิ้งโซดา 3
# คื่นไฉ่ 3
# ซอสพิซซ่า 3
# salt 3
# เป็ดย่าง 3
# ข้าวบาสมาติ 3
# ข้าวไรซ์เบอร์รี่หุงสุก 3
# ถั่วป่น 3
# แป้งท้าว 3
# หมี่กึง 3
# วิปปิ้งครีม 3
# มะเขือ 3
# ปลาซุกิ 3
# ซีอี๊วขาว 2
# มะกรูด 2
# บล็อคโครี่ 2
# เส้น 2
# ถั่ว 2
# ไก่จ๊อ 2
# น้ำมะขาวเปียก 2
# ชีอิ๊วขาว 2
# เป็ด 2
# ซ้อสปรุงรส 2
# ถั่วแดง 2
# แผ่นเกี้ยว 2
# ปลาช่อนหั่น 2
# หมี่หยก 2
# Angel Hair 2
# น้ำซุบ 2
# ข้าวแช่เย็น 2
# แป้งพิซซ่าสำเร็จ 2
# เป็ดพะโล้ 2
# ผิวมะกรูด 2
# ซอสข้นคนอร์ 2
# พริกน้ำส้ม 2
# หมี่ขาว 2
# กระทิ 2
# พาสลี่ 2
# มาการีน 2
# แป้งสำหรับทอด 2
# ดอกไม้กวาด 2
# ผักกะหล่ำ 2
# italian seasoning 2
# ซีอิ้ว ดำ 2
# Red Pepper Flakes 2
# ซอสภูเขาทองฝาเขียว 2
# ซีอิ๋ว 2
# น้ำเลม่อน 2
# ไก่ไข่ 2
# หัวไชโป๊ว 2
# บล๊อกโคลี่ 2
# เครื่องยาจีน 2
# ข้าวโอ๊ต 2
# พริกสีแดง 2
# หอม 2
# น้ำโซดา 2
# หมี่เบตง 2
# ปลาทอด 2
# ไวไวรสหอยลายผัดฉ่า 2
# ซอสทงคัตสึ 2
# ซุปหมูก้อน 2
# pasta 2
# ดอกชมจันทร์ 2
# เยื่อไผ่ 2
# พาสลีย์ 2
# บรอคคอลลี่ 2
# กระเทียบ 2
# แป้งต็อก 2
# ซอลปรุงรส 2
# ใบกุ้ยฉ่าย 2
# แกงกะหรี่ 2
# ผง cumin 2
# ผง coriander 2
# เส้นมะกะโรนี 2
# มะกอกดำ 2
# เครื่องแกงใต้ 2
# เนื้อวัวบด 2
# เล้ง 2
# แมกกี้ 2
# ควินัวหุงสุก 2
# คีนัว 2
# ไชโป๊วสับ 2
# ใบชะพลู 2
# ผักตามชอบ 2
# ผงหมาล่า 2
# น้ำสำหรับต้มเส้น 2
# ปลาดอลลี่ 2
# มะกอก 2
# ใบยอ 2
# น้ำบูดู 2
# นํ้ามันหอย 2
# ไข่ปลาหมึก 2
# ซอสลุงหนวด 2
# ดีปลีผง 2
# บร็อคโคลี่ 2
# เครื่องเคียง 2
# สามชั้นสไลซ์ 2
# oregano 2
# ซอสผัดไทสำเร็จรูป 2
# เนื้อเป็ด 2
# ซีอิ๋วดำหวาน 2
# ผักที่ชอบ 2
# กระเพา 2
# ส่วนผสมซอส 2
# พริกหั่น 2
# เครื่องตุ๋นยาจีน 2
# เซี่ยงจี้ 2
# น้ำอ้อย 2
# ทาบาสโก เรดเปปเปอร์ซอส 2
# เพนเน่ 2
# ขมิ้น 2
# ดอกโสน 2
# เพสโตซอส 2
# พริกคั่ว 2
# สันคอ 2
# ซีอี๋วขาว 2
# ซอส XO 2
# ซุคคีนี 2
# น้ำจิ้ม กระเทียม 2
# หอมเเดง 2
# ยีสต์ 2
# ใบกุ่ยช่าย 2
# ข้าวหอม 2
# แป้งทอด 2
# ผักเครื่องเคียง 2
# สปาเกตตี 2
# น้ำอุ่น 2
# ผักขม 2
# ถั่วแขก 2
# ซีอี้วขาว 2
# หมึกกล้วย 2
# น้ำส้ม 2
# อกเป็ด 2
# พริก+กระเทียม 2
# ซอสแดง 2
# ใบบัวบก 2
# garlic 2
# parsley 2
# oil 2
# soy sauce 2
# ใบกระ เพรา แดง 2
# แป้งขนมปัง 2
# เส้น angel hair 2
# ส่วนผสมเครื่องปรุง 2
# โชวยุ 2
# ซ้อสมะเขือเทศ 2
# ซีรัป 2
# เส้นเพนเน่ 2
# chicken 2
# พาสลีย์สับ 2
# เส้นเฟตตูชินี 2
# ปลาแซลม่อน 2
# เส้นจันทน์ 2
# เครื่องแกง 2
# ไทม์ 2
# ใบเบย์ 2
# กระทียมสับ 2
# ซีอิ้วเด็กสมบูรณ์ 2
# ปลาแผ่น 2
# มันหมู 2
# โบโลน่าพริก 2
# สาหร่ายแผ่น 2
# Soba tsuyu 2
# น้ำสต้อค 2
# ขาไก่ 2
# น้ำซอสเย็นตาโฟ 2
# ซี๊อิ๋วดำหวาน 2
# พาสลีย์แห้ง 2
# แขนง 2
# ใบสาระแหน่ 2
# ปลาดุกย่าง 2
# ผงนัว 2
# หมี่ขาวไวไว 2
# ต้น 2
# ผงโรยข้าว 2
# แปะก๊วย 2
# แป้งเท้า 2
# วาซาบิ 2
# เนื้อปลาทับทิม 2
# หอมเล็กเจียว 2
# พริกหั่นเฉียง 2
# สาหร่ายแผ่นใหญ่ 2
# นำ้ตาลทราย 2
# ซอสข้นปรุงรสคนอร์ รสหมู 2
# หมี่ฮกเกี้ยน 2
# หอมซอย 2
# เส้นปลา 2
# เกี๊ยวปลา 2
# พริกสามสี 2
# ฟัก 2
# ตันหอม 2
# ยอดอ่อนทานตะวัน 2
# หญ้าหวาน 2
# ซอสมะเขือ 2
# สี่อิ๋วขาวสูตร 2
# แครท 2
# คนอร์ ซอสข้นปรุงรส 2
# ผงหม่าล่า 2
# เส้นแองเจิลแฮร์ 2
# เส้นเซี่ยงไฮ้ 2
# น้ำหวานดอกมะพร้าว 2
# ถั่วเน่า 2
# ต้นกระเทียม 2
# น้ำมะขาม 2
# เกร็ดขนมปัง 2
# เส้นโซบะ 2
# โยเกิร์ต 2
# เกลอ 2
# ถั่วผักยาว 2
# ปลาเส้น 2
# ถั่วแระญี่ปุ่น 2
# บวบเหลี่ยม 2
# น้ำจิ้มหมูหัน 2
# ซี่อิ๋วขาวสูตร1 2
# ถั่วคั่ว 2

# %%
d = {'Type_fcs': df_name, 'RegEx': df_ch_regex, 'Example':df_example}
df = pd.DataFrame(data=d)
# df.to_excel('FCS_RegEx.xlsx' ,index=False)
df
# Out:
#          Type_fcs                                     RegEx  \
# 0          น้ำปลา                             น้ำปลา(?!ร้า)
# 1        กระเทียม  ^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม
# 2          ไข่ไก่               ^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))
# 3          น้ำตาล                                    น้ำตาล
# 4           เกลือ                                     เกลือ
# ..            ...                                       ...
# 187      ปลากระพง                                  ปลากระพง
# 188       ไส้อั่ว                                   ไส้อั่ว
# 189    ใบสะระแหน่                                  สะระแหน่
# 190  เส้นก๋วยจั๊บ                              เส้นก๋วยจั๊บ
# 191          ผงฟู                                      ผงฟู
#
#                                                Example
# 0    น้ำปลา, น้ำปลาอย่างดี, น้ำปลาดี, น้ำปลาไส้ตัน,...
# 1    กระเทียม, กระเทียมสับ, กระเทียมเจียว, กระเทียม...
# 2    ไข่ไก่, ไข่, ไข่ต้ม, ไข่เค็ม, ไข่แดง, ไข่ขาว, ...
# 3    น้ำตาลทราย, น้ำตาล, น้ำตาลปี๊บ, น้ำตาลทรายแดง,...
# 4    เกลือ, เกลือป่น, เกลือเม็ด, เกลือชมพู, เกลือแก...
# ..                                                 ...
# 187                                           ปลากระพง
# 188                                            ไส้อั่ว
# 189                               ใบสะระแหน่, สะระแหน่
# 190                                       เส้นก๋วยจั๊บ
# 191                                               ผงฟู
#
# [192 rows x 3 columns]
