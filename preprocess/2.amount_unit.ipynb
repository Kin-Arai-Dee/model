# %%
import pandas as pd

df = pd.read_json('../data/clean_recipe_data_ugc.json')

# %%
import re
def remove_emojis(data):
    emoji = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoji, '', data)

# %%
import sys
from pathlib import Path

# in jupyter (lab / notebook), based on notebook path
module_path = str(Path.cwd().parents[0])

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from dictionary.title_dict import title_dict

# %%
old_df = df

# %%
import re
from dictionary.regex_util import clean_char_regex,space_regex

# %%
measure = {
  'กำมือ' : 28.35 ,
  # 'ฝา' : 40
  'ช.ต.' : 15,
  'ทัพพี' : 50 ,
  'ขีด' : 100 ,
  'ช้อนโต๊ะ' : 15 ,
  'กรีบ' : 6 ,
  'ถ้วยตวง' : 220 ,
  # 'เหง้า' : 5 ,
  'ช้อนช้า' : 5 ,
  'กิโลกรัม' : 1000 ,
  'ช้อนแกง' : 15,
  'ช้อนกินข้าว' : 10,
  'กระบวย' : 250,
  'ครึ่งลิตร' : 500,
  'ขวดน้ำ' : 500,
  'ออนซ์' : 28.4,
  # 'แก้ว' : 480,
  'มิลลิกรัม': 0.001,
  'ลิตร': 1000
}

min_unit = ['โรยหน้า','สำหรับลวกเส้น','little','ใบโรยหน้า']
avg_unit = ['แล้วแต่ปริมาณ','ขนาดชอบ','ตามใจชอบ', 'ตามสมควร','ตามความพอใจ','ตามใจ']

# %%
def clean_text(text):
    cleaned_text = re.sub(r'[^\w\s\-\.\,\(\)\{\}\[\]\/\+\u0E00-\u0E7F]+|_', ' ', text)
    cleaned_text = re.sub(space_regex, ' ', cleaned_text)
    return cleaned_text

# %%
def remove_text_to_unit(input_string):
    cleaned_text = clean_text(input_string)
    return cleaned_text

# %%
df['amounts'] = df['ingredients'].apply(lambda ingredients : [(clean_text(ingredient['ingredientName']),clean_text(ingredient['amount'])) for ingredient in ingredients])

# %%
from dictionary.fraction_mapper import fraction_mapper

# %%
df[['amounts']].sample(10)
# Out:
#                                                 amounts
# 3268  [(เนื้อหมูสไลซ์, 200 กรัม), (กะหล่ำปลีหั่น, 10...
# 2345  [(แกงกะหรี่ก้อน Daiso, 4 ก้อน), (เนื้อหมู หรือ...
# 1252  [(หมูสับ, 250 กรัม), (พริกแกงใต้, 1 ช้อนโต๊ะ),...
# 1428  [(ปลาทูสด, 4ตัว), (พริกแกงส้ม, 2ช้อนโต๊ะ), (น้...
# 3532  [(หมี่ฮ่องกง, 150 กรัม), (น้ำพริกหมูหยอง, 3 ช้...
# 2582  [(กระเพาะปลา, 3 ขีด), (โครงไก่, 1 โครง), (ปีกบ...
# 1927  [(หมูเด้ง, 400ก.), (กุ้ง, ครึ่งโล), (กระเทียม,...
# 280   [(เนื้อปูนึ่งแกะ, ปริมาณตามชอบ), (ไข่ไก่, 2 ฟอ...
# 195   [(เส้นเซี่ยงไฮ้แบบตัด, 1ห่อ), (สันนอกสไลด์, 1แ...
# 3008  [(หมูบด, 500 กรัม), (น้ำตาลทราย, 2-3 ช้อนชา), ...

# %%
df['is_has_amoungs'] = df['ingredients'].apply(lambda ingredients: len([x['amount'] for x in ingredients if x['amount']])/len(ingredients))

# %%
df
# Out:
#                                               title  \
# 0                        ผัดโหระพาไก่สับเป็ดสับคีโต
# 1                                         กุ้งอบเนย
# 2                        สปาเกตตี ผัดปลาหมึกไข่เค็ม
# 3                              มาม่าผัดขี้เมากุ้ง 🦐
# 4     แกงกะหรี่ญี่ปุ่น\n{แกงกระหรี่สูตรHoney Apple}
# ...                                             ...
# 4502                               ไข่เจียววุ้นเส้น
# 4503                             พริกหยวกผัดพริกเผา
# 4504                           สเต็กแซลมอนพริกไทยดำ
# 4505                      ผัดเผ็ดปลาดุก น้ำขลุกขลิก
# 4506                      ผัดวุ้นเส้นกระเพราหมูกรอบ
#
#                                                url  allTimeScore  view  \
# 0     recipes/ugc/0f3a82d664274df380f802495e5c0d8c           750   680
# 1     recipes/ugc/d19b99c83bbf49bf89c2d31279c5ce28          1188   948
# 2     recipes/ugc/1398926e639148469a2326af3e14918a           751   641
# 3     recipes/ugc/f8791e4d0eb0413dbb020a6c5a0da392           749   739
# 4     recipes/ugc/f7da2ced90b3489080046a932f3f3a14          3382  3332
# ...                                            ...           ...   ...
# 4502  recipes/ugc/06ff7cbecffa46e88656c1938bf250a8           361   221
# 4503  recipes/ugc/f2097cc5a9494fdea2f0d06b3e0e53a1          1862  1782
# 4504  recipes/ugc/628c5edecc2142a98dc27d3f09fef7f4          6851  6751
# 4505  recipes/ugc/9944eda2954540a4b55251e5af26d3cd          3731  3691
# 4506  recipes/ugc/273249a7881248359acd7e8b7fabbe64          1939  1939
#
#       totalLike                                             photos  \
# 0             1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 1             4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 3             1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# ...         ...                                                ...
# 4502          2  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4503          2  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4504          7  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4505          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4506          0  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 0     [{'ingredientName': 'ไก่สับเป็ดสับต้มแล้ว', 'a...
# 1     [{'ingredientName': 'กุ้งขาวใหญ่', 'amount': '...
# 2     [{'ingredientName': 'เส้นสปาเกตตี(แห้ง)', 'amo...
# 3     [{'ingredientName': 'บะหมี่กึ่งสำเร็จรูป', 'am...
# 4     [{'ingredientName': 'น้ำสะอาด', 'amount': '1.2...
# ...                                                 ...
# 4502  [{'ingredientName': 'ไข่ไก่', 'amount': '2 ฟอง...
# 4503  [{'ingredientName': 'สันคอหมูสไลด์', 'amount':...
# 4504  [{'ingredientName': 'แซลมอน', 'amount': '2 ชิ้...
# 4505  [{'ingredientName': 'ปลาดุกหั่นเป็นชิ้น', 'amo...
# 4506  [{'ingredientName': 'วุ้นเส้น', 'amount': '1 ซ...
#
#                                                    tags  \
# 0     [{'externalId': 'chicken-recipes', 'primaryNam...
# 1     [{'externalId': 'main-dish-recipes', 'primaryN...
# 2     [{'externalId': 'main-dish-recipes', 'primaryN...
# 3     [{'externalId': 'noodle-recipes', 'primaryName...
# 4     [{'externalId': 'main-dish-recipes', 'primaryN...
# ...                                                 ...
# 4502  [{'externalId': 'egg-recipes', 'primaryName': ...
# 4503  [{'externalId': 'pork-recipes', 'primaryName':...
# 4504  [{'externalId': 'egg-recipes', 'primaryName': ...
# 4505  [{'externalId': 'fish-recipes', 'primaryName':...
# 4506  [{'externalId': 'pork-recipes', 'primaryName':...
#
#                                                 amounts  is_has_amoungs
# 0     [(ไก่สับเป็ดสับต้มแล้ว, ), (น้ำปลาเมกกาเซฟ(คีโ...        0.857143
# 1     [(กุ้งขาวใหญ่, 1/2 kg (10 ตัว)), (เกลือ, 1 ช้อ...        1.000000
# 2     [(เส้นสปาเกตตี(แห้ง), 60 กรัม), (หมึกสด, 70 กร...        1.000000
# 3     [(บะหมี่กึ่งสำเร็จรูป, 2 ห่อ), (กุ้ง, 300 กรัม...        1.000000
# 4     [(น้ำสะอาด, 1.25ลิตร), (เกลือป่น, 1/2ช้อนชา), ...        1.000000
# ...                                                 ...             ...
# 4502  [(ไข่ไก่, 2 ฟอง), (วุ้นเส้น, ), (ถั่วฟักยาว, )...        0.200000
# 4503  [(สันคอหมูสไลด์, 100 กรัม), (พริกหยวก, 1 ถ้วย)...        1.000000
# 4504  [(แซลมอน, 2 ชิ้น), (ซอสพริกไทยดำ, ตามชอบ), (เน...        1.000000
# 4505  [(ปลาดุกหั่นเป็นชิ้น, 400 กรัม), (พริกแกงแดง, ...        1.000000
# 4506  [(วุ้นเส้น, 1 ซองเล็ก), (หมูกรอบ, 1 ถ้วย), (ใบ...        1.000000
#
# [4507 rows x 10 columns]

# %%
df = df[df['is_has_amoungs'] > 0.5]

# %%
df[['is_has_amoungs']].sample(20)
# Out:
#       is_has_amoungs
# 2955        1.000000
# 2028        1.000000
# 2951        1.000000
# 2219        0.944444
# 755         1.000000
# 204         1.000000
# 1381        1.000000
# 3279        1.000000
# 3462        1.000000
# 3578        0.833333
# 2093        1.000000
# 2479        1.000000
# 4192        1.000000
# 747         1.000000
# 1880        1.000000
# 470         1.000000
# 2544        1.000000
# 4112        0.800000
# 1002        1.000000
# 1526        1.000000

# %%
df
# Out:
#                                               title  \
# 0                        ผัดโหระพาไก่สับเป็ดสับคีโต
# 1                                         กุ้งอบเนย
# 2                        สปาเกตตี ผัดปลาหมึกไข่เค็ม
# 3                              มาม่าผัดขี้เมากุ้ง 🦐
# 4     แกงกะหรี่ญี่ปุ่น\n{แกงกระหรี่สูตรHoney Apple}
# ...                                             ...
# 4501                          ข้าวหน้าไก่เทอริยากิ🐓
# 4503                             พริกหยวกผัดพริกเผา
# 4504                           สเต็กแซลมอนพริกไทยดำ
# 4505                      ผัดเผ็ดปลาดุก น้ำขลุกขลิก
# 4506                      ผัดวุ้นเส้นกระเพราหมูกรอบ
#
#                                                url  allTimeScore  view  \
# 0     recipes/ugc/0f3a82d664274df380f802495e5c0d8c           750   680
# 1     recipes/ugc/d19b99c83bbf49bf89c2d31279c5ce28          1188   948
# 2     recipes/ugc/1398926e639148469a2326af3e14918a           751   641
# 3     recipes/ugc/f8791e4d0eb0413dbb020a6c5a0da392           749   739
# 4     recipes/ugc/f7da2ced90b3489080046a932f3f3a14          3382  3332
# ...                                            ...           ...   ...
# 4501  recipes/ugc/eca41e6df856429ca99289229fe0ec7a           884   874
# 4503  recipes/ugc/f2097cc5a9494fdea2f0d06b3e0e53a1          1862  1782
# 4504  recipes/ugc/628c5edecc2142a98dc27d3f09fef7f4          6851  6751
# 4505  recipes/ugc/9944eda2954540a4b55251e5af26d3cd          3731  3691
# 4506  recipes/ugc/273249a7881248359acd7e8b7fabbe64          1939  1939
#
#       totalLike                                             photos  \
# 0             1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 1             4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 3             1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# ...         ...                                                ...
# 4501          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4503          2  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4504          7  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4505          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4506          0  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 0     [{'ingredientName': 'ไก่สับเป็ดสับต้มแล้ว', 'a...
# 1     [{'ingredientName': 'กุ้งขาวใหญ่', 'amount': '...
# 2     [{'ingredientName': 'เส้นสปาเกตตี(แห้ง)', 'amo...
# 3     [{'ingredientName': 'บะหมี่กึ่งสำเร็จรูป', 'am...
# 4     [{'ingredientName': 'น้ำสะอาด', 'amount': '1.2...
# ...                                                 ...
# 4501  [{'ingredientName': 'เนื้อไก่', 'amount': '100...
# 4503  [{'ingredientName': 'สันคอหมูสไลด์', 'amount':...
# 4504  [{'ingredientName': 'แซลมอน', 'amount': '2 ชิ้...
# 4505  [{'ingredientName': 'ปลาดุกหั่นเป็นชิ้น', 'amo...
# 4506  [{'ingredientName': 'วุ้นเส้น', 'amount': '1 ซ...
#
#                                                    tags  \
# 0     [{'externalId': 'chicken-recipes', 'primaryNam...
# 1     [{'externalId': 'main-dish-recipes', 'primaryN...
# 2     [{'externalId': 'main-dish-recipes', 'primaryN...
# 3     [{'externalId': 'noodle-recipes', 'primaryName...
# 4     [{'externalId': 'main-dish-recipes', 'primaryN...
# ...                                                 ...
# 4501  [{'externalId': 'chicken-recipes', 'primaryNam...
# 4503  [{'externalId': 'pork-recipes', 'primaryName':...
# 4504  [{'externalId': 'egg-recipes', 'primaryName': ...
# 4505  [{'externalId': 'fish-recipes', 'primaryName':...
# 4506  [{'externalId': 'pork-recipes', 'primaryName':...
#
#                                                 amounts  is_has_amoungs
# 0     [(ไก่สับเป็ดสับต้มแล้ว, ), (น้ำปลาเมกกาเซฟ(คีโ...        0.857143
# 1     [(กุ้งขาวใหญ่, 1/2 kg (10 ตัว)), (เกลือ, 1 ช้อ...        1.000000
# 2     [(เส้นสปาเกตตี(แห้ง), 60 กรัม), (หมึกสด, 70 กร...        1.000000
# 3     [(บะหมี่กึ่งสำเร็จรูป, 2 ห่อ), (กุ้ง, 300 กรัม...        1.000000
# 4     [(น้ำสะอาด, 1.25ลิตร), (เกลือป่น, 1/2ช้อนชา), ...        1.000000
# ...                                                 ...             ...
# 4501  [(เนื้อไก่, 100กรัม), (หัวหอม, 1/2ลูก), (กะหล่...        1.000000
# 4503  [(สันคอหมูสไลด์, 100 กรัม), (พริกหยวก, 1 ถ้วย)...        1.000000
# 4504  [(แซลมอน, 2 ชิ้น), (ซอสพริกไทยดำ, ตามชอบ), (เน...        1.000000
# 4505  [(ปลาดุกหั่นเป็นชิ้น, 400 กรัม), (พริกแกงแดง, ...        1.000000
# 4506  [(วุ้นเส้น, 1 ซองเล็ก), (หมูกรอบ, 1 ถ้วย), (ใบ...        1.000000
#
# [3742 rows x 10 columns]

# %%
from pandas import json_normalize

df_normalized = json_normalize(df.sample()['ingredients'].tolist()[0])

df_normalized
# Out:
#    ingredientName        amount
# 0      Smoked Ham        2 แผ่น
# 1        ไข่ไก่สด         2 ฟอง
# 2       ซีอิ๊วขาว    1 ช้อนโต๊ะ
# 3        นมข้นจืด    1 ช้อนโต๊ะ
# 4       น้ำมันพืช  1-2 ช้อนโต๊ะ
# 5  ข้าวสวยหอมมะลิ         1 จาน

# %%
not_match = []
# map title to dict
def map_title_dictionary(title):
  title = remove_emojis(title)
  title = title.strip()
  if title in title_dict:
    return title_dict[title]
  else:
    not_match.append('title')
    # print('not_match:',title)
    return None

# %%
df['title2'] = df['title'].apply(map_title_dictionary)
# Out:
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_69055/620666365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['title2'] = df['title'].apply(map_title_dictionary)

# %%
df = df[df['title2'].notnull()]

# %%
df
# Out:
#                                               title  \
# 0                        ผัดโหระพาไก่สับเป็ดสับคีโต
# 1                                         กุ้งอบเนย
# 2                        สปาเกตตี ผัดปลาหมึกไข่เค็ม
# 3                              มาม่าผัดขี้เมากุ้ง 🦐
# 4     แกงกะหรี่ญี่ปุ่น\n{แกงกระหรี่สูตรHoney Apple}
# ...                                             ...
# 4501                          ข้าวหน้าไก่เทอริยากิ🐓
# 4503                             พริกหยวกผัดพริกเผา
# 4504                           สเต็กแซลมอนพริกไทยดำ
# 4505                      ผัดเผ็ดปลาดุก น้ำขลุกขลิก
# 4506                      ผัดวุ้นเส้นกระเพราหมูกรอบ
#
#                                                url  allTimeScore  view  \
# 0     recipes/ugc/0f3a82d664274df380f802495e5c0d8c           750   680
# 1     recipes/ugc/d19b99c83bbf49bf89c2d31279c5ce28          1188   948
# 2     recipes/ugc/1398926e639148469a2326af3e14918a           751   641
# 3     recipes/ugc/f8791e4d0eb0413dbb020a6c5a0da392           749   739
# 4     recipes/ugc/f7da2ced90b3489080046a932f3f3a14          3382  3332
# ...                                            ...           ...   ...
# 4501  recipes/ugc/eca41e6df856429ca99289229fe0ec7a           884   874
# 4503  recipes/ugc/f2097cc5a9494fdea2f0d06b3e0e53a1          1862  1782
# 4504  recipes/ugc/628c5edecc2142a98dc27d3f09fef7f4          6851  6751
# 4505  recipes/ugc/9944eda2954540a4b55251e5af26d3cd          3731  3691
# 4506  recipes/ugc/273249a7881248359acd7e8b7fabbe64          1939  1939
#
#       totalLike                                             photos  \
# 0             1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 1             4  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 3             1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4             5  [{'contentUrl': 'https://img.wongnai.com/p/196...
# ...         ...                                                ...
# 4501          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4503          2  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4504          7  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4505          1  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4506          0  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 0     [{'ingredientName': 'ไก่สับเป็ดสับต้มแล้ว', 'a...
# 1     [{'ingredientName': 'กุ้งขาวใหญ่', 'amount': '...
# 2     [{'ingredientName': 'เส้นสปาเกตตี(แห้ง)', 'amo...
# 3     [{'ingredientName': 'บะหมี่กึ่งสำเร็จรูป', 'am...
# 4     [{'ingredientName': 'น้ำสะอาด', 'amount': '1.2...
# ...                                                 ...
# 4501  [{'ingredientName': 'เนื้อไก่', 'amount': '100...
# 4503  [{'ingredientName': 'สันคอหมูสไลด์', 'amount':...
# 4504  [{'ingredientName': 'แซลมอน', 'amount': '2 ชิ้...
# 4505  [{'ingredientName': 'ปลาดุกหั่นเป็นชิ้น', 'amo...
# 4506  [{'ingredientName': 'วุ้นเส้น', 'amount': '1 ซ...
#
#                                                    tags  \
# 0     [{'externalId': 'chicken-recipes', 'primaryNam...
# 1     [{'externalId': 'main-dish-recipes', 'primaryN...
# 2     [{'externalId': 'main-dish-recipes', 'primaryN...
# 3     [{'externalId': 'noodle-recipes', 'primaryName...
# 4     [{'externalId': 'main-dish-recipes', 'primaryN...
# ...                                                 ...
# 4501  [{'externalId': 'chicken-recipes', 'primaryNam...
# 4503  [{'externalId': 'pork-recipes', 'primaryName':...
# 4504  [{'externalId': 'egg-recipes', 'primaryName': ...
# 4505  [{'externalId': 'fish-recipes', 'primaryName':...
# 4506  [{'externalId': 'pork-recipes', 'primaryName':...
#
#                                                 amounts  is_has_amoungs  \
# 0     [(ไก่สับเป็ดสับต้มแล้ว, ), (น้ำปลาเมกกาเซฟ(คีโ...        0.857143
# 1     [(กุ้งขาวใหญ่, 1/2 kg (10 ตัว)), (เกลือ, 1 ช้อ...        1.000000
# 2     [(เส้นสปาเกตตี(แห้ง), 60 กรัม), (หมึกสด, 70 กร...        1.000000
# 3     [(บะหมี่กึ่งสำเร็จรูป, 2 ห่อ), (กุ้ง, 300 กรัม...        1.000000
# 4     [(น้ำสะอาด, 1.25ลิตร), (เกลือป่น, 1/2ช้อนชา), ...        1.000000
# ...                                                 ...             ...
# 4501  [(เนื้อไก่, 100กรัม), (หัวหอม, 1/2ลูก), (กะหล่...        1.000000
# 4503  [(สันคอหมูสไลด์, 100 กรัม), (พริกหยวก, 1 ถ้วย)...        1.000000
# 4504  [(แซลมอน, 2 ชิ้น), (ซอสพริกไทยดำ, ตามชอบ), (เน...        1.000000
# 4505  [(ปลาดุกหั่นเป็นชิ้น, 400 กรัม), (พริกแกงแดง, ...        1.000000
# 4506  [(วุ้นเส้น, 1 ซองเล็ก), (หมูกรอบ, 1 ถ้วย), (ใบ...        1.000000
#
#                          title2
# 0        ผัดโหระพาไก่สับเป็ดสับ
# 1                     กุ้งอบเนย
# 2        สปาเกตตีปลาหมึกไข่เค็ม
# 3            มาม่าผัดขี้เมากุ้ง
# 4              แกงกะหรี่ญี่ปุ่น
# ...                         ...
# 4501       ข้าวหน้าไก่เทอริยากิ
# 4503         พริกหยวกผัดพริกเผา
# 4504       สเต็กแซลมอนพริกไทยดำ
# 4505              ผัดเผ็ดปลาดุก
# 4506  ผัดวุ้นเส้นกระเพราหมูกรอบ
#
# [3623 rows x 11 columns]

# %%
len(not_match)
# Out:
# 119

# %%
df['title'] = df.pop('title2')
# Out:
# /var/folders/y4/ns3s970s7vdc16tn3zs1l6km0000gp/T/ipykernel_69055/2276603009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['title'] = df.pop('title2')

# %%
df = df.sort_values(by='is_has_amoungs', ascending=False)

df = df.drop_duplicates(subset='title', keep='first')

# %%
df
# Out:
#                           title                                           url  \
# 4506  ผัดวุ้นเส้นกระเพราหมูกรอบ  recipes/ugc/273249a7881248359acd7e8b7fabbe64
# 4060               ไข่ตุ๋นมาม่า  recipes/ugc/d2ca1bdc515a4d6990bee805f217c279
# 2506    เกี่ยมอี๋คั่วไส้หมูก้อน  recipes/ugc/ffbd2984f00a4836a5b19814d0aeee49
# 2507    ออรินจิคั่วเกลือพริกไทย  recipes/ugc/66e7abffe91a43b5a454876653c9af76
# 2508        กระหล่ำปลีทอดน้ำปลา  recipes/ugc/f0e49ced084447ecaac336fb91115718
# ...                         ...                                           ...
# 2878         สุกี้น้ำกระดูกอ่อน  recipes/ugc/7087159c34eb492591df3bb39fb2ebbc
# 784               ผัดผักรวมมิตร  recipes/ugc/5887aa72057e40f7b22192d89e8bb19f
# 3237              ผัดมาม่าต้มยำ  recipes/ugc/b30648906cb84cc3bb3495ca75b895b8
# 2240       สปาเก็ตตี้ขี้เมาเห็ด  recipes/ugc/95804aa0dfc440be89af3c59ac8992f3
# 1289       เบอร์เกอร์หมูชุ่มฉ่ำ  recipes/ugc/ea691bb354014bde9a0ead45d78b3a86
#
#       allTimeScore   view  totalLike  \
# 4506          1939   1939          0
# 4060          1519   1179          5
# 2506           946    826          6
# 2507          1862   1792          4
# 2508          1365   1305          3
# ...            ...    ...        ...
# 2878           628    398          8
# 784            987    947          1
# 3237           397    377          2
# 2240           877    817          6
# 1289         99441  99191         10
#
#                                                  photos  \
# 4506  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 4060  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2506  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2507  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2508  [{'contentUrl': 'https://img.wongnai.com/p/196...
# ...                                                 ...
# 2878  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 784   [{'contentUrl': 'https://img.wongnai.com/p/196...
# 3237  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 2240  [{'contentUrl': 'https://img.wongnai.com/p/196...
# 1289  [{'contentUrl': 'https://img.wongnai.com/p/196...
#
#                                             ingredients  \
# 4506  [{'ingredientName': 'วุ้นเส้น', 'amount': '1 ซ...
# 4060  [{'ingredientName': 'ไข่ไก่', 'amount': '2ฟอง'...
# 2506  [{'ingredientName': 'เกี่ยมอี๋ลวก', 'amount': ...
# 2507  [{'ingredientName': 'เห็ดออรินจิ', 'amount': '...
# 2508  [{'ingredientName': 'กระหล่ำปลี', 'amount': '1...
# ...                                                 ...
# 2878  [{'ingredientName': 'กระดูกอ่อน', 'amount': '1...
# 784   [{'ingredientName': 'กะหล่ำดอก', 'amount': '1 ...
# 3237  [{'ingredientName': 'กุ้งขาวปอกเปลือก', 'amoun...
# 2240  [{'ingredientName': 'สปาเก็ตตี้', 'amount': '2...
# 1289  [{'ingredientName': 'เนื้อหมูบด', 'amount': '4...
#
#                                                    tags  \
# 4506  [{'externalId': 'pork-recipes', 'primaryName':...
# 4060  [{'externalId': 'egg-recipes', 'primaryName': ...
# 2506  [{'externalId': 'main-dish-recipes', 'primaryN...
# 2507  [{'externalId': 'chicken-recipes', 'primaryNam...
# 2508  [{'externalId': 'vegetable-recipes', 'primaryN...
# ...                                                 ...
# 2878  [{'externalId': 'vegetable-recipes', 'primaryN...
# 784   [{'externalId': 'vegetable-recipes', 'primaryN...
# 3237  [{'externalId': 'noodle-recipes', 'primaryName...
# 2240  [{'externalId': 'main-dish-recipes', 'primaryN...
# 1289  [{'externalId': 'pork-recipes', 'primaryName':...
#
#                                                 amounts  is_has_amoungs
# 4506  [(วุ้นเส้น, 1 ซองเล็ก), (หมูกรอบ, 1 ถ้วย), (ใบ...        1.000000
# 4060  [(ไข่ไก่, 2ฟอง), (บะหมี่กึ่งสำเร็จรูป ลวกสุก, ...        1.000000
# 2506  [(เกี่ยมอี๋ลวก, 1ถ้วย), (ไส้ต้มเปื่อย, 10ชิ้น)...        1.000000
# 2507  [(เห็ดออรินจิ, 3 ขีด), (เนื้ออกไก่, 2 ขีด), (เ...        1.000000
# 2508  [(กระหล่ำปลี, 10 ใบ), (น้ำปลา, 2 ชต ), (กระเที...        1.000000
# ...                                                 ...             ...
# 2878  [(กระดูกอ่อน, 1/2 กิโลกรัม), (ผักบุ้ง, 1 กำ), ...        0.545455
# 784   [(กะหล่ำดอก, 1 หัวเล็ก), (ข้าวโพดอ่อน, 5-6 ฝัก...        0.538462
# 3237  [(กุ้งขาวปอกเปลือก, 6 ตัว), (ไข่ไก่, 1 ฟอง), (...        0.538462
# 2240  [(สปาเก็ตตี้, 2 kg), (เห็ดเข็มทอง, 1.5 kg), (เ...        0.533333
# 1289  [(เนื้อหมูบด, 400g), (หอมหัวใหญ่สับเกือบละเอีย...        0.533333
#
# [2787 rows x 10 columns]

# %%
df[['title','ingredients']]
# Out:
#                           title  \
# 4506  ผัดวุ้นเส้นกระเพราหมูกรอบ
# 4060               ไข่ตุ๋นมาม่า
# 2506    เกี่ยมอี๋คั่วไส้หมูก้อน
# 2507    ออรินจิคั่วเกลือพริกไทย
# 2508        กระหล่ำปลีทอดน้ำปลา
# ...                         ...
# 2878         สุกี้น้ำกระดูกอ่อน
# 784               ผัดผักรวมมิตร
# 3237              ผัดมาม่าต้มยำ
# 2240       สปาเก็ตตี้ขี้เมาเห็ด
# 1289       เบอร์เกอร์หมูชุ่มฉ่ำ
#
#                                             ingredients
# 4506  [{'ingredientName': 'วุ้นเส้น', 'amount': '1 ซ...
# 4060  [{'ingredientName': 'ไข่ไก่', 'amount': '2ฟอง'...
# 2506  [{'ingredientName': 'เกี่ยมอี๋ลวก', 'amount': ...
# 2507  [{'ingredientName': 'เห็ดออรินจิ', 'amount': '...
# 2508  [{'ingredientName': 'กระหล่ำปลี', 'amount': '1...
# ...                                                 ...
# 2878  [{'ingredientName': 'กระดูกอ่อน', 'amount': '1...
# 784   [{'ingredientName': 'กะหล่ำดอก', 'amount': '1 ...
# 3237  [{'ingredientName': 'กุ้งขาวปอกเปลือก', 'amoun...
# 2240  [{'ingredientName': 'สปาเก็ตตี้', 'amount': '2...
# 1289  [{'ingredientName': 'เนื้อหมูบด', 'amount': '4...
#
# [2787 rows x 2 columns]

# %%
with open('../dictionary/select_output.txt', 'r') as file:
  ans = [int(line.split()[-1])-1 for line in file.readlines()]

# %%
# ans

# %%
c = 0

def split_string_by_word(s,pattern):
    global c
    # Split by "หรือ" or any substring inside parentheses
    parts = re.split(pattern, s)
    # Remove any empty parts and strip whitespace
    selector = [part.strip() for part in parts if part]
    if not selector:
      return ''
    # if len(tmp_ans) < c:
    #   print(selector)
    #   c+=1
    #   return selector[tmp_ans[c]]
    elif len(selector)> 1:
      pass
      select = ans[c]
      print(s, '|',selector, '|',selector[select])
      c+=1
      return selector[select]
    return selector[0]

# %%
def remove_leading_zeros(s: str):
    parts = s.split('.')
    if len(parts) == 2:
        left, right = parts
        if left == '0':
            left = ''
        return f"{left}.{right}"
    else:
        return s.lstrip('0') or '0'

# %%
def replace_amount_word(s: str):
    s = s.replace('ครึ่ง','.5')
    s = s.replace('ส่วน','/')
    s = s.replace('ใน','/')
    s = s.replace('X','*')
    s = s.replace('x','*')
    s = s.replace('ถึง','-')
    s = s.replace('0้อนโต๊ะ','ช้อนโต๊ะ')
    s = s.replace('ประมาณ','')
    s = s.replace('12. ข้าวสวย 150-200 กรัม','150-200 กรัม')
    s = s.replace('2-3 ต้น / 2-3 ช้อนโต๊ะ','2-3 ช้อนโต๊ะ')
    s = split_string_by_word(s,r'หรือ|\(|\)')
    return s

# %%
def split_name_by_word(s,p):
  origin = s
  # for m in measure.keys():
  #   if m in s:
  #     print(s,p)
  
  # for m in (min_unit+avg_unit):
  #   if m in s:
  #     is_p_not_in = True
  #     for m in measure.keys():
  #       if m in measure.keys():
  #          is_p_not_in = False
  #     if is_p_not_in:
  #       print(s,p)
  s = re.split(r'ประมาณ|\(|\)', s)
  s = [part.strip() for part in s if part]
  # if not p:
  #   print(origin,s,'ไม่มีหน่วย')
  if not s: return 1
  elif len(s) > 1:
    if p:
      print(origin,s,p)
    return ''.join(s)
  return ''.join(s)

# %%
from dictionary.ingredient_map import ingredient_map

# %%
def replace_name_word(s: str,p):
    if s  == 'กระเทียมกรีบ':
        return ('กระเทียม','1 กรีบ')
    if s.startswith('Lobster 0.7-1kg'):
        return ('Lobster','0.7-1kg')
    if s  == 'ปูเนื้อ (ตัวนี้หนักประมาณ 7 ขีด) 1 ตัว':
        return ('ปูเนื้อ','ขึด')
    if s == 'เนื้อปลาอินทรีย์หนักประมาณ 2 ขีด':
        return ('เนื้อปลาอินทรีย์','2 ขึด')
    if s == 'คอหมูย่าง ประมาณ 4 ขีด':
        return ('คอหมูย่าง','4 ขึด')
    if s == '(บะหมี่กึ่งสำเร็จรูปของอะไรก็ได้)':
        return ('คอหมูย่าง','4 ขึด')
    if s == '(ส่วนผสมปรุงผักโขม คันจังหรือซอสถั่วเหลือง 1 ช้อนชา+น้ำมันงา 1 ช้อนชา)':
        return ('ซอสถั่วเหลือง+น้ำมันงา','2 ช้อนชา')
    if s == 'วุ้นเส้น 80 กรัม':
        return ('วุ้นเส้น','160 กรัม')

    s = re.sub(r"^\d+[.)|\s]*",'',s)
    s = re.sub(r'\(([^)]+)\)','',s)
    s = split_name_by_word(s,p)

    if s in ingredient_map:
        return ingredient_map[s]
    return s, None

# %%
# replace_name_word('1. ไอซ์ 2 กรัม 💰','')
replace_name_word('1). แหนม ','')
# Out:
# ('แหนม', None)

# %%
def recur_change_to_number(number_list):
  if not number_list:
    return 0
  if '-' in number_list:
    dash_index = number_list.index('-')
    return (recur_change_to_number(number_list[:dash_index]) + recur_change_to_number(number_list[dash_index+1:]))/2
  number_list2 = []
  for num in number_list:
    try:
      number_list2.append(remove_leading_zeros(str(eval(num))))
    except:
      number_list2.append(num.strip())
  try:
    return eval(''.join(number_list2))
  except:
    # print(number_list2)


    if '+' == number_list2[-1]:
      recur_change_to_number(number_list2[:-1])
    else:
      # print('+'.join(number_list2))
      return eval('+'.join(number_list2))

# recur_change_to_number(['1','1/2'])

# %%
def amount_value(number_matchs):
  original = number_matchs
  for i, match_str in enumerate(number_matchs):
    new_value = ''
    for match in match_str:
      if match in fraction_mapper:
        new_value += fraction_mapper[match]
      else:
        new_value += match
    number_matchs[i] = new_value.strip()

  value =  recur_change_to_number(number_matchs)
  printf = False
  if len(original) > 1 and ('+' not in original and '-' not in original) :
    # print(original, value)
    printf = True
  return value, printf

# amount_value(['1','+','¼','+','1+⅞','-','1⅞','+','⅞'])
# amount_value(['.0','.5'])

# %%
count = 0
c = 0

p_list = []
def split_size_generater(ingredient):
  global count 
  global p_list
   
  sizes = []

  p_it = False

  for x in ingredient:
    name, amount = x

    if type(name) != str:
      print('--------------',name,'------------')
    name, new_amount = replace_name_word(name,amount)
    if type(name) != str:
      print(x,'+++++++++++',name,'++++++++')

    # fraction_regex = re.findall(r'[\u00BC-\u00BE\u2150-\u215E]+',x)
    if new_amount:
      amount = new_amount
    amount = amount.replace('\u200b','')
    amount = replace_amount_word(amount)

    
    number_matchs = re.findall(r'((?:[\d\u00BC-\u00BE\u2150-\u215E]+(?:\.\d+)?(?:\s*[\/]\s*\d+)?[\u00BC-\u00BE\u2150-\u215E]*)|(?:[\+\-\*])|(?:\.\d+))',amount)
    # if len(matchs) > 1:
    units = re.sub(r'((?:[\d\u00BC-\u00BE\u2150-\u215E]+(?:\.\d+)?(?:\s*[\/]\s*\d+)?[\u00BC-\u00BE\u2150-\u215E]*)|(?:[\+\-\*])|(?:\.\d+))','',amount).strip()

    value, p = amount_value(number_matchs)

    if p: 
      p_it = p
    # if(len(number_matchs)>2):
    #   print(count, ':', value, "|",x)
    sizes.append((name,value,units))

  count += 1
  if(p_it):
    p_list.append(count)
  # print(sizes)

  return sizes

# %%
count = 0
c = 0
df['amounts_split_size'] = df['amounts'].apply(split_size_generater)

# df[['amounts','amounts_split_size']]
# Out:
# 1 กระป๋อง (หรือ400กรัม) | ['1 กระป๋อง', '400กรัม'] | 400กรัม
# 5-10 เม็ด(แล้วแค่ความชอบ) | ['5-10 เม็ด', 'แล้วแค่ความชอบ'] | 5-10 เม็ด
# 1/3 แพ็ค (50กรัม) | ['1/3 แพ็ค', '50กรัม'] | 50กรัม
# 1 หัว (130กรัม) | ['1 หัว', '130กรัม'] | 130กรัม
# 1/2 หัว (36กรัม) | ['1/2 หัว', '36กรัม'] | 36กรัม
# 1 ถ้วย (240มิลลิลิตร) | ['1 ถ้วย', '240มิลลิลิตร'] | 240มิลลิลิตร
# 1/2 แพ็ค (35กรัม) | ['1/2 แพ็ค', '35กรัม'] | 35กรัม
# 1 ช้อนโต๊ะ (15กรัม) | ['1 ช้อนโต๊ะ', '15กรัม'] | 15กรัม
# 2 เม็ด (22กรัม) | ['2 เม็ด', '22กรัม'] | 22กรัม
# 1 ช้อนโต๊ะ (15มิลลิกรัม) | ['1 ช้อนโต๊ะ', '15มิลลิกรัม'] | 15มิลลิกรัม
# 1 ใบ (3กรัม) | ['1 ใบ', '3กรัม'] | 3กรัม
# 1/2 ก้อน (70กรัม) | ['1/2 ก้อน', '70กรัม'] | 70กรัม
# 1 ช้อนโต๊ะ (14มิลลิกรัม) | ['1 ช้อนโต๊ะ', '14มิลลิกรัม'] | 14มิลลิกรัม
# 1 กำมือหรือตามชอบ | ['1 กำมือ', 'ตามชอบ'] | 1 กำมือ
# 15-20 เม็ดหรือตามชอบ | ['15-20 เม็ด', 'ตามชอบ'] | 15-20 เม็ด
#  100 กรัม หรือตามชอบ | ['100 กรัม', 'ตามชอบ'] | 100 กรัม
# 1 ช้อนชา หรือตามชอบ | ['1 ช้อนชา', 'ตามชอบ'] | 1 ช้อนชา
# 1 กล่อง (250 ml) | ['1 กล่อง', '250 ml'] | 250 ml
# 5-10 ไม้ (แล้วแต่ความยาว) | ['5-10 ไม้', 'แล้วแต่ความยาว'] | 5-10 ไม้
# 1 ช้อนโต๊ะ (เล็ก) | ['1 ช้อนโต๊ะ', 'เล็ก'] | 1 ช้อนโต๊ะ
# 1 ช้อนโต๊ะ (เล็ก) | ['1 ช้อนโต๊ะ', 'เล็ก'] | 1 ช้อนโต๊ะ
# 1 ช้อนโต๊ะ (เล็ก) | ['1 ช้อนโต๊ะ', 'เล็ก'] | 1 ช้อนโต๊ะ
# 1 ช้อนโต๊ะ (เล็ก) | ['1 ช้อนโต๊ะ', 'เล็ก'] | 1 ช้อนโต๊ะ
# 1 ช้อนโต๊ะ (เล็ก) | ['1 ช้อนโต๊ะ', 'เล็ก'] | 1 ช้อนโต๊ะ
# 1 ช้อนโต๊ะ (เล็ก) | ['1 ช้อนโต๊ะ', 'เล็ก'] | 1 ช้อนโต๊ะ
# 10 ตัว (แล้วแต่ความเหมาะสม) | ['10 ตัว', 'แล้วแต่ความเหมาะสม'] | 10 ตัว
# 1/2 kg (10 ตัว) | ['1/2 kg', '10 ตัว'] | 1/2 kg
# เนื้อหมูหั่นบางๆ ชิ้นใหญ่ประมาณ 2 นิ้ว ['เนื้อหมูหั่นบางๆ ชิ้นใหญ่', '2 นิ้ว'] 3.5 ขีด
# 3-5กลีบ หรือตามชอบ | ['3-5กลีบ', 'ตามชอบ'] | 3-5กลีบ
# 3 ขีด หรือตามชอบ | ['3 ขีด', 'ตามชอบ'] | 3 ขีด
# 4 ก้อน หรือตามชอบ | ['4 ก้อน', 'ตามชอบ'] | 4 ก้อน
# 10 ดอก หรือตามชอบ | ['10 ดอก', 'ตามชอบ'] | 10 ดอก
# ต้นหอมหั่นท่อน ประมาณ 2นิ้ว ['ต้นหอมหั่นท่อน', '2นิ้ว'] 2 ต้น
# 15เม็ดหรือตามชอบ | ['15เม็ด', 'ตามชอบ'] | 15เม็ด
# ขิงยาวประมาณ  ['ขิงยาว', ''] 1 แว่น
# 10-15ตัวหรือตามความพอใจ | ['10-15ตัว', 'ตามความพอใจ'] | 10-15ตัว
# 3 ช้อนชา (ถ้วยเล็ก) | ['3 ช้อนชา', 'ถ้วยเล็ก'] | 3 ช้อนชา
# 3ช้อนโต๊ะ (หรือตามความชอบ) | ['3ช้อนโต๊ะ', 'ตามความชอบ'] | 3ช้อนโต๊ะ
# 2ต้น (1/2ถ้วย) | ['2ต้น', '1/2ถ้วย'] | 1/2ถ้วย
# 1 ขวด (เหยาะหน้าก๋วยเตี๋ยว) | ['1 ขวด', 'เหยาะหน้าก๋วยเตี๋ยว'] | เหยาะหน้าก๋วยเตี๋ยว
# 3 ซอง(พร้อมผง) | ['3 ซอง', 'พร้อมผง'] | 3 ซอง
# 1ถุง(20บาท) | ['1ถุง', '20บาท'] | 1ถุง
# 1 ช้อนโต๊ะ (หรือตามชอบ) | ['1 ช้อนโต๊ะ', 'ตามชอบ'] | 1 ช้อนโต๊ะ
# 1 ถ้วย (สำหรับทำน้ำซุป) | ['1 ถ้วย', 'สำหรับทำน้ำซุป'] | 1 ถ้วย
# 1ชต(พูนๆ) | ['1ชต', 'พูนๆ'] | 1ชต
# 1/2 kg หรือ ( ตามชอบ) | ['1/2 kg', '', 'ตามชอบ'] | 1/2 kg
# 1 กำ,หรือตามชอบ | ['1 กำ,', 'ตามชอบ'] | 1 กำ,
# 50-100ตัว(ขึ้นอยู่กับจำนวนคน) | ['50-100ตัว', 'ขึ้นอยู่กับจำนวนคน'] | 50-100ตัว
# 1กิโลกรัม(เผื่อล้างหอย) | ['1กิโลกรัม', 'เผื่อล้างหอย'] | 1กิโลกรัม
# 1ขวด(ล้างหอย) | ['1ขวด', 'ล้างหอย'] | 1ขวด
# 1ห่อ(ใหญ่) | ['1ห่อ', 'ใหญ่'] | 1ห่อ
# 1+1/2 ถ้วยตวง (ข้าวสาร)  | ['1+1/2 ถ้วยตวง', 'ข้าวสาร', ''] | 1+1/2 ถ้วยตวง
# ต้นหอมหั่นท่อนประมาณ1นิ้ว ['ต้นหอมหั่นท่อน', '1นิ้ว'] 5 ต้น
# แครอทหั่นท่อนประมาณ1 นิ้ว ['แครอทหั่นท่อน', '1 นิ้ว'] 50 กรัม
# 8 ตัวหรือตามชอบ | ['8 ตัว', 'ตามชอบ'] | 8 ตัว
# 8 ตัวหรือตามชอบ  | ['8 ตัว', 'ตามชอบ'] | 8 ตัว
# 1/4 ถ้วย (หรือมากน้อยตามที่ชอบ) | ['1/4 ถ้วย', 'มากน้อยตามที่ชอบ'] | 1/4 ถ้วย
# 10-15 ขา (ขาอวบๆ) | ['10-15 ขา', 'ขาอวบๆ'] | 10-15 ขา
# 1 อัน (ไม่ใส่ก็ได้) | ['1 อัน', 'ไม่ใส่ก็ได้'] | 1 อัน
# 3ช้อนโต๊ะ(เพิ่มหรือลดก้อได้ตามชอบค่ะ | ['3ช้อนโต๊ะ', 'เพิ่ม', 'ลดก้อได้ตามชอบค่ะ'] | 3ช้อนโต๊ะ
# .5ช้อนชาหรือตามชอบ | ['.5ช้อนชา', 'ตามชอบ'] | .5ช้อนชา
# 1 ถุง(ขนาดตามชอบ) | ['1 ถุง', 'ขนาดตามชอบ'] | 1 ถุง
# 110g (4ก้อน) | ['110g', '4ก้อน'] | 110g
# 3 กรีบ (ซอยบางๆ) | ['3 กรีบ', 'ซอยบางๆ'] | 3 กรีบ
# พริกขี้หนูแห้ง หั่นประมาณ 1 ซม. ['พริกขี้หนูแห้ง หั่น', '1 ซม.'] 5 เม็ด
# 4ดอก(แช่น้ำ) | ['4ดอก', 'แช่น้ำ'] | 4ดอก
# บะหมี่กึ่งสำเร็จรูปรสไก่เผ็ด (นิสชิน ['บะหมี่กึ่งสำเร็จรูปรสไก่เผ็ด', 'นิสชิน'] 1 ซอง
# 1 ถ้วยหรือตามต้องการ | ['1 ถ้วย', 'ตามต้องการ'] | 1 ถ้วย
# 1-2 ช้อนชา หรือตามชอบ | ['1-2 ช้อนชา', 'ตามชอบ'] | 1-2 ช้อนชา
# 1ถ้วย (หยิบมือ) | ['1ถ้วย', 'หยิบมือ'] | 1ถ้วย
# 2 กำมือ (กำมือเราได้แค่นี้) | ['2 กำมือ', 'กำมือเราได้แค่นี้'] | 2 กำมือ
# 85 กรัม (สุกแล้ว 200 กรัม) | ['85 กรัม', 'สุกแล้ว 200 กรัม'] | 85 กรัม
# 10 กรัม ( 2 ช้อนชา) | ['10 กรัม', '2 ช้อนชา'] | 10 กรัม
# 20 กรัม ( 1 ช้อนโต๊ะ) | ['20 กรัม', '1 ช้อนโต๊ะ'] | 20 กรัม
# 10 กรัม ( 2 ช้อนชา) | ['10 กรัม', '2 ช้อนชา'] | 10 กรัม
# 10 กรัม ( 2 ช้อนชา) | ['10 กรัม', '2 ช้อนชา'] | 10 กรัม
# 10 กรัม ( 2 ช้อนชา) | ['10 กรัม', '2 ช้อนชา'] | 10 กรัม
# 1แก้ว (250มล.) | ['1แก้ว', '250มล.'] | 250มล.
# 1 ก้อน (หั่นเป็นชิ้นเล็กๆ) | ['1 ก้อน', 'หั่นเป็นชิ้นเล็กๆ'] | 1 ก้อน
# .5ลูกหรือ 1ลูกเล็ก | ['.5ลูก', '1ลูกเล็ก'] | .5ลูก
# แป้งมัน (หมักหมู ['แป้งมัน', 'หมักหมู'] 1 1/2 ช้อนชา
# 5ฟัก(หรือตามชอบ) | ['5ฟัก', 'ตามชอบ'] | 5ฟัก
# 4ฟัก(หรือตามชอบ) | ['4ฟัก', 'ตามชอบ'] | 4ฟัก
# .อกไก่หั่นชิ้นปานกลางหรือ ประมาณ 1 นิ้ว ['.อกไก่หั่นชิ้นปานกลางหรือ', '1 นิ้ว'] 150 กรัม
# ต้นหอมหั่นขนาดประมาณ 1 นิ้วครึ่ง ['ต้นหอมหั่นขนาด', '1 นิ้วครึ่ง'] 1 ต้น
# 1 ช้อนโต๊ะ + 1 ช้อนชา (แล้วแต่ชอบ)  | ['1 ช้อนโต๊ะ + 1 ช้อนชา', 'แล้วแต่ชอบ', ''] | 1 ช้อนโต๊ะ + 1 ช้อนชา
# 2 ถ้วยหรือ.5หม้อน้ำย่อม | ['2 ถ้วย', '.5หม้อน้ำย่อม'] | 2 ถ้วย
# 10 บาท ( 1 กำ) | ['10 บาท', '1 กำ'] | 1 กำ
#  (ตามชอบ) | ['', 'ตามชอบ'] | ตามชอบ
# ผงเครื่องพะโล้ตราโลโบ้ (ไม่ปรุงรสและวัตถุกันเสีย ['ผงเครื่องพะโล้ตราโลโบ้', 'ไม่ปรุงรสและวัตถุกันเสีย'] 1 ช้อนโต๊ะ
# 1/2 ช้อนชา / หรือ 1 ช้อนโต๊ะ | ['1/2 ช้อนชา /', '1 ช้อนโต๊ะ'] | 1 ช้อนโต๊ะ
# 1 กล่อง (125 มิล.) | ['1 กล่อง', '125 มิล.'] | 125 มิล.
# พริกหอม (ลูกกำจัด,พริกหอม,มะข่วง,มะเเขว่น ['พริกหอม', 'ลูกกำจัด,พริกหอม,มะข่วง,มะเเขว่น'] 5 -6 เม็ด
# 500กรัม(1/2ก.ก.) | ['500กรัม', '1/2ก.ก.'] | 500กรัม
# 1 1/2ถ้วยตวง(หรือตามชอบ) | ['1 1/2ถ้วยตวง', 'ตามชอบ'] | 1 1/2ถ้วยตวง
# 20 กรัม หรือ 1 ชต. | ['20 กรัม', '1 ชต.'] | 20 กรัม
# 3 ลูก หรือ 350 กรัม | ['3 ลูก', '350 กรัม'] | 350 กรัม
# ตีนไก่5-8ตีน ประมาณ30บาท ['ตีนไก่5-8ตีน', '30บาท'] 5-8ตีน

# %%
df[['amounts_split_size']].sample(20)
# Out:
#                                      amounts_split_size
# 1275  [(ปลาทู, 1, ตัว), (กะทิอัมพวา, 350, มล.), (น้ำ...
# 1108  [(เส้นหมี่ฮกเกี้ยน, 200, กรัม), (ผักกวางตุ้ง, ...
# 206   [(เส้นหมี่ขาว, 3, ก้อน), (ซอสเย็นตาโฟ, 7, ช้อน...
# 1644  [(ข้าวโพดหวาน, 1, ฝัก), (ไข่เค็ม, 2, ฟอง), (กุ...
# 4412  [(เส้นพาสต้าขนาดเล็ก, 220, กรัม), (แฮมเบคอน+ไส...
# 2800  [(เส้นเฟตตูชินี, 1, กำเล็ก), (น้ำพริกเผาต้มยำ,...
# 2525  [(สันนอก, 150, กรัม), (ตะไคร้, 2, ต้น), (หอมแด...
# 350   [(ข้าวสวยหุงค้างคืน, 0, ), (ปลาหมึกแห้ง, 4.5, ...
# 2923  [(ผักบุ้ง, 2, กำ), (กระเทียม, 4.0, กลีบ), (เต้...
# 3073  [(หมู, 1.5, กก.), (ใบชะพลู, 0, ตามชอบ), (กะหล่...
# 2618  [(ข้าวสวยแช่เย็น, 2, ทัพพี), (ไก่จ๊อ, 3, ลูก),...
# 1885  [(หมูสับ, 100, กรัม), (พริกแดง, 5, เม็ด), (พริ...
# 3128  [(หมูสันใน, 0.5, กิโล), (น้ำปลา, 0.5, ช้อนโต๊ะ...
# 1470  [(ลูกชิ้นหมู, 500, กรัม), (หอมหัวใหญ่ หั่น, 2,...
# 1209  [(หมูชิ้น, 1, ขีด), (ข้าวสวยหุงแห้ง, 3, ถ้วย),...
# 525   [(นิสชินรสต้มยำกุ้ง, 3, ซอง), (หมูสับ, 2, ขีด)...
# 2535  [(สะโพกบน, 4, ชิ้น), (โค้ก, 1, กป), (น้ำมันหอย...
# 3925  [(กระเทียมสับ, 4, กลีบ), (หอมใหญ่ซอย, 1, ลูกเล...
# 1914  [(อกไก่, 2, ชิ้น), (น้ำตาลทราย, 2, ช้อนชา), (ซ...
# 1891  [(อกไก่, 3, ชิ้น), (เศษไก่, 2, ขีด), (รากผักชี...

# %%
new_ingredients =  df['amounts_split_size'].tolist()

# %%
new_ingredients = sum(new_ingredients, [])

# %%
def contains_numbers(string,value,unit):
    pattern = r'\d'
    if re.search(pattern, string) and not value:
      print(string, '|',unit)

# %%
all_ingredients  = []
all_units = []

for ingredinet in new_ingredients:
  name,value,unit = ingredinet

  contains_numbers(name,value,unit )

  all_ingredients.append(tuple([name.strip(),unit]))
  all_units.append(unit.strip())
# Out:
# น้ำมันมะกอกแคลอรี่0 | ตามชอบ
# เส้นสปาเกตตี้ชนิดกลม เบอร์3 | เเล้วเเต่ทาน
# พริกหยวก3สี | ตามใจชอบ
# น้ำมันมะกอกแคลอรี่0 | นิดหน่อย
# น้ำสะอาด2 | ใส่/ซอส
# น้ำมันมะกอกแคลอรี่0 สำหรับผัด | นิดหน่อย
# ++เบอเกอร์ข้าวสำหรับ 2ชิ้น++ |
# เส้นสปาเกตตี้ เบอร์3 ต้มสุก |
# อลาวรี้ 4 ชีส | ตามชอบ
# สปาเก็ตตี้ no3 |

# %%
all_ingredients
# Out:
# [('วุ้นเส้น', 'ซองเล็ก'),
#  ('หมูกรอบ', 'ถ้วย'),
#  ('ใบกระเพรา', 'ถ้วย'),
#  ('พริก', 'เม็ด'),
#  ('กระเทียม', 'กลีบ'),
#  ('ซีอิ้วขาวสูตรลดโซเดี่ยม', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส', 'ช้อนโต๊ะ'),
#  ('น้ำสะอาด', 'ถ้วย ช้อนโต๊ะ'),
#  ('น้ำมันหมูสำหรับผัด', 'ช้อนโต๊ะ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('บะหมี่กึ่งสำเร็จรูป ลวกสุก', 'ก้อน'),
#  ('นมสด รสจืด กล่องเล็ก', 'กล่อง'),
#  ('แครอท หั่นเต๋า', 'ตามชอบ ไม่ขอบไม่ใส่ก็ได้'),
#  ('ปวยเล้ง หรืออื่นๆตามชอบ', 'ตามชอบไม่ชอบไม่ใส่'),
#  ('น้ำปลา หรือผงปรุงรส', 'ช้อนชา'),
#  ('พริกไทยขาว', 'ช้อนชา'),
#  ('เกี่ยมอี๋ลวก', 'ถ้วย'),
#  ('ไส้ต้มเปื่อย', 'ชิ้น'),
#  ('หมูก้อนหั่น', 'แผ่น'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ต้นหอม', 'ต้น'),
#  ('น้ำตาล', 'ชช'),
#  ('น้ำปลา', 'ชช'),
#  ('ซอสฝาเขียว', 'ชช'),
#  ('น้ำมัน', 'ชต'),
#  ('กระเทียมเจียวกากหมู', 'ชต'),
#  ('เห็ดออรินจิ', 'ขีด'),
#  ('เนื้ออกไก่', 'ขีด'),
#  ('เกลือ', 'ช้อนชา'),
#  ('พริกไทย', 'ชช.'),
#  ('น้ำมันพืช', 'ชต.'),
#  ('กระหล่ำปลี', 'ใบ'),
#  ('น้ำปลา', 'ชต'),
#  ('กระเทียม', 'กลีบ'),
#  ('น้ำมัน', 'ชต'),
#  ('น้ำเปล่า', 'ชต'),
#  ('กุ้งขาว', 'kg.'),
#  ('วุ้นเส้น', 'กรัม'),
#  ('น้ำตาลปี๊ป', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วดำ', 'ช้อนชา'),
#  ('ซอสหอยนางรม', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('น้ำเปล่า', 'ถ้วย'),
#  ('เบคอน,ขิงแก่,กระเทียม,พริกไทยป่น,พริกไทยดำ,คื่นช่าย,ต้นหอม', 'ตามชอบ'),
#  ('ซอสข้นคนอร์', 'ช้อนโต๊ะ'),
#  ('หนังปลาแซลมอนติดเนื้อ', 'ถ้วย'),
#  ('โชยุ', 'ช้อนชา'),
#  ('พริกไทยป่น', 'ช้อนชา'),
#  ('น้ำมันพืช', 'กะให้พอท่วมหนังปลา'),
#  ('เส้นฟูซืลี', 'กรัม'),
#  ('หมูบด', 'กรัม'),
#  ('หอมหัวใหญ่', 'ลูก'),
#  ('มะเขือเทศ', 'ลูก'),
#  ('เนย', 'ช้อนโต๊ะ'),
#  ('เกลือ', 'เหยาะๆ ลงไป'),
#  ('พริกไทย', 'เหยาะๆ ลงไป'),
#  ('อาริกาโน', 'ช้อนโต๊ะ'),
#  ('แป้งข้าวโพด', 'ช้อนโต๊ะ'),
#  ('แป้งอเนกประสงค์', 'ช้อนโต๊ะ'),
#  ('ซอสมะเขือเทศ', 'ช้อนโต๊ะ'),
#  ('เนื้อหมูตรงสันคอ', 'กรัม'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('งาขาวคั่ว', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('วุ้นเส้น', 'ห่อเล็ก'),
#  ('เนื้อหมู', 'ตามชอบ'),
#  ('ผักบุ้ง', 'กำเล็ก'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('น้ำจิ้มสุกี้', 'ตามชอบ'),
#  ('ผงคนอร์', 'ช้อนชา'),
#  ('ปลาซุกิ', 'กรัม'),
#  ('ไข่', 'ฟอง'),
#  ('เกล็ดขนมปัง', 'กรัม'),
#  ('แป้งอเนกประสงค์', 'กรัม'),
#  ('เลมอน', 'ลูก'),
#  ('พริกไทยดำป่น', 'ช้อนชา'),
#  ('เกลือ', 'ช้อนชา'),
#  ('ปลากระป๋อง', 'กระป๋อง'),
#  ('มะนาว', 'ลูก'),
#  ('หอมแดง', 'หัว'),
#  ('พริกขี้หนู', 'เม็ด'),
#  ('น้ำปลา', 'ช้อนชา'),
#  ('มาม่าต้มยำกุ้งน้ำใส', 'ห่อ'),
#  ('หมูยอ', 'แท่ง'),
#  ('กุ้งสด', 'ตามชอบ'),
#  ('กะหล่ำปลี', 'หัว'),
#  ('มะนาว', 'ลูก'),
#  ('พริก', 'เม็ด'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ไข่เค็ม', 'ฟอง'),
#  ('หอมแขก', 'หัว'),
#  ('มะเขือเทศ', 'ผล'),
#  ('น้ำปลา', 'ชช'),
#  ('ลูกชิ้นปลา', 'ขีด'),
#  ('กระชายซอย', 'บาท'),
#  ('ใบมะกรูด', 'ใบ'),
#  ('ใบกระเพรา', 'ต้น'),
#  ('พริกขี้หนูสวน', 'เม็ด'),
#  ('กระเทียมสับ', 'กลีบ'),
#  ('พริกเหลืองซอย', 'เม็ด'),
#  ('น้ำตาล', 'ชช'),
#  ('น้ำมันหอย', 'ชต'),
#  ('น้ำปลา', 'ชช'),
#  ('ซอสปรุงรส', 'ชช'),
#  ('น่องไก่', 'น่อง'),
#  ('เลือดไก่', 'ก้อน'),
#  ('เครื่องในไก่', 'กรัม'),
#  ('เห็ดหอม', 'ดอก'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('เกลือป่น', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วดำ', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'กรัม'),
#  ('เส้นหมี่', 'กรัม'),
#  ('เก๋ากี้', 'เม็ด'),
#  ('พริกไทยป่น', 'ช้อนชา'),
#  ('หัวไชเท้า', 'หัว'),
#  ('กะหล่ำปลี', 'หัว'),
#  ('ผักชี', 'ต้น'),
#  ('พาสต้าดิบ', 'กรัม'),
#  ('เบคอน', 'กรัม'),
#  ('กระเทียม', 'กลีบ'),
#  ('หัวหอมใหญ่', 'หัว'),
#  ('น้ำมันมะกอก', 'ช้อนโต๊ะ'),
#  ('เกลือ', 'ช้อนชา'),
#  ('พริกไทย', 'ช้อนชา'),
#  ('โหระพา', 'กิ่ง'),
#  ('เส้นเฟตตูชินิ', 'กรัม'),
#  ('เบคอน', 'กรัม'),
#  ('whipping cream', 'ถ้วย'),
#  ('พาร์มีซานชีสขูด', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'กลีบ'),
#  ('หัวหอมใหญ่', 'หัวเล็ก'),
#  ('ไข่แดง', 'ฟอง'),
#  ('เกลือ', 'นิดหน่อย'),
#  ('พริกไทย', 'นิดหน่อย'),
#  ('เพรสลี่', 'กิ่ง'),
#  ('นมสด', 'นิดหน่อย'),
#  ('ข้าวสวย', 'ถ้วย'),
#  ('หมูยอหั่น', 'ถ้วย'),
#  ('หอมหัวใหญ่', 'ถ้วย'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('น้ำพริกเผา', 'ช้อนโต๊ะพูนๆ'),
#  ('น้ำมันสำหรับผัด', 'ช้อนโต๊ะ'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('คนอร์ผงปรุงรส', 'ช้อนชา'),
#  ('ใบโหระพาเด็ด', 'ช้อนชา'),
#  ('พริกชี้ฟ้าหั่นเฉียง', 'เม็ด'),
#  ('ผักสดเช่นแตงกวา,ใบโหระพา ฯลฯ', 'ตามชอบ'),
#  ('สันนอก', 'กรัม'),
#  ('ตะไคร้', 'ต้น'),
#  ('หอมแดง', 'หัว'),
#  ('กระเทียม', 'กลีบ'),
#  ('พริกขี้หนู', 'เม็ด'),
#  ('ต้นหอม', 'ต้น'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำตาล', 'ช้อนชา'),
#  ('เนื้อหมูส่วนสันคอ', 'Kg'),
#  ('กระเทียมกลีบเล็ก', 'กรัม'),
#  ('รากผักชี', 'ราก'),
#  ('พริกไทย', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ถ้วยตวง'),
#  ('ซีอิ๊วขาว', 'ถ้วยตวง'),
#  ('น้ำมันพืช', 'ถ้วยตวง'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('แตงกวา', 'ลูก'),
#  ('ผักชี', 'แล้วแต่ชอบ'),
#  ('ปลากระป๋อง', 'กระป๋อง'),
#  ('คะน้า', 'กำ'),
#  ('พริก', 'เม็ด'),
#  ('กระเทียม', 'กลีบ'),
#  ('ซอสหอยนางรม', 'ตามชอบ'),
#  ('น้ำปลา', 'ตามชอบ'),
#  ('เนื้อหมู', 'ขีด'),
#  ('ซอสหอยนางรม', 'ช้อนโต๊ะ'),
#  ('ซอสปรุงรสฝาเขียว', 'ช้อนโต๊ะ'),
#  ('ซีอิ๋วขาว', 'ช้อนโต๊ะ'),
#  ('กระเทียมทุบ', 'กีบ'),
#  ('กุ้งแม่น้ำ', 'กรัม'),
#  ('วุ้นเส้น', 'กรัม'),
#  ('เบค่อน', 'กรัม'),
#  ('กระเทียม', 'กลีบ'),
#  ('พริกไทย', 'ช้อนโต๊ะ'),
#  ('ขิงแก่', 'แง่ง'),
#  ('นมสด', 'ช้อนโต๊ะ'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('ซอสปรุงรส', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วดำ', 'ช้อนโต๊ะ'),
#  ('รสดีเมนู', 'ช้อนโต๊ะ'),
#  ('หมูสไลด์', 'ตามชอบ'),
#  ('ข้าวสวยเย็น', 'สำหรับ  ท่าน'),
#  ('กิมจิ', 'ช้อนโต๊ะ'),
#  ('น้ำมันงา', 'ช้อนชา'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วเห็ดหอม', 'ช้อนโต๊ะ'),
#  ('น้ำมัน', 'เล็กน้อย'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('หมูสับ', 'ขีด'),
#  ('ซอสมะเขือเทศเข้มข้น 1 ขวดใหญ่', 'ถ้วยตวง'),
#  ('มะเขือเทศหั่นเต๋า', 'ขีด'),
#  ('มันฝรั่งหั่นเต๋า', 'ลูก'),
#  ('กระเทียมสับ', 'กลีบ'),
#  ('บะหมี่กึ่งสำเร็จรูป', 'ก้อน'),
#  ('วุ้นเส้นจากถั่วเขียว', 'ห่อ'),
#  ('เกลือ', 'ช้อนชา'),
#  ('พริกไทย', 'ช้อนชา'),
#  ('น้ำมันมะกอกหรือน้ำมันปาล์ม', 'ถ้วยตวง'),
#  ('ข้าว', 'ทัพพี'),
#  ('ไข่', 'ฟอง'),
#  ('กุ้ง', 'เยอะๆ'),
#  ('มะเขือเทศ', 'ถ้ากิน'),
#  ('หอมใหญ่', 'ถ้ากิน'),
#  ('ต้นหอม', 'ถ้ากิน'),
#  ('ผักชี', 'ถ้ากิน'),
#  ('น้ำตาล', 'ตามใจ'),
#  ('น้ำปลา', 'ตามใจ'),
#  ('ซีอิ๊วขาว', 'ช้อน'),
#  ('ไส้กรอก ยี่ห้อไหนก็ได้ ตามรูปเป็นของเบทาโกร', 'ถุง'),
#  ('วุ้นเส้นสด', 'ถุงเล็ก'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซอสถั่วเหลืองภูเขาทองฝาเขียว', 'ช้อนโต๊ะ'),
#  ('น้ำมันพืช', 'ช้อนชา'),
#  ('ต้นหอมซอย', 'ต้น'),
#  ('พริกขี้หนู', 'เม็ด'),
#  ('น้ำเปล่า', 'ช้อนโต๊ะ'),
#  ('ปลาทูน่าในน้ำแร่', 'กระป๋อง'),
#  ('พริกแกงเผ็ด', 'ช้อนโต๊ะ'),
#  ('กระชาย', 'กรัม'),
#  ('กะทิกล่อง', 'กรัม'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำเปล่า', ''),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('เส้นสปาเกตตี้', 'กรัม'),
#  ('ผักเคียงตามชอบ เช่น แตงกวา กะหล่ำ', ''),
#  ('หมูสับ', 'กรัม'),
#  ('ใบเหลียง', 'แพ็ค'),
#  ('กระเทียม', 'เม็ด'),
#  ('พริก', 'เม็ด'),
#  ('ไข่', 'ฟอง'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ชะอม', 'มัด'),
#  ('พริกแกงส้ม', 'ขีด'),
#  ('กุ้งสด', 'ตัว'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำตาลปี๊ป', 'ช้อนโต๊ะ'),
#  ('น้ำเปล่า', 'หม้อ'),
#  ('ซี๊อิ๋วขาว', 'ช้อนโต๊ะ'),
#  ('หมูยอ', 'ห่อ'),
#  ('ไข่แดงเค็ม', 'ลูก'),
#  ('หัวหอม/ผักชีฝรั่ง/ต้นหอม', 'ตามชอบ'),
#  ('น้ำมะนาว', 'ลูก'),
#  ('พริกขี้หนู', 'เม็ด'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('ไก่สับ', 'กรัม'),
#  ('น้ำตาล', 'ช้อนโต๊ะ'),
#  ('ผักกาดหอม/กระหล่ำปลี', 'ตามชอบ'),
#  ('กุนเชียงหมูทอดสุกแล้วหั่นชิ้น', 'ช้อนโต๊ะ'),
#  ('หมูสับหยาบ', 'ถ้วยตวง'),
#  ('พริกชี้ฟ้าสับ', 'ช้อนโต๊ะ'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('ใบกระเพราเด็ด', 'หยิบมือ'),
#  ('ข้าวกล้อง', 'ทัพพี'),
#  ('น้ำมันพืชสำหรับผัด', 'ช้อนโต๊ะ'),
#  ('เส้นหมี่ขาวแช่น้ำ 3 นาที', 'ซอง'),
#  ('ไส้กรอกbbqหั่นชิ้น', 'แพ็ค'),
#  ('กะทิ', 'กล่องเล็ก'),
#  ('น้ำตาลปี๊บ', 'ชต'),
#  ('น้ำพริกเผา', 'ชต'),
#  ('หอมแดงและหอมใหญ่สับหยาบ', 'ชต'),
#  ('ผงปรุงรสหมู', 'ชช'),
#  ('น้ำมันหอย', 'ชต'),
#  ('แครอทซอย', 'ตามชอบ'),
#  ('กะหล่ำปลีซอย', 'ตามชอบ'),
#  ('เห็ดหูหนูดำซอย', 'ตามชอบ'),
#  ('ขึ้นฉ่ายซอย', 'ตามชอบ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('Rigatoni', 'g'),
#  ('นมสด', 'ml'),
#  ('วีปครีมสด', 'ml'),
#  ('หอมหัวใหญ่หั่นชิ้นเล็ก', 'ช้อนโต๊ะ'),
#  ('กระเทียมหั่นละเอียด', 'ช้อนชา'),
#  ('หอยเชลล์', 'ตามชอบ'),
#  ('กุ้ง', 'ตามชอบ'),
#  ('ไข่แดงเค็มสุกแล้วยี้ให้ละเอียด', 'ลูก'),
#  ('หมึกกล้วย ขนาดเล็ก', 'ตัว'),
#  ('คึ่นช่าย', 'ต้น'),
#  ('หมูสับ', 'กรัม'),
#  ('เส้นหมี่สด', 'พอ'),
#  ('เนื้อหมูสันนอก', 'กิโลกรัม'),
#  ('อร่อยชัวร์', 'ถ้วย'),
#  ('น้ำมันหอย', 'ถ้วย'),
#  ('นมสด', 'ถ้วย'),
#  ('รากผักชี', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'ช้อนโต๊ะ'),
#  ('พริกไทย', 'ช้อนโต๊ะ'),
#  ('น้ำตาลปี๊บ', 'น้ำตาลปิ้บ  ถ้วย'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วดำ', 'ช้อนชา'),
#  ('แป้งมัน', 'ถ้วย'),
#  ('ผักชี', 'ต้น'),
#  ('พอร์กช็อป', 'ชิ้น'),
#  ('เกล็ดขนมปัง', 'ถ้วย'),
#  ('แป้งสาลีอเนกประสงค์', 'ถ้วย'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('เกลือ', 'ปรุงรส'),
#  ('พริกไทย', 'ปรุงรส'),
#  ('ปาปริก้า', 'ปรุงรส'),
#  ('มัสตาร์ด', 'ช้อนชา'),
#  ('น้ำมันรำข้าว', 'สำหรับทอด'),
#  ('มะนาว', 'สำหรับเสิร์ฟ'),
#  ('กะหล่ำปลี', 'สำหรับเสิร์ฟ'),
#  ('ซีอิ๊วดำหวาน', 'ช้อนโต๊ะ'),
#  ('ซอสวูสเตอร์เชีย', 'ช้อนชา'),
#  ('ซอสมะเขือเทศ', 'ช้อนโต๊ะ'),
#  ('เกลือผสมผงกระเทียม', 'ช้อนชา'),
#  ('ขิงผง', 'ช้อนชา'),
#  ('น้ำมัน', 'ช้อนโต๊ะ'),
#  ('กระเทียมสับ', 'กลีบ'),
#  ('หมูหมัก', 'กรัม'),
#  ('หอมใหญ่', 'หัว'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('ผงปรุงรส', 'ช้อนชา'),
#  ('ซอสปรุงรส', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('พริกหยวก', 'เม็ด'),
#  ('เส้นใหญ่', 'กิโล'),
#  ('อาหารทะเล', 'ตามชอบ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ผงปรุงรส', 'ช้อนชา'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('น้ำตาล', 'ช้อนชา'),
#  ('น้ำมันพืช', 'ตามชอบค่ะ'),
#  ('ต้นหอมซอย', 'ตามชอบค่ะ'),
#  ('พริกไทย', 'ช้อนชา'),
#  ('ตั้งฉ่าย', 'ช้อนโต๊ะ'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('เส้นหมี่ตะคุพร้อมน้ำปรุง', 'ห่อ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('กุ้งผ่าหลังเอาเส้นดำออก', 'ตัว'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('ใบถุยช่ายหั่นท่อน', 'ตัน'),
#  ('พริกป่น', 'ช้อนชา'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('มะนาวผ่าซีก', 'ซีก'),
#  ('น้ำเปล่า', 'ถ้วย'),
#  ('ข้าวมัน', 'ถ้วย'),
#  ('ส้มตำไทย', 'ถ้วย'),
#  ('สปาเกตตี้', 'ถ้วย'),
#  ('เนื้อไก่', 'กรัม'),
#  ('หัวหอมใหญ่หั่น', 'ถ้วย'),
#  ('มะเขือเทศ', 'ลูก'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('เกลือ น้ำตาล', 'ตามชอบ'),
#  ('ซอสมะเขือเทศ', 'ช้อนโต๊ะ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('หมี่เหลือง', 'กิโลกรัม'),
#  ('หมูสันคอ', 'กิโลกรัม'),
#  ('คะน้า', 'กำ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ซีอิ้วดำ', 'ชต.'),
#  ('น้ำมันมะกอก', 'ชต'),
#  ('กระเทียมตบ', 'กลีบ'),
#  ('สปาเกตตี', 'กรัม'),
#  ('ปลาอินทรีย์เค็ม', 'ชิ้น'),
#  ('ยอดคะน้า', 'ต้น'),
#  ('กระเทียม', 'กลีบ'),
#  ('พริกจินดา', 'เม็ด'),
#  ('น้ำมัน-ทอดปลา', 'ถ้วย'),
#  ('น้ำมัน-ผัด', 'ช้อนโต๊ะ'),
#  ('ข้าวโพดอ่อนแพคเล็ก', 'แพค'),
#  ('เนื้อสะโพกไก่', 'ชิ้น'),
#  ('พริกแกง', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('น้ำปลา', 'ตามชอบ'),
#  ('น้ำเปล่า', 'ถ้วย'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('ปูม้า', 'ตัว'),
#  ('มะละกอสับ', 'ถ้วยตวง'),
#  ('มะเขือเทศลูกเล็ก', 'ลูก'),
#  ('พริก', 'เม็ด'),
#  ('ถั่วฝักยาว', 'ฝัก'),
#  ('กระเทียม', 'กลีบเล็ก'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำตาลปี๊บ', 'ช้อนโต๊ะ'),
#  ('มะนาว', 'ช้อนโต๊ะ'),
#  ('เส้นหมี่เหลือง', 'kg'),
#  ('เนื้อหมู', 'g'),
#  ('คะน้า', 'g'),
#  ('แครอท', 'g'),
#  ('กระเทียม', 'กลีบ'),
#  ('น้ำตาล', 'ช้อนโต๊ะ'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ผงปรุงรสคนอร์', 'ช้อนชา'),
#  ('กะหล่ำปี', 'กรัม'),
#  ('ไข่ไก่เต็มใบ', 'ฟอง'),
#  ('ไข่ขาว', 'มล'),
#  ('ซุปปลาแห้ง', 'มล'),
#  ('แป้งสาลีอเนกประสงค์', 'ช้อนโต๊ะ'),
#  ('มายองเนสไขมันต่ำ', 'ตามชอบ'),
#  ('ซอสพิซซ่าญี่ปุ่น', 'ตามชอบ'),
#  ('ปูอัด', 'ตามชอบ'),
#  ('กุนเชียง', 'เส้น'),
#  ('หมูยอ', 'แท่ง'),
#  ('ไส้กรอก', 'กรัม'),
#  ('ข้าวสวย', 'ถ้วยตวง'),
#  ('ต้นหอม', 'ต้น'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('น้ำตาล', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('ผงปรุงรส', 'ช้อนโต๊ะ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('กระเทียม', 'กลีบ'),
#  ('หมูสับ', 'กรัม'),
#  ('พริกหวาน', 'ลูก'),
#  ('หอมใหญ่', 'ลูกใหญ่'),
#  ('แครอท', 'หัว'),
#  ('กระเทียม', 'กลีบใหญ่'),
#  ('น้ำมันมะกอก', 'ช้อนโต๊ะ'),
#  ('แป้งสาลี', 'ช้อนโต๊ะ'),
#  ('มะเขือเทศกระป๋อง', 'กรัม'),
#  ('ซอสมะเขือเทศ', 'ช้อนโต๊ะ'),
#  ('วูสเตอร์ซอส', 'ช้อนโต๊ะ'),
#  ('คอนซูเม่แบบผง', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('น้ำเปล่า', 'cc'),
#  ('เกลือ', 'ช้อนชา'),
#  ('พริกไทย', 'ตามชอบ'),
#  ('กุ้ง', 'ตัว'),
#  ('รากผักชีสับ', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'ช้อนโต๊ะ'),
#  ('พริกไทยขาว', 'ช้อนชา'),
#  ('น้ำปลาอย่างดี', 'ช้อนโต๊ะ'),
#  ('น้ำมันสำหรับผัด', 'ช้อนโต๊ะ'),
#  ('ข้าวสวย', 'ถ้วย'),
#  ('ไส้กรอกสอดไส้ชีส', 'แท่ง'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('หอมหัวใหญ่ หั่นเต๋า', 'ถ้วย'),
#  ('ต้นหอมซอย', 'ต้น'),
#  ('น้ำมันสำหรับทอดและผัด', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('น้ำมันหอย', 'ช้อนชา'),
#  ('ซีอิ้วขาว', 'ช้อนชา'),
#  ('พริกไทยป่น', 'ช้อนชา'),
#  ('เนื้อหมู', 'g.'),
#  ('เส้นมักกะโรนี', 'g.'),
#  ('น้ำตาล', 'ช้อนชา'),
#  ('ซอสหอย', 'ช้อนโต๊ะ'),
#  ('แครอท', 'ชิ้น'),
#  ('มะเขือเทศ', 'ลูกเล็ก'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ซอสมะเขือเทศ', 'ช้อนโต๊ะ'),
#  ('ผักกาดหอม', 'ใบใหญ่'),
#  ('เส้นสปาเกตตี้', 'กรัม'),
#  ('หมูกรอบ', 'กรัม'),
#  ('กระเทียมสับ', 'ชช'),
#  ('พริกขี้หนูสับ', 'ชช'),
#  ('โหระพา', 'ต้น'),
#  ('น้ำตาลทราย', 'ชช'),
#  ('น้ำมันหอย', 'ชต'),
#  ('ซอสปรุงรส', 'ชช'),
#  ('น้ำปลา', 'ชช'),
#  ('น้ำมันพืช', 'ชต'),
#  ('หมูสับ', 'ขีด'),
#  ('ผักโขม', 'ต้น'),
#  ('แครอทซอยเป็นเส้น', 'ตามชอบ'),
#  ('เห็ดออริจิซอยเป็นเส้น', 'หัว'),
#  ('ถั่วงอกหัวโต', 'กำมือ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('งาขาวคั่ว', 'ตามชอบ'),
#  ('สาเกสำหรับทำอาหาร', 'ช้อนชา'),
#  ('มินริน', 'ช้อนชา'),
#  ('ดอกเกลือ', 'ช้อนชา'),
#  ('ซอสญี่ปุ่น ซี่อิ๊วขาว อย่างใดอย่างหนึ่ง', 'ช้อนชา'),
#  ('น้าตาลทราย น้ำเชื่อม อย่างใดอย่างหนึ่ง', 'ช้อนโต๊ะ'),
#  ('น้ำมันงา', 'ช้อนชา'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('ต้นหอมซอย', 'ต้น'),
#  ('พริกไทยป่น', 'ตามชอบ'),
#  ('โคชูจัง', 'ช้อนโต๊ะ'),
#  ('หมูสามชั้น', 'กรัม'),
#  ('หน่อไม้', 'กรัม'),
#  ('กระเทียมสับ', 'กลีบ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('ผงปรุงรส', 'ช้อนชา'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วดำหวาน', 'ช้อนโต๊ะ'),
#  ('พริกใหญ่', 'เม็ด'),
#  ('หมูหั่นชิ้นหมัก', 'ขีด'),
#  ('ดอกกระหล่ำ', 'หัว'),
#  ('เส้นหมี่/เส้นใหญ่', 'ขีด'),
#  ('กระเทียมสับ', 'ชต.'),
#  ('พริกไทย', 'ชต.'),
#  ('ซอสปรุงรส', 'ชต.'),
#  ('น้ำตาล', 'ชต.'),
#  ('ไข่ดาว', 'ฟอง'),
#  ('แป้งมัน', 'ชต.'),
#  ('น้ำเปล่า', 'ถ้วย'),
#  ('ไข่', 'ฟอง'),
#  ('แหนม', 'ท่อนยาว'),
#  ('น้ำมัน', 'ช้อนโต๊ะ'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('กระเพาะปลา', 'ขีด'),
#  ('โครงไก่', 'โครง'),
#  ('ปีกบนไก่', 'กก.'),
#  ('เลือดไก่', 'ก้อน'),
#  ('ซีอิ๊วขาว', 'ถต.'),
#  ('น้ำมันหอย', 'ถต.'),
#  ('น้ำตาลทราย', 'ถต.'),
#  ('ต้นหอม', 'ต้น'),
#  ('พริกไทยป่น', 'ชช.'),
#  ('รากผักชี', 'ราก'),
#  ('แป้งมันฮ่องกง', 'ถต.'),
#  ('ปลาทูนึ่ง', 'ตัว'),
#  ('หัวกะทิ', 'ถ้วย'),
#  ('หางกะทิ', 'ถ้วย'),
#  ('พริกแกง', 'ข้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('น้ำตาลปี๊บ', 'ช้อนโต๊ะ'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('ลูกชิ้นปลา', 'ถุง'),
#  ('ไข่ขาว', 'ฟอง'),
#  ('นมจืด', 'ช้อนโต๊ะ'),
#  ('ไส้กรอก', 'อัน'),
#  ('ไข่กุ้ง', 'ตามชอบ'),
#  ('เกลือ', 'เล็กน้อย'),
#  ('พริกไทย', 'ตามชอบ'),
#  ('เนยเค็ม', 'ก้อน'),
#  ('อกเป็ด', 'ชิ้น'),
#  ('น้ำส้ม', 'ถ้วย'),
#  ('แป้งสาลีอเนกประสงค์', 'ช้อนโต๊ะ'),
#  ('แยมส้มมาม่าเลท', 'ช้อนโต๊ะ'),
#  ('เกลือ พริกไทย', 'หยิบมือ'),
#  ('น้ำมันพืช', 'เล็กน้อย'),
#  ('เนื้อหอยลาย', 'ขีด'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('ซอสภูเขาฝาเขียว', 'ช้อนโต๊ะ'),
#  ('ซอสหอยนางรม', 'ช้อนโต๊ะ'),
#  ('พริกเผา', 'ช้อนโต๊ะ'),
#  ('น้ำมันถั่วเหลือง', 'ช้อนชา'),
#  ('กระเทียม', 'หัว'),
#  ('พริกแดง', 'เม็ด'),
#  ('บะหมี่กึ่งสำเร็จรูป', 'ซอง'),
#  ('นมจืด', 'กล่่อง'),
#  ('ชีส', 'แผ่น'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ถั่วแขก', 'กก.'),
#  ('ปลาหมึกสด', 'กก.'),
#  ('หมูสับ', 'ขีด'),
#  ('พริกขี้หนู', 'เม็ด'),
#  ('กระเทียม', 'หัว'),
#  ('ซีอิ้วขาว', 'ช้อนชา'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('เกลือ', 'ช้อนชา'),
#  ('น้ำมันพืช', 'ถ้วย'),
#  ('ปลาช่อนนา', 'ตัว'),
#  ('หมูบด', 'ขีด'),
#  ('ตะไคร้ซอย', 'หัว'),
#  ('ขมิ้นซอย', 'หัว'),
#  ('กระเทียมไทย', 'กลีบ'),
#  ('กะปิ', 'ช้อนโต๊ะ'),
#  ('เกลือป่น', 'ช้อนชา'),
#  ('พริกแห้ง', 'เม็ด'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('ผักชีซอยละเอียด', 'ถ้วยตวง'),
#  ('สันคอหมู', 'ชิ้น'),
#  ('กระเทียมสับหยาบ', 'กลีบ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('พริกไทยดำ', 'ช้อนโต๊ะ'),
#  ('นมสด', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('เกลือ', 'หยิบมือ'),
#  ('มะเขือเทศฝาน', 'ชิ้น'),
#  ('ชีสแผ่น', 'แผ่น'),
#  ('บะหมี่เหลือง', 'ตามชอบ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('กะหล่ำปลี', 'กรัม'),
#  ('ถั่วงอก', 'กรัม'),
#  ('เนื้อหมู', 'กรัม'),
#  ('พริกแกงเผ็ดสำเร็จรูป', 'ช้อนชา'),
#  ('ถั่วฟักยาว', 'กรัม'),
#  ('น้ำปลา', 'ช้อนชา'),
#  ('น้ำตาล', 'ช้อนชา'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('กะทิ', 'มล.'),
#  ('น้ำเปล่า', 'มล.'),
#  ('น้ำมันพืช', 'มล.'),
#  ('แหนม', 'กรัม'),
#  ('ไข่', 'ฟอง'),
#  ('หอมใหญ่หั่นหยาบ', 'หัว'),
#  ('กระเทียมสับหรือซอย', 'ตามชอบ'),
#  ('ต้นหอมหั่นท่อนสั้น', 'ต้น'),
#  ('น้ำมัน', 'ช้อนโต๊ะ'),
#  ('น้ำปลาหรือเกลือ พริกไทย', 'ปรุงรสเล็กน้อย'),
#  ('ผักคะน้า', 'กรัม'),
#  ('กระเทียม', 'กลีบ'),
#  ('พริกขี้หนูสวน', 'เม็ด'),
#  ('ซอสหอยนางรมตราแม่ครัว', 'ทัพพี'),
#  ('ซีอิ้วขาวสูตร1 ตราเด็กสมบูรณ์', 'ช้อนโต๊ะ'),
#  ('น้ำเปล่า', 'ถ้วย'),
#  ('ซอสภูเขาทองตราลุงหนวด', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('สะโพกบน', 'ชิ้น'),
#  ('โค้ก', 'กป'),
#  ('น้ำมันหอย', 'ชต'),
#  ('ซีอิ๊วขาว', 'ชต'),
#  ('ซอสแมคกี้', 'ชต'),
#  ('น้ำตาลปี๊บ', 'ชช'),
#  ('น้ำมันงา', 'ชช'),
#  ('น้ำมันพืช', 'ชต'),
#  ('พริกไทยป่น', 'ชช'),
#  ('น้ำมันหอย', 'ช้อนชา'),
#  ('หมูสับ', 'กรัม'),
#  ('น้ำมันปาล์ม', 'ช้อนโต๊ะ'),
#  ('พริกจินดาแดงสับหยาบ', 'เม็ด'),
#  ('กระเทียมสับหยาบ', 'กีบ'),
#  ('น้ำต้มสุก', 'ช้อนโต๊ะ'),
#  ('พริกไทป่น', 'ช้อนชา'),
#  ('น้ำปลา', 'ช้อนชา'),
#  ('สตอ', 'ตามใจชอบ'),
#  ('แหนม', 'แท่ง'),
#  ('ข้าวสวย', 'จาน'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('กระเทียม', 'กลีบ'),
#  ('หอมแดง', 'โรยหน้า'),
#  ('พริก', 'โรยหน้า'),
#  ('น้ำตาล', 'เล็กน้อย'),
#  ('เกลือ', 'เล็กน้อย'),
#  ('พริกไทย', 'เล็กน้อย'),
#  ('น้ำมันพืช', 'เล็กน้อย'),
#  ('เนื้อหมูหั่น', 'กรัม'),
#  ('กะปิ ตรา เรือใบ', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทรายขาว', 'ช้อนโต๊ะ'),
#  ('ซอสหอยนางรมตราสามแม่ครัว', 'ช้อนโต๊ะ'),
#  ('กระเทียบไทยสับ', 'ช้อนโต๊ะ'),
#  ('พริกขี้หนูหั่น', 'ช่อนโต๊ะ'),
#  ('ใบมะกรูด', 'ใบ'),
#  ('ผักชีโรยหน้า', 'ช้อนโต๊ะ'),
#  ('หมูสันใน', 'กรัม'),
#  ('ไข่ไก่-หมักหมู', 'ฟอง'),
#  ('ซอสหอยนางรม-หมักหมู', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว-หมักหมู', 'ช้อนโต๊ะ'),
#  ('น้ำตาล-หมักหมู', 'ช้อนโต๊ะ'),
#  ('เหล้าจีน-หมักหมู', 'ช้อนโต๊ะ'),
#  ('แป้งมัน-หมักหมู', 'ช้อนโต๊ะ'),
#  ('พริกไทย-หมักหมู', 'ช้อนโต๊ะ'),
#  ('น้ำมันงา-หมักหมู', 'ช้อนโต๊ะ'),
#  ('เต้าเจี้ยว', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'กลีบ'),
#  ('ซอสหอยนางรม', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('น้ำตาล', 'ช้อนโต๊ะ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('แป้งมัน', 'ช้อนโต๊ะ'),
#  ('แป้งท้าว', 'ช้อนโต๊ะ'),
#  ('ยอดคะน้า', 'กก'),
#  ('น้ำมัน', 'ช้อนโต๊ะ'),
#  ('ข้าวสวย', 'ถ้วย'),
#  ('หนำเลี้ยบแกะเม็ด', 'เม็ด'),
#  ('หมูบด', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'กลีบ'),
#  ('ขิงอ่อน', 'แง่ง'),
#  ('มะนาว', 'ใบ'),
#  ('หอมแดง', 'หัว'),
#  ('พริกจินดา', 'เม็ด'),
#  ('เม็ดมะม่วงหิมพานต์', 'ถุงเล็ก'),
#  ('น้ำมัน', 'ช้อนโต๊ะ'),
#  ('ปลาทูทอด', 'ตัว'),
#  ('ข้าวสวยค้างคืน', 'ถ้วย'),
#  ('กระเทียมสับ', 'กลีบใหญ่'),
#  ('ตะไคร้ซอย', 'ต้น'),
#  ('แครอทหั่นเต๋าเล็กๆ', 'ตามชอบ'),
#  ('พริกขี้หนูซอย', 'ตามชอบ'),
#  ('ใบมะกรูดซอย', 'ใบ'),
#  ('น้ำตาลทราย', 'ตามชอบ'),
#  ('น้ำมันหอย', 'ตามชอบ'),
#  ('ซีอิ้วขาว', 'ตามชอบ'),
#  ('ผงปรุงรสคนอร์', 'ตามชอบ'),
#  ('น้ำมัน', 'ช้อนโต๊ะ'),
#  ('แตงกวา ต้นหอม', 'ตามชอบ'),
#  ('มาม่าโอเค รสฮอท แอนด์ สไปซี่', 'ห่อ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ทูน่าในน้ำแร่', 'กระป๋อง'),
#  ('ต้นหอม', 'ต้น'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('หมูบด', 'ขีด'),
#  ('เส้นเล็ก', 'กรัม'),
#  ('แครอท', 'หัว'),
#  ('คะน้า', 'ต้น'),
#  ('พริกไทยป่น', 'ช้อนชา'),
#  ('น้ำตาล', 'ช้อนชา'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('ปลาสลิด', 'ตัว'),
#  ('ผักคะน้า/ผักแขนง', 'ต้น'),
#  ('นำ้พริกเผา+น้ำมันพริกเผา', 'ช้อนโต๊ะ'),
#  ('ข้าวหอมมะลิหุงสุก', 'จานพูนๆ'),
#  ('น้ำปลา', 'ตามชอบ'),
#  ('กระเทียม', 'กลีบ'),
#  ('อกไก่', 'กรัม'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('เต้าหู้ไข่', 'หลอด'),
#  ('บะหมี่ผัก', 'ก้อน'),
#  ('พริกจินดา', 'เม็ด'),
#  ('กระเทียมจีน', 'กลีบ'),
#  ('น้ำมันหอยโซเดียมต่ำ', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาวโซเดียมต่ำ', 'ช้อนชา'),
#  ('น้ำตาลหญ้าหวาน', 'ช้อนชา'),
#  ('น้ำปลา', 'ซ้อนชา'),
#  ('ดอกไม้กวาด', 'กำ'),
#  ('เนื้อหมู', 'กรัม'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('ผงปรุงรสหมูคนอร์', 'ช้อนชา'),
#  ('กระเทียมสับ', 'ตามชอบ'),
#  ('ขนมจีน', 'กก'),
#  ('แหนมตุ้มจิ๋ว', 'เม็ด'),
#  ('หอมหัวใหญ่', 'หัว'),
#  ('พริกหยวก', 'เม็ด'),
#  ('ใบมะกรูด', 'ใบ'),
#  ('พริกเหลือง', 'เม็ด'),
#  ('โหระพา', 'ต้น'),
#  ('มะเขือเทศ', 'ผล'),
#  ('กระเทียม+พริกสับ', 'ชต'),
#  ('น้ำมันพืช', 'ชต'),
#  ('น้ำมันหอย', 'ชต'),
#  ('ซอสปรุงรส', 'ชต'),
#  ('ซีอิ้วขาว', 'ชต'),
#  ('น้ำตาลทราย', 'ชต'),
#  ('บะหมี่กึ่งสำเร็ึจรูปไวไว', 'ซอง'),
#  ('น้ำมันพืช', 'เล็กน้อย'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ไส้กรอก', 'ตามชอบ'),
#  ('กะหล่ำปลี', 'ตามชอบ'),
#  ('แครอท', 'ตามชอบ'),
#  ('น้ำตาลทราย', 'เล็กน้อย'),
#  ('พริกป่น', 'เล็กน้อย'),
#  ('หมูบด', 'กรัม'),
#  ('ใบกะเพรา', 'พอ'),
#  ('แครอท', 'ตามต้องการ'),
#  ('คนอร์อร่อยชัวร์', 'ชต.'),
#  ('ซอสหอยนางรม', 'ชต.'),
#  ('พริก กระเทียม', 'พอ'),
#  ('สันคอหมู', 'กรัม'),
#  ('กระเทียมไทย', 'กลีบ'),
#  ('พริกไทยดำ', 'เม็ด'),
#  ('ซีอิ๊วดำ', 'ช้อนชา'),
#  ('กุ้งสับ', 'ตัว'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('น้ำมันมะกอก', 'ช้อนชา'),
#  ('พริกไทยป่น', 'ช้อนชา'),
#  ('ซีอิ๊วขาว', 'ช้อนชา'),
#  ('ข้าวสวย', 'ทัพพี'),
#  ('เนื้อหมูสามชั้นหนาๆๆ', 'กรัม'),
#  ('พริกขี้หนูสีแดง', 'เม็ด'),
#  ('พริกหยวก', 'ตามใจชอบ'),
#  ('เกลือป่น', 'ช้อนชา'),
#  ('น้ำมันรำข้าว', 'ช้อนชา'),
#  ('กระเทียม ไท', 'กีบ'),
#  ('ต้นหอม', 'ต้น'),
#  ('น้ำปลาอย่างดี', 'ช้อนชา'),
#  ('น้ำสะอาด', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย ขาว', 'ช้อนชา'),
#  ('ไส้หมู', 'ขีด'),
#  ('ซอสภูเขา', 'ช้อน'),
#  ('ซีอิ้วเด็ก', 'ช้อน'),
#  ('ข้าวไรซ์เบอร์รี่หุงสุก', 'กรัม'),
#  ('ข้าวโพด', 'กรัม'),
#  ('ถั่วลันเตา', 'กรัม'),
#  ('ลูกเกด', 'กรัม'),
#  ('ถั่ว', 'กรัม'),
#  ('แครอท', 'กรัม'),
#  ('อกไก่', 'กรัม'),
#  ('ผักสลัดตกแต่งหัวจาน', 'กรัม'),
#  ('น้ำสลัดงาคั่วญี่ปุ่น', 'ช้อนโต๊ะ'),
#  ('น้ำมันรำข้าว', 'ช้อนโต๊ะ'),
#  ('ซอสปรุงรส', 'ช้อนโต๊ะ'),
#  ('ผงปรุงรสไก่', 'ช้อนชา'),
#  ('มะนาว', 'ผล'),
#  ('เส้นใหญ่', 'ถ้วย'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('น้ำมันพืช', 'เล็กน้อย'),
#  ('แครอท', 'ถ้วย'),
#  ('เห็ดนางรมหลวง', 'ถ้วย'),
#  ('ข้าวโพดอ่อน', 'ถ้วย'),
#  ('หมูสับ', 'ถ้วย'),
#  ('น้ำเปล่า', 'พอ'),
#  ('น้ำตาลทราย', 'ตามชอบ'),
#  ('น้ำมันหอย', 'ตามชอบ'),
#  ('อร่อยชัวร์', 'ตามชอบ'),
#  ('พริกขี้หนู', 'เมล็ด'),
#  ('กระเทียม', 'กลีบใหญ่'),
#  ('ซีอิ๊วดำเล็กน้อย', 'เล็กน้อย'),
#  ('ใบกะเพรา', 'ต้น'),
#  ('ข้าว', 'ถ้วย'),
#  ('หมูบด', 'ขีด'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('คะน้า', 'กำ'),
#  ('หอมใหญ่', 'ผล'),
#  ('มะเขือเทศ', 'ลูก'),
#  ('ซีอิ้วดำ', 'ชต'),
#  ('น้ำตาลทราย', 'ชต'),
#  ('ซอสปรุงรส', 'ชต'),
#  ('พริกไท', 'ชช'),
#  ('น้ำปลา', 'ชต'),
#  ('น้ำมันพืช', 'ชต'),
#  ('แป้งชุบทอด', 'ถ้วยตวง'),
#  ('แป้งข้าวเจ้า', 'ถ้วยตวง'),
#  ('แป้งมัน', 'ถ้วยตวง'),
#  ('รสดี', 'ช้อนชา'),
#  ('น้ำเย็นจัด', 'ถ้วยตวง'),
#  ('หอยแมลงภู่สด', 'กรัม'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('น้ำมัน', 'ถ้วยตวง'),
#  ('ผักชีต้นหอม', 'แล้วแต่ชอบ'),
#  ('พริกไทยป่น', 'แล้วแต่ชอบ'),
#  ('หมู', 'ขีด'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('คะน้า', 'ต้น'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('ซอสปรุงรส', 'ช้อนโต๊ะ'),
#  ('ผงปรุงรส', 'ช้อนชา'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('หอมใหญ่', 'หัว'),
#  ('แครอท หั่นเป็นลูกเต๋า', 'ช้อนโต๊ะ'),
#  ('ต้นหอม', 'ต้น'),
#  ('ข้าวสวย', 'ถ้วย'),
#  ('ปูอัดอย่างดี ฉีกเป็นเส้นๆ', 'ก่อเล็ก'),
#  ('ต้นหอม', 'ต้น'),
#  ('ผักชี', 'ตามชอบ ใส่ไม่ใส่ได้หมด'),
#  ('มายองเนส', 'ตามชอบ'),
#  ('มันแกว หรือ คึ่นช่ายฝรั่งหั่นเต๋า', 'ปริมาณตามชอบ'),
#  ('เกลือ พริกไทย มัสตาร์ด', 'ตามชอบ'),
#  ('ครัวซฮงท์ แบบไม่มีไส้', 'อัน'),
#  ('ผักสลัด', 'ใบ'),
#  ('ปลาทู', 'ตัว'),
#  ('ซีอิ้วขาว', 'ช้อนชา'),
#  ('คนอร์ซอสค้นปรุงรสหมู', 'ช้อนชา'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('พริก', 'เม็ด'),
#  ('น้ำสะอาด', 'ถ้วย'),
#  ('ปลาหมึกแช่', 'ตัว'),
#  ('หมูบด', 'ขีด'),
#  ('หอมใหญ่', 'หัว'),
#  ('พริกชี้ฟ้าเหลือง', 'เม็ด'),
#  ('โหระพา', 'กำ'),
#  ('น้ำตาลทราย', 'ชช'),
#  ('น้ำปลา', 'ชช'),
#  ('น้ำมันหอย', 'ชต'),
#  ('ซอสปรุงรส', 'ชช'),
#  ('น้ำมันพืช', 'ชต'),
#  ('ไข่ไก่เบอร์ 0', 'ฟอง'),
#  ('หมูยอหั่นชิ้นตามชอบ', 'ช้อนโต๊ะ'),
#  ('กุนเชียงหมูหั่นชิ้นตามชอบ', 'ช้อนโต๊ะ'),
#  ('หมูสับหยาบ', 'ช้อนโต๊ะ'),
#  ('ซอสปรุงรส', 'ช้อนโต๊ะ'),
#  ('พริกไทยป่น', 'ช้อนโต๊ะ'),
#  ('พริกไทยป่น', 'ช้อนโต๊ะ'),
#  ('ต้นหอยซอย', 'ช้อนโต๊ะ'),
#  ('เนยจืด', 'ช้อนชา'),
#  ('ไก่หั่น', 'กรัม'),
#  ('หอมใหญ่หั่นเสี้ยวบางๆ', 'กรัม'),
#  ('มะเขือเทศหั่นเสี้ยวบางๆ', 'กรัม'),
#  ('แครอทซอย', 'กรัม'),
#  ('พริกหวานสีเขียว สีแดง หั่นพอดีคำ', 'กรัม'),
#  ('ต้นหอมหั่นท่อน', 'ต้น'),
#  ('กระเทียมสับ', 'ช้อนโต๊ะ'),
#  ('แป้งมัน หรือ แป้งข้าวโพดละลายน้ำข้นๆ', 'ช้อนโต๊ะ'),
#  ('บะหมี่ลวก', 'ก้อน'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('ซอสมะเขือเทศ', 'ถ้วย'),
#  ('หมี่โคราชพร้อมซอส', 'ห่อ'),
#  ('เนื้อสัตว์', 'ตามชอบ'),
#  ('ถั่วงอก', 'ตามชอบ'),
#  ('ต้นกุยช่าย', 'ตามชอบ'),
#  ('น้ำเปล่า', 'ml'),
#  ('ไช้โป๊วสับ', 'เล็กน้อย'),
#  ('บะหมี่กึ่งสำเร็จรูปนิชชิน', 'ซอง'),
#  ('เชดด้าชีส', 'แผ่น'),
#  ('นมจืด', 'กล่อง'),
#  ('ไข่แดง', 'ฟอง'),
#  ('หัวหอมใหญ่', 'ตามชอบ'),
#  ('เกลือ', 'ตามชอบ'),
#  ('พริกไทย', 'ตามชอบ'),
#  ('เนย', 'ชิ้น'),
#  ('ไส้กรอก', 'อัน'),
#  ('เส้นสปาเก็ตตี้', 'กำมือ'),
#  ('ปลาหมึก', 'กรัม'),
#  ('โหระพา', 'กรัม'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('กระเทียม', 'ช้อนโต๊ะ'),
#  ('พริก', 'ช้อนชา'),
#  ('พริกไทยดำ', 'เล็กน้อย'),
#  ('เครื่องเทศอิตาเลียน', 'เล็กน้อย'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซีอิ้วขาว หรือ ซอสแมกกี้', 'ช้อนโต๊ะ'),
#  ('ข้าวสวยที่เย็นแล้ว', 'ถ้วย'),
#  ('เนื้อปู', 'ขีด'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('ต้นหอม', 'ต้น'),
#  ('หอมใหญ่', 'หัว'),
#  ('มะเขือเทศ', 'ลูก'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต๊ะ'),
#  ('ซอสถั่วเหลือง', 'ช้อนโต๊ะ'),
#  ('น้ำมันพืช', 'ช้อนโต๊ะ'),
#  ('เนื้อไก่ลอกหนัง', 'กรัม'),
#  ('ผักบุ้ง', 'ต้น'),
#  ('พริกชี้ฟ้าแดง', 'เม็ด'),
#  ('ผงขมิ้น', 'ช้อนโต๊ะ'),
#  ('เกลือป่น', 'ช้อนชา'),
#  ('น้ำปลา', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('น้ำตาลทราย', 'ช้อนโต๊ะ'),
#  ('กะเทียม', 'กลีบ'),
#  ('น้ำมันสำหรับผัด', 'ช้อนโต๊ะ'),
#  ('ซอสหอยนางรมย์', 'ช้อนโต๊ะ'),
#  ('ข้าวต้ม หรือ ข้าวสวย', 'ถ้วย'),
#  ('ทูน่าในน้ำแร่', 'กระป๋อง'),
#  ('ต้นหอมซอย', 'ตามชอบ'),
#  ('ไข่ไก่', 'ฟอง'),
#  ('น้ำซุปไก่', 'ถ้วย'),
#  ('เกลือ', 'นิดหน่อย'),
#  ('พริกไทย', 'ตามชอบ'),
#  ('ขาเห็ดหอมเจ', 'ถุง'),
#  ('คึ่นช่าย', 'ต้น'),
#  ('พริกขี้หนู', 'เม็ด'),
#  ('มะนาว', 'ลูก'),
#  ('อกไก่', 'อกใหญ'),
#  ('ข้าวบาสมาติ', 'กระป๋องตวงช'),
#  ('chicken biryani', 'กล่องนึง'),
#  ('ก้านพลู', 'ก้าน'),
#  ('อบเชย', 'แท่ง'),
#  ('พริกแห้ง', 'ลูก'),
#  ('มัสตาร์ดดำ', 'ช้อนชา'),
#  ('พริกปาปริก้า', 'ช้อนชา'),
#  ('หัวหอมหั่น', 'ถ้วย'),
#  ('มะเขือเทศหั่น', 'ลูก'),
#  ('หมู', 'โล'),
#  ('ใบกระเพรา', 'ต้น'),
#  ('น้ำตาลทราย', 'ช้อนชา'),
#  ('ซีอิ๊วขาว', 'ช้อนโต๊ะ'),
#  ('ซอสปรุงรส', 'ช้อนโต๊ะ'),
#  ('น้ำมันหอย', 'ช้อนโต'),
#  ('ซีอิ๊วดำ', 'ช้อนชา'),
#  ('น้ำเปล่า', 'แก้ว'),
#  ('พริกแดง', 'เม็ด'),
#  ('กระเทียมกลีบ', 'กลีบ'),
#  ('ผักกาดขาว', 'ใบ'),
#  ('ต้นหอม', 'ต้น'),
#  ('เห็ดออริจิน', 'ต้น'),
#  ('ผักชีฝรั่ง', 'ต้น'),
#  ('หมูบด', 'ช้อนโต๊ะ'),
#  ('พริกป่น', 'ช้อนโต๊ะ'),
#  ('มะนาว', 'ลูก'),
#  ('น้ำตาล', 'ช้อนชา'),
#  ('ข้าวคั่ว', 'ช้อนชา'),
#  ('น้ำพริกกะปิ', 'ช้อนโต๊ะ'),
#  ('ผักกาดแก้ว', 'ต้น'),
#  ('กระเทียม', 'กลีบ'),
#  ('ข้าวสวย', 'ถ้วย'),
#  ('ปลาทูแกะเนื้อ', 'ตัว'),
#  ('ซีอิ้วขาว', 'ช้อนโต๊ะ'),
#  ('เนื้อหมู', 'g'),
#  ('ผักบุ้ง', 'กำ'),
#  ('ลูกจันทน์', 'ลูก'),
#  ('ยี่หร่า', 'ช้อนชา'),
#  ('เม็ดผักชี', 'ช้อนชา'),
#  ('เม็ดพริกไทย', 'ช้อนชา'),
#  ('งาขาว', 'ช้อนชา'),
#  ('ก้านพลู', 'ก้าน'),
#  ('ถั่งลิงสงคั่วปน', 'ช้อนโต๊ะ'),
#  ('กะทิ', 'g'),
#  ('น้ำพริกเผา', 'ช้อนโต๊ะ'),
#  ('กุ้งแห้งป่น', 'ช้อนโต๊ะ'),
#  ('พริกแกง', 'ช้อนโต๊ะ'),
#  ('ปลากระป๋อง', 'กระป๋อง'),
#  ('พริกแกงเผ็ด', 'ขีด'),
#  ('พริกชี้ฟ้าแดง', 'เม็ด'),
#  ('ใบโหระพา', 'ต้น'),
#  ...]

# %%
len(all_ingredients)
# Out:
# 25014

# %%
uniq_ingredients = list((set(all_ingredients)))

# %%
len(uniq_ingredients)
# Out:
# 9571

# %%
ingredients_with_unit = {}
for ingre in uniq_ingredients:
  if ingre[0] not in ingredients_with_unit:
    ingredients_with_unit[ingre[0]] = []
  ingredients_with_unit[ingre[0]].append(ingre[1])

# %%
len(ingredients_with_unit.keys())
# Out:
# 5479

# %%
ingredients_with_unit
# Out:
# {'ยากิโชบะรสโชยุ': ['ซอง'],
#  'หัวไชเท้า': ['ลูก', 'อัน', '', 'หัวกลาง', 'หัวเล็ก', 'หัว'],
#  'สะตอ': ['ฟัก', 'แพ็ค', 'ตามชอบ', 'ฝัก', 'ต้น', 'ตามใจชอบ', 'เม็ด'],
#  'หอยเชลล์': ['กรัม', 'ตามชอบ', 'ตัว', 'ชิ้น', 'กิโลกรัม'],
#  'น้ำมันปาล์ม': ['cc', 'ถ้วย', 'ช้อนโต๊ะ', 'ทัพพี', 'ml', 'ถ้วยตวง', 'ขวด'],
#  'ไส้กรอกเวียนนา': ['ชิ้น'],
#  'เนื้อหมู': ['ตามต้องการ',
#   'โล',
#   'กิโลกรัม',
#   'ชิ้นใหญ่',
#   'ขีด',
#   'กรัม /  ถ้วยตวง',
#   'ตามใจชอบ',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'g.',
#   'แพค',
#   'ถ้วย',
#   '',
#   'ชิ้น',
#   'กรัม',
#   'g',
#   'kg',
#   'ถ้วยเล็ก',
#   'แพ๊ค',
#   'เล็กน้อย'],
#  'เห็ด': ['',
#   'กรัม',
#   'แพ็ค',
#   'หัว',
#   'ดอก',
#   'kg',
#   'ตามใจชอบ',
#   'ตามชอบ',
#   'ถ้วย'],
#  'วุ้นเส้นสด': ['กรัม', 'ห่อ', 'ห่อเล็ก', 'นิดหน่อย', 'ถุงเล็ก', 'ถ้วย'],
#  'หมูส่วนสันคอ': ['กิโลกรัม'],
#  'ใบกระวาน': ['ใบ'],
#  'ไส้กรอกไก่': ['', 'แท่ง', 'ชิ้น', 'กรัม'],
#  'น้ำตาลทรายแดง': ['. ช้อนชา',
#   'ชช',
#   'ช้อนชา',
#   'เล็กน้อย',
#   'ชต',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ'],
#  'กระดูกหมู': ['kg',
#   'ขีด',
#   'ก.ก.',
#   'กก',
#   'กิโล',
#   'กก.',
#   'ชิ้น',
#   'เส้น',
#   'กรัม',
#   'โล'],
#  'ปลากรอบ': ['ถ้วย', 'ตัว', ''],
#  'ไข่เจียว': ['ฟอง'],
#  'เส้นบุก': ['ห่อ', 'ถุง', 'ตามชอบ', 'กรัม'],
#  'พริก': ['ขีด',
#   'แล้วแต่ขอบ',
#   'ตามชอบ',
#   'โรยหน้า',
#   '',
#   'ลูก',
#   'กำ',
#   'ดอก',
#   'เม็ด',
#   'ช้อนชา',
#   'ถ้าชอบ'],
#  'น้ำจิ้มซีฟู้ด': ['ช้อนโต๊ะ', 'ถ้วยน้ำจิ้ม', 'ถ้วย'],
#  'มะนาวฝาน': ['ลูก', 'แผ่น', 'ชิ้น'],
#  'มาม่า โอเรียนทอล': ['ห่อ'],
#  'น้ำมันสำหรับผัดไก่': ['ช้อนโต๊ะ'],
#  'สะโพกไก่ทอดเลาะกระดูกหั่นเป็นชิ้นพอคำ': ['ชิ้น'],
#  'ยอดผักกระเฉด': ['ถ้วย'],
#  'ผงปรุงรสคนอร์': ['ชช.',
#   '',
#   'ช้อนโต๊ะ',
#   'ชช',
#   'ช้อนชา',
#   'เล็กน้อย',
#   'ชต',
#   'ช.ช',
#   'ตามชอบ',
#   'ช.ช.'],
#  'น้ำเชื่ิอมใบเตย': ['ช้อนโต๊ะ'],
#  'พริกหวานหั่นชิ้นพอคำ': ['กรัม'],
#  'บลอคโคลี่': ['หัว'],
#  'กระเทียมปอกเปลือก': ['หัว', 'เม็ด'],
#  'กระดาษฟอยล์สำหรับห่อแซนวิช': [''],
#  'กระเพรา': ['กำมือ',
#   'ถ้วย',
#   'ก้าน',
#   'ต้น',
#   'แล้วแต่ชอบ',
#   'กำ',
#   'มัด',
#   'ตามชอบ',
#   'นิดหน่อย',
#   '',
#   'กิ่ง'],
#  'ผงปรุงรสหมู สูตรไม่ใส่ผงชูรส': ['ชช'],
#  'ซีอิ๊วเห็ดหอม': ['แล้วแต่ชอบ', 'ตามต้องการ', 'ช้อนโต๊ะ', 'ช้อนชา'],
#  'น้ำตาลปิ๊บ': ['ทัพพี', 'ช้อนชา', 'ช้อนใหญ่', '', 'ช้อนโต๊ะ'],
#  'เส้นพาสต้าเฟตูชินี่แห้ง': ['g'],
#  'น้ำส้มสายชู': ['ชต.',
#   'ช้อน',
#   'กรัม',
#   'ชต',
#   'ตามชอบ',
#   'กระบวย',
#   'ขวด',
#   'ถ้วย',
#   'ช้อนโต๊ะ',
#   'ตามความชอบ',
#   'ทัพพี',
#   'ช้อนชา',
#   'กะเอา'],
#  'ข้าวสารหอมมะลิ': ['ถ้วยตวง', 'ถ้วย'],
#  'น้ำสต๊อกเนื้อ': ['ถ้วย'],
#  'ขิงขูดละเอียด': ['ชต', 'ช้อนชา'],
#  'ผักกาดดอง': ['ตามชอบ', 'กระป๋องเล็ก', 'กระป๋อง', 'หัว'],
#  'แครอทซอย': ['กรัม', 'ตามชอบ', 'ถ้วยเล็ก', 'ช้อนโต๊ะ', 'แว่น'],
#  'ซีอิ๋วขาว': ['ช้อนชา',
#   'ชต.',
#   'กรัม',
#   'ตามชอบ',
#   'กระบวย',
#   'ชช.',
#   '',
#   'ช้อนโต๊ะ'],
#  'ผักกาดหอม': ['กรัม', 'ตามชอบ', '', 'กิโลกรัม', 'ใบใหญ่', 'ต้น', 'ใบ'],
#  'ไม้หอม': ['ห่อเล็ก'],
#  'Rice Wine': ['ช้อนโต๊ะ'],
#  'Emmental Cheese': ['ห่อ'],
#  'เส้นหมี่เหลืองเจ': ['ห่อ'],
#  'ปลาทูแกะเอาแต่เนื้อ': ['ตัว'],
#  'หมูหมัก': ['ช้อนโต๊ะ', 'ช้อน', 'กรัม', 'kg', 'ขีด'],
#  'นมสด': ['มิลลิลิตร',
#   'นิดหน่อย',
#   'ชต',
#   'มล.',
#   'ml.',
#   'ถต.',
#   'ถ้วย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ml',
#   'กล่อง',
#   'ช้อนชา',
#   'ซีซี',
#   'กล่องเล็ก',
#   'cc',
#   'oz',
#   'ถ้วยตวง'],
#  'ข้าวเปล่า': ['กรัม', 'cup', 'ตามชอบ', 'ถ้วย'],
#  'เส้นอุด้ง': ['มัด', 'ถุง', 'ตามช', 'กรัม'],
#  'ข้าวโพดหวาน': ['กรัม', 'ฟัก', 'ฝัก', 'ชต.'],
#  'ส้ม': ['ลูก'],
#  'โป็ยกั๊ก': ['กรัม'],
#  'หอมหัวใหญ่ หั่นชิ้นใหญ่': ['หัว'],
#  'เห็ดเข็มทอง': ['ขีด',
#   'ตามชอบ',
#   'แพค',
#   '',
#   'กรัม',
#   'ห่อ',
#   'แพ็ค',
#   'g',
#   'กำ',
#   'ตามใจชอบได้เลยจ้า',
#   'ถุง',
#   'ห่อเล็ก',
#   'kg'],
#  'บล็อคเคอรี่': ['ชิ้นเล็ก'],
#  'ซี่อิ๋วขาวสูตร1': ['ช้อนชา', 'ช้อนโต๊ะ'],
#  'กระชาย': ['แง่ง',
#   'กำมือ',
#   'ถ้วยเล็ก',
#   'กลีบ',
#   'ขีด',
#   'เหง้า',
#   'ตามชอบ',
#   'ตามต้องการ',
#   'ก้าน',
#   'ช้อนโต๊ะ',
#   'แท่ง',
#   'กรัม'],
#  'ใบโหรพา': ['ต้น', 'มัด', 'กำมือ', 'กำ', 'ตามชอบ'],
#  'รากผักชี': ['ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   ',ราก',
#   'หัว',
#   'kg',
#   'ราก',
#   'ตามชอบ',
#   '',
#   'ต้น'],
#  'เนื้อปลาสลิด': ['ตัว'],
#  'Bacon Chunk': ['slaps'],
#  'ผักโรยสำหรับตกแต่ง': [''],
#  'ผักหวาน': ['ตามชอบ'],
#  'ใบแมงลัก': ['กำ', 'กรัม', 'ต้น'],
#  'มะเขือเทศ puree': ['g'],
#  'หมูสับหมักกับน้ำตาลทราย ซอสปรุงรส พริกไทย': ['กรัม'],
#  'ขึ้นฉ่ายหั่นท่อนยาว หั่นละเอียด': ['ท่อน'],
#  'มะเขือ': ['ลูก', ''],
#  'น้ำส้ม-เกลือ': ['ช้อนชา'],
#  'ใบโหระพา': ['ขีด',
#   'กำใหญ่ๆ',
#   'ตามใจชอบ',
#   'ใบ',
#   'กำมือ',
#   'ก้าน',
#   'หยิบมือ',
#   'กรัม',
#   'ต้น',
#   'กิ่ง',
#   'แล้วแต่ชอบ',
#   'กำ',
#   'ช่อ',
#   'ตามชอบ',
#   'บาท',
#   'ถ้วยเล้ก',
#   'ตามต้องการ',
#   'นิดหน่อย',
#   'ถ้วย',
#   ''],
#  'คนอร์ซุปก้อนรสต้มยำ': ['ก้อน'],
#  'น้ำพริกมันกุ้ง': ['ชต.', 'ช้อนโต๊ะ'],
#  'เนื้อหมูตรงสันคอ': ['กรัม'],
#  'ใบกุยช่าย': ['กำ', 'ช้อนโต๊ะ', 'กรัม'],
#  'ซอสปรุงรส ฝาเขียว': ['ช้อนโต๊ะ'],
#  'Lobster 0.7-1kg': ['ตัว'],
#  'กระเทียมสับหยาบ': ['ถ้วย', 'ช้อนโต๊ะ', 'หัว', 'กลีบ', 'กรีบ', 'กีบ', 'เม็ด'],
#  'พริกไทยดำบด.': ['เล็กน้อย'],
#  'หมูบด,สับ แบบมีมันเล็กน้อย': ['กรัม'],
#  'น้ำสลัดงาคั่วญี่ปุ่น': ['ช้อนโต๊ะ', 'ถ้วย'],
#  'ผงกระหรี่': ['ชช', 'ช้อนชา', 'นิดหน่อย', 'ชต.', 'ช้อนโต๊ะ', 'ซอง'],
#  'ซีอิ้วขาว': ['ชต',
#   'ขาว',
#   'ตามชอบ',
#   'ช้อนขาว',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ชช',
#   'โต๊ะ',
#   'ช้อนชา',
#   'tbsp',
#   'ช้อนโต้ะ',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'กรัม',
#   'นิดหน่อย',
#   'ซ้อนโต้ะ',
#   'เหยาะ'],
#  'หอมหัวใหญ่ขนาดกลาง': ['หัว'],
#  'เพนเน่': ['ถ้วย', 'ก.'],
#  'กระเทียม': ['เม็ด',
#   'ช้อนชา',
#   'ซีก',
#   'กำมือ',
#   'ชต.',
#   'เล็กน้อย',
#   'บาท',
#   'กลีบ',
#   'กลีบเล็ก',
#   'กลับ',
#   'กรัม',
#   'กลีบใหญ่',
#   'ถ้วยตวง',
#   'หัว',
#   'แล้วแต่ชอบ',
#   'ขีด',
#   'กำ',
#   'กลีบกลาง',
#   'ชต',
#   'ตามใจชอบ',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'หัวทุบ',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'กลีบกลางๆ',
#   'กรีบ',
#   'กรัมมือ',
#   'หัวใหญ่',
#   'กีบ'],
#  'หัวกะทิ': ['ถ้วย', 'กรัม', 'ถ้วยตวง', 'โล', 'กิโล', 'มล.'],
#  'มิโสะ': ['ช้อนโต๊ะ'],
#  'น้ำมันพืช สำหรับผัด': ['ช้อนโต๊ะ'],
#  'มะเขือเทศเข้มข้น': ['g', 'กระป๋อง'],
#  'เต้าหู้ขาวแข็ง': ['ก้อน', 'แผ่น'],
#  'เนื้อสัตว์ และลูกชิ้นต่างๆ': ['กรัม'],
#  'เกี้ยวกุ้งสำเร็จรูป': ['ห่อ'],
#  'เบคอน,ขิงแก่,กระเทียม,พริกไทยขาว,พริกไทยดำ,คื่นช่าย': [''],
#  'พริกไทย': ['เหยาะ',
#   'นิดหน่อย แล้วแต่ชอบ',
#   'ตามใจฉัน',
#   'ชต',
#   'ตามชอบ',
#   'พอ',
#   'หลายๆเหยาะ',
#   'โรยหน้า',
#   'ชช.',
#   'ปลายช้อน',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ชช',
#   'หยิบ',
#   'หน่อย',
#   'ปรุงรสตามชอบ',
#   'เม็ด',
#   'ช้อนชา',
#   'ช้อนโต้ะ',
#   'เล็กน้อย ตามชอบ',
#   'กก',
#   'ts',
#   'ชต.',
#   'หยิบมือ',
#   'เล็กน้อย',
#   'ช้อน',
#   'กรัม',
#   'ตามชอ',
#   'นิดหน่อย',
#   'ปรุงรส',
#   'แล้วแต่ชอบ'],
#  'ดาชิ': ['ถ้วยตวง', 'ถ้วย'],
#  'พริกขี้หนูแดง': ['เม็ด', 'เม็ดโรยหน้า', 'เล็กน้อย', 'ตามชอบ'],
#  'เส้นสปาฯ': ['กรัม'],
#  'ไข่ไก่ตี': ['ฟอง'],
#  'ซีอิ้วขาวไม่ใส่วัตถุกันเสีย': ['ช้อนโต๊ะ'],
#  'โอวิลติน': ['ชต'],
#  'ขิงแก่': ['ช้อนโต๊ะ', 'แง่ง', 'หัว', 'กรัม'],
#  'พริกเขียวหวาน': ['เม็ด'],
#  'หมูหั่นชิ้น': ['ขีด', '', 'ชิ้น', 'g', 'กรัม'],
#  'เบคอน': ['ห่อ',
#   'แผ่นยาว',
#   'ขีด',
#   'แผ่นอวบๆ',
#   'ตามชอบ',
#   'ชิ้น',
#   'เส้น',
#   'แผ่น',
#   'กรัม'],
#  'แป้งสาลี': ['ถ้วย', 'ชต.', 'ช้อนโต๊ะ', 'กรัม'],
#  'ตังฉ่าย': ['เล็กน้อย', 'ช้อนโต๊ะ', 'ตามชอบ'],
#  'ไข่ดาว': ['ฟอง'],
#  'พริกไทยบุพอแตกใส่น้ำซุป': ['ช้อนชา'],
#  'กุนเชียงอย่างดี': ['ชิ้น', 'ชิ้นโต'],
#  'น้ำตาล-หมักหมู': ['ช้อนโต๊ะ'],
#  'เนย': ['ชต.',
#   'เล็กน้อย',
#   'กรัม',
#   'ก้อนเล็ก',
#   'ชต',
#   'ตามชอบ',
#   'ก.',
#   'ตามต้องการ',
#   'ถ้วย',
#   '',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'ก้อน',
#   'g',
#   'ช้อนชา',
#   'ช้อนโต้ะ'],
#  'เนื้อไก่สับหยาบ': ['ถ้วย'],
#  'ข้าวสวยที่เย็นแล้ว': ['ถ้วย'],
#  'ซอสปรุงรสฝาเขียว': ['ทัพพี',
#   'ช้อนชา',
#   'ช้อน',
#   'ชต',
#   'กระบวย',
#   '',
#   'ช้อนโต๊ะ'],
#  'สาเก': ['ช้อนโต๊ะ', 'ชต', 'ถ้วย', 'ช้อนชา'],
#  'น้ำมัน ถั่วเหลือง': ['ช้อนโต๊ะ', 'ทัพพี'],
#  '- ผักชีใบเลื่อย': ['ต้น'],
#  'เต้าหู้ปลา': ['แล้วแต่ชอบ', 'แพค', 'อัน'],
#  'ถั่วฝักยาวซอยลวก': ['ตามชอบ'],
#  'มิ้นท์': ['ตามความเหมาะสม'],
#  'ผักกึ้นฉ่าย': ['ต้น'],
#  'ปลาซุกิ': ['g', 'กรัม'],
#  'เนื้อปลานิล': ['ตัว'],
#  'น้ำมันพืช': ['tbs',
#   'mL',
#   'ชต',
#   'พอท่วมกระเทียม',
#   'ถ้วยเล็ก',
#   'กระบวย',
#   'ขวด',
#   'พอ',
#   'ตามชอบค่ะ',
#   'ช.ต',
#   'มิลลิลิตร',
#   'ชช.',
#   'ถ้วย',
#   'ลิตร',
#   'กะให้ท่วมหมูขึ้นมาหน่อย',
#   '',
#   'ช้อนโต๊ะ',
#   'ของกระทะ',
#   'สำหรับผัด',
#   'กระทะ',
#   'สำหรับทอด',
#   'ชช',
#   'ทัพพี',
#   'กะให้พอท่วมหนังปลา',
#   'มล.',
#   'ช้อนชา',
#   'ช.ต.',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'กรัม',
#   'ถ้วยตวง',
#   'ถ้วย   ชต',
#   'นิดหน่อย'],
#  'หมูนุ่มหมักแล้วที่ขายเป็นหมูกะทะ': ['ขีด'],
#  'พริกแกงเขียวหวานสำเร็จรูปตามตลาดสด': ['บาท'],
#  'ปลาดุกหั่นชิ้น': ['ตัว'],
#  'ใบยี่หร่า': ['กำ', 'ใบ'],
#  'น้ำเปล่า/น้ำซุป': ['ช้อนชา', 'ถ้วย'],
#  'แป้งข้าวเจ้า': ['กรัม', 'ถ้วยตวง', 'ช้อนโต๊ะ'],
#  'ต้นกระเทียมญี่ปุ่น': ['ต้น'],
#  'พริกเขียวแดง': ['เม็ด'],
#  'ไข้เท้า': ['เล็กน้อย'],
#  'กระเทียมสับ': ['',
#   'ขีด',
#   'หัวเล็ก',
#   'กรีบ',
#   'ชต',
#   'ชัอนโต๊ะ',
#   'ชช',
#   'ตามใจชอบ',
#   'ช้อนชา',
#   'ช.ต.',
#   'ปริมาณตามชอบ',
#   'ชช.',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กลับ',
#   'กรัม',
#   'g',
#   'หัว',
#   'แล้วแต่ชอบ',
#   'ตามชอบ',
#   'บาท',
#   'กลีบ',
#   'กลีบใหญ่',
#   'ตามต้องการ',
#   'ช.ต',
#   'นิดหน่อย',
#   'ช็อนโต๊ะ'],
#  'หนวดปลาหมึกกล้วย': ['กิโลกรัม'],
#  'ซีอิ๊วญี่ปุ่น': ['ช้อนโต๊ะ', ''],
#  'หัวหอมซอย': ['ช้อนโต๊ะ', 'หัว', 'ถ้วย'],
#  'หางกะทิ': ['ถ้วยตวง', 'ถ้วย', 'กรัม'],
#  'ซี้ออิ้วหวาน': ['ช้อนโต๊ะ'],
#  'พริกแดงใหญ่': ['เม็ด'],
#  'ข้าวสวยหอมมะลิหุงค้างคืน': ['ถ้วย'],
#  'กุ้งแช่แข็งปอกเปลือก': ['กิโลกรัม'],
#  'ซ้อสปรุงรส': ['ช.ต.', 'ชช.'],
#  'เกี้ยมอี๋': ['กรัม'],
#  'น้ำซุปผัก': ['นิดหน่อย'],
#  'สันนอกสไลด์': ['แพ็ค'],
#  'หอนแครง': ['ตัว'],
#  'งาขาว สำหรับเเต่งหน้า': [''],
#  'ดอกไม้จีน': ['ช้อนโต๊ะ'],
#  'ผงนัว': ['', 'ช้อนชา'],
#  'น้ำมัน.': ['. ช้อนชา'],
#  'พริกไทยดำโขลก': ['ช้อน'],
#  'น้ำสต็อกไก่': ['ถ้วย'],
#  'คนอร์ซอสเข้มข้น': ['ช้อนโต๊'],
#  'ซอสเทริยากิ': ['ชต', 'ช.ต.', '', 'ช้อนโต๊ะ'],
#  'ผัก': ['', 'ตามความชอบ', 'ตามใจชอบ', 'ตามชอบ'],
#  'น้ำเปล่า': ['กระบวย',
#   'ม.ล',
#   'ขวด',
#   'cc',
#   'ml.',
#   'ใส่ท่วมหมู',
#   'มิลลิลิตร',
#   'นิดหน่อย',
#   'ถ้วย',
#   'ลิตร',
#   '',
#   'กิโลกรัม',
#   'ช้อนโต๊ะ',
#   'กระทะ',
#   'ตามใจชอบ',
#   ',มิลลิลิตร',
#   'ทัพพี',
#   'พอเหมาะ',
#   'พอ',
#   'มล.',
#   'ช้อนชา',
#   'ช.ต.',
#   'แก้วเล็ก',
#   'g.',
#   'ถต.',
#   'ถต',
#   'ชต.',
#   'เล็กน้อย',
#   'ถ้าย',
#   'ช้อน',
#   'กรัม',
#   'ข้อนชา',
#   'ml',
#   'สำหรับลวกเส้น',
#   'ข้อนิ้ว',
#   'ถ้วยน้ำจิ้ม',
#   'ถ้วยตวง',
#   'ตามความเหมาะสม',
#   'tbs',
#   'ท่วมหมู',
#   'มิลลิลตร',
#   'มล',
#   'หม้อ',
#   'แก้ว',
#   'ชต',
#   'ถ้วน',
#   'แก้วกาแฟ',
#   'ตามชอบ',
#   'ถ้วยเล็ก'],
#  'ขนมปังขาว': ['แผ่น'],
#  'ผักขี': ['ต้น'],
#  'ผักเครื่องเคียง': ['', 'ตามชอบ'],
#  'บะหมี่กึ่งสำเร็จรูป': ['', 'ซอง', 'ห่อ', 'ก้อน'],
#  'หมูหยอง': ['ช้อนโต๊ะ', 'ตามชอบ', '', 'ขีด', 'หยิบมือ'],
#  'น้ำมะนาวสด': ['ช้อนโต๊ะ'],
#  'หมูสันใน/หมูสามชั้น': ['ขีด'],
#  'ซอสภูเขาทองตราลุงหนวด': ['ช้อนโต๊ะ'],
#  'น้ำมันงา': ['ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'สำหรับทอด',
#   'ชช',
#   'ช้อนชา',
#   'tbsp',
#   'ชต.',
#   'ช้อน',
#   'ถ้วยตวง',
#   'ชต',
#   'ช.ช',
#   'กะเอา',
#   'ชช.',
#   ''],
#  'ใบมะกรูดฉีก': ['กรัม', 'ตามชอบ', '', 'ใบ'],
#  'เต้าหูปลาสอดไส้ชีสใส่อะไรลงไปก็ได้ตามความชอบ': ['กรัม'],
#  'พริก หอมแดง มะนาว': ['ตามชอบ'],
#  'กะทิ': ['ทัพพี',
#   'มล.',
#   'กระป๋อง',
#   'ถ้วย',
#   'ชต.',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ml',
#   'g',
#   'Ml',
#   'กก',
#   'ถ้วยเล็ก',
#   'กล่องเล็ก',
#   'มิล.',
#   'มิลลิลิตร',
#   'ขวดเล็ก',
#   'ลิตร',
#   'มล',
#   'กล่อง',
#   'กิโล'],
#  'คากิ หรือ คากะ': ['แล้วความแต่ต้องการ'],
#  'หมูยอพริกไทยอุบล': ['ท่อนใบตอง'],
#  'ข้าวสาร': ['กำมือ', 'กรัม', 'ถ้วยตวง', 'กป.', 'ถ้วย'],
#  'อาหารทะเลลวกสุกตามต้องการ': ['ถ้วย'],
#  'พริกป่นเกาหลี': ['ช้อนโต๊ะ', 'ชต.'],
#  'น้ำจิ้มสุกี้': ['ตามชอบ',
#   'ขวด',
#   'ปริมาณตามชอบ',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ช้อนโต้ะ'],
#  'สันนอกหมู': ['กรัม', '.  กรัม'],
#  'ไส้กรอกอกไก่ชีส ของFarmfresh': ['ชิ้น'],
#  'เกลือ': ['tps',
#   'ปรุงรสตามชอบ',
#   'พอ',
#   'ชต ชช',
#   'ช้อนชา',
#   'กะเอา',
#   'สำหรับปรุงรส',
#   'หยิมมือ',
#   'โรยบางๆพอค็มปะเเล่ม',
#   'กำมือ',
#   'นิดนึง',
#   'ปลายช้อน',
#   'ชต.',
#   'หยิบมือ',
#   'เล็กน้อย',
#   'ถุง',
#   'ช้อน',
#   'ปลายหยิบมือ',
#   'หนึ่งหยิบมือ',
#   'กรัม',
#   'ปรุงรส',
#   'tbs',
#   'ชต',
#   'ประมาน  ช้อน',
#   'ช.ช',
#   'ตามชอบ',
#   'ts',
#   'หยิบนิ้วมือ',
#   'ช.ช.',
#   'ตามต้องการ',
#   'ชช.',
#   'นิด',
#   'นิดหน่อย',
#   '',
#   'กิโลกรัม',
#   'ช้อนโต๊ะ',
#   'ปลายช้อนชา',
#   'ตามความชอบ',
#   'เหยาะๆ ลงไป',
#   'กระจับมือ',
#   'ชช',
#   'ไม่ช้อนชา',
#   'ตามใจชอบ'],
#  'น้ำตาลมะพร้าว': ['ชต', 'ช้อนโต๊ะ', 'ช้อนชา'],
#  'หอมหัวใหญ่สับ': ['หัว', 'ช้อนโต๊ะ'],
#  'ใบกะเพรา': ['แล้วแต่',
#   '',
#   'ตามใจชอบ',
#   'พอ',
#   'ใบ',
#   'หากชอบ',
#   'กำมือ',
#   'ถ้วย',
#   'ก้าน',
#   'กำใหญ่',
#   'กรัม',
#   'แล้วแต่ความชอบ',
#   'ต้น',
#   'กิ่ง',
#   'แล้วแต่ชอบ',
#   'กำ',
#   'ตามชอบ',
#   'หยิบมือแล้วแต่ชอบ',
#   'ใส่ตามชอบ'],
#  'กุ้งสด หรือ': ['ขีด'],
#  'น้ำมันหอมเจียว': ['ช้อนชา'],
#  'ใบโหะพา': ['กรัม'],
#  'เส้นสปาเกตตี้โฮลวีท': ['กรัม'],
#  'หอมใหญ่สับ': ['ตามชอบ', 'ถ้วย', 'ช้อนโต๊ะ', 'หัว', 'ลูก', 'ถ้วยตวง'],
#  'น้ำอุ่น': ['ชต', 'กรัม'],
#  'พริกไทยป่นสำหรับโรยหน้า': ['ช้อนชา', 'เล็กน้อย'],
#  'เส้นจัน 1หยิบมือ': ['หยิบมือ'],
#  'เกลือ หรือ น้ำปลา': ['ช้อนชา', 'ช้อนชา /  ช้อนโต๊ะ'],
#  'ถั่วลิสงคั่วป่น': ['ถ้วย', 'ช้อนโต๊ะ'],
#  'มันหมูสไลด์หันบางเป็นเส้น': ['กก'],
#  'น้ำสต๊อกเปลือกกุ้ง': ['ชต'],
#  'Baxters Cream of Mushroom': ['กระป๋อง'],
#  'ซีอิ๊วดำ': ['ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'นิดหน่อย',
#   'ชต',
#   'ตามชอบ',
#   'ชช.',
#   'ปลายช้อน',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ชช',
#   'เหยาะ',
#   'ช้อนชา'],
#  'ฟักทอง': ['ชิ้น', 'กรัม', 'g', 'ลูก', 'ถ้วยตวง', 'ชิ้นเล็ก', 'ลูกเล็ก'],
#  'งาขาว': ['ชต',
#   'ตามชอบ',
#   'สำหรับเสิร์ฟ',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ช้อนชา',
#   'ชต.',
#   'เล็กน้อย',
#   'แล้วแต่ชอบ'],
#  'ผงหมักหมูแดงสำเร็จรูป': ['ซอง'],
#  'ข้าวโพดอ่อนหั่นแว่นหนาๆ': ['กรัม'],
#  'เนื้อหมู หั่นแผ่นหนา': ['ชิ้น'],
#  'น้ำปลาอย่างดี': ['ช้อนชา', 'ช้อนโต๊ะ', 'ชต'],
#  'แกงไตปลา': ['ช้อนโต๊ะ'],
#  'น้ำสะอาดอุณหภูมิห้อง': ['ลิตร'],
#  'ซอสแมคกี้': ['ชช', 'ชต'],
#  'น้ำมัน พืช': ['ช้อนโต๊ะ'],
#  'กระดูกเล้ง': ['กก', 'กรัม', 'โล', 'ชิ้น'],
#  'หมี่ข้าวแช่น้ำผัดซีอิ้วดำหวาน': ['ห่อ'],
#  'หมูสไลด์': ['g', 'กรัม', 'ขีด', 'ตามชอบ', '', 'แผ่น'],
#  'น้ำมันหอย': ['ตามชอบ',
#   'ช้อนโต',
#   'ช.ต.',
#   'ถต.',
#   'ช.ต',
#   'ชช.',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ช้อยโต๊ะ',
#   'ช่อนชา',
#   'เหยาะๆ ลงไป',
#   'ใช้ปรุงรส',
#   'ชช',
#   'tbs',
#   'ทัพพี',
#   'เหยาะ',
#   'ช้อนชา',
#   'ช้อนโต้ะ',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'ข้อนชา',
#   'ถ้วยตวง',
#   'นิดหน่อย',
#   'ข้อนโต๊ะ',
#   'ชต',
#   'ชอนโต๊ะ',
#   'ช้อนโต๊'],
#  'ผงปรุงรส/พริกป่น/น้ำส้มสายชู/น้ำปลา': ['ตามชอบ'],
#  'ผงกระเทียม': ['ชต.', 'ตามชอบ', 'ชช.', '', 'ช้อนโต๊ะ'],
#  'หัวชายเท้า': ['หัว'],
#  'เครื่องแกงมัสมั่น': ['ช้อนโต๊ะ'],
#  'ออริกาโน': ['ตามชอบ', 'ช้อนโต๊ะ', 'ชช'],
#  'เห็ดฟาง': ['ถ้วย', 'ตามใจชอบ', 'กรัม', 'หัว', 'ลูก', 'ขีด', 'ดอก', 'ตามชอบ'],
#  'ข้าวกล้องผสมข้าวไรซ์เบอร์รี่': ['ทัฟพี'],
#  'ไชโป๊ป': ['ชต.'],
#  'น้ำมันหอยสูตร1': ['ช้อนโต๊ะ'],
#  'ใบสาระแหน่': ['หยิบ', 'กรัม'],
#  'น้ำเย็ร': ['ถ้วยตวง'],
#  'หมูสับ': ['ถ้วย',
#   '',
#   'กก.',
#   'กิโลกรัม',
#   'ถ้วยซุป',
#   'ขีด',
#   'ตามใจชอบ',
#   'กิโล',
#   'ทัพพี',
#   'พอ',
#   'ตามใจขอบเลยจ้า',
#   'ขึด',
#   'นิดนึง',
#   'ชต.',
#   'kg.',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ช้ินโต๊ะ',
#   'g',
#   'kg',
#   'ชต',
#   'กก',
#   'สำหรับจาน',
#   'ตามชอบ',
#   'ถ้วยเล็ก',
#   'บาท',
#   'กรัม ตามชอบ',
#   'ขีเ',
#   'ถ้วยตวง'],
#  'พริกไทป่น': ['ช้อนโต๊ะ',
#   'ตามชอบ',
#   '',
#   'ชช',
#   'ตามใจชอบ',
#   'ช้อนชา',
#   'เล็กน้อย'],
#  'spaghetti': ['g'],
#  'สาระแหน่ โรย': ['นิดหน่อย'],
#  'ซอสฝาเหลืองสูตรคั่วกะทะ': ['ช้อนโต๊ะ'],
#  'สปาเกตตี': ['กก', 'กรัม'],
#  'งาขาวตามชอบ': [''],
#  'ตับไก่ติดหัวใจไม่กึ๋น': ['ตับ'],
#  'หมู หั่นชิ้น': ['กรัม'],
#  'แป้งมัน': ['พอ',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'ชช',
#   'ช้อนชา',
#   'ชต.',
#   'ช้อน',
#   'กรัม',
#   'ถ้วยตวง',
#   'ชต'],
#  'นม': ['g', 'ถ้วย', 'ช้อนโต๊ะ'],
#  'มักกะโรนี ดิบ': ['กรัม'],
#  'ซุปก้อนรสหมู': ['ก้อน'],
#  'ถั่วงอก': ['กก',
#   'กำมือ',
#   'หยิบมือ',
#   'บาท',
#   'ถุง',
#   'กรัม',
#   'ถ้วยตวง',
#   'kg',
#   'ขีด',
#   'กำ',
#   'ตามขนาดชอบ',
#   'ตามชอบ',
#   'กิโล',
#   'ถุงเล็ก',
#   'ถ้วย',
#   '',
#   'กก.',
#   'ถั่วตวง',
#   'ตามใจชอบ'],
#  'พาสต้า': ['g', 'ก.', 'ถ้วย', 'กรัม'],
#  'ซีอิ๊วขาว โลว์โซเดียม': ['ตามชอบ'],
#  'ข้าวโพดอ่อน ผ่าครึ่ง หั่นชิ้นพอ': ['กรัม'],
#  'เต้าเจี้ยว': ['ชต',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'เหยาะๆ ลงไป',
#   'ชช',
#   'ทัพพี',
#   'ช้อนชา',
#   'ชต.',
#   'ถ้วยตวง',
#   'แล้วแต่ชอบ'],
#  'น้ำมันมะกอก': ['ตามชอบ',
#   '',
#   'ชต',
#   'ชช',
#   'tps',
#   'ทัพพี',
#   'มิลลิกรัม',
#   'ช้อนชา',
#   'เล็กน้อยสำหรับทอด',
#   'ถ้วย',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'สเปรย์',
#   'กะเองนะ',
#   'g',
#   'ช้อนโต๊ะ   ช้อนโต๊ะ'],
#  'หมูแดง': ['ขีด', 'กรัม', 'เส้น', 'จาน'],
#  'สตอเบอรี่สด': ['กรัม'],
#  'เกี้ยวปูอัดนึ่ง จากสูตรก่อนหน้า': ['ชิ้น'],
#  'คะน้า': ['ตามชอบ',
#   'กิโล',
#   '',
#   'กำเล็ก',
#   'ต้น',
#   'g',
#   'ใบ',
#   'มัด',
#   'กำมือ',
#   'ก้าน',
#   'กรัม',
#   'ถ้วยตวง',
#   'แล้วแต่ชอบ',
#   'kg',
#   'ขีด',
#   'กำ'],
#  'กระเทียมโขลกหยาบๆ': ['กลีบ'],
#  'พริกแกงใต้หรือพริกแกงแดง': ['ชต.'],
#  'ผงแกงกะหรี่': [''],
#  'ข้าวสวนค้างคืน': ['ถ้วย'],
#  'เห็ดหอมแช่น้ำหั่นชิ้นตามขวาง': ['ดอก'],
#  'ชีอิ้วขาว': ['ชช', 'ชต.', 'ช้อน'],
#  'กระเทียมซอย': ['กลีบ',
#   'ตามชอบใจ',
#   'กีบ',
#   'ช้อนชา',
#   'ช้อนโต๊ะ',
#   'หัว',
#   'ขีด'],
#  'ม่าม่าโอเรียลทอลคิทเช่น รสฮอตแอนด์สไปซี่': ['ห่อ'],
#  'ผัดกาดขาว': ['ตามชอบ', 'ใบ'],
#  'เนื้อหมูหั่นเป็นชิ้น': ['กรัม'],
#  'เกลือป่น': ['ชต.',
#   'หยิบมือ',
#   'เล็กน้อย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ชต',
#   'ตามชอบ',
#   'ชข.',
#   'ช้นชา',
#   'ชช.',
#   'นิดหน่อย',
#   '',
#   'ปลายช้อนชา',
#   'ชช',
#   'หยิบ',
#   'ช้อนชา',
#   './ช้อนชา'],
#  'หมูเส้น': ['เส้น'],
#  'สับปะรด': ['ผล', 'ชิ้น', 'กรัม', 'หัว', 'ลูก'],
#  'เนื้อหมูส่วนที่ติดมัน+กระดูกอ่อน': ['กก.'],
#  'น้ำมันหอยตราแม่ครัว': ['ช้อนโต๊ะ'],
#  'ซีอิ๊วขาว Low Sodium หรือ น้ำปลา Low Sodium': ['ช้อนโต๊ะ'],
#  'เครื่องปรุงรส น้ำปลา, น้ำมันหอย, ซีอิ๊วขาว, น้ำตาลทราย': [''],
#  'หอมแดง ซอย': ['ช้อนโต๊ะ'],
#  'ผักกาดแก้ว': ['ต้น', 'หัว', 'ตามชอบ', ''],
#  'เมล็ดงา': [''],
#  'เห็ดออรินจิ': ['แพ็ค',
#   'ต้น',
#   'หัว',
#   'ดอก',
#   'อัน',
#   'โคนใหญ่',
#   'กอด',
#   'ขีด',
#   'ตามชอบ',
#   'กรัม',
#   'ห่อ'],
#  'คีนัว': ['ถ้วย'],
#  'หน่อไม้ดองสีขาว': ['กก'],
#  'ซีอิ้วเด็กสมบูรณ์': ['ตามใจ', 'ช้อน'],
#  'เส้นสปาเก็ตตี้': ['ตามชอบ',
#   'ตามต้องการ',
#   'ถุงเล็ก',
#   'ถ้วย',
#   '',
#   'จาน',
#   'g',
#   'ตามใจชอบ',
#   'g.',
#   'กำมือ',
#   'หยิบมือ',
#   'ถุง',
#   'ห่อเล็ก',
#   'กรัม',
#   'ซอง',
#   'ห่อ',
#   'แล้วแต่ชอบ',
#   'กำ',
#   'ซองเล็ก'],
#  'ใบโหระพา/จริงๆ ควรเป็นใบกะเพรา': ['กำ'],
#  'น้ำกะทิ': ['มล.', 'ถ้วยตวง', 'ช้อนโต๊ะ'],
#  'พริดสด': ['เม็ด'],
#  'น้ำตาลปี๊ป': ['ขีด', 'ชช', 'ช้อนชา', 'ช้อน', 'ช้อนโต๊ะ'],
#  'มะเขือเทศหั่นเต๋า': ['ลูก', 'ขีด', 'ถ้วย', 'กรัม'],
#  'กุ้งตัวเล็ก': ['ขีด'],
#  'บะหมี่ลวก': ['ก้อน', 'ถ้วยตวง'],
#  'ขึ้นฉ่าย': ['ถ้วยตวง',
#   'กำ',
#   'ตามชอบ',
#   'บาท',
#   '',
#   'ต้น',
#   'กำมือ',
#   'เล็กน้อย',
#   'กรัม'],
#  'ซอสหอยฯ': ['ชช.'],
#  'มันกุ้ง': ['ตัว', 'ช้อนโต๊ะ', 'ช้อนโต้ะ', 'โล', 'ขีด', 'ชต'],
#  'ข้าวสวย': ['ทัพพี',
#   'ถ้วยเล็ก',
#   'ถุง',
#   'ที่',
#   'ถ้วยตวง',
#   'ถ้วยชามสำหรับ  ท่าน',
#   'ชาม',
#   'ตามชอบ',
#   'ก.',
#   'ถต.',
#   'ตามต้องการ',
#   'ถ้วย',
#   'หม้อ',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'จาน',
#   'ตามความชอบ'],
#  'เห็ดออริจิ': ['หัว', 'kg'],
#  'ถั่วดำหมัก': ['ชช.'],
#  'น้ำปลาโลว์โซเดียม': ['ช้อนชา'],
#  'แม็กกี้': ['เหยาะ', 'แล้วแต่ชอบ'],
#  'พริกไทยดำทุบหยาบ': ['ช้อนโต๊ะ'],
#  'อกไก่ลอกหน้ง': ['g'],
#  'เส้นสปาสเก็ตตี้': ['กรัม'],
#  'ซีอิ้วดำหวาน': ['ชต', 'ถ้วย', 'ช้อนโต๊ะ', 'ชช', 'ทัพพี'],
#  'ต้มหอมซอย': ['ส.', ''],
#  'เส้นราเม็ง': ['ห่อ'],
#  'เนยสดเค็ม': ['กรัม', '', 'ชต.'],
#  'ซอสมะเขือเทศ': ['ทัพพี',
#   'หมดขวด/รูป',
#   'ช้อนชา',
#   'กะเอา',
#   'ชต.',
#   'ช้อน',
#   'กรัม',
#   'ถ้วยตวง',
#   'tbs',
#   'ชต',
#   'ตามชอบ',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ช้อนโต๊',
#   'ตามใจชอบ'],
#  'หอยลายลวกสุกแกะเปลือก': [''],
#  'เนื้อหอยลายต้มสุก': ['กรัม'],
#  'ต้นหอมผักชีซอยตามชอบ': [''],
#  'น้ำเย็นจัด': ['ถ้วย',
#   'ช้อนโต๊ะ',
#   'เล็กน้อย',
#   'ถ้วยตวง',
#   'นิดหน่อย',
#   'ชาม',
#   'แก้ว'],
#  'ผักชี/ต้นหอม': ['ต้น', 'ตามชอบ'],
#  'ซุปหมูก้อน': ['ก้อน'],
#  'เต้าหู้เหลือง': ['ก้อน', 'แผ่น', 'กรัม', 'ชิ้น'],
#  'มะม่วงเบา': ['ลูก', 'กรัม'],
#  'ขิง': ['ตามชอบ', '', 'ตามใจชอบ', 'ช้อนชา', 'กรัม', 'หัว'],
#  'พริกไทยดำ': ['เล็กน้อย',
#   'นิดหน่อย',
#   'ตามความชอบ',
#   'ชช',
#   'ตามชอบ',
#   'เม็ด',
#   'ช้อนชา',
#   'ปริมาณตามชอบ',
#   'ชช.',
#   'พวง',
#   'หยิบมือ',
#   '',
#   'ช้อนโต๊ะ',
#   'ซอง'],
#  'มันหมูสำหรับเจียวน้ำมัน': ['ตามชอบ'],
#  'กากหมู': ['นิดหน่อย', 'ตามชอบ', 'ถ้วย', 'กรัม'],
#  'หอมหัวใหญ่สับละเอียด': ['หัว', 'ลูก', 'ชต', 'ช้อนโต๊ะ'],
#  'พริกสด': ['เม็ด/ตามชอบ', 'เม็ด', 'ดอก', 'ตามชอบ', 'ปลายช้อนชา'],
#  'กุ้งแห้วแช่น้ำ': ['ชต'],
#  'หมูบดหรือหมูสับ': ['ช้อนโต๊ะ'],
#  'กุนเชียงทอด': ['ถ้วยตวง', 'ถ้วย', 'ชิ้น'],
#  'น้ำสลัดซีอิ้วญี่ปุ่น': ['ช้อนโต๊ะ'],
#  'ผงฟู': ['ช้อน', 'ช้อนโต๊ะ', 'ชช', 'ช้อนชา'],
#  'กระเทียมทุบ': ['กลีบ',
#   'ตามชอบ',
#   'กีบ',
#   'เม็ด',
#   'ช้อนชา',
#   'กำมือ',
#   '',
#   'ช้อนโต๊ะ',
#   'หัว',
#   'ช้อนโต้ะ'],
#  'ผักชีฝรั่งหั่นท่อน': ['ต้น'],
#  'เต้าหู้กระดาน': ['ก้อนสี่เหลี่ยม'],
#  'เห็ดออริจิน': ['กรัม', 'ต้น', 'ดอก'],
#  'ปาปริก้า': ['ปรุงรส', 'ช้อนโต๊ะ', 'ช้อนชา'],
#  'มะเขือเทศ': ['ตามชอบ',
#   'ลูกเล็ก',
#   '',
#   'ถ้ากิน',
#   'กิโลกรัม',
#   'ตามใจชอบ',
#   'หัวใหญ่',
#   'ลูกใหญ่',
#   'ผล',
#   'g.',
#   'ไว้แต่งจาน',
#   'ชิ้น',
#   'กรัม',
#   'ถ้วยตวง',
#   'หัว',
#   'ลูก',
#   'ชต',
#   'กรั'],
#  'หอมใหญ่': ['กรัม',
#   'หัว',
#   'ลูก',
#   'หัวเล็ก',
#   'กก',
#   'ก.',
#   '',
#   'กก.',
#   'ถ้ากิน',
#   'ช้อนโต๊ะ',
#   'หัวใหญ่',
#   'ลูกใหญ่',
#   'ผล',
#   'ซีก',
#   'ชต.'],
#  'คึ่นไช่': ['ต้น'],
#  'น้ำมันพืช/Olive Oil': [''],
#  'ซอสปรุงรส': ['โต๊ะ',
#   'ทัพพี',
#   'ช้อนชา',
#   'ช.ต.',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'กรัม',
#   'เหยาะ',
#   'ช้ินชา',
#   'ชต',
#   'ตามชอบ',
#   'ช.',
#   'กระบวย',
#   'ปริมาณตามชอบ',
#   'หยด',
#   'ชช.',
#   'นิดหน่อย',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ข้อนโต๊ะ',
#   'ชช'],
#  'น้ำตาลปิ๊ปละลายน้ำ': ['ช้อนโต๊ะ'],
#  'ถัวฝักยาว': ['ตามชอบ'],
#  'พริกหยวกเหลืองหั่นยาว': ['เล็กน้อย'],
#  'พริกดองน้ำสม': ['ตามชอบ'],
#  'พริกชี้ฟ้าแห้งเม็ดใหญ่': ['ชต'],
#  'เอ็นข้อไก่': ['บาท'],
#  'แป้งชุบทอด': ['ชต', 'พอ', 'ช้อนโต๊ะ', 'ห่อ', 'ถ้วยตวง'],
#  'พริกขี้หนูสวนโขลก': ['เม็ด เม็ดเล็ก'],
#  'แป้งชุปทอด': ['ชต.'],
#  'เนยเค็ม': ['ชช', 'เล็กน้อย', 'ก้อนเล็ก', '', 'ช้อนโต๊ะ', 'ก้อน'],
#  'มันฝรั่งขนสดใหญ่': ['หัว'],
#  'ปีกไก่ตัดปลาย': ['กก.'],
#  'น้ำตาลปี๊บ': ['ชต',
#   'ชช',
#   'ตามชอบ',
#   'ทัพพี',
#   'ช้อนชา',
#   'กะเอา',
#   'นิดนึง',
#   'ชช.',
#   'ถ้วย',
#   'ชต.',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'g',
#   'น้ำตาลปิ้บ  ถ้วย',
#   'นิดหน่อย',
#   'กิโลกรัม'],
#  'สันในไก่': ['กก', 'กรัม', 'ขีด', 'กิโล', 'ชิ้น', 'เส้น'],
#  'แซลม่อนเสต้ก': [''],
#  'ผักเหลียง': ['มัด'],
#  'ฟักเขียวขนาดกลางหั่นเป็นชิ้นพอคำหนาหน่อย': ['ลูก'],
#  'เนื้อสันคอหมู': ['', 'กรัม'],
#  'ผงปรุงรส': ['ตามชอบ',
#   'ช้านชา',
#   'ชช.',
#   'นิดหน่อย',
#   '',
#   'ช้อนโต๊ะ',
#   'ก้อน',
#   'ชช',
#   'ช้อนชา',
#   'ช่อนโต๊ะ',
#   'ช้นโต๊ะ',
#   'ปลายช้อน',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'กรัม',
#   'ข้อนชา',
#   'ใส่ไม่ใส่ก็ได้'],
#  'พริกแกงฉู่ฉี่': ['', 'ช้อนโต๊ะ'],
#  'หมู': ['โล',
#   'kg',
#   'ขีด',
#   'ตามชอบ',
#   'กิโล',
#   'กก.',
#   'ชิ้น',
#   'กิโลกรัม',
#   'กรัม'],
#  'อกไก่ติดหนัง': ['อก'],
#  'ใส้กรอกไก่': ['ชิ้น'],
#  'นำ้ตาลทราย': ['ช้อนโต๊ะ', 'ช้อนชา'],
#  'กระเทียมสับพอหยาบ': ['กลีบ'],
#  'ส่วนผสมสำหรับหอมใหญ่ผัด': [''],
#  'ขิงสับละเอียด': ['ชต', 'ช้อนโต๊ะ', 'กรัม', 'ช้อนชา'],
#  'น้ำโค้ก': ['มิลลิลิตร'],
#  'ตับปิ้ง': ['ชิ้น'],
#  'แตงกวา': ['ผล',
#   'ลูกเล็ก',
#   'ปริมาณตามชอบ',
#   '',
#   'ชิ้น',
#   'หัว',
#   'ลูกใหญ่',
#   'ลูก',
#   'ผักเครื่องเคียง',
#   'ตามชอบ'],
#  'น้ำมันพีช': ['ช้อนโต๊ะ'],
#  'หมูชิ้นหมัก': ['กรัม'],
#  'แป้งมันผสมน้ำข้นๆ': ['ถ้วย'],
#  'หมูสาม': ['เส้น'],
#  'พริกแกงเผ็ดนครสวรรค์': ['ขีด'],
#  'ใบสะระเหน่': ['ใบ'],
#  'เยื่อไผ่': ['ถุง', 'ถ้วย'],
#  'แครอท': ['ตามใจชอบ',
#   'ตามชอบ',
#   'พอ',
#   'ผล',
#   'ขึด',
#   'นิ้ว',
#   'ตามต้องการ',
#   'ถ้วย',
#   '',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'แท่ง',
#   'กรัม',
#   'เส้น',
#   'แว่น',
#   'แผ่น',
#   'ต้น',
#   'g',
#   'หัว',
#   'หยิบ',
#   'หัวใหญ่',
#   'ลูก',
#   'นึง',
#   'อัน',
#   'ถ้วยเล็ก',
#   'ท่อน',
#   'ชต.',
#   'เล็กน้อย',
#   'ถ้วยตวง',
#   'นิดหน่อย',
#   'นิดนึงตามชอบ',
#   'ขีด',
#   'หัวเล็ก',
#   'ชต'],
#  'พาเมซานชีส': ['กรัม', 'ตามชอบ', 'g'],
#  'เกลือ Low Sodium': ['ช้อนชา'],
#  'เนื้อหมูสับติดมันเล็กน้อย': ['กก.'],
#  'บะหมี่': ['ก้อน', 'ถุง', ''],
#  'แป้งทอดกรอบ สำหรับคลุกปลา': ['ถ้วย'],
#  'ผงปรุงรสผัดคนอร์': ['ชช', 'ช้อนชา'],
#  'ก้อนแกงกะหรี่สำเร็จรูป': ['กล่อง'],
#  'เนื้อหมูเด้ง': ['กรัม'],
#  'มักกะโรนี': ['ตามใจชอบ', 'ถ้วย', 'กรัม', 'จาน', 'ตามชอบ', 'ถ้วยตวง'],
#  'คึ่นช่าย หั่นเป็นท่อน': ['กำ'],
#  'น้ำมัน': ['ชต',
#   'ช้อนโต๊ะสำหรับเจียวกระเทียมและทอดปลาหมึกฝอย',
#   'ตามชอบ',
#   'ถ้วยเล็ก',
#   'ขวด',
#   'ชช.',
#   'ช็อนโต๊ะ',
#   'ถ้วย',
#   '',
#   'ใส่พอท่วมไข่',
#   'ช้อนโต๊ะ',
#   'สำหรับทอด',
#   'ชช',
#   'ใช้ผัด',
#   'ทัพพี',
#   'พอ',
#   'ช้อนชา',
#   'ช้อนกินข้าว',
#   'ช.ต.',
#   'แค่พอเคลือบกระทะ',
#   'ถต.',
#   'ถต',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'ใช้ทอด',
#   'กรัม',
#   'ช้อยชา',
#   'ถ้วยตวง',
#   'นิดหน่อย',
#   'ถ้วย   ช้อนโต๊ะ',
#   'ตามเหมาะสม'],
#  'น้ำพริก เผา': ['ช้อนโต๊ะ'],
#  'กว้างตุ้ง': ['กำ'],
#  'ข่าซอย': ['ช้อน', 'ช้อนโต๊ะ', 'g'],
#  'เห็ดแชมปิญอง': ['ลูก', 'ดอก', 'ตามชอบ', 'ถ้วย', 'กรัม'],
#  'ถั่วป่น': ['ถ้วย', 'ช้อนโต๊ะ'],
#  'หัวปลี': ['กรัม', 'หัว', 'สำหรับเสิร์ฟ'],
#  'ขึ้นฉ่ายซอย': ['ต้น', 'พอโรยหน้า', 'ตามชอบ'],
#  'ส่วนผสมข้าวผัด': [''],
#  'ซอสปรุงรสคนอร์': ['ช้อนชา'],
#  'กระท้อน': [''],
#  'ไวไวหอยลายผัดฉ่า': ['ซอง'],
#  'หัวหอมหั่นเสี้ยว': ['หัว'],
#  'พริบลาบเหนือ': ['ช้อนโต๊ะ'],
#  'พริกชี้ฟ้าเหลือง': ['เม็ด'],
#  'ตีนไก่': ['กก', 'โล', 'Kg', 'กิโล', 'กรัม', 'ตีน'],
#  'มะพร้าวคั่ว': ['ช้อนชา', 'ขีด', 'ชต.', '', 'ช้อนโต๊ะ', 'กรัม'],
#  'ส่วนผสมข้าวต้ม': [''],
#  'ลูกชิ้นปลา': ['',
#   'กิโลกรัม',
#   'ขีด',
#   'ชิ้น',
#   'กรัม',
#   'ลูก',
#   'กก',
#   'ตามชอบ',
#   'ถุง'],
#  'ผักสลัดตามใจชอบ': ['ถ้วย'],
#  'พริกหยวก3สี': ['ตามใจชอบ'],
#  'แครอท หั่นเป็นลูกเต๋า': ['หัว', 'ช้อนโต๊ะ'],
#  'เต้าหู้ญี่ปุ่นคินุ': ['กรัม'],
#  'น้ำซุปกระดูก': ['ถ้วย'],
#  'ผงคะนอร์': ['ช้อนชา'],
#  'เนยสด': ['ชช.',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ชช',
#   'ช้อนชา',
#   'แล้วแต่ชอบ',
#   'ช้อนโต๊'],
#  'ข้าวโพดอ่อน': ['กรัม',
#   'ถ้วยตวง',
#   'ฟัก',
#   'ฝัก',
#   'ผัก',
#   'ตามใจชอบ',
#   'อัน',
#   'ตามชอบ',
#   'ตามต้องการ',
#   'ถ้วย',
#   '',
#   'ชิ้น',
#   'แท่ง',
#   'แพ็ค',
#   'ต้น',
#   'หัว',
#   'ถ้วยเล็ก'],
#  'น้ำตาลปร๊บ': ['ชช'],
#  'หมูยอลวก': ['ตามชอบ'],
#  'ถั่วลันเตา': ['ตามชอบ',
#   'ถ้วย',
#   '',
#   'ชิ้น',
#   'จาน',
#   'ฝัก',
#   'แพ็กเล็ก',
#   'ถุง',
#   'กรัม',
#   'kg',
#   'ขีด',
#   'กำ'],
#  'ต้นหอมหั่นสั้น': ['ต้น'],
#  'แครอทต้มสุก': ['ถ้วยตวง'],
#  'กระเทียมบุบหยาบ': ['หัว'],
#  'พริกตำ': ['ชต', 'ตามชอบ'],
#  'ผักสลัด': ['ขีด',
#   'ตามชอบ',
#   'กอง',
#   'ถ้วย',
#   'สำหรับเสิร์ฟ',
#   '',
#   'ชาม',
#   'ตามความชอบ',
#   'ใบ',
#   'ต้นใหญ่',
#   'ก้าน',
#   'กรัม',
#   'จาน'],
#  'ซอสปรุงรสทาคูมิ': ['ช้อนโต๊ะ'],
#  'หอมเจียว': ['ช้อนชา', 'กรัม', 'ตามชอบ', 'ชช.', 'ถ้วย', '', 'ช้อนโต๊ะ'],
#  'ขิงสดหั่นเป็นแว่น': [''],
#  'น้ำปลา': ['ช้อรโต๊ะ',
#   'ชต',
#   'ชิมตามชอบ',
#   'ชช',
#   'ตามใจชอบ',
#   'ปรุงรสตามชอบ',
#   'ทัพพี',
#   'พอ',
#   'ช้อนชา',
#   'ตามใจ',
#   'ช.ต.',
#   'นิดนึง',
#   'ชช.',
#   'ลต',
#   'ชต.',
#   'เล็กน้อย',
#   '',
#   'ช้อน',
#   'ซ้อนชา',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'เหยาะๆ ลงไป',
#   'ช้อยชา',
#   'ปรุงรส',
#   'tbs',
#   'แล้วแต่ชอบ',
#   'เหยาะ',
#   'ช้อนใหญ่',
#   'ช้อนโต้ะ',
#   'เหยาะๆลงไป',
#   'ตามชอบ',
#   'กระบวย',
#   'ขวด',
#   'ml.',
#   'ขะยอก',
#   'ช.ต',
#   'ถ้วยตวง',
#   'ขยอก',
#   'นิดหน่อย',
#   'ช็อนโต๊ะ',
#   'tbs ตามชอบ'],
#  'ใบแมงรัก': ['กำ'],
#  'น้ำมะขามเปียก': ['ทัพพี',
#   'ช้อนชา',
#   'ช่้อนโต๊ะ',
#   'กระบวย',
#   'ชต',
#   'ตามชอบ',
#   'ปรุงรสตามชอบ',
#   'ถ้วย',
#   'ชต.',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'น้ำหมักหมูแดง': ['ทั้งหมด'],
#  'เกลือชมพู': ['ตามชอบ', 'ช้อนชา', 'เล็กน้อย', 'กรัม', 'นิดหน่อย'],
#  'ชีสพาร์เมซาน': ['กรัม'],
#  'น้ำตาล ทราย': ['ช้อนชา'],
#  'แป้งเอนกประสงค์': ['ถ้วยตวง', 'ถ้วย', 'ช้อน', 'กรัม'],
#  'กุ้งสดปอกเปลื้อก': ['ตัว'],
#  'มะเขือพ่วง': ['ตามชอบ'],
#  'หมูหั่น': ['กรัม', 'g', 'ตามต้องการ'],
#  'ปลาทูน่าในน้ำแร่': ['กรัม', 'กระป๋อง'],
#  'กุ้งสับละเอียด': ['กรัม'],
#  'ต้มหอมผักชี/ผักชีฝรั่ง ซอย': ['ต้น'],
#  'ผักชีต้นหอม': ['ต้น',
#   'เล็กน้อย',
#   'ถ้า',
#   'แล้วแต่ชอบ',
#   'กำ',
#   'ชต',
#   'ตามชอบ',
#   'หยิบมือ'],
#  'ผงปรุงรสไก่': ['ชต.', 'ช้อนโต๊ะ', 'ชต', 'ชช', 'ช้อนชา'],
#  'หอม': ['ชต.', 'หัว'],
#  'ไข่ไก่เต็มใบ': ['ฟอง'],
#  'ต้นหอมซอย': ['สำหรับโรยหน้า',
#   'เล็กน้อย',
#   'ตามชอบค่ะ',
#   'นิดหน่อย',
#   'ขีด',
#   'ตกแต่ง',
#   'ตามชอบ',
#   'ถต.',
#   'ถ้วย',
#   'ชต.',
#   'หยิบมือ',
#   '',
#   'ช้อนโต๊ะ',
#   'ต้น',
#   'กำ'],
#  'ผักชีเด็ดยอด': [''],
#  'ผักสลัดกรีนโอ๊ค': ['ห่อ'],
#  'มะเขือเทศหั่นชิ้นเล็ก': ['ลูก'],
#  'ต้นหอม ผักชี ซอย': ['ต้น', 'อย่างละ ต้น'],
#  'ข้าวหุงสุก แบบแข็ง ๆ': ['ถ้วย'],
#  'เนื้ออกไก่': ['kg', 'ขีด', 'ตามชอบ', 'ถ้วย', 'ชิ้น', 'กรัม', 'อก'],
#  'พริกขี้หนูแห้งทอด': ['ถ้วย', 'เม็ด'],
#  'หอยแมลงภู่': ['kg', 'ขีด', '', 'กรัม'],
#  'ตะใคร้หั่นฝอย': ['ต้น'],
#  'พริกหวาน 3 สี สีละ': ['ลูก'],
#  'เส้นสปาเกตตี้ ต้มสุก': ['กรัม'],
#  'น่องไก่ติดสะโพก ล้างทำความสะอาดแล้วผึ่งให้แห้ง': ['ชิ้น'],
#  'เนื้อปลาอินทรีย์': ['กรัม', 'กิโล', 'ขึด'],
#  'เห็ดฝางทำความสะอาดหั่น': ['ตามชอบ'],
#  'กระเทียมเจียวกากหมู': ['ชต', 'ถ้วย'],
#  'ข้าวไข่เทอร์นาโด': ['จาน'],
#  'ตะไคร้หั่น': ['ต้น'],
#  'ยอดข้าวโพดอ่อน': ['ถ้วย', 'ฝัก'],
#  'น้ำซุปดาชิ': ['ถ้วยตวง', 'ถ้วย'],
#  'ผักขึ้นช่าย': ['ต้น'],
#  'ปูอัดหั่นพอคำ': ['กำมือ'],
#  'พริกแกงใต้': ['ขีด', 'ช้อนโต๊ะ', 'ช้อนชา', 'กรัม'],
#  'สาหร่ายแผ่น': ['แผ่น', ''],
#  'ออริกาโน่อบแห้ง': ['ตามชอบ', 'ชต'],
#  'หมี่โคราชพร้อมซอส': ['ห่อ'],
#  'แครอทหั่นท่อน': ['กรัม', 'ตามชอบ'],
#  'ตะไคร้ทุบหั่นท่อนเล็ก': ['ต้า'],
#  'หอมแดงสับ': ['ช้อนโต๊ะ', 'ชต.'],
#  'เนยจืด': ['กรัม',
#   'ก้อนเล็ก',
#   'ชต',
#   'ช้อนโต๊ะ',
#   'ก้อน',
#   'ใช้ทากะทะ',
#   'ช้อนชา',
#   'tbsp'],
#  'เนื้อปู': ['ถ้วยเล็กๆ', 'กรัม', 'ตามใจเรา', 'kg', 'ขีด', 'กก.'],
#  'ผง cumin': ['ช้อนโต๊ะ'],
#  'น้ำมันสำหรับทำอาหาร': ['ชต'],
#  'โชยุญี่ปุ่น': ['ชต.', 'ช้อนโต๊ะ'],
#  'แป้งทอดกรอบคนอร์': ['ถ้วย', 'ช้อนโต๊ะ'],
#  'น้ำมันพืช สำหรับทอด': ['ขวดเล็ก', 'ช้อนชา'],
#  'แครอทฝอย': ['ชต', 'หยิบมือ', 'กรัม', 'ลูก', 'นิดหน่อย'],
#  'เส้นหมี่ไวไว': ['ห่อ'],
#  'กะปิหมักเค็ม': ['ช้อน'],
#  'ชุดผักผัดเผ็ด': ['เเพ๊ค'],
#  'ใบกระเพรา': ['ถ้วยตวง',
#   'ต้น',
#   'กิ่ง',
#   'แล้วแต่ชอบ',
#   'ขีด',
#   'กำ',
#   'ตามชอบ',
#   'บาท',
#   'แพค',
#   'ถ้วย',
#   '',
#   'ตามใจชอบ',
#   'พอ',
#   'ใบ',
#   'ตามสะดวก',
#   'กำมือ',
#   'ก้าน',
#   'หยิบมือ',
#   'กำใหญ่',
#   'กรัม'],
#  'เนื้อหมูสันใน': ['กรัม', 'กร้ม', 'ขีด'],
#  'กุ้งฝอยเล็ก': ['ช้อนโต๊ะ'],
#  'พริกแกงเผ็ด': ['ขีด',
#   'ชต',
#   'ช้อนโต๊ะ ตามชอบ',
#   'ตามชอบ',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ช้อนชา',
#   'บาท',
#   'โล'],
#  'พริกชี้ฟ้าเขียว แดง': ['เม็ด'],
#  'ไข่': ['', 'ฟอง', 'ใบ', 'ลูก'],
#  'ปลากะพงชิ้นขนาดฝ่ามือ': ['ชิ้น'],
#  'น่องไก่ติดสะโพก': ['ชิ้น', 'น่อง'],
#  'น้ำตาล': ['ใส่แค่ปลายช้อน',
#   'ปลายช้อน',
#   'ชต. ชช.',
#   'ชต.',
#   'หยิบมือ',
#   'เล็กน้อย',
#   'กระบวน',
#   '. ชต',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ชัอนชา',
#   'kg',
#   'ชต',
#   'ช.ช',
#   'ตามชอบ',
#   'ช.',
#   'ปลายหยิบมือ',
#   'ช.ช.',
#   'tsp',
#   'ช.ต',
#   'ถ้วยตวง',
#   'ชช.',
#   'นิดหน่อย',
#   'ช็อนโต๊ะ',
#   'ถ้วย',
#   '',
#   'ปลายช้อนชา',
#   'ช้อนช้า',
#   'ข้อนโต๊ะ',
#   'ชช',
#   'โต๊ะ',
#   'ทัพพี',
#   'เหยาะนิดหน่อย',
#   'ช้อนชา',
#   'กะเอา',
#   'ตามใจ'],
#  'พริกขี้ฟ้า': ['เม็ด'],
#  'ผักชีซอย': ['ต้น', 'ตามชอบ', '', 'ขีด', 'กำมือ', 'ถ้วย', 'ชต.', 'กรัม'],
#  '- น้ำปลา': ['ช้อนโต๊ะ'],
#  'ดีปลีผง': ['ช้อนชา'],
#  'นํ้าตาลปี๊บ': ['ช้อนโต๊ะ'],
#  'ซอสเห็ดหอมหรือน้ำมันหอย': ['ช้อนโต๊ะ'],
#  'ลูกผักชีป่น': ['ช้อนชา'],
#  'ส่วนของซอส': [''],
#  'พริกไทยอ่อน': ['ตามชอบ',
#   'ถ้วย',
#   '',
#   'ขีด',
#   'ตามสะดวก',
#   'พวงเล็ก',
#   'ก้าน',
#   'พวง',
#   'กรัม',
#   'ฟัก',
#   'กิ่ง',
#   'ช่อ'],
#  'กระทิ': ['ถ้วยเล็ก', 'ถ้วย'],
#  'ซอสหอยนางรม': ['ชช',
#   'ช้อนโต๊',
#   'ซ้อนโต๊ะ',
#   'ทัพพี',
#   'ช้อนชา',
#   'ช.ต.',
#   'ชช.',
#   'ชต.',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ชต',
#   'เหยาะๆลงไป',
#   'ตามชอบ',
#   'นิดหน่อย',
#   '',
#   'เหยาะๆ ลงไป'],
#  'มะเขือเทศสับ': ['ชต.', 'ลูก'],
#  'ผักสดเช่นแตงกวา,ใบโหระพา ฯลฯ': ['ตามชอบ'],
#  'ข้าวสวยเย็น': ['สำหรับ  คน', '', 'สำหรับ  ท่าน'],
#  'Capelin Roe/Tobiko': ['ตามชอบ'],
#  'เส้นสปาเกตตี้': ['ตามชอบ',
#   'ก.',
#   'ตามต้องการ',
#   '',
#   'แท่ง',
#   'ห่อ',
#   'g',
#   'สำหรับคน',
#   'มัด',
#   'กำมือ',
#   'กรัม',
#   'โอเค',
#   'กำ'],
#  'พริกสับ': ['ตามชอบ', 'ชข.', 'ช้อนโต๊ะ', 'เม็ด'],
#  'หมูบดปรุงรสหมักด้วยผงหมักไส้เกี๊ยวชายสี่': ['ตามชอบ'],
#  'หมูสไลด์ ตามชอบ': [''],
#  'ไชโป๊ะสับ': ['ชต.'],
#  'ไก่หั่นเต๋า': ['กรัม'],
#  'นํ้ามันหอย': ['ช้อนโต๊ะ', 'ช้อนโต๊'],
#  'เลือดหลอด เบทาโกร': ['หลอด'],
#  'เส้นสปาเก็ตตี้โฮลวีท': ['กรัม'],
#  'น้ำสะอาด': ['ถ้วยเล็ก',
#   'สำหรับต้ม',
#   'กระบวย',
#   'ถ้วยตวง',
#   'มิลลิลิตร',
#   'ขัน',
#   'ลิตร',
#   'ชาม',
#   'ถ้วยตวงข้าว',
#   'หม้อ',
#   'สำหรับต้มเส้น',
#   'พอท่วม',
#   'ต้มเส้น',
#   'ถ้วย ช้อนโต๊ะ',
#   'ทัพพี',
#   'มล.',
#   'ช้อนชา',
#   'กะเอา',
#   'ถต.',
#   'ถ้วย',
#   'เล็กน้อย',
#   '',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'ขวดใหญ่',
#   'แก้ว'],
#  'น้ำต้มสุก': ['เล็กน้อย',
#   'ทัพพีเล็ก',
#   'นิดหน่อย',
#   'ถ้วย',
#   'ลิตร',
#   'ช้อนโต๊ะ',
#   'ทัพพี'],
#  'มักกะโรนีแบบตัว': ['กรัม'],
#  'เส้นสปาเก็ตตี้แบบแบน': ['กำ'],
#  'ต้นหอม': ['ช้อนชา',
#   'ใบ',
#   'กำมือ',
#   'สำหรับเสิร์ฟ',
#   'ไว้แต่งจาน',
#   'ชต.',
#   '',
#   'ถ้ากิน',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'ต้น',
#   'หัว',
#   'ไม่ต้องใส่เยอะมาก',
#   'ต้น ตามชอบ',
#   'กำ',
#   'ต้น หั่นท่อน',
#   'ถ้วยเล็ก',
#   'ซอย',
#   'เล็กน้อย',
#   'บาท',
#   'ถ้าชอบ',
#   'โรยหน้า',
#   'นิดหน่อย',
#   'กำเล็ก',
#   'ตามใจชอบ',
#   'ตามชอบ'],
#  'ซอสฝาเหลือง': ['ช้อนชา', 'ช้อนโต๊ะ'],
#  'เส้นหมี่ข้าวกล้อง': ['ก้อน', 'g', 'กำมือ', 'กรัม', 'ห่อ'],
#  'ผงปรุงรสหมู + ผงชูรส + เกลือ': ['กรัม'],
#  'ซีอิ้วขาว สูตรเจ': ['ช้อนโต๊ะ'],
#  'พริกขี้หนูกับกระเทียมตำรวมกัน': ['ช้อนโต๊ะ'],
#  'น้ำพริกแกงกะหรี่': ['กรัม'],
#  'ยอดคะน้าอ่อน': ['ต้น'],
#  'ปลาทอด': ['ตัว', 'ชิ้น'],
#  'ข้าวโพดต้ม': ['ชต.', 'ฝัก'],
#  'แฮมหั่นชิ้นสี่เหลี่ยม': ['กรัม'],
#  'ผัดกระเฉด': ['กำ'],
#  'น้ำสำอาด': ['ถ้วยเล็ก'],
#  'Yamamori': ['ถ้วยตวง'],
#  'ต้อหอมซอย': ['ต้น'],
#  'ไส้กรอกหนังกรอบหั่นชิ้น': ['ตามชอบ'],
#  'ซีอิ้วพรีเมี่ยม': ['ชต'],
#  'ข้าวหอมมะลิ': ['ถ้วยตวง', 'ถ้วย', 'กรัม', 'ถุง'],
#  'น้ำมันหอยสูตรเจ': ['ชต.'],
#  'อกไก่ลอกหนัง': ['g', 'กรัม'],
#  'กระเทียมกลีบใหญ่สับหยาบ': ['กลีบ'],
#  'ซุปก้อนรสต้มยำ': ['ก้อน'],
#  'แป้งทอดกรอบ': ['ตามชอบ',
#   'พอ',
#   'ถ้วย',
#   'ชต.',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ซอง',
#   'ทัพพี',
#   'ตามสะดวก',
#   'ถต',
#   'ถ้วยเล็ก',
#   'ถุง',
#   'ถ้วยตวง',
#   'ชาม',
#   'ชต'],
#  'ใบเมี่ยงทูโทน ขมิ้น-บีทรูท ตราทรีเลดี้': ['แผ่น'],
#  'เม็ดผักชี': ['ช้อนโต๊ะ', 'ช้อนชา'],
#  'dark soy sauce': ['tbs'],
#  'ไส้กรอกสอดไส้ชีส': ['แท่ง'],
#  'ผักกวางตุ้งฮ่องเต้': ['ต้น'],
#  'ซอสเห็ดหอม+ซีอิ๊วขาวอย่างละ': ['ชช.'],
#  'ผักชี': ['นิดหน่อย',
#   'หัว',
#   'กิ่ง',
#   'แล้วแต่ชอบ',
#   'ขีด',
#   'กำ',
#   'ตามชอบ ใส่ไม่ใส่ได้หมด',
#   'ตามชอบ',
#   'เอาไว้ตกแต่ง',
#   'แพค',
#   '',
#   'ถ้ากิน',
#   'ช้อนโต๊ะ',
#   'สำหรับตกแต่ง',
#   'ต้น',
#   'ก้่าน',
#   'ตามใจชอบ',
#   'ตามใจ',
#   'มัด',
#   'สำหรับโรยหน้า',
#   'ก้าน',
#   'หยิบมือ',
#   'เล็กน้อย',
#   'บาท',
#   'กรัม'],
#  'คนอร์ เนเชอรัล ผงไม่มีชูรส': ['ชช.'],
#  'กระเทียมโทนผ่า4': ['เม็ด'],
#  'ยอดคะน้า': ['ปริมาณตามชอบ', 'ยอด', 'กรัม', 'ต้น', 'กำ', 'กก'],
#  'เกี๊ยวปลา': ['ตามชอบ', 'ลูก'],
#  'ต้นอ่อนทานตะวัน': ['ต้น', 'ถุง', 'กรัม', 'ขีด', 'ถ้วย'],
#  'กุ้งแกะเปลือกลวกสุก': ['เล็กน้อย'],
#  'ไข่ขาว': ['จากไข่ไก่  ฟอง', 'ช้อนโต๊ะ', 'มล', 'ฟอง'],
#  'ข้าวแช่เย็น': ['ถ้วย', 'ช้อนโต๊ะ'],
#  'กระเทียมสับละเอียด': ['ชช.',
#   'ถ้วย',
#   'ช้อนโต๊ะ',
#   'ชช',
#   'g',
#   'ช้อนชา',
#   'ชต.',
#   'กลีบ',
#   'กรัม',
#   'หัว',
#   'ชต',
#   'ช้อนโต๊ะขึ้นไป'],
#  'อกไก่ต้ม': ['ปริมาณตามชอบ', 'กรัม'],
#  'เส้นหมี่ขาวแช่น้ำ 3 นาที': ['ซอง'],
#  'กะเพรากุ้ง': ['ช้อนโต๊ะ'],
#  'Kosher Salt': [''],
#  'กะทิสด': ['กิโล', 'ถ้วย'],
#  'ไส้กรอก ทอด': ['อัน'],
#  'ผักสามารถปรับเปลี่ยนได้ค่ะ': ['mm'],
#  'น้ำปลาพริก': ['ถ้วย', ''],
#  'เนื้อปลาทับทิม': ['ต้ว', 'ตัว'],
#  'คื่นช่าย': ['มัด', 'ตามชอบ', '', 'ช้อนโต๊ะ', 'กำเล็ก', 'ต้น', 'กรัม'],
#  'ถั่วพลู': ['อัน'],
#  'ปลาหมึกหั่นแว่น': ['g', 'ตัว'],
#  'สปาเก็ตตี้': ['', 'g', 'กำมือ', 'กรัม', 'ห่อ', 'kg'],
#  'งาขาว งาดำ สาหร่ายคั่ว': ['ชต.'],
#  'กะหล่ำปลีฝอย': ['ถ้วย', 'กำมือ'],
#  'มะเขือเทศสด': ['ลูก'],
#  'น้ำมันถั่วเหลืิอง': ['ช้อนโต๊ะ'],
#  'ดอกขจร': ['ถ้วย'],
#  'ทูน่าสด': ['ชิ้น'],
#  'มะกะโรนีต้มสุก': ['ถ้วย', 'ชาม', 'ถ้วย สำหรับ  ท่าน'],
#  'ผักชีใบเลื่อย': ['ใบ', 'ต้น', 'ตามชอบ'],
#  'กุ้งสดแกะเปลือก': ['กิโล', 'ตัว'],
#  'มะระซอย': ['ลูก'],
#  'ส่วนผสมซอส': [''],
#  'แยมส้มมาม่าเลท': ['ช้อนโต๊ะ'],
#  'มะเขือพวง': ['กำมือ', 'กรัม', 'ลูก', 'ตามใจชอบ', 'ถ้วย', 'หยิบมือ'],
#  'พริกแห้งดอกใหญ่': ['ดอก'],
#  'ใบเหลียง': ['แพ็ค', 'จานพูนๆ', 'กำ'],
#  'หางหมู': ['หาง'],
#  'ผงต้มยำ': ['ช้อนช้า'],
#  'พริกหยวกหั่น': ['เม็ด', 'ลูก', 'ผล', 'ถ้วย'],
#  'น้ำมะนาว น้ำปลา': ['ช้อนทานข้าว'],
#  'น้ำตาลทราย.': ['ช้อนชา', 'ตามชอบ'],
#  'โชยุ': ['ชช',
#   'ตามใจชอบ',
#   'ช้อนชา',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'ตามชอบ',
#   'ถ้วยตวง',
#   'ถ้วย',
#   ''],
#  'ตะไคร้': ['ถ้วย',
#   '',
#   'ช้อนชา',
#   'ก้าน',
#   'ช้อนโต๊ะ',
#   'ต้น',
#   'หัว',
#   'ตามชอบ',
#   'ท่อน'],
#  'น้ำจิ้มบ๊วย': ['ถ้วย'],
#  '้เกลือ': ['เล็กน้อย'],
#  'รสดีอร่อยชัวร์': ['ช้อนโต๊ะ'],
#  'เส้นขนมจีนอบแห้ง': ['กรัม'],
#  'เส้นหมี่สด': ['พอ', 'ห่อ'],
#  'แอปเปิลแดง': ['กรัม'],
#  'น้ำเปล่า สำหรับผัด': ['ช้อนชา'],
#  'ผักชีหั่นซอย': ['ถ้วย'],
#  'มาม่ายี่ห้อใหนก้อได้': ['ห่อ'],
#  'ซ้อสมะเขือเทศ': ['ช้อนโต๊ะ'],
#  'หอมหัวใหญ่หั่นหยาบ': [''],
#  'ผักแกล้ม': [''],
#  'ไชโป้': ['ขีด'],
#  'ผักกะหล่ำเขียว': ['หัวเล็ก'],
#  'เส้นมักกะโรนีต้มสุก': ['ถ้วย'],
#  'บะหมี่กึ่งสำเร็จรูปรสไก่เผ็ด': ['ห่อ'],
#  'ข้าวสุกเย็น': ['ถ้วย'],
#  'หอยลายน้ำพริกเผากระป๋อง': ['กระป๋อง'],
#  'ซอสหมักเนื้อย่างเกาหลี': ['tbs'],
#  'ผักคอส': ['ต้น', 'กรัม', 'หัว'],
#  'ซีอิ๊วlow sodium': ['ช้อนโต๊ะ'],
#  'ถั่วฝักยาว หั่นขวาง': ['ช้อนโต๊ะ'],
#  'นมจืด': ['ถ้วยเล็ก',
#   'ml.',
#   'กล่่อง',
#   'มิลลิลิตร',
#   'ถ้วย',
#   'ช้อนโต๊ะ',
#   'กล่อง',
#   'กรัม',
#   'ml',
#   'ถ้วยตวง',
#   'นิดหน่อย',
#   'แก้ว'],
#  'ไข่เจียวแผ่นบางหั่นเส้น': ['ถ้วย'],
#  'หมึกกล้วย ขนาดเล็ก': ['ตัว'],
#  'ใบมะกรุดฉีก': ['ช้อนโต๊ะ'],
#  'โหรภา': ['กำ'],
#  'ขนมปังเบอร์เกอร์ ซื้อได้ที่Tops BigC Macro': [''],
#  'Marjoram powder': ['เล็กน้อย'],
#  'แป้งทอดกรอบ คนอร์': ['ช้อนโต๊ะ'],
#  'ถั่วฝักยาวหั่น': ['พอ', 'เส้น', 'ขีด'],
#  'ข้าวสารล้างน้ำให้สะอาด สะเด็ดน้ำ': ['ถ้วย'],
#  'เครื่องต้มยำ': ['ช้อนชา', 'ชุด', 'ซอยตามใจชอบ'],
#  'กุ้ง แกะเปลือก': ['กรัม'],
#  'ซอสสุกี้': ['ตามชอบ'],
#  'ผงปรุงรสหมู': ['ตามชอบ',
#   'นิดหน่อย',
#   'ก้อน',
#   'ชช',
#   'ช้อนชา',
#   'ช้อน',
#   'ช้อนโต๊ะ'],
#  'ซอสเทาซันท์ไอแลนด์': ['กรัม'],
#  'บะหมี่ไข่เส้นแบน': ['ก้อน'],
#  'น้ำพริก': ['ช้อนโต๊ะ'],
#  'พริกไทยอ่อนรูดเป็นเม็ด': ['ช้อนโต๊ะ'],
#  'ดอกชมจันทน์': ['กำ'],
#  'พาร์สลี่แห้ง': ['ช้อนโต๊ะ'],
#  'salt': ['grams', 'เล็กน้อย', ''],
#  'มาการีน': ['ช้อนชา', 'ก้อน'],
#  'เบค่อน': ['กรัม', 'ตามชอบ', 'แพค', '', 'เส้น'],
#  'ผักชีใบยาวซอย': ['ถ้วย'],
#  'คิคโคแมน ซอสถั่วเหลือง  สำหรับปรุงรส': ['ช้อนโต๊ะ'],
#  'ผงชูรส': ['',
#   'ช้อนโต๊ะ',
#   'ปลายช้อนชา',
#   'ชช',
#   'ช้อนชา',
#   'เล็กน้อย',
#   'ปรุงรสตามชอบ'],
#  'ลูกจันทน์': ['ลูก'],
#  'ใบคะน้า': ['กรัม'],
#  'ซีอิ๊วดำหวาน': ['ช.ต', '', 'ช้อนโต๊ะ', 'ทัพพี', 'ช้อนชา', 'ตามชอบ'],
#  'วาซาบิ': ['', 'ช้อนชา'],
#  'น้ำพริกแกงเขียวหวาน': ['กรัม'],
#  'มอสซาเรลลาชีส': ['ตามชอบ', 'กรัม'],
#  'มะเขือเทศควักไส้': ['ผล'],
#  'หัวหอมใหญ่หั่น': ['ลูก', 'ถ้วย'],
#  'แอปเปิ้ลลูกเล็ก': ['ผล'],
#  'ขนมปังโฮลวีท': ['แผ่น'],
#  'กุ้งขาวแกะ': ['กรัม'],
#  'หมี่เหลือง': ['หยิบมือ', 'กรัม', 'คนทาน', 'ก้อน', 'หัว', 'กิโลกรัม'],
#  'มะเขือเปราะหั่น': ['ลูก'],
#  'ผักทองหั่น': ['ชิ้น'],
#  'เนื้อเป็ด': ['กรัม', 'ถ้วย'],
#  'เห็ดออริจิซอยเป็นเส้น': ['หัว'],
#  'ไข่เค็ม': ['ใบ', 'ลูก', 'สำหรับเสิร์ฟ', 'ฟอง'],
#  'อกไก่บด': ['กรัม', 'ถ้วย'],
#  'กระเพาะปลาหั่นท่อนแช่น้ำ': ['กรัม'],
#  'พริกหยวก': ['ตามใจชอบ',
#   'เม็ดใหญ่',
#   'ถ้วย',
#   'ดอด',
#   'หัว',
#   'ดอก',
#   'เม็ด',
#   'อัน',
#   'ลูก'],
#  'ไข้ไก่': ['ฟอง'],
#  'เส้นโซเม้ง': ['กำ'],
#  'ตัวมักกะโรนี': ['ถ้วย'],
#  'พริกไทยสามสีป่น': ['ตามชอบ'],
#  'กระเทียมไทย': ['ถ้วย',
#   'ช้อนโต๊ะ',
#   'กรีบ',
#   'หัวใหญ่',
#   'ทัพพี',
#   'เม็ด',
#   'ช้อนชา',
#   'กำมือ',
#   'หยิบมือ',
#   'กลีบ',
#   'กรัม',
#   'หัว',
#   'กำ',
#   'ตามชอบ'],
#  'น้ำมันสำหรับเมนูไข่': ['ช้อนโต๊ะ'],
#  'ปลาหมึกสด': ['ชิ้น', 'กรัม', 'ตัว', 'กก.', 'ขีด'],
#  'ปูม้า': ['ตัวเล็ก', 'กรัม', 'ตัว'],
#  'ต้นหอมและกระเทียมสับ': ['ช้อนโต๊ะ'],
#  'พริกสับหยาบ': ['เม็ด'],
#  'พริกไทยขาวป่น': ['เล็กน้อย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'ตามชอบ',
#   'นิดหน่อย',
#   '',
#   'ชช',
#   'ตามใจชอบ',
#   'ช้อนชา'],
#  'เนื้อสัตว์ ตามชอบ': ['g'],
#  'เกลือเม็ด': ['ช้อนโต๊ะ', 'ช้อนชา'],
#  'ขิงซอย': ['ปริมาณตามชอบ',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'กำมือ',
#   'นิดหน่อย',
#   'ขีด'],
#  'ออริกาโน่': ['ช้อนชา', 'ช้อน', 'ก็แล้วแต่ชอบ', 'นิดหน่อย', 'ตามชอบ', ''],
#  'บะหมี่กึ่งสำเร็ึจรูปไวไว': ['ซอง'],
#  'หอยนางรมสด': ['กิโลกรัม'],
#  'ส่วนผสมการหมักไก่': [''],
#  'น้ำปลาเมกกาเซฟ': ['ชช'],
#  'หมูสันคอ': ['ขีด', 'ชิ้น', 'กิโลกรัม', 'กรัม', 'g'],
#  'น้ำอ้อย': ['กิโลกรัม', 'ช้อนโต๊ะ'],
#  'ต้นขึ้นฉ่ายหั่น': ['ต้น'],
#  'ผงคนอร์': ['ช้อนโต๊ะ', 'ช้อนชา', 'เล็กน้อย', 'ช้อน', 'ชต'],
#  'แป้งสาลีชุบทอด': ['ช้อนโต๊ะ'],
#  'ข้าว': ['ทัพพี',
#   'ทับพี',
#   'กรัม',
#   'จาน',
#   'คนทาน',
#   'ถ้วน',
#   'ถ้วยเล็ก',
#   'ถ้วย',
#   'ชาม',
#   'สำหรับ  ท่าน'],
#  'ผักขมแช่แข็ง': ['ถ้วย'],
#  'งาขาวคั่ว': ['ชต',
#   'ตามชอบ',
#   'ชช.',
#   '',
#   'ช้อนโต๊ะ',
#   'ชช',
#   'ช้อนชา',
#   'สำหรับโรยหน้า'],
#  'วุ้นเส้นสดหรือวุ้นเส้นที่แช่น้ำแล้ว': ['กำมือ'],
#  'ซอสหม่าล่าสำเร็จรูป': ['ซอง'],
#  'ผงปรุงรสไก่หรือหมู': ['ช้อนโต๊ะ'],
#  'ไก่ย่าง': ['ถ้วยตวง'],
#  'กุยช่าย': ['', 'กรัม', 'กำ', 'กำมือ', 'ขีด', 'ตามชอบ', 'ปริมาณตามชอบ'],
#  'เกลือแกง': ['ทัพพี', 'ช้อนโต๊ะ', 'ช้อนชา'],
#  'ไส้กรอกเจ': ['อัน'],
#  'ซอสถั่วเหลือง': ['ชต.',
#   'ช้อน',
#   'ชต',
#   'ชช.',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'ช้อนชา'],
#  'เส้นหมี่ขาว': ['ห่อเล็ก', 'ก้อน', 'ห่อใหญ่', 'กรัม', 'ห่อ', 'กก'],
#  'ข้าวไรซ์เบอร์รี่หุงสวยๆ': ['ถ้วย'],
#  'ลูกชิ้นบิ๊กอิสรา': ['กรัม'],
#  'กะปิอย่างดี': ['ช้อนโต๊ะ'],
#  'ตะไคร้ใหญ่': ['ต้น'],
#  'ตะไคร้ใบมะกรูด': [''],
#  'เนื้อวัวสับ': ['ตามชอบ', 'ถ้วย', 'กรัม'],
#  'พริกขี้หนูสีแดง': ['เม็ด'],
#  'ต้นหอม/ผักชี ซอย': ['ตามชอบ'],
#  'ซีอิ้วหวาน ตราเด็กสมบูรณ์': ['ช้อนโต๊ะ'],
#  'หอมใหญ่หั่นเต๋า': ['หัว', 'ลูก', 'ตามชอบ', 'ถ้วย', 'กรัม'],
#  'ถั่วแระญี่ปุ่น': ['g.', 'ถ้วย'],
#  'พริกไทย กระเทียม รากผักชี ตำรวมกัน': ['ช้อนโต๊ะ'],
#  'สปาเก็ตตี้ต้มสุก': ['g.'],
#  'ดอกกะหล่ำ': ['หัว', 'หัวเล็ก', 'ชิ้น', 'กรัม'],
#  'กะปิดี': ['ช้อนโต๊ะ', 'ช้อนตักแกง', 'ชต'],
#  'สันนอกหมูหั่น': ['ขีด'],
#  'เนื้อปลากระพง': ['ขีด'],
#  'น้ำมันสำหรับทอด': ['พอ',
#   'กรัม',
#   'ถ้วยตวง',
#   'ตามชอบ',
#   'ถ้วยเล็ก',
#   'ขวด',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ'],
#  'อิงลิชมัฟฟิน หรือ ขนมปัง': ['ชิ้น'],
#  'ผงขมิ้น': ['ชช', 'ช้อนชา', 'ช้อนโต๊ะ'],
#  'ซุคลาโรส': ['ช้อนชา'],
#  'ปูนึ่งสุก': ['ตัว'],
#  'เส้นไวไว': ['ห่อ'],
#  'กะปิ': ['ช้อนชา',
#   'ชต.',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ชต',
#   'ตามชอบ',
#   'ชช.',
#   'ช้อนพูนๆ',
#   'นิดหน่อย',
#   ''],
#  'สับปะรดหั่นเล็ก': ['ชต'],
#  'น้ำปลาร้าแซ่บไมค์': ['ช้อนโต๊ะ'],
#  'ต้นตำลึง': ['กำมือ'],
#  'พริกแดงซอย': ['เม็ด'],
#  'ผักตกแต่ง': ['แล้วแต่ชอบ'],
#  'ต้นหอมซอส': ['กรัม'],
#  'ใบ Basil แห้ง': ['ช้อนโต๊ะ'],
#  'ใบกระเพราแดง': ['กำ', 'ตามใจชอบ', 'ใบ', 'กำมือ'],
#  'รากผักชี+กระเทียม+พริกไทย': ['ช้อนชา', 'หนึ่งช้อนโต๊ะ'],
#  'เนื้อปลาหรือทูน่ากระป๋อง': ['ตัว/กระป๋อง'],
#  'น้ำมะนาว': ['ลูกใหญ่',
#   'ช้อนชา',
#   'ชต.',
#   'ช้อน',
#   'ลูก',
#   'ช้อนช้า',
#   'ชต',
#   'ช้อนโต๊ะ   ช้อนชา',
#   'ตามชอบ',
#   '',
#   'ช้อนโต๊ะ'],
#  'แมงกะพรุนอย่างดี ล้างเรียบร้อย': ['ถุง'],
#  'หมึกแห้งแช่น้ำจนนิ่ม หั่นเป็นเส้นๆ': ['ตัวเล็ก'],
#  'กะหล่ำปลีหั่นฝอย': ['ถ้วย', 'กรัม'],
#  'น้ำปลา ครึ่งถ้วยตวง': [''],
#  'น้ำมันถั่ว เ หล ื ิ อง': ['ช้อนโต๊ะ'],
#  'ซีอิ้วดำ': ['ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'กรัม',
#   'ข้อนชา',
#   'ตามชอบเพิ่มสีสัน',
#   'นิดหน่อย',
#   'นิดหน่อยเพิ่มสีสัน',
#   'แล้วแต่ชอบ',
#   'ชต',
#   'ตามชอบ',
#   'ชช.',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ชช',
#   'ช้อนโต๊',
#   'นิดนึง  หยด',
#   'ช้อนชา'],
#  'กุ้งก้ามกรามลวก': ['ตัว'],
#  'กึ้นช่าย': ['ต้น'],
#  'Sage powder': ['เล็กน้อย'],
#  'ต้นถั่วงอก ตัดราก': ['ขีด'],
#  'เห็ดหอมหั่นแช่น้ำใว้ในตู้เย็น1 คืน': ['ดอก'],
#  'เนื้อโคขุน': ['กรัม'],
#  'พริกกระเทียมสับ': ['ช้อนโต๊ะ'],
#  'เห็ดชิเมจิ': ['ดอก', 'กรัม', 'ตามชอบ', 'ถ้วย', '', 'ห่อ', 'ต้น'],
#  'พริกเขียว แดง': ['เม็ด'],
#  'เครื่องปรุง': ['ตามใจชอบ', ''],
#  'ถั่วพู': ['ฟัก', 'ฝัก', 'กรัม'],
#  'ไส้กรอกหมูทอด': ['ชิ้น'],
#  'ซีอิ้วเกาหลี ถ้าไม่มีใช้ของไทยได้': ['กะเอา'],
#  'เส้นก๋วยเตี๋ยวเล็ก': ['กิโลกรัม', 'ห่อเล็ก'],
#  'เส้นหมี่ซั่ว': ['กำ', 'ใจ', 'กรัม', 'ห่อ'],
#  'โปรตีนถั่วเหลือง': ['g.'],
#  'ขมิ้น': ['หัว', 'แง่ง'],
#  'มักโรนี': ['กรัม'],
#  'มะเขือเทศลูกเล็กผ่าครึ่ง': ['ลูก'],
#  'เห็ดหอมสด': ['ชิ้น', 'กรัม', 'หัว', 'kg', 'ดอก', ''],
#  'อกไก่/ สันในไก่': ['กิโลกรัม'],
#  'กุ้งหั่นชิ้น': ['ตัว'],
#  'ซอสพิซซ่าญี่ปุ่น': ['ตามชอบ'],
#  'ชูรส': ['ช้อนโต๊ะ', 'ชช', 'ช้อนชา'],
#  'น้ำอาจาดแม่ประนอม': ['ขวด'],
#  '้น้ำมันงา': ['ช้อนโต๊ะ'],
#  'ปลาสลิดทอดแกะเนื้อ': ['ตัว'],
#  'ไข่ปลาหมึก': ['กรัม', 'ตามชอบ'],
#  'เต้าหู้ เลือกแบบแข็งหรือแบบนิ่มก็ได้': ['ก้อน'],
#  'หางกระทิ': ['ถ้วย'],
#  'corn': ['cup'],
#  'ซอสถั่วเหลืองปรุงรส': ['เล็กน้อย'],
#  'ก้านพลู': ['ช้อนโต๊ะ', 'ก้าน'],
#  'ผง Tikka': ['ช้อนโต๊ะ'],
#  'ซีอิ๋วดำ': ['เล็กน้อย', 'ช้อน', 'พอให้หมูมีสี', 'ถ้วย', '', 'ช้อนชา'],
#  'อกไก่สับ': ['กรัม', 'ถ้วย', '', 'ชิ้น'],
#  'หอมแดงซอย': ['หัว',
#   'ชต.',
#   'กลีบ',
#   'ช้อนโต็ะ',
#   'หัวเล็ก',
#   'ตามชอบ',
#   'ถ้วย',
#   'หยิบมือ',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'แป้งท้าวยายม่อม': ['', 'กรัม', 'ชต'],
#  '++ข้าวผัดกระเทียม++': [''],
#  'ไส้อั่ว': ['ชิ้นเล็ก', 'กก', 'กรัม'],
#  'กะหล่ำปีซอย': ['กรัม'],
#  'ไก่น่องสะโพก': ['น่อง'],
#  'วีปครีมสด': ['ml'],
#  'พริกแกงเผ็ดสำเร็จรูป': ['ช้อนชา'],
#  '้เส้นสปาเก็ตตี้': ['ซอง'],
#  'ปลาร้าสับ': ['ถ้วย'],
#  'ถั่วลิสงแกะเปลือก': ['ช้อนโต็ะ'],
#  'ซอสเทอริยากิ ยามาโมริ': ['ชต'],
#  'พริกไทยป่น': ['ช้อนชา',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'ช่อนชา',
#   '/ช้อนชา',
#   'แล้วแต่ชอบ',
#   'เหยาะหน้าก๋วยเตี๋ยว',
#   'ตามชอบ',
#   'ส.',
#   'ใส่ตามชอบ',
#   'โรยหน้า',
#   'ชช.',
#   'นิดหน่อย',
#   '',
#   'ช้อนช้า',
#   'เหยาะๆ ลงไป',
#   'ชช',
#   'ตามใจชอบ'],
#  'น้ำตาลไว้ชูรส': ['นิดหน่อย'],
#  'บะหมี่หยก': ['ก้อน'],
#  'หอมใหญ่หั่นชิ้นเล็ก': ['ลูก'],
#  'ผงปรุรงส': ['ช้อนชา'],
#  'เห็ดที่ชอบ': ['ถ้วยใหญ่'],
#  'มันฝรั่ง': ['',
#   'กิโลกรัม',
#   'หัว',
#   'หัวใหญ่',
#   'กรัม',
#   'ลูก',
#   'หัวเล็ก',
#   'ลูกกลาง'],
#  'ซอสปรุงรส แบบโซเดียมน้อยตราเด็กสมบูรณ์': ['ช้อนชา'],
#  'หมี่กึง เต้าหู้และเห็ดหอม': ['ชาม'],
#  'ข้าวสวยค้างคืน': ['ถ้วย'],
#  'พริกไทยบด': ['ช้อนชา', 'เสี้ยวช้อนโต๊ะ'],
#  'เห็ดเข็มทองหั่น': ['ช้อนโต๊ะ'],
#  'ขาไก่ต้มสุก': ['ก.ก.'],
#  'คนอร์อร่อยชัวร์': ['ช้อนชา', 'ชต.', 'ชต', 'ชช.', 'ช้อนโต๊ะ'],
#  'ถั่วฟักยาว': ['', 'ช้อนโต๊ะ', 'กรัม', 'ฟัก'],
#  'สับประรด': ['ชิ้น'],
#  'กะหล่ำปลีเล็ก': ['หัว'],
#  'ซีอิ๊วดำเค็ม': ['ตามชอบ'],
#  'ผักชีฝรั่ง': ['กรัม', 'ตามชอบ', 'ใบ', '', 'ช้อนโต๊ะ', 'ต้น'],
#  'ขิง+พริกสด+กระเทียม สับละเอียด': ['ตามชอบ'],
#  'พรีโก้ซอสมะเขือเทส': ['กป.'],
#  'กุ้งสด': ['kg',
#   'ขีด',
#   'ตัว ตามชอบ',
#   'ตามที่มี',
#   'ตามชอบ',
#   'ขึด',
#   'ปริมาณตามชอบ',
#   'ตัว',
#   'กก.',
#   'กิโลกรัม',
#   'กรัม',
#   'ถ้วยตวง'],
#  'ลูกชิ้นเอ็นหมู': ['กิโลกรัม'],
#  'ตะไคร้หั่นยาวทุบ': ['ชิ้น'],
#  'รากผักชี กระเทียม พริกไทยโขลก': ['ช้อนโต๊ะ'],
#  'เชดดาร์ชีส': ['แผ่น'],
#  'ปลาหมึกกรอบ': ['ชิ้น', 'ตัวใหญ่', 'ชิ้นใหญ่', 'ขีด', 'ตามชอบ'],
#  'โลโลน่า': ['แพค'],
#  'ผัด 3 สี ต้มสุก': ['ขีด'],
#  'ข้าวกล้อง': ['ถ้วย', 'กรัม', 'ทัพพี'],
#  'น้ำมันดอกคาโนล่า': [''],
#  'ข้าวโพดหวานต้มสุก': ['ฝัก'],
#  'นํ้าพริกเผา': ['ช้อนโต๊ะ'],
#  'หมูย่าง': ['ขีด'],
#  'ผงซุป': ['ช้อนชา'],
#  'แม๊กกี้': ['ช้อนโต๊ะ', 'แล้วแต่ชอบ', 'ตามต้องการ', 'นิดหน่อย'],
#  'ปลาหมึกไข่': ['กรัม'],
#  'ซอสภูเขาทอง': ['ช้อนชา', 'ช้อน', 'ช้อนโต๊ะ'],
#  'เส้นพาสต้าแบบแบน': ['กำมือ'],
#  'เบคอนหั่น': ['เส้น', 'กรัม', 'ขีด'],
#  'เบคอน/กากหมู': ['ตามใจชอบ'],
#  'เกลือและพริกไทย สำหรับปรุงรส': ['', 'ตามชอบ'],
#  'ผักใบเขียวตามชอบ': ['กรัม'],
#  'แครอทหั่นเต๋าเล็ก': ['กรัม', '', 'ช้อนโต๊ะ'],
#  'ไข่ไก่ + ไข่เหลือจากชุบไก่ทอด': ['ฟอง'],
#  'ปลาแซลมอนไข่กุ้ง Sea life': ['ช้อนชา'],
#  'น้ำพริกตาแดง': ['ตามชอบ', 'ช้อนโต๊ะ'],
#  'น้ำตาลละลาย': ['ชต'],
#  'ผักโขม': ['แพ็ค', 'ต้น', 'g', 'ถุง', 'ตามชอบ', 'กำมือ', 'ช้อนโต๊ะ', 'กรัม'],
#  'เตวนจัง': ['ช่อนโต๊ะ'],
#  'ไข่ไก่/ไข่เป็ด': [''],
#  'กุ้งแห้ง': ['ช้อนโตีะ',
#   'tbsp',
#   'เล็กน้อย',
#   'ถ้วยตวง',
#   'ขีด',
#   'ชต',
#   'ตามชอบ',
#   'กำมือ',
#   'ถ้วย',
#   'ชต.',
#   'หยิบมือ',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'หน่ำเลี้ยบ': ['เม็ด'],
#  'ข้าวสวย.': ['ถ้วย'],
#  'หัวหอมใหญ่หั่นเต๋า': ['หัว'],
#  'หนวดหมึกกระดอง': ['ขีด'],
#  'เห็ดหอมดอกกลาง': ['ดอก'],
#  'พริกขี้หนูธรรมดา': ['เม็ด'],
#  'ผงฮอทเเอนด์สไปซี่': ['ชต'],
#  'มายองเนส': ['ถุง',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'ชช.',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ช้อนชา'],
#  'คื่นไช้': ['ต้น', ''],
#  'บะหมี่ หรือเส้นเล็ก': ['ตามชอบ'],
#  'พริกสดหั่น': ['เมล็ด', 'เม็ด'],
#  'ซอสปรุงรสฝาเหลือง': ['ช้อนโต๊ะ'],
#  'แครอดหั่นลูกเต๋า': ['หัว'],
#  'มะนาวสด': ['ซีก'],
#  'ถั่วฝักยาว': ['ถ้วย',
#   'สำหรับเสิร์ฟ',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'เส้น',
#   'ต้น',
#   'กำ',
#   'อัน',
#   'เล็กน้อย',
#   'ถ้วยตวง',
#   'ฝัก',
#   'ขีด',
#   'ตามชอบ'],
#  'กระชายหั่นเส้น': ['ถ้วย', 'หยิบมือ'],
#  'น้ำตาลทรายสำหรับแหนมคลุก': ['ช้อนชา'],
#  'ปลาหมึกหั่น': ['เล็กน้อย'],
#  'พริกชี้ฟ้าแดงโครกหยาบ': ['เม็ด'],
#  'ปวยเล้ง หรืออื่นๆตามชอบ': ['ตามชอบไม่ชอบไม่ใส่'],
#  'ไข่เจียวหั่นฝอย': ['ตามชอบ', 'ฟอง'],
#  'บล็อคโครี่': ['ตามชอบ', ''],
#  'หนังหมูต้มสุก': ['บาท'],
#  'เนื้อปลาดอร์รี่': ['ตามชอบ'],
#  'กระเทียมจีน': ['กีบ',
#   'เม็ด',
#   'กลีบ',
#   'กลับ',
#   'กลีบใหญ่',
#   'หัว',
#   'ตามชอบ',
#   'กีบใหญ่',
#   ''],
#  'บ๊อกชอย': ['หัว'],
#  'ผงโรยข้าว': ['ตามใจชอบ', 'ช้อน'],
#  'ถั่วลูกไก่แช่น้ำและต้มจนสุกนุ่ม': ['ตามชอบ'],
#  'ผักสลัดตามชอบ': ['ปริมาณตามต้องการ', 'กำมือ', '', 'จาน'],
#  'พริกแห้งป่น': ['ทัพพี'],
#  'เนือหมู': ['กรัม'],
#  'ผักที่ชอบ': ['กรัม', 'ตามต้องการ'],
#  'ซอสมัสตาร์ด': ['ช้อนโต๊ะ'],
#  'ผักชีต้นหอมสับ': ['ชต'],
#  'พริกแกง': ['ตามสะดวก',
#   'ช้อน',
#   'kg',
#   'ข้อนโต๊ะ',
#   'ขีด',
#   'ช่อนโต๊ะ',
#   'ชต.',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'เพนเน่ต้มสุก': ['ถ้วย'],
#  'ไข่กุ้ง': ['ตามชอบ', 'ชต', 'ชต.', 'เล็กน้อย', 'กรัม', 'แล้วแต่ชอบ'],
#  'ปีกกลางไก่': ['กรัม'],
#  'แหนม': ['อัน',
#   'ชิ้น',
#   'แท่ง',
#   'แท่งเล็ก',
#   'ท่อนเล็ก',
#   'g',
#   'กรัม',
#   'ห่อ',
#   'ท่อนยาว',
#   'ลูก'],
#  'ปลากระป๋อง': ['กระป๋อง', 'กป.', 'กระปุก'],
#  'ซอสหอยนางรมตราแม่ครัว': ['ทัพพี', 'ช้อนโต๊ะ'],
#  'ปลาโอขูดแห้ง': ['กรัม'],
#  'ผักกาดขาว/ผักอื่นๆ': ['ตามใจชอบ'],
#  'แป้งตอตีญ่าแผานใหญ่': [''],
#  'ต้นหอม ผักชี': ['ช้อนชา', 'กำ', 'ช้อนโต๊ะ', 'ต้น'],
#  'น้ำจิ้ม 1 - น้ำส้มสายชู': ['ช้อนโต๊ะ'],
#  'พริกหวาน สีแดง + สีเหลือง หั่นเป็นชิ้นเล็กๆ': ['ตามต้องการ'],
#  'เลือดหมู': ['ก้อน'],
#  'พริกขี้หนูแห้งหั่นท่อน เอาเม็ดพริกออก': ['เม็ด'],
#  'พริกไทยอ่อนตัดเป็นท่อนสั้นๆ': ['ฝัก'],
#  'โรสแมรี่': ['tps', 'ช้อนโต๊ะ', 'ช้อนชา', 'หยิบมือ'],
#  'ถั่วลันเตาแช่แข็ง': ['ตามชอบ'],
#  'กระเทียมโทน': ['กรีบ', 'กีบ', 'เม็ด', 'กลีบ'],
#  'ลูกผักชี': ['ช้อนชา', 'ลูก', 'ตามชอบ', 'ช้อนโต๊ะ'],
#  'สี่อิ๋วขาวสูตร1': ['ทัพพี', 'ช้อนชา', 'ช้อนโต๊ะ'],
#  'เต้าเจี้ยว ตามชอบ สูตรนี้ไม่ได้ใส่เพราะไม่มี': [''],
#  'เส้นสปาเก็ตตี้ต้มสุก': ['ถ้วย', 'กรัม', 'ตามชอบ'],
#  'บรอคคอลลี่': ['ตามชอบ'],
#  'พริกแกงน้ำเงี้ยวสำเร็จ': ['ซองเล็ก'],
#  'มะเขือเทส': ['ลูก'],
#  'ผงคนอร์รสลาบ': ['กรัม'],
#  'สันในหมู': ['กรัม', 'ขีด', ''],
#  'กระหล่ำปลี': ['หัว', 'ถ้วยตวง', '', 'หัวเล็ก', 'ใบ', 'กำมือ', 'ใข'],
#  'เส้นหมี': ['ห่อ'],
#  'น้ำเชื่อมใบเตย': ['ช้อนโต๊ะ'],
#  'แตงกวาแช่เย็น': ['ลูกใหญ่'],
#  'ส่วนผสมแป้งทอด': [''],
#  'กระเทียมสำหรับใส่ไก่': ['กลีบ'],
#  'เห็ดหอมดอกใหญ่': ['ดอก', 'กรัม'],
#  'ข้าวบาสมาติ': ['ถ้วยตวง', 'ถ้วยตวงข้าว', 'กระป๋องตวงช'],
#  'ปลาทูน่ากระป๋อง': ['กระป๋องเล็ก'],
#  'หมูสามชั้นเจียวเหลือง': ['ถ้วย'],
#  'หอมแดง': ['กลีบใหญ่',
#   'ถ้วยตวง',
#   'ขีด',
#   'หัวเล็ก',
#   'ตามชอบ',
#   'ลูกเล็ก',
#   'เม็ด',
#   'โรยหน้า',
#   'กำมือ',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'หัว',
#   'ลูก',
#   'ช้อนชา'],
#  'น้ำตาลปีบ': ['ชช.', 'ช้อน', 'ช้อนโต๊ะ', 'ช้อนชา', 'นิดหน่อย', 'ขีด', 'ชต'],
#  'กะปิ ตรา เรือใบ': ['ช้อนโต๊ะ'],
#  'เต้าหู้ไข่ไก่': ['อัน', 'หลอด'],
#  'กระเทียมเจียว พริกไทย ต้นหอม ผักชีซอยไว้โรยหน้า': ['ตามใจชอบ'],
#  'น้ำจิ้ม - พริกชี้ฟ้า แดง เขียว เหลือง อย่างละ 1 เม็ด': ['เม็ด'],
#  'กระเทียมกลีบเล็ก': ['กลีบ', 'กรัม', 'ช้อนโต๊ะ'],
#  'กระชาย ล้างให้สะอาด ตำให้ละเอียด': ['กรัม'],
#  'ผง coriander': ['ช้อนโต๊ะ', 'ช้อนชา'],
#  'ไก่สับ': ['ช้อนโต๊ะ', 'กรัม', 'ขีด'],
#  'ซอสพริก': ['ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'เหยาะๆ ลงไป',
#   'ทัพพี',
#   'ช้อนชา',
#   'ชต.',
#   'ช้อน',
#   'กรัม',
#   'ตามชอบ',
#   'กระบวย'],
#  'ตำลึง จำนวนตามชอบ': [''],
#  'ปีกบนไก่': ['กรัม', 'กก.', 'ชิ้น'],
#  'เส้นจันทน์': ['กำ', 'กิโลกรัม'],
#  'น้ำมันมะกอกแคลอรี่0 สำหรับผัด': ['นิดหน่อย'],
#  'ถั่วฝักยาว ถั่วพลู ผักกาดดองหั่น มะระจีนลวก ใบแมงลัก หรือผักอื่นๆตามชอบ': [''],
#  'แครอท บลอกโคลี ถั่วแขก': [''],
#  'ต้นหอมหั่นเป็นท่อน': ['ต้น'],
#  'ผงปรุงรสรสหมู': ['เล็กน้อย', 'ตามชอบ', 'ช้อนชา', 'ช้อนโต๊ะ'],
#  'เต้าหู้ทอด': ['ถ้วย', 'พวง', 'ช้อนโต๊ะ', 'ก้อน', 'ถ้วยตวง'],
#  'ซีอิ๋วดำหวาน': ['กระบวย'],
#  'ข้าวกล้องสุก': ['ทัพพี'],
#  'หัวหอมหัวใหญ่ หั่นเต๋า': ['หัว'],
#  'ใบสะระแหน่': ['กรัม', 'ตามชอบ', 'ถ้วย', '', 'ต้น'],
#  'มาคูมิซอส': ['ช้อนโต๊ะ'],
#  'กุ้งแช่บ๊วย': ['ตัว'],
#  'เกลือ น้ำตาล': ['ตามชอบ', ''],
#  'ซี่อิ้ว': ['ช้อนโต้ะ'],
#  'ซอสฝาเขียว': ['ช้อนชา', 'ชต', 'ชช.', 'ช้อนโต๊ะ', 'ช้อร', 'ชช'],
#  'ใบกระเพราตามชอบ': ['ต้น'],
#  'พริกหั่น': ['ตามชอบ', 'เม็ด'],
#  'หอมใหญ่ซอย': ['ตามชอบ', 'ลูกเล็ก', 'หัว'],
#  'แป้งถั่วลันเตา': ['กรัม'],
#  'ขมิ้นชันป่น': ['ช้อนชา'],
#  'ต้นหอม+ผักชี หั่นเป็นท่อน': ['กำ'],
#  'สัปปะรด ครึ่งลูก': ['ลูก'],
#  'หอยลาย': ['โล', 'KG', 'กรัม', 'g', 'kg'],
#  'พริกป่น น้ำตาลทราย ปรุงรส': [''],
#  'สะโพกไก่ติดหนังเลาะกระดูก': ['ชิ้น'],
#  'พริกไทยเม็ด': ['กิ่ง',
#   'ตามชอบ',
#   'พวง',
#   '',
#   'ช้อนโต๊ะ',
#   'เม็ด',
#   'ช้อนชา',
#   'กำมือ',
#   'ห่อเล็ก',
#   'กรัม',
#   'ห่อ'],
#  'รสดี': ['ซองเล็ก',
#   'นิดหน่อย',
#   'ช้อนชา',
#   'ชช.',
#   'ปลายช้อน',
#   'เล็กน้อย',
#   '',
#   'ช้อน',
#   'ช้อนโต๊ะ'],
#  'พริกไทยสด': ['ขีด', 'ตามชอบ', 'ก้าน', 'พวง', 'ชิ้น', 'หัว'],
#  'กระเทียวซอย': ['กลีบ'],
#  'ไข่ต้มหรือผักเคียง': ['ตามชอบ'],
#  'หมี่ขาวไวไว': ['ห่อ', 'ห่อเล็ก'],
#  'ผงเติมทิพ.': ['ช้อนชา'],
#  'ผักตามใจชอบ': ['ขีด'],
#  'ยอดมะพร้าว': ['โล', 'หัว', 'ถ้วย'],
#  'เศษเนื้อน่องไก่': ['กรัม'],
#  'เคยกุ้งสด': ['ช้อนชา'],
#  'ต้น': [''],
#  'รสดีหมู': ['ช้อนชา', 'ชต.', 'ช้อนโต๊ะ'],
#  'ตั้งฉ่าย': ['ถ้วย', 'หยิบมือ', 'ช้อนโต๊ะ'],
#  'พริกหนุ่ม': ['กรัม', 'เม็ด'],
#  'ผงคนอร์รสไก่': ['ช้อนชา'],
#  'ตับหมู': ['ชิ้น',
#   'ช้อนโต๊ะ',
#   'ชิ้นฝ่ามือ',
#   'บาท',
#   'กรัม',
#   'kg',
#   'ขีด',
#   'กิโล'],
#  'ข้าวเหนียวดิบ': ['kg'],
#  'ปลาหมึกแห้ง': ['กรัม', 'ตัว'],
#  'ใบกระเพราหรือโหระพา': [''],
#  'สามชั้น': ['กก'],
#  'ไข่ไก่ เบอร์3': ['ฟอง'],
#  'เนื้อบด': ['กรัม', 'g'],
#  'พริก กระเทียม ตามชอบ': [''],
#  'ต้นหอม/ผักชี': ['ต้น', 'ตามชอบ'],
#  'ตับไก่1ก้อนหั่น5': ['ก้อน'],
#  'ซี้อิ้วขาว': ['ช้อนโต๊ะ', 'ช้อน'],
#  'ไข่ไก่': ['. ฟอง',
#   'ใบ',
#   'ฟ.',
#   'ฟองใหญ่',
#   'กรัม',
#   'ฟองต่อชาม',
#   'ลูก',
#   'ตามชอบ',
#   '',
#   'ฟอง'],
#  'ปลาเส้น': ['ชิ้น', 'เส้น'],
#  'น้ำมันพืชสำหรับทอด': ['ถ้วยตวง', 'ถ้วย', '', 'ช้อนโต๊ะ'],
#  'นมสดรสจืด': ['ml.', 'ถ้วย', 'ถ้วยตวง'],
#  'ไวไว': ['ซอง', 'ห่อ'],
#  'ส่วนแป้งสำหรับชุปทอด': [''],
#  'ผักสามสี': ['กรัม', 'อย่างละ ช้อน', 'ตามชอบ', 'ถ้วยเล็ก', ''],
#  'หอมใหญ่หั่นเสี้ยว': ['ลูก', 'ลูกเล็ก', 'ถ้วย', 'กรัม'],
#  'ซอสฮอลแลนเดซ': ['ตามต้องการ'],
#  'สันคอหมู หรือ เนื้อ': ['ชิ้น'],
#  'กระเทียนโทน': ['กีบ'],
#  'ชุดทำก๋วยเตี๋ยวไก่': [''],
#  'ไข่ไก่ หรือ ไข่เป็ด': ['ฟอง'],
#  'เม็ดพริกไทยสด': [''],
#  'แตงกวา มะนาว': [''],
#  'ผักโรยผักชี คื่นช่าย': [''],
#  'กระเทียม สับ': ['ช้อนโต๊ะ', 'ช้อนชา', 'กลีบ'],
#  'พริกแกงเผ็ดขมิ้น': ['กรัม'],
#  'เนื้อหมูบด': ['ขีด', '', 'กรัม', 'g'],
#  'กรือโป๊ะ': ['เส้น'],
#  'ถั่วลิสงบด': ['ช้อนชา', 'ขีด', 'ตามชอบ', 'ช้อนโต๊ะ'],
#  'ซีอิ๊วขาว': ['เหยาะ',
#   'ชต',
#   'เหยาะๆลงไป',
#   'ตามชอบ',
#   'ถ้วยตวง',
#   'นิดหน่อย',
#   '',
#   'ช้วนโต๊ะ',
#   'ช้อนช้า',
#   'เหยาะๆ ลงไป',
#   'ข้อนโต๊ะ',
#   'ชช',
#   'ช้อนโต๊ะ ตามชอบ',
#   'ทัพพี',
#   'พอ',
#   'ช้อนชา',
#   'ช.ต.',
#   'ช',
#   'ถต.',
#   'ชช.',
#   'ถ้วย',
#   'ชต.',
#   'เล็กน้อย',
#   'ช้อน',
#   'ช้อนโต๊ะ',
#   'ใช้ปรุงรส'],
#  'หมูยออย่างดี': ['กรัม'],
#  'หมูสามชั้นแบบทอดเสร็จ': ['ชิ้น'],
#  'เส้นมะกะโรนี': ['ฟอง', 'กรัม'],
#  'เส้นก๋วยจั๊บญวน': ['ห่อ'],
#  'หอมแดงหั่นสไลด์': ['ตามชอบ'],
#  'ดอกจัน': ['ดอก'],
#  'พริกเผา': ['ช้อนโต๊ะ', 'ช้อนชา', 'ช้อน', 'ชต', 'ตามชอบ'],
#  'พริกไทปุ่น': ['ชช'],
#  'ไส้กรอกหรือเนื้อสัตว์': ['ตามความชอบ'],
#  'แครอตต้มสุก หั่นชิ้นเล็กๆ': ['ช้อนโต๊ะ'],
#  'เส้นเกี๊ยมอี๋': ['กรัม'],
#  'หอมหัวใหญ่': ['ชต.',
#   'กรัม',
#   'หัว',
#   'ลูก',
#   'ตามใจชอบ',
#   'ตามชอบ',
#   'ผล',
#   'ลูกเล็ก',
#   'ใส่ไม่ใส่ก็ได้ตามชอบ',
#   'ถ้วย',
#   '',
#   'ช้อนโต๊ะ',
#   'ต้น',
#   'หัวใหญ่'],
#  'น้ำมันมะกอกแคลอรี่0': ['นิดหน่อย', 'ตามชอบ'],
#  'แครอทหั่นเป็นแว่นพอดีคำ': ['ถ้วยเล็ก'],
#  'น้ำผึ้ง': ['ถ้วย',
#   'ช้อนโต๊ะ',
#   'ทัพพี',
#   'ช้อนชา',
#   'ชต.',
#   'ถ้วยตวง',
#   'ตามชอบ'],
#  'น้ำมัน-ผัด': ['ช้อนโต๊ะ'],
#  ...}

# %%
len(all_units)
# Out:
# 25014

# %%
uniq_units = list((set(all_units)))

# %%
with open('../data/unit2.txt', 'w') as f:
  f.write('\n'.join(uniq_units))
  f.close()

# %%
with open('../data/ingredients_name.txt', 'w') as f:
  f.write('\n'.join(sorted(list(ingredients_with_unit.keys()))
))

# %%
import json

with open('../data/all_ingredients_unit_map.json', 'w',encoding='utf-8') as f:
  json.dump(ingredients_with_unit, f,ensure_ascii=False)

# %%
with open('../data/all_ingredients2.txt', 'w') as f:
  f.write('\n'.join([u[0] + ','+ u[1] for u in uniq_ingredients]))
  f.close()

# %%
def generate_new_ingredients(ingredients):
  try:
    return [{ 'ingredientName': x[0] , 'amount': x[1], 'unit': x[2]} for x in ingredients]
  except:
    print(ingredients)
    return None

# %%
df['new_ingredients'] = df['amounts_split_size'].apply(generate_new_ingredients)

# %%
df['ingredients'] = df.pop('new_ingredients')
df = df.drop(['amounts_split_size','amounts'],axis=1)

# %%
df['url'] = df['url'].apply(lambda x: f'https://www.wongnai.com/{x}')

# %%
with open('../data/data_with_unit.json', 'w', encoding='utf-8') as file:
    df.to_json(file,orient='records', force_ascii=False)
