# %%
import re
import pandas as pd
from pythainlp.util import normalize

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('../data/2.non.csv').sort_values(by=['frequency'], ascending=False).reset_index()
list_df = []
for i in range(len(df)):
    list_df.append([ df.loc[i]['ingredients'] , df.loc[i]['frequency'] ])

# %%
all_facility_unique = [[normalize(i[0]),i[1],0] for i in list_df if i[1] >= 1]

# %%
def search_fsc(all_facility_unique, ch_regex):
    list_exam = []
    for i in range (len(all_facility_unique)) : 
        if re.search(ch_regex, all_facility_unique[i][0]):
            if all_facility_unique[i][1] > 1:
                print(all_facility_unique[i][0],all_facility_unique[i][1])
            all_facility_unique[i][2] = 1
            if all_facility_unique[i][1] > 1:
                list_exam.append(all_facility_unique[i][0])
    example = ', '.join(list_exam)
#     print(example)
    return all_facility_unique,example

def make_table(name,ch_regex,example):
    global df_name
    global df_ch_regex
    global df_example
    df_name.append(name)
    df_ch_regex.append(ch_regex)
    df_example.append(example)

df_name = []
df_ch_regex = []
df_example = []

# %%
all_facility_unique
# Out:
# [['น้ำปลา', 736, 0],
#  ['กระเทียม', 633, 0],
#  ['ไข่ไก่', 627, 0],
#  ['น้ำตาลทราย', 619, 0],
#  ['น้ำตาล', 584, 0],
#  ['น้ำมันหอย', 575, 0],
#  ['น้ำมันพืช', 423, 0],
#  ['เกลือ', 417, 0],
#  ['ซอสปรุงรส', 338, 0],
#  ['น้ำมัน', 328, 0],
#  ['น้ำเปล่า', 306, 0],
#  ['ซีอิ๊วขาว', 294, 0],
#  ['ซีอิ้วขาว', 289, 0],
#  ['กระเทียมสับ', 276, 0],
#  ['พริกไทย', 274, 0],
#  ['ต้นหอม', 228, 0],
#  ['แครอท', 224, 0],
#  ['ซอสหอยนางรม', 213, 0],
#  ['หมูสับ', 197, 0],
#  ['ข้าวสวย', 197, 0],
#  ['ผงปรุงรส', 193, 0],
#  ['มะนาว', 191, 0],
#  ['พริกไทยป่น', 163, 0],
#  ['พริกขี้หนู', 158, 0],
#  ['กุ้ง', 152, 0],
#  ['มะเขือเทศ', 139, 0],
#  ['หอมใหญ่', 135, 0],
#  ['เนื้อหมู', 123, 0],
#  ['น้ำสะอาด', 113, 0],
#  ['รากผักชี', 111, 0],
#  ['เกลือป่น', 108, 0],
#  ['น้ำมันมะกอก', 103, 0],
#  ['ซอสมะเขือเทศ', 103, 0],
#  ['หอมแดง', 100, 0],
#  ['พริกแห้ง', 100, 0],
#  ['พริกป่น', 99, 0],
#  ['ผักชี', 97, 0],
#  ['ใบมะกรูด', 94, 0],
#  ['น้ำมันงา', 93, 0],
#  ['น้ำตาลปี๊บ', 90, 0],
#  ['พริก', 89, 0],
#  ['ใบโหระพา', 89, 0],
#  ['ต้นหอมซอย', 88, 0],
#  ['ถั่วฝักยาว', 84, 0],
#  ['หอมหัวใหญ่', 83, 0],
#  ['ใบกะเพรา', 82, 0],
#  ['ใบกระเพรา', 82, 0],
#  ['อกไก่', 81, 0],
#  ['ซีอิ๊วดำ', 77, 0],
#  ['ถั่วงอก', 76, 0],
#  ['หมูบด', 76, 0],
#  ['พริกไทยดำ', 75, 0],
#  ['คะน้า', 74, 0],
#  ['ข้าวโพดอ่อน', 74, 0],
#  ['ไข่', 73, 0],
#  ['เนย', 70, 0],
#  ['น้ำมันรำข้าว', 67, 0],
#  ['น้ำมะนาว', 67, 0],
#  ['น้ำพริกเผา', 67, 0],
#  ['ซีอิ้วดำ', 62, 0],
#  ['แป้งทอดกรอบ', 59, 0],
#  ['แป้งมัน', 56, 0],
#  ['เห็ดหอม', 56, 0],
#  ['กระเทียมเจียว', 55, 0],
#  ['เส้นสปาเก็ตตี้', 55, 0],
#  ['เนื้อไก่', 54, 0],
#  ['โชยุ', 53, 0],
#  ['เต้าเจี้ยว', 53, 0],
#  ['ตะไคร้', 52, 0],
#  ['ปลาหมึก', 52, 0],
#  ['เบคอน', 52, 0],
#  ['โหระพา', 52, 0],
#  ['ไส้กรอก', 50, 0],
#  ['หัวหอมใหญ่', 49, 0],
#  ['นมสด', 49, 0],
#  ['กุ้งสด', 48, 0],
#  ['ซอสพริก', 48, 0],
#  ['วุ้นเส้น', 47, 0],
#  ['น้ำซุป', 46, 0],
#  ['น้ำมันสำหรับผัด', 45, 0],
#  ['หอมแดงซอย', 45, 0],
#  ['กระเทียมไทย', 45, 0],
#  ['ผักกาดขาว', 43, 0],
#  ['กะปิ', 43, 0],
#  ['พริกชี้ฟ้าแดง', 43, 0],
#  ['พริกสด', 42, 0],
#  ['กะทิ', 42, 0],
#  ['เส้นใหญ่', 42, 0],
#  ['กะหล่ำปลี', 40, 0],
#  ['พริกแกงเผ็ด', 39, 0],
#  ['พริกขี้หนูสวน', 39, 0],
#  ['ผักบุ้ง', 39, 0],
#  ['แฮม', 39, 0],
#  ['หมูยอ', 37, 0],
#  ['หมูสามชั้น', 36, 0],
#  ['แตงกวา', 36, 0],
#  ['กุ้งแห้ง', 35, 0],
#  ['พริกจินดา', 35, 0],
#  ['มิริน', 35, 0],
#  ['น้ำมะขามเปียก', 35, 0],
#  ['ข้าว', 35, 0],
#  ['เส้นสปาเกตตี้', 34, 0],
#  ['ผงปรุงรสคนอร์', 34, 0],
#  ['ขึ้นฉ่าย', 34, 0],
#  ['เห็ดเข็มทอง', 34, 0],
#  ['น้ำมันสำหรับทอด', 33, 0],
#  ['ผักคะน้า', 33, 0],
#  ['มันฝรั่ง', 33, 0],
#  ['แป้งข้าวโพด', 32, 0],
#  ['พริกไท', 32, 0],
#  ['กระเทียมจีน', 32, 0],
#  ['ซอสปรุงรสฝาเขียว', 32, 0],
#  ['น้ำส้มสายชู', 31, 0],
#  ['ข่า', 31, 0],
#  ['ผักชีฝรั่ง', 30, 0],
#  ['มาม่า', 29, 0],
#  ['ซอสถั่วเหลือง', 29, 0],
#  ['ซีอิ๋วขาว', 28, 0],
#  ['แครอทหั่นเต๋า', 28, 0],
#  ['ซีอิ้วปรุงรส', 28, 0],
#  ['น้ำผึ้ง', 28, 0],
#  ['พริกแกง', 28, 0],
#  ['รสดี', 28, 0],
#  ['คนอร์', 27, 0],
#  ['น้ำตาลทรายแดง', 26, 0],
#  ['พริกชี้ฟ้า', 26, 0],
#  ['พริกไทยอ่อน', 26, 0],
#  ['ซีอิ้วดำหวาน', 26, 0],
#  ['ซอสเห็ดหอม', 26, 0],
#  ['พริกไทยดำป่น', 25, 0],
#  ['กระเทียมสับละเอียด', 25, 0],
#  ['ไข่ต้ม', 25, 0],
#  ['พริกแดง', 25, 0],
#  ['หัวไชเท้า', 24, 0],
#  ['กุนเชียง', 24, 0],
#  ['ผงปรุงรสหมู', 24, 0],
#  ['น้ำมันถั่วเหลือง', 24, 0],
#  ['ข้าวคั่ว', 24, 0],
#  ['เนื้ออกไก่', 24, 0],
#  ['ผักกวางตุ้ง', 24, 0],
#  ['พริกขี้หนูซอย', 24, 0],
#  ['ลูกชิ้นปลา', 24, 0],
#  ['ไข่เป็ด', 24, 0],
#  ['ปลากระป๋อง', 23, 0],
#  ['ผักสลัด', 23, 0],
#  ['พริกไทป่น', 23, 0],
#  ['หมู', 23, 0],
#  ['กระดูกหมู', 23, 0],
#  ['ปูอัด', 23, 0],
#  ['หัวหอม', 22, 0],
#  ['เนื้อหมูสับ', 22, 0],
#  ['เนยจืด', 22, 0],
#  ['เกล็ดขนมปัง', 22, 0],
#  ['เต้าหู้ไข่', 22, 0],
#  ['หมูหมัก', 22, 0],
#  ['ใบมะกรูดซอย', 22, 0],
#  ['ตะไคร้ซอย', 22, 0],
#  ['บะหมี่กึ่งสำเร็จรูป', 21, 0],
#  ['กระหล่ำปลี', 21, 0],
#  ['สันในไก่', 21, 0],
#  ['น้ำปลาร้า', 20, 0],
#  ['หมูสันใน', 20, 0],
#  ['งาขาว', 20, 0],
#  ['ถั่วลันเตา', 20, 0],
#  ['กระเทียมทุบ', 20, 0],
#  ['ไข่เค็ม', 20, 0],
#  ['งาขาวคั่ว', 20, 0],
#  ['กระชาย', 20, 0],
#  ['สันคอหมู', 20, 0],
#  ['ผงชูรส', 19, 0],
#  ['เนยเค็ม', 19, 0],
#  ['ขนมจีน', 19, 0],
#  ['กระเพรา', 19, 0],
#  ['ชีส', 19, 0],
#  ['พริกจินดาแดง', 19, 0],
#  ['เห็ดออรินจิ', 19, 0],
#  ['พริกไทยเม็ด', 19, 0],
#  ['คะน้าฮ่องกง', 19, 0],
#  ['พริกหยวก', 18, 0],
#  ['เห็ดหอมสด', 18, 0],
#  ['เส้นหมี่', 18, 0],
#  ['น้ำตาลทรายขาว', 18, 0],
#  ['น้ำมันปาล์ม', 18, 0],
#  ['นมจืด', 18, 0],
#  ['มะเขือเทศราชินี', 18, 0],
#  ['มะเขือเปราะ', 17, 0],
#  ['ผักกาดหอม', 17, 0],
#  ['สะโพกไก่', 17, 0],
#  ['สี่อิ๋วขาวสูตร1', 17, 0],
#  ['พริกเผา', 17, 0],
#  ['ลูกชิ้นหมู', 17, 0],
#  ['ต้นหอมหั่นท่อน', 17, 0],
#  ['น้ำตาลมะพร้าว', 17, 0],
#  ['ซี่โครงหมู', 17, 0],
#  ['ใบมะกรูดฉีก', 16, 0],
#  ['เห็ดฟาง', 16, 0],
#  ['เหล้าจีน', 16, 0],
#  ['ลูกชิ้น', 16, 0],
#  ['เห็ด', 16, 0],
#  ['แหนม', 16, 0],
#  ['ยอดคะน้า', 16, 0],
#  ['คนอร์อร่อยชัวร์', 16, 0],
#  ['กิมจิ', 16, 0],
#  ['กระเทียมไท', 16, 0],
#  ['ออริกาโน่', 16, 0],
#  ['พริกไทยขาวป่น', 16, 0],
#  ['ซีอิ๊วดำหวาน', 16, 0],
#  ['เนยสด', 16, 0],
#  ['กระเทียมสับหยาบ', 15, 0],
#  ['ผักชีซอย', 15, 0],
#  ['ต้นหอมผักชี', 15, 0],
#  ['พริกขี้หนูแดง', 15, 0],
#  ['มายองเนส', 15, 0],
#  ['เส้นหมี่ขาว', 15, 0],
#  ['น้ำจิ้มสุกี้', 15, 0],
#  ['น้ำต้มสุก', 15, 0],
#  ['ขิงซอย', 15, 0],
#  ['ชะอม', 14, 0],
#  ['ไข่แดง', 14, 0],
#  ['หมูสไลด์', 14, 0],
#  ['น้ำตาลปี๊ป', 14, 0],
#  ['ผัก', 14, 0],
#  ['นมข้นจืด', 14, 0],
#  ['ข้าวกล้อง', 14, 0],
#  ['มักกะโรนี', 14, 0],
#  ['ผงคนอร์', 14, 0],
#  ['น้ำตาลปีบ', 14, 0],
#  ['เนื้อหมูบด', 14, 0],
#  ['อบเชย', 14, 0],
#  ['พริกใหญ่', 14, 0],
#  ['หอมเจียว', 14, 0],
#  ['น้ำ', 14, 0],
#  ['พริกไทยขาว', 14, 0],
#  ['ตับหมู', 13, 0],
#  ['พริกขี้หนูตำ', 13, 0],
#  ['กระเทียมกลีบใหญ่', 13, 0],
#  ['หมูกรอบ', 13, 0],
#  ['ซอสน้ำมันหอย', 13, 0],
#  ['ไก่', 13, 0],
#  ['หมูชิ้น', 13, 0],
#  ['ผักโขม', 13, 0],
#  ['ซอสฝาเขียว', 13, 0],
#  ['อร่อยชัวร์', 13, 0],
#  ['โคชูจัง', 12, 0],
#  ['ซีอิ๊วเห็ดหอม', 12, 0],
#  ['หัวกะทิ', 12, 0],
#  ['ไข่กุ้ง', 12, 0],
#  ['พริกแดงจินดา', 12, 0],
#  ['ปลาทู', 12, 0],
#  ['ซอยหอยนางรม', 12, 0],
#  ['พริกขี้หนูสด', 12, 0],
#  ['กระเทียมตำ', 12, 0],
#  ['มันกุ้ง', 12, 0],
#  ['เห็ดหูหนู', 12, 0],
#  ['เต้าหู้', 12, 0],
#  ['ทูน่าในน้ำแร่', 12, 0],
#  ['ไก่สับ', 12, 0],
#  ['น้ำปลาอย่างดี', 12, 0],
#  ['คื่นช่าย', 12, 0],
#  ['น้ำตาลปิ๊บ', 12, 0],
#  ['เบค่อน', 12, 0],
#  ['ซอสฝาเหลือง', 11, 0],
#  ['กะเพรา', 11, 0],
#  ['อกไก่สับ', 11, 0],
#  ['ผักกระเฉด', 11, 0],
#  ['แผ่นเกี๊ยว', 11, 0],
#  ['กระเทียมซอย', 11, 0],
#  ['เห็ดชิเมจิ', 11, 0],
#  ['ไข่ขาว', 11, 0],
#  ['น้ำเย็น', 11, 0],
#  ['สะตอ', 11, 0],
#  ['ซอสหอย', 11, 0],
#  ['ถั่วลิสงคั่ว', 11, 0],
#  ['พริกขี้หนูสับ', 11, 0],
#  ['พริกไทยดำบด', 11, 0],
#  ['แครอทหั่น', 11, 0],
#  ['เส้นเล็ก', 11, 0],
#  ['ซอสเทริยากิ', 11, 0],
#  ['น่องไก่', 11, 0],
#  ['กวางตุ้ง', 10, 0],
#  ['เลือดไก่', 10, 0],
#  ['น้ำมันพืชสำหรับผัด', 10, 0],
#  ['ต้นหอมหั่น', 10, 0],
#  ['น้ำมันหมู', 10, 0],
#  ['กระชายซอย', 10, 0],
#  ['ฟักทอง', 10, 0],
#  ['เห็ดหอมแห้ง', 10, 0],
#  ['ใบกระวาน', 10, 0],
#  ['หอมแขก', 10, 0],
#  ['ซอสเทอริยากิ', 10, 0],
#  ['กุยช่าย', 10, 0],
#  ['หอมใหญ่สับ', 10, 0],
#  ['วุ้นเส้นสด', 10, 0],
#  ['เครื่องปรุงรส', 10, 0],
#  ['ข้าวสาร', 10, 0],
#  ['มะเขือเทศหั่นเต๋า', 10, 0],
#  ['ผงกะหรี่', 10, 0],
#  ['มะเขือพวง', 10, 0],
#  ['มะเขือยาว', 10, 0],
#  ['ซีอิ๊ว', 10, 0],
#  ['ผักชีต้นหอม', 9, 0],
#  ['เชดด้าชีส', 9, 0],
#  ['น้ำตาลกรวด', 9, 0],
#  ['เต้าหู้เหลือง', 9, 0],
#  ['ข้าวเปล่า', 9, 0],
#  ['มะเขือเทศสีดา', 9, 0],
#  ['เห็ดแชมปิญอง', 9, 0],
#  ['พริกแกงใต้', 9, 0],
#  ['ขิง', 9, 0],
#  ['น้ำตาลหญ้าหวาน', 9, 0],
#  ['สาเก', 9, 0],
#  ['เส้นก๋วยเตี๋ยว', 9, 0],
#  ['ถั่วลิสง', 9, 0],
#  ['กระเทียมโทน', 9, 0],
#  ['สปาเก็ตตี้', 9, 0],
#  ['พริกจินดาสีแดง', 9, 0],
#  ['น้ำพริกกะปิ', 9, 0],
#  ['หัวหอมแดง', 9, 0],
#  ['เส้นหมี่เหลือง', 9, 0],
#  ['พริกแกงเขียวหวาน', 9, 0],
#  ['หอมใหญ่หั่นเต๋า', 9, 0],
#  ['ผักสามสี', 9, 0],
#  ['พริกไทยสด', 9, 0],
#  ['พริกสับ', 9, 0],
#  ['น้ำมันคาโนล่า', 8, 0],
#  ['หมูหั่นชิ้น', 8, 0],
#  ['เม็ดมะม่วงหิมพานต์', 8, 0],
#  ['กระเทียมจีนสับ', 8, 0],
#  ['ซีอิ๊วหวาน', 8, 0],
#  ['กุ้งแม่น้ำ', 8, 0],
#  ['เต้าหู้ทอด', 8, 0],
#  ['ข้าวโพด', 8, 0],
#  ['ผงกระหรี่', 8, 0],
#  ['บะหมี่', 8, 0],
#  ['ไก่น่องสะโพก', 8, 0],
#  ['มะขามเปียก', 8, 0],
#  ['ปีกไก่', 8, 0],
#  ['หน่อไม้ดอง', 8, 0],
#  ['บะหมี่ผัก', 8, 0],
#  ['แป้งอเนกประสงค์', 8, 0],
#  ['ตั้งฉ่าย', 8, 0],
#  ['กะเทียม', 8, 0],
#  ['น้ำปลาดี', 8, 0],
#  ['ดอกกะหล่ำ', 8, 0],
#  ['น้ำมันมะพร้าว', 8, 0],
#  ['มอสซาเรลล่าชีส', 8, 0],
#  ['แป้งมันฮ่องกง', 8, 0],
#  ['เส้นพาสต้า', 8, 0],
#  ['ซอสแมคกี้', 8, 0],
#  ['ชีสแผ่น', 8, 0],
#  ['ขนมปัง', 8, 0],
#  ['ข้าวหอมมะลิ', 8, 0],
#  ['สันในหมู', 8, 0],
#  ['ไข่ดาว', 8, 0],
#  ['เส้นหมี่ข้าวกล้อง', 8, 0],
#  ['บล็อคโคลี่', 8, 0],
#  ['กุ้งขาว', 8, 0],
#  ['น้ำเชื่อม', 8, 0],
#  ['ปลาหมึกสด', 8, 0],
#  ['น้ำจิ้มไก่', 8, 0],
#  ['พริกแห้งทอด', 8, 0],
#  ['เนื้อหมูสามชั้น', 8, 0],
#  ['น้ำพริกตาแดง', 8, 0],
#  ['ต้นหอมญี่ปุ่น', 8, 0],
#  ['ซีอิ๋วดำ', 8, 0],
#  ['อกไก่หั่น', 7, 0],
#  ['ไส้กรอกรมควัน', 7, 0],
#  ['ผงปรุงรสไก่', 7, 0],
#  ['หมี่ซั่ว', 7, 0],
#  ['น้ำเย็นจัด', 7, 0],
#  ['โป๊ยกั๊ก', 7, 0],
#  ['เส้นสปาเก็ตตี้ต้มสุก', 7, 0],
#  ['หมูเด้ง', 7, 0],
#  ['แป้งสาลีอเนกประสงค์', 7, 0],
#  ['น้ำกระเทียมดอง', 7, 0],
#  ['ผงปรุงรสรสหมู', 7, 0],
#  ['มะละกอ', 7, 0],
#  ['สันคอหมูสไลด์', 7, 0],
#  ['มะพร้าวคั่ว', 7, 0],
#  ['คึ่นช่าย', 7, 0],
#  ['มะนาวแป้น', 7, 0],
#  ['หน่อไม้', 7, 0],
#  ['เนื้อปู', 7, 0],
#  ['ผงพะโล้', 7, 0],
#  ['พริกชี้ฟ้าซอย', 7, 0],
#  ['มะเขือเทศลูกเล็ก', 7, 0],
#  ['เต้าหู้ขาว', 7, 0],
#  ['กระเทียบสับ', 7, 0],
#  ['เห็ดนางฟ้า', 7, 0],
#  ['สปาเกตตี้', 7, 0],
#  ['เห็ดหูหนูดำ', 7, 0],
#  ['ข้าวกล้องหุงสุก', 7, 0],
#  ['น้ำสต๊อกหมู', 7, 0],
#  ['สตอ', 7, 0],
#  ['คนอร์ผงรสหมู', 7, 0],
#  ['หมูหยอง', 7, 0],
#  ['ผงกระเทียม', 7, 0],
#  ['หมี่เหลือง', 7, 0],
#  ['เส้นสปาเกตตี', 7, 0],
#  ['ข้าวสวยแช่เย็น', 7, 0],
#  ['ไข่แดงเค็ม', 7, 0],
#  ['ตีนไก่', 7, 0],
#  ['ข้าวโพดหวาน', 7, 0],
#  ['สับปะรด', 7, 0],
#  ['เกลือเม็ด', 7, 0],
#  ['พริกอ่อน', 7, 0],
#  ['ต้นหอม ผักชี', 6, 0],
#  ['ถั่วลิสงป่น', 6, 0],
#  ['ใบมะกูด', 6, 0],
#  ['ไส้กรอกไก่', 6, 0],
#  ['ทูน่ากระป๋อง', 6, 0],
#  ['ซีอิ้วขาวโลว์โซเดียม', 6, 0],
#  ['ซี๊อิ๋วขาว', 6, 0],
#  ['น้ำมันพริกเผา', 6, 0],
#  ['นมสดจืด', 6, 0],
#  ['แครอทซอย', 6, 0],
#  ['ผงปรุงรสเห็ดหอม', 6, 0],
#  ['น้ำปลาไส้ตัน', 6, 0],
#  ['ขิงแก่', 6, 0],
#  ['คนอร์ผง', 6, 0],
#  ['ปลาทูน่าในน้ำแร่', 6, 0],
#  ['บะหมี่ไข่', 6, 0],
#  ['เกลือชมพู', 6, 0],
#  ['อาริกาโน', 6, 0],
#  ['ฟองเต้าหู้', 6, 0],
#  ['กระเทียมกลีบเล็ก', 6, 0],
#  ['ใบมะกรูดหั่นฝอย', 6, 0],
#  ['ซอสพริกศรีราชา', 6, 0],
#  ['กระเทียมดอง', 6, 0],
#  ['ผักกาดแก้ว', 6, 0],
#  ['น้ำสลัด', 6, 0],
#  ['หมูสามชั้นสไลด์', 6, 0],
#  ['หมูสันนอก', 6, 0],
#  ['แป้งชุบทอด', 6, 0],
#  ['คนอร์รสหมู', 6, 0],
#  ['หางกะทิ', 6, 0],
#  ['มัสตาร์ด', 6, 0],
#  ['แป้งสาลี', 6, 0],
#  ['พริกหวาน', 6, 0],
#  ['ซุปก้อน', 6, 0],
#  ['น้ำกะทิ', 6, 0],
#  ['ข้าวสวยหอมมะลิ', 6, 0],
#  ['แหนมหมู', 6, 0],
#  ['พริกชี้ฟ้าแห้ง', 6, 0],
#  ['ปลาสลิด', 6, 0],
#  ['ผงซุปก้อนหมู', 6, 0],
#  ['มะระ', 6, 0],
#  ['น้ำตาลดอกมะพร้าว', 6, 0],
#  ['แครรอท', 6, 0],
#  ['หน่อไม้ฝรั่ง', 6, 0],
#  ['เนื้อสะโพกไก่', 6, 0],
#  ['กระเทียมบุบ', 6, 0],
#  ['เก๋ากี้', 6, 0],
#  ['ขิงอ่อน', 6, 0],
#  ['น้ำมันกระเทียมเจียว', 6, 0],
#  ['ต้มหอม', 6, 0],
#  ['นม', 6, 0],
#  ['น้ำมันพืชสำหรับทอด', 6, 0],
#  ['หอยเชลล์', 6, 0],
#  ['ผักกาดดอง', 6, 0],
#  ['น้ำตาลโตนด', 6, 0],
#  ['เส้นอุด้ง', 6, 0],
#  ['มะม่วงเปรี้ยว', 6, 0],
#  ['เกลือแกง', 6, 0],
#  ['โครงไก่', 6, 0],
#  ['ปลาทูนึ่ง', 6, 0],
#  ['กุ้งสับ', 6, 0],
#  ['ซีอิ้ว ขาว', 6, 0],
#  ['ข้าวไรซ์เบอรี่', 5, 0],
#  ['งาคั่ว', 5, 0],
#  ['หมูแดง', 5, 0],
#  ['โรสแมรี่', 5, 0],
#  ['ต้นอ่อนทานตะวัน', 5, 0],
#  ['ข้าวสวยเก่า', 5, 0],
#  ['ผงซุปหมูก้อน', 5, 0],
#  ['น้ำสต๊อก', 5, 0],
#  ['ปลาอินทรีย์เค็ม', 5, 0],
#  ['ตั้งโอ๋', 5, 0],
#  ['ตะใคร้', 5, 0],
#  ['เห็ดหอมแช่น้ำ', 5, 0],
#  ['ซีอิ้วเห็ดหอม', 5, 0],
#  ['เส้นยากิโซบะ', 5, 0],
#  ['ทูน่า', 5, 0],
#  ['กุนเชียงหมู', 5, 0],
#  ['ผักชีฝรั่งซอย', 5, 0],
#  ['ไข่ไก่สด', 5, 0],
#  ['ต้นหอมผักชีซอย', 5, 0],
#  ['หอมใหญ่หั่นเสี้ยว', 5, 0],
#  ['ดอกเกลือ', 5, 0],
#  ['ใบกระเพา', 5, 0],
#  ['กระดูกเล้ง', 5, 0],
#  ['ข้าวเย็น', 5, 0],
#  ['มะเขือเทศลูกใหญ่', 5, 0],
#  ['หอยลาย', 5, 0],
#  ['ออริกาโน', 5, 0],
#  ['พาสต้าดิบ', 5, 0],
#  ['น้ำปลาแท้', 5, 0],
#  ['ลูกผักชี', 5, 0],
#  ['ใบกระเพราแดง', 5, 0],
#  ['เนื้อหมูสันใน', 5, 0],
#  ['ซอสพริกไทยดำ', 5, 0],
#  ['พริกหยวกหั่น', 5, 0],
#  ['ชูรส', 5, 0],
#  ['พริกขี้หนูแห้ง', 5, 0],
#  ['น้ำร้อน', 5, 0],
#  ['ปลากระพง', 5, 0],
#  ['ถั่วฟักยาว', 5, 0],
#  ['ไส้อั่ว', 5, 0],
#  ['ผงปรุงรสตราคนอร์', 5, 0],
#  ['ซอสโชยุ', 5, 0],
#  ['ต้นหอม ผักชีซอย', 5, 0],
#  ['กระเทียม ไท', 5, 0],
#  ['ซีอิ๊วขาวเห็ดหอม', 5, 0],
#  ['มาม่าเกาหลี', 5, 0],
#  ['บล๊อคโคลี่', 5, 0],
#  ['เนื้อหมูสันนอก', 5, 0],
#  ['ใบสะระแหน่', 5, 0],
#  ['เส้นก๋วยจั๊บ', 5, 0],
#  ['ข้าวหุงสุก', 5, 0],
#  ['หอยแมลงภู่', 5, 0],
#  ['พริกเหลือง', 5, 0],
#  ['ผงฟู', 5, 0],
#  ['เม็ดพริกไทย', 5, 0],
#  ['คนอร์ก้อน', 5, 0],
#  ['ข้าวญี่ปุ่น', 5, 0],
#  ['พริกแกงแดง', 5, 0],
#  ['ผงปรุงรสคนอร์อร่อยชัวร์', 5, 0],
#  ['เห็ดนางรมหลวง', 5, 0],
#  ['ปลาหมึกกรอบ', 5, 0],
#  ['พาร์เมซานชีส', 5, 0],
#  ['กระเทียมตำละเอียด', 5, 0],
#  ['ไชเท้า', 5, 0],
#  ['หมูสันคอ', 5, 0],
#  ['แครอทฝอย', 5, 0],
#  ['สามเกลอ', 5, 0],
#  ['ใบโหรพา', 5, 0],
#  ['แป้งโกกิ', 5, 0],
#  ['ผงซุป', 5, 0],
#  ['ผงเติมทิพ', 5, 0],
#  ['ซอสโคชูจัง', 5, 0],
#  ['ฮอตดอก', 5, 0],
#  ['มันกุ้งเสวย', 5, 0],
#  ['ซอสแม็กกี้', 5, 0],
#  ['เนื้อสับ', 4, 0],
#  ['ถั่วลิสงบด', 4, 0],
#  ['พริกหวานหั่นเต๋า', 4, 0],
#  ['แป้ง', 4, 0],
#  ['กระเทียมฝาน', 4, 0],
#  ['olive oil', 4, 0],
#  ['เครื่องพะโล้', 4, 0],
#  ['หมูหั่น', 4, 0],
#  ['ซอสเย็นตาโฟ', 4, 0],
#  ['ตับ', 4, 0],
#  ['ผักต่างๆ', 4, 0],
#  ['เต้าหู้แข็ง', 4, 0],
#  ['ซอสเห็ด หอม', 4, 0],
#  ['ขิงสับละเอียด', 4, 0],
#  ['มะเขือเทศเชอร์รี่', 4, 0],
#  ['เส้นหมี่ซั่ว', 4, 0],
#  ['ก๋วยเตี๋ยวเส้นใหญ่', 4, 0],
#  ['เนื้อ', 4, 0],
#  ['ผงดาชิ', 4, 0],
#  ['ผักชีใบเลื่อย', 4, 0],
#  ['ผงปาปริก้า', 4, 0],
#  ['ผักสด', 4, 0],
#  ['ข้าวไรซ์เบอร์รี่', 4, 0],
#  ['ซีอิ๊วญี่ปุ่น', 4, 0],
#  ['กะปิดี', 4, 0],
#  ['หอมหัวใหญ่สับละเอียด', 4, 0],
#  ['ข้าวโพดต้ม', 4, 0],
#  ['น้ำมันทอด', 4, 0],
#  ['ใบผักชี', 4, 0],
#  ['เบคอนหั่น', 4, 0],
#  ['น้ำจิ้มซีฟู้ด', 4, 0],
#  ['ตับไก่', 4, 0],
#  ['แตงร้าน', 4, 0],
#  ['มะเขือม่วง', 4, 0],
#  ['กุ้งลายเสือ', 4, 0],
#  ['ซีอิ้ว', 4, 0],
#  ['ตังฉ่าย', 4, 0],
#  ['กระดูกอ่อน', 4, 0],
#  ['คนอร์ผง รสหมู', 4, 0],
#  ['คนอร์ซุปก้อนรสหมู', 4, 0],
#  ['ปลาร้าต้มสุก', 4, 0],
#  ['น้ำตาลปิ้บ', 4, 0],
#  ['ข้าวสุก', 4, 0],
#  ['โยเกิร์ตรสธรรมชาติ', 4, 0],
#  ['ซอสข้นปรุงรสคนอร์', 4, 0],
#  ['แป้งข้าวเจ้า', 4, 0],
#  ['หัวหอมใหญ่สับ', 4, 0],
#  ['ข้าวสวยหุงสุก', 4, 0],
#  ['สาหร่าย', 4, 0],
#  ['หมี่ฮ่องกง', 4, 0],
#  ['ขิงสับ', 4, 0],
#  ['ข้าวโพดต้มสุก', 4, 0],
#  ['เส้นมาม่า', 4, 0],
#  ['สันนอกหมู', 4, 0],
#  ['เนื้อสัตว์', 4, 0],
#  ['น่องไก่ติดสะโพก', 4, 0],
#  ['ปลาแซลมอน', 4, 0],
#  ['กระเพาะปลา', 4, 0],
#  ['เต้าหู้หลอด', 4, 0],
#  ['ผักกะเฉด', 4, 0],
#  ['ผงขมิ้น', 4, 0],
#  ['น้ำตาลปี้บ', 4, 0],
#  ['น้ำซุปไก่', 4, 0],
#  ['พริกหนุ่ม', 4, 0],
#  ['ก้านพลู', 4, 0],
#  ['เส้นบุก', 4, 0],
#  ['น้ำตาลปึก', 4, 0],
#  ['ซอสภูเขา', 4, 0],
#  ['ขึ้นช่าย', 4, 0],
#  ['เห็ดออริจิน', 4, 0],
#  ['เส้นมักกะโรนี', 4, 0],
#  ['ผักแขนง', 4, 0],
#  ['เกลือ พริกไทย', 4, 0],
#  ['น้ำมันหอย', 4, 0],
#  ['เส้นบะหมี่กึ่งสำเร็จรูป', 4, 0],
#  ['ข้าวสวยญี่ปุ่น', 4, 0],
#  ['ดาชิ', 4, 0],
#  ['กะหล่ำดอก', 4, 0],
#  ['เครื่องในไก่', 4, 0],
#  ['หอมหัวใหญ่สับ', 4, 0],
#  ['เนื้อหมูหั่น', 4, 0],
#  ['ยี่หร่าป่น', 4, 0],
#  ['เนื้อปลา', 4, 0],
#  ['โบโลน่า', 4, 0],
#  ['หัวปลี', 4, 0],
#  ['รากผักชีสับ', 4, 0],
#  ['เนื้อวัว', 4, 0],
#  ['กุ้งแห้งฝอย', 4, 0],
#  ['ครีม', 4, 0],
#  ['กะหล่ำปลีหั่น', 4, 0],
#  ['ปลาเค็ม', 4, 0],
#  ['ไวน์ขาว', 4, 0],
#  ['ข่าซอย', 4, 0],
#  ['ถั่วงอกลวก', 4, 0],
#  ['ปูม้า', 4, 0],
#  ['กระเทียมกลีบ', 4, 0],
#  ['ดอกกระหล่ำ', 4, 0],
#  ['ขึ้นฉ่ายซอย', 4, 0],
#  ['มอสซาเรลลาชีส', 4, 0],
#  ['ปลาซาบะ', 4, 0],
#  ['แซลมอน', 4, 0],
#  ['ผักสลัดตามชอบ', 4, 0],
#  ['พาเมซานชีส', 4, 0],
#  ['ปลานิล', 4, 0],
#  ['กากหมู', 4, 0],
#  ['ข้าวสวยหุงค้างคืน', 4, 0],
#  ['ปลาหมึกแห้ง', 4, 0],
#  ['ยี่หร่า', 4, 0],
#  ['พริกซอย', 4, 0],
#  ['แครอทหั่นเต๋าเล็ก', 4, 0],
#  ['น้ำดื่ม', 4, 0],
#  ['เนื้อปลาแซลมอน', 4, 0],
#  ['รสดีเมนู', 4, 0],
#  ['พาสต้า', 4, 0],
#  ['พริกตำ', 4, 0],
#  ['กุ้งสดแกะเปลือก', 4, 0],
#  ['ผักบุ้งจีน', 4, 0],
#  ['อกไก่หั่นชิ้น', 4, 0],
#  ['แป้งเอนกประสงค์', 4, 0],
#  ['แป้งมันละลายน้ำ', 4, 0],
#  ['แม๊กกี้', 4, 0],
#  ['ใบกระเพราเด็ด', 4, 0],
#  ['มะม่วงเบา', 4, 0],
#  ['กุ้งแห้งป่น', 4, 0],
#  ['ขิงอ่อนซอย', 4, 0],
#  ['ปาปริก้า', 4, 0],
#  ['ทูน่ากระป๋องในน้ำแร่', 4, 0],
#  ['แป้งท้าวยายม่อม', 4, 0],
#  ['ผงปรุงรส คนอร์', 3, 0],
#  ['เต้าหู้พวง', 3, 0],
#  ['รสดีหมู', 3, 0],
#  ['กุ้ง ปลาหมึก', 3, 0],
#  ['สี่อิ๋วดำสูตรเค็ม', 3, 0],
#  ['มะกะโรนีต้มสุก', 3, 0],
#  ['ไข่ออนเซน', 3, 0],
#  ['คนอร์ขวดสูตรเข้มข้น', 3, 0],
#  ['ถั่วหวาน', 3, 0],
#  ['พริกชี้ฟ้าแดงหั่นแฉลบ', 3, 0],
#  ['เกลือหิมาลายัน', 3, 0],
#  ['หมี่กรอบ', 3, 0],
#  ['กระเทียม สับ', 3, 0],
#  ['ผักชีหั่น', 3, 0],
#  ['เส้นมาม่าลวก', 3, 0],
#  ['กระเทียมแกะเปลือก', 3, 0],
#  ['พริกทอด', 3, 0],
#  ['กระเทียวเจียว', 3, 0],
#  ['ตำลึง', 3, 0],
#  ['หอมแดงเจียว', 3, 0],
#  ['ออริกาโน่แห้ง', 3, 0],
#  ['ซอสภูเขาทอง', 3, 0],
#  ['เนื้ออกไก่สับ', 3, 0],
#  ['น้ำสลัดงาญี่ปุ่น', 3, 0],
#  ['ซอสเพสโต้', 3, 0],
#  ['น้ำซุปหรือน้ำเปล่า', 3, 0],
#  ['พริกไทยดำเม็ด', 3, 0],
#  ['เครื่องแกงเขียวหวาน', 3, 0],
#  ['Mozzarella cheese', 3, 0],
#  ['หนำเลี๊ยบ', 3, 0],
#  ['ซีอิ้วหวาน', 3, 0],
#  ['น้ำมันสำหรับทอดปลา', 3, 0],
#  ['ข้าวสวยร้อนๆ', 3, 0],
#  ['เครื่องปรุง', 3, 0],
#  ['เส้นเหลือง', 3, 0],
#  ['ข้าวเหนียว', 3, 0],
#  ['ผงเติมทิพ.', 3, 0],
#  ['หมูบดติดมัน', 3, 0],
#  ['ซอลหอยนางรม', 3, 0],
#  ['ถั่วฝักยาวหั่น', 3, 0],
#  ['กะหล่ำ', 3, 0],
#  ['หอมแดงสับละเอียด', 3, 0],
#  ['ถั่วฝักยาวซอย', 3, 0],
#  ['กุนเชียงทอด', 3, 0],
#  ['ซอสมะเขือเทศเข้มข้น', 3, 0],
#  ['กุ้ยช่าย', 3, 0],
#  ['แครอทหั่นชิ้น', 3, 0],
#  ['กะเพราแดง', 3, 0],
#  ['ดอกหอม', 3, 0],
#  ['สัปปะรด', 3, 0],
#  ['เนื้อปลาดอลลี่', 3, 0],
#  ['เนื้อหมูสไลด์', 3, 0],
#  ['โซดา', 3, 0],
#  ['ไวไว', 3, 0],
#  ['ถั่วพู', 3, 0],
#  ['หอมหัวใหญ่หั่นเต๋า', 3, 0],
#  ['สี่อิ๋วหวาน', 3, 0],
#  ['พริกแกงพะแนง', 3, 0],
#  ['ยอดข้าวโพดอ่อน', 3, 0],
#  ['เนื้อวัวสับ', 3, 0],
#  ['น้ำสต็อก', 3, 0],
#  ['น้ำตาลทรายเล็กน้อย', 3, 0],
#  ['คนอร์อร่อยชัว', 3, 0],
#  ['พริกขี้หนูตำละเอียด', 3, 0],
#  ['เส้นแก้ว', 3, 0],
#  ['ผักชีสับ', 3, 0],
#  ['น้ำส้มสายชูข้าว', 3, 0],
#  ['แป้งทอดกรอบคนอร์', 3, 0],
#  ['กระเทียมสด', 3, 0],
#  ['เส้นสปาเก็ตตี้โฮลวีท', 3, 0],
#  ['เครื่องต้มยำ', 3, 0],
#  ['ต้นหอม ผักชี ซอย', 3, 0],
#  ['ใบยี่หร่า', 3, 0],
#  ['เส้นหมี่ฮกเกี้ยน', 3, 0],
#  ['กระเทียมตำหยาบ', 3, 0],
#  ['แครอทหั่นเส้น', 3, 0],
#  ['ปลาสลิดทอด', 3, 0],
#  ['เผือก', 3, 0],
#  ['ซอส', 3, 0],
#  ['ต้นหอมผักชีหั่น', 3, 0],
#  ['ไส้กรอกหมู', 3, 0],
#  ['กุ้งแกะเปลือก', 3, 0],
#  ['ไข่เยี่ยวม้า', 3, 0],
#  ['พริกไทเม็ด', 3, 0],
#  ['เต้าเจี๊ยว', 3, 0],
#  ['ก้อนแกงกะหรี่ญี่ปุ่น', 3, 0],
#  ['หัวหอมสับ', 3, 0],
#  ['โปรตีนเกษตร', 3, 0],
#  ['ใบกุยช่าย', 3, 0],
#  ['เห็ดโคนญี่ปุ่น', 3, 0],
#  ['กระเทียมปอกเปลือก', 3, 0],
#  ['สี่อิ๋วดำสูตรหวาน', 3, 0],
#  ['ข้าวเสาไห้', 3, 0],
#  ['กระหล่ำปลีซอย', 3, 0],
#  ['แคร์รอต', 3, 0],
#  ['กุ่ยช่าย', 3, 0],
#  ['ผงปาปริกา', 3, 0],
#  ['ชีอิ้วขาว', 3, 0],
#  ['บ๊วยดอง', 3, 0],
#  ['นมสดรสจืด', 3, 0],
#  ['ปลาหมึกกล้วย', 3, 0],
#  ['หัวหอมซอย', 3, 0],
#  ['น้ำปลาร้าต้มสุก', 3, 0],
#  ['พริกขี้หนูบุบ', 3, 0],
#  ['มะนาวฝาน', 3, 0],
#  ['มักกะโรนีต้มสุก', 3, 0],
#  ['ไชโป๊ว', 3, 0],
#  ['หน่อไม้ต้ม', 3, 0],
#  ['น้ำซุปดาชิ', 3, 0],
#  ['ผักกาด', 3, 0],
#  ['น้ำมันสำหรับผัดเล็กน้อย', 3, 0],
#  ['คอหมูย่าง', 3, 0],
#  ['ผักชี/ต้นหอม', 3, 0],
#  ['พริกไทยป่นเล็กน้อย', 3, 0],
#  ['ข้าวสารหอมมะลิ', 3, 0],
#  ['คนอร์ต้มยำ', 3, 0],
#  ['พริกสดหั่น', 3, 0],
#  ['คื่นไช้', 3, 0],
#  ['ไข่เจียวหั่นฝอย', 3, 0],
#  ['เต้าเจียว', 3, 0],
#  ['รากผักชีทุบ', 3, 0],
#  ['แครอทหั่นแว่น', 3, 0],
#  ['วิปครีม', 3, 0],
#  ['แครอทขูด', 3, 0],
#  ['ใบโหระพาสับ', 3, 0],
#  ['เนื้อบด', 3, 0],
#  ['ไก่หมัก', 3, 0],
#  ['แป้งสาลีเอนกประสงค์', 3, 0],
#  ['แคปหมู', 3, 0],
#  ['แครอทสับ', 3, 0],
#  ['กุ้งกุลาดำ', 3, 0],
#  ['ปลากรอบ', 3, 0],
#  ['เนื้อหมูหั่นชิ้น', 3, 0],
#  ['เต้าหู้นิ่ม', 3, 0],
#  ['หอมหัวใหญ่สับหยาบ', 3, 0],
#  ['พาร์สลีย์', 3, 0],
#  ['เนยแท้', 3, 0],
#  ['น้ำเปล่าหรือน้ำซุป', 3, 0],
#  ['แม็กกี้', 3, 0],
#  ['เนยสดเค็ม', 3, 0],
#  ['บวบ', 3, 0],
#  ['ใบเตย', 3, 0],
#  ['ใบแมงลัก', 3, 0],
#  ['หมูนุ่ม', 3, 0],
#  ['โหรพา', 3, 0],
#  ['กระเทียมขูด', 3, 0],
#  ['เต้าหู้อ่อน', 3, 0],
#  ['เต้าหู้ปลา', 3, 0],
#  ['ขิงขูด', 3, 0],
#  ['เนื้อหอยแมลงภู่', 3, 0],
#  ['ผักคอส', 3, 0],
#  ['คนอร์ซอสข้นปรุงรสหมู', 3, 0],
#  ['ยอดมะพร้าวอ่อน', 3, 0],
#  ['กระเทียมตบ', 3, 0],
#  ['มะกะโรนี', 3, 0],
#  ['ปลาไข่', 3, 0],
#  ['เนื้อปลาอินทรีย์', 3, 0],
#  ['น้ำมันงาเกาหลี', 3, 0],
#  ['ซอสภูเขาฝาเขียว', 3, 0],
#  ['เนื้อหอยลาย', 3, 0],
#  ['ปีกบนไก่', 3, 0],
#  ['ซอสมะเขือเทศโรซ่า', 3, 0],
#  ['ถั่วงอกหัวโต', 3, 0],
#  ['มะละกอสับ', 3, 0],
#  ['คนอร์เห็ดหอม', 3, 0],
#  ['พริกแกงน้ำยา', 3, 0],
#  ['เส้นบะหมี่', 3, 0],
#  ['หมึก', 3, 0],
#  ['กะหล่ำปลีซอย', 3, 0],
#  ['ซี้อิ้วขาว', 3, 0],
#  ['พริกไทย ป่น', 3, 0],
#  ['ผัดกาดขาว', 3, 0],
#  ['วุ้นเส้นห่อเล็ก', 3, 0],
#  ['พริกแกงส้ม', 3, 0],
#  ['ใบเหลียง', 3, 0],
#  ['กะทิกล่อง', 3, 0],
#  ['พริกป่นตามชอบ', 3, 0],
#  ['black pepper', 3, 0],
#  ['ข้าวสวยเย็น', 3, 0],
#  ['เบคกิ้งโซดา', 3, 0],
#  ['คื่นไฉ่', 3, 0],
#  ['พริกแกงคั่ว', 3, 0],
#  ['น้ำปลาทิพรส', 3, 0],
#  ['แครอทหั่นฝอย', 3, 0],
#  ['ซอสพิซซ่า', 3, 0],
#  ['เส้นหมี่ไวไว', 3, 0],
#  ['หอยแมลงภู่นิวซีแลนด์', 3, 0],
#  ['เห็ดหอมแห้งแช่น้ำจนนิ่ม', 3, 0],
#  ['ยอดมะพร้าว', 3, 0],
#  ['พริกป่นเกาหลี', 3, 0],
#  ['พริกไทดำ', 3, 0],
#  ['salt', 3, 0],
#  ['เป็ดย่าง', 3, 0],
#  ['ข้าวบาสมาติ', 3, 0],
#  ['หอมใหญ่ซอย', 3, 0],
#  ['เต้าหู้ไข่ไก่', 3, 0],
#  ['ข้าวไรซ์เบอร์รี่หุงสุก', 3, 0],
#  ['น้ำตาลทราย ขาว', 3, 0],
#  ['เห็ดหูหนูขาว', 3, 0],
#  ['ถั่วป่น', 3, 0],
#  ['ข้าวหอมมะลิหุงสุก', 3, 0],
#  ['แป้งท้าว', 3, 0],
#  ['มันฝรั่งหั่นเต๋า', 3, 0],
#  ['หอมหัวใหญ่ซอย', 3, 0],
#  ['สะโพกไก่เลาะกระดูก', 3, 0],
#  ['งาดำ', 3, 0],
#  ['เลือดหมู', 3, 0],
#  ['หมี่กึง', 3, 0],
#  ['วิปปิ้งครีม', 3, 0],
#  ['มะเขือ', 3, 0],
#  ['แครอท หั่นเต๋า', 3, 0],
#  ['ปลาซุกิ', 3, 0],
#  ['เกลือพริกไทย', 2, 0],
#  ['บะหมี่กึ่งสำเร็จรูปรสต้มยำ', 2, 0],
#  ['พริกแดงซอย', 2, 0],
#  ['ซีอี๊วขาว', 2, 0],
#  ['มะกรูด', 2, 0],
#  ['หอยแมลงภู่ต้มสุก', 2, 0],
#  ['ถั่วลิสงตำ', 2, 0],
#  ['พริกสดซอย', 2, 0],
#  ['หมูสับลวก', 2, 0],
#  ['แครอท หั่นเป็นลูกเต๋า', 2, 0],
#  ['บล็อคโครี่', 2, 0],
#  ['น้ำสลัดงาคั่วญี่ปุ่น', 2, 0],
#  ['เส้น', 2, 0],
#  ['ถั่ว', 2, 0],
#  ['ไข่ลวก', 2, 0],
#  ['เนื้ออกไก่ลอกหนัง', 2, 0],
#  ['ไก่จ๊อ', 2, 0],
#  ['เนยละลาย', 2, 0],
#  ['พริกชี้ฟ้าเหลือง', 2, 0],
#  ['เนื้อหมูส่วนสันคอ', 2, 0],
#  ['ไข่ไก่เบอร์ 0', 2, 0],
#  ['น้ำมะขาวเปียก', 2, 0],
#  ['ข่าสับละเอียด', 2, 0],
#  ['ชีอิ๊วขาว', 2, 0],
#  ['เป็ด', 2, 0],
#  ['หอมใหญ่ซอยบางๆ', 2, 0],
#  ['ต้นหอม-ผักชีซอย', 2, 0],
#  ['ซ้อสปรุงรส', 2, 0],
#  ['ต้นกุยช่าย', 2, 0],
#  ['เบค่อนตามชอบ', 2, 0],
#  ['บะหมี่ลวก', 2, 0],
#  ['ถั่วแดง', 2, 0],
#  ['น้ำพริกหนุ่ม', 2, 0],
#  ['ไก่หั่น', 2, 0],
#  ['หอมใหญ่หั่นชิ้นเล็ก', 2, 0],
#  ['แครอทขูดฝอย', 2, 0],
#  ['แผ่นเกี้ยว', 2, 0],
#  ['ปลาช่อนหั่น', 2, 0],
#  ['ซอสปรุงรสเห็ดหอม', 2, 0],
#  ['คะน้ายอด', 2, 0],
#  ['หอมใหญ่หั่น', 2, 0],
#  ['มะเขือเทศสับละเอียด', 2, 0],
#  ['เส้นหมี่แช่น้ำ', 2, 0],
#  ['โรสแมรี่อบแห้ง', 2, 0],
#  ['หมี่หยก', 2, 0],
#  ['Angel Hair', 2, 0],
#  ['น้ำซุบ', 2, 0],
#  ['ข้าวแช่เย็น', 2, 0],
#  ['กะปิอย่างดี', 2, 0],
#  ['ขิงขูดละเอียด', 2, 0],
#  ['มะเขือเทศหั่นลูกเต๋า', 2, 0],
#  ['แครอทหั่นเต๋าเล็กๆ', 2, 0],
#  ['ปลาทูทอด', 2, 0],
#  ['เส้นมักกะโรนีต้มสุก', 2, 0],
#  ['ไส้กรอกหมูรมควัน', 2, 0],
#  ['แป้งพิซซ่าสำเร็จ', 2, 0],
#  ['มะละกอขูด', 2, 0],
#  ['เป็ดพะโล้', 2, 0],
#  ['พริกไทยนิดหน่อย', 2, 0],
#  ['ผิวมะกรูด', 2, 0],
#  ['ถั่วลิสงคั่วบด', 2, 0],
#  ['พริกหยวกสีเหลือง', 2, 0],
#  ['ซอสข้นคนอร์', 2, 0],
#  ['กระเทียมทุบหยาบ', 2, 0],
#  ['พริกน้ำส้ม', 2, 0],
#  ['พริกแกงเผ็ดใต้', 2, 0],
#  ['เส้นสปาเกตตี้ ต้มสุก', 2, 0],
#  ['ลูกผักชีป่น', 2, 0],
#  ['หมี่ขาว', 2, 0],
#  ['มะเขือเทศสับ', 2, 0],
#  ['เนยสดจืด', 2, 0],
#  ['กระทิ', 2, 0],
#  ['มาม่าลวก', 2, 0],
#  ['ปีกกลางไก่', 2, 0],
#  ['พาสลี่', 2, 0],
#  ['มาการีน', 2, 0],
#  ['แป้งสำหรับทอด', 2, 0],
#  ['เนยรสจืด', 2, 0],
#  ['กุ้งขาวขนาดกลาง', 2, 0],
#  ['น้ำมะนาวสด', 2, 0],
#  ['พริกแดงสับ', 2, 0],
#  ['แหนมตุ้มจิ๋ว', 2, 0],
#  ['ดอกไม้กวาด', 2, 0],
#  ['น้ำซุปกระดูกหมู', 2, 0],
#  ['กิมจิสับละเอียด', 2, 0],
#  ['ผงปรุงรสผัดคนอร์', 2, 0],
#  ['น้ำตาลเล็กน้อย', 2, 0],
#  ['กระเทียมเจียวกากหมู', 2, 0],
#  ['กระเทียม+พริก', 2, 0],
#  ['แครอท หั่นชิ้นเล็ก', 2, 0],
#  ['ผักกะหล่ำ', 2, 0],
#  ['น้ำมันมะกอกแคลอรี่0', 2, 0],
#  ['italian seasoning', 2, 0],
#  ['ซีอิ้ว ดำ', 2, 0],
#  ['ข้าวโพดอ่อนหั่นแฉลบ', 2, 0],
#  ['ไส้กรอกหั่นชิ้น', 2, 0],
#  ['กระหล่ำปลีหั่น', 2, 0],
#  ['พริกหวานสีแดง', 2, 0],
#  ['Red Pepper Flakes', 2, 0],
#  ['พริกแดง-พริกเขียว', 2, 0],
#  ['พริกแห้งจินดา', 2, 0],
#  ['ผักชีลาว', 2, 0],
#  ['เต้าหู้ขาวแข็ง', 2, 0],
#  ['น้ำมันพืช สำหรับทอด', 2, 0],
#  ['ขิงแก่ซอย', 2, 0],
#  ['คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส', 2, 0],
#  ['ปีกไก่บน', 2, 0],
#  ['ซอสภูเขาทองฝาเขียว', 2, 0],
#  ['หน่อไม้ฝอย', 2, 0],
#  ['ไข่ขาวพาสเจอร์ไรซ์', 2, 0],
#  ['พริกขี้หนูแห้งซอย', 2, 0],
#  ['น้ำมัน พืช', 2, 0],
#  ['ซีอิ๋ว', 2, 0],
#  ['ซี่โครงไก่', 2, 0],
#  ['น้ำเลม่อน', 2, 0],
#  ['ถั่วลิสงคั่วป่น', 2, 0],
#  ['ปีกไก่กลาง', 2, 0],
#  ...]

# %%
ch_regex = "น้ำปลา(?!ร้า)"
name = "น้ำปลา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำปลา 736
# น้ำปลาอย่างดี 12
# น้ำปลาดี 8
# น้ำปลาไส้ตัน 6
# น้ำปลาแท้ 5
# น้ำปลาทิพรส 3
# น้ำปลา Low Sodium 2
# น้ำปลาพริก 2
# น้ำปลาเมกะเชฟ 2
# เกลือ หรือ น้ำปลา 2

# %%
ch_regex = "^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม|กระเทียวเจียว|กระเทียบ|กระทียมสับ|garlic|^น้ำจิ้ม กระเทียม$"
name = "กระเทียม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระเทียม 633
# กระเทียมสับ 276
# กระเทียมเจียว 55
# กระเทียมไทย 45
# กระเทียมจีน 32
# กระเทียมสับละเอียด 25
# กระเทียมทุบ 20
# กระเทียมไท 16
# กระเทียมสับหยาบ 15
# กระเทียมกลีบใหญ่ 13
# กระเทียมตำ 12
# กระเทียมซอย 11
# กระเทียมโทน 9
# กระเทียมจีนสับ 8
# กะเทียม 8
# กระเทียบสับ 7
# ผงกระเทียม 7
# กระเทียมกลีบเล็ก 6
# กระเทียมดอง 6
# กระเทียมบุบ 6
# กระเทียม ไท 5
# กระเทียมตำละเอียด 5
# กระเทียมฝาน 4
# กระเทียมกลีบ 4
# กระเทียม สับ 3
# กระเทียมแกะเปลือก 3
# กระเทียวเจียว 3
# กระเทียมสด 3
# กระเทียมตำหยาบ 3
# กระเทียมปอกเปลือก 3
# กระเทียมขูด 3
# กระเทียมตบ 3
# กระเทียมทุบหยาบ 2
# กระเทียมเจียวกากหมู 2
# กระเทียม+พริก 2
# กระเทียมจีนหั่น 2
# กระเทียบ 2
# กระเทียมหั่นละเอียด 2
# เกลือผสมผงกระเทียม 2
# กระเทียมหั่น 2
# กระเทียมทุบพอแตก 2
# น้ำจิ้ม กระเทียม 2
# กระเทียมหัวใหญ่ 2
# garlic 2
# กะเทียมสับ 2
# กระทียมสับ 2
# กระเทียมโขลกละเอียด 2
# กระเทียมสำหรับเจียว 2
# กระเทียมเผา 2
# กระเทียมโขลกหยาบๆ 2
# กระเทียมจีนซอย 2
# กระเทียมสไลด์ 2

# %%
ch_regex = "^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))|ไก่ไข่"
name = "ไข่ไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่ไก่ 627
# ไข่ 73
# ไข่ต้ม 25
# ไข่เค็ม 20
# ไข่แดง 14
# ไข่ขาว 11
# ไข่ดาว 8
# ไข่แดงเค็ม 7
# ไข่ไก่สด 5
# ไข่ออนเซน 3
# ไข่เยี่ยวม้า 3
# ไข่เจียวหั่นฝอย 3
# ไข่ลวก 2
# ไข่ไก่เบอร์ 0 2
# ไข่ขาวพาสเจอร์ไรซ์ 2
# ไก่ไข่ 2
# ไข่ไก่ต้ม 2
# ไข่ไก่เบอร์ 1 2
# ไข่เจียว 2
# ไข่ไก่2 2
# ไข่ไก่เต็มใบ 2
# ไข่ฝอย 2
# ไข่ไก่เบอร์0 2
# ไข่ไก 2
# ไข่ออนเซ็น 2
# ไข่ไก่เบอร์1 2
# ไข่เค็มต้ม 2

# %%
ch_regex = "น้ำตาล(?!หญ้าหวาน)|นำ้ตาลทราย"
name = "น้ำตาล"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำตาลทราย 619
# น้ำตาล 584
# น้ำตาลปี๊บ 90
# น้ำตาลทรายแดง 26
# น้ำตาลทรายขาว 18
# น้ำตาลมะพร้าว 17
# น้ำตาลปี๊ป 14
# น้ำตาลปีบ 14
# น้ำตาลปิ๊บ 12
# น้ำตาลกรวด 9
# น้ำตาลดอกมะพร้าว 6
# น้ำตาลโตนด 6
# น้ำตาลปิ้บ 4
# น้ำตาลปี้บ 4
# น้ำตาลปึก 4
# น้ำตาลทรายเล็กน้อย 3
# น้ำตาลทราย ขาว 3
# น้ำตาลเล็กน้อย 2
# น้ำตาลปิ๊ป 2
# น้ำตาลปีป 2
# เกลือ น้ำตาล 2
# น้ำตาลทราย. 2
# น้ำตาลทราย 2
# น้ำตาล ทราย 2

# %%
ch_regex = "เกลือ|salt|เกลอ"
name = "เกลือ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เกลือ 417
# เกลือป่น 108
# เกลือเม็ด 7
# เกลือชมพู 6
# เกลือแกง 6
# ดอกเกลือ 5
# สามเกลอ 5
# เกลือ พริกไทย 4
# เกลือหิมาลายัน 3
# salt 3
# เกลือพริกไทย 2
# เกลือ Low Sodium 2
# เกลือสำหรับต้มเส้น 2
# เกลือผสมผงกระเทียม 2
# เกลือหิมาลัย 2
# เกลือ น้ำตาล 2
# เกลือและพริกไทย สำหรับปรุงรส 2
# เกลือสมุทร 2
# เกลือ/พริกไทย 2
# เกลือ หรือ น้ำปลา 2
# เกลือป่นหยาบ 2
# เกลอ 2

# %%
ch_regex = "ซอสปรุงรส|ซอสฝาเขียว|ซอสฝาเหลือง|ซอสแมคกี้|ซอสแม็กกี้|ซอสข้นปรุงรสคนอร์|แม๊กกี้|ซอส|แม็กกี้|คนอร์ซอสข้นปรุงรสหมู|ซอสข้นคนอร์|ซอลปรุงรส|แมกกี้|ซ้อสปรุงรส"
name = "ซอสปรุงรส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสปรุงรส 338
# ซอสหอยนางรม 213
# ซอสมะเขือเทศ 103
# ซอสพริก 48
# ซอสปรุงรสฝาเขียว 32
# ซอสถั่วเหลือง 29
# ซอสเห็ดหอม 26
# ซอสน้ำมันหอย 13
# ซอสฝาเขียว 13
# ซอสฝาเหลือง 11
# ซอสหอย 11
# ซอสเทริยากิ 11
# ซอสเทอริยากิ 10
# ซอสแมคกี้ 8
# ซอสพริกศรีราชา 6
# ซอสพริกไทยดำ 5
# ซอสโชยุ 5
# ซอสโคชูจัง 5
# ซอสแม็กกี้ 5
# ซอสเย็นตาโฟ 4
# ซอสเห็ด หอม 4
# ซอสข้นปรุงรสคนอร์ 4
# ซอสภูเขา 4
# แม๊กกี้ 4
# ซอสภูเขาทอง 3
# ซอสเพสโต้ 3
# ซอสมะเขือเทศเข้มข้น 3
# ซอส 3
# แม็กกี้ 3
# คนอร์ซอสข้นปรุงรสหมู 3
# ซอสภูเขาฝาเขียว 3
# ซอสมะเขือเทศโรซ่า 3
# ซอสพิซซ่า 3
# ซ้อสปรุงรส 2
# ซอสปรุงรสเห็ดหอม 2
# ซอสข้นคนอร์ 2
# ซอสภูเขาทองฝาเขียว 2
# ซอสทงคัตสึ 2
# ซอลปรุงรส 2
# ซอสปรุงรสไก่ 2
# แมกกี้ 2
# ซอสลุงหนวด 2
# ซอสผัดไทสำเร็จรูป 2
# ส่วนผสมซอส 2
# ซอสหอยนางรมตราแม่ครัว 2
# ทาบาสโก เรดเปปเปอร์ซอส 2
# ซอสหอยนางรส 2
# เพสโตซอส 2
# ซอส XO 2
# ซอสแดง 2
# น้ำซอสเย็นตาโฟ 2
# ซอสข้นปรุงรสคนอร์ รสหมู 2
# ซอสมะเขือ 2
# คนอร์ ซอสข้นปรุงรส 2

# %%
ch_regex = "น้ำมันหอย|ซอสหอย|ซอยหอยนางรม|นำ้มันหอย|ซอลหอยนางรม|นํ้ามันหอย"
name = "น้ำมันหอย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมันหอย 575
# ซอสหอยนางรม 213
# ซอสน้ำมันหอย 13
# ซอยหอยนางรม 12
# ซอสหอย 11
# น้ำมันหอย 4
# ซอลหอยนางรม 3
# น้ำมันหอย low sodium 2
# น้ำมันหอย 2
# ซอสหอยนางรมตราแม่ครัว 2
# ซอสหอยนางรส 2

# %%
ch_regex = "น้ำมัน(?!(หอย|พริกเผา|งา))|olive oil|oil"
name = "น้ำมัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมันพืช 423
# น้ำมัน 328
# น้ำมันมะกอก 103
# น้ำมันรำข้าว 67
# น้ำมันสำหรับผัด 45
# น้ำมันสำหรับทอด 33
# น้ำมันถั่วเหลือง 24
# น้ำมันปาล์ม 18
# น้ำมันพืชสำหรับผัด 10
# น้ำมันหมู 10
# น้ำมันคาโนล่า 8
# น้ำมันมะพร้าว 8
# น้ำมันกระเทียมเจียว 6
# น้ำมันพืชสำหรับทอด 6
# olive oil 4
# น้ำมันทอด 4
# น้ำมันสำหรับทอดปลา 3
# น้ำมันสำหรับผัดเล็กน้อย 3
# น้ำมันมะกอกแคลอรี่0 2
# น้ำมันพืช สำหรับทอด 2
# น้ำมัน พืช 2
# น้ำมันพิช 2
# น้ำมัน หอย 2
# น้ำมันพืช. 2
# น้ำมันสำหรับทอดไก่ 2
# น้ำมันมะพร้าวสำหรับผัด 2
# น้ำมันสำหรับทอดและผัด 2
# oil 2
# น้ำมันมะกรอก 2
# น้ำมันมะกอกสเปรย์ 2
# น้ำมันสำหรับทอดไข่ 2
# น้ำมัน ถั่วเหลือง 2

# %%
ch_regex = "น้ำเปล่า|น้ำสะอาด|น้ำต้มสุก|^น้ำ$|น้ำเย็น|น้ำร้อน|น้ำดื่ม|น้ำอุ่น|น้ำสำหรับต้มเส้น"
name = "น้ำเปล่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำเปล่า 306
# น้ำสะอาด 113
# น้ำต้มสุก 15
# น้ำ 14
# น้ำเย็น 11
# น้ำเย็นจัด 7
# น้ำร้อน 5
# น้ำดื่ม 4
# น้ำซุปหรือน้ำเปล่า 3
# น้ำเปล่าหรือน้ำซุป 3
# น้ำสะอาดสำหรับต้มเส้น 2
# น้ำสำหรับต้มเส้น 2
# น้ำอุ่น 2
# น้ำเปล่า/น้ำซุป 2

# %%
ch_regex = "ซีอิ๊วขาว|ซีอิ้วขาว|ซอสถั่วเหลือง|ซีอิ๋วขาว|สี่อิ๋วขาวสูตร1|ซีอิ้วปรุงรส|^ซีอิ๊ว$|ซี๊อิ๋วขาว|ซีอิ้ว ขาว|ซีอิ้ว|ชีอิ้วขาว|ซี้อิ้วขาว|ซีอี๊วขาว|ชีอิ๊วขาว|ซีอิ๋ว|ซี่อิ๋วขาวสูตร1|สี่อิ๋วขาวสูตร 2|soy sauce|ซีอี้วขาว|ซีอี๋วขาว|สี่อิ๋วขาวสูตร|สี่อิ่ว"
name = "ซีอิ๊วขาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ๊วขาว 294
# ซีอิ้วขาว 289
# ซีอิ้วดำ 62
# ซอสถั่วเหลือง 29
# ซีอิ๋วขาว 28
# ซีอิ้วปรุงรส 28
# ซีอิ้วดำหวาน 26
# สี่อิ๋วขาวสูตร1 17
# ซีอิ๊ว 10
# ซีอิ๋วดำ 8
# ซีอิ้วขาวโลว์โซเดียม 6
# ซี๊อิ๋วขาว 6
# ซีอิ้ว ขาว 6
# ซีอิ้วเห็ดหอม 5
# ซีอิ๊วขาวเห็ดหอม 5
# ซีอิ้ว 4
# ซีอิ้วหวาน 3
# ชีอิ้วขาว 3
# ซี้อิ้วขาว 3
# ซีอี๊วขาว 2
# ชีอิ๊วขาว 2
# ซีอิ้ว ดำ 2
# ซีอิ๋ว 2
# ซีอิ้วขาวเห็ดหอม 2
# ซีอิ๋วดำหวาน 2
# ซีอี๋วขาว 2
# ซีอี้วขาว 2
# soy sauce 2
# ซีอิ้วเด็กสมบูรณ์ 2
# ซีอิ๊วขาว. 2
# สี่อิ๋วขาวสูตร 2
# ซี่อิ๋วขาวสูตร1 2

# %%
ch_regex = "^(?!.*ซอส|หมู).*พริกไทย.*|พริกไท|black pepper|Red Pepper Flakes"
name = "พริกไทย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกไทย 274
# พริกไทยป่น 163
# พริกไทยดำ 75
# พริกไท 32
# พริกไทยอ่อน 26
# พริกไทยดำป่น 25
# พริกไทป่น 23
# พริกไทยเม็ด 19
# พริกไทยขาวป่น 16
# พริกไทยขาว 14
# พริกไทยดำบด 11
# พริกไทยสด 9
# ซอสพริกไทยดำ 5
# เม็ดพริกไทย 5
# เกลือ พริกไทย 4
# พริกไทยดำเม็ด 3
# พริกไทเม็ด 3
# พริกไทยป่นเล็กน้อย 3
# พริกไทย ป่น 3
# black pepper 3
# พริกไทดำ 3
# เกลือพริกไทย 2
# พริกไทยนิดหน่อย 2
# Red Pepper Flakes 2
# หมูหมักพริกไทยดำ 2
# พริกไทยขาวเม็ด 2
# พริกไทยดำบดหยาบ 2
# เกลือและพริกไทย สำหรับปรุงรส 2
# พริกไทยบด 2
# พริกไทยเม็ดตำละเอียด 2
# เกลือ/พริกไทย 2
# พริกไทยป่นสำหรับโรยหน้า 2
# พริกไทขาวเม็ด 2
# รากผักชี+กระเทียม+พริกไทย 2
# พริกไทยป่นตามชอบ 2

# %%
ch_regex = "ต้นหอม|ต้มหอม|ตันหอม"
name = "ต้นหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ต้นหอม 228
# ต้นหอมซอย 88
# ต้นหอมหั่นท่อน 17
# ต้นหอมผักชี 15
# ต้นหอมหั่น 10
# ผักชีต้นหอม 9
# ต้นหอมญี่ปุ่น 8
# ต้นหอม ผักชี 6
# ต้มหอม 6
# ต้นหอมผักชีซอย 5
# ต้นหอม ผักชีซอย 5
# ต้นหอม ผักชี ซอย 3
# ต้นหอมผักชีหั่น 3
# ผักชี/ต้นหอม 3
# ต้นหอม-ผักชีซอย 2
# ผักชี ต้นหอม 2
# ต้มหอมซอย 2
# ต้นหอมหั่นฝอย 2
# ต้นหอม/ผักชี 2
# ตันหอม 2

# %%
ch_regex = "แครอท|แคร์รอต|แครท|ผักสามสี"
name = "แครอท"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แครอท 224
# แครอทหั่นเต๋า 28
# แครอทหั่น 11
# ผักสามสี 9
# แครอทซอย 6
# แครอทฝอย 5
# แครอทหั่นเต๋าเล็ก 4
# แครอทหั่นชิ้น 3
# แครอทหั่นเส้น 3
# แคร์รอต 3
# แครอทหั่นแว่น 3
# แครอทขูด 3
# แครอทสับ 3
# แครอทหั่นฝอย 3
# แครอท หั่นเต๋า 3
# แครอท หั่นเป็นลูกเต๋า 2
# แครอทขูดฝอย 2
# แครอทหั่นเต๋าเล็กๆ 2
# แครอท หั่นชิ้นเล็ก 2
# แครอทหั่นยาว 2
# แครอทหั่นละเอียด 2
# แครอทหั่นท่อน 2
# แครท 2
# แครอทสไลด์ 2

# %%
ch_regex = "^(?!.*บะหมี่|ผง|กระดูก|ลูกชิ้น|ซี่โครง|ตับ|น้ำมัน|น้ำสต๊อก|คนอร์|แหนม|กุนเชียง|กาก|รสดี|ซุป|น้ำ|แคป|ซอส|มัน|กระเทียม|ไส้กรอก|เลือด|แฮม).*หมู(?!ยอ|กรอบ|หยอง|แดง|แฮม).*|สามชั้นสไลซ์|สันคอ"
name = "เนื้อหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูสับ 197
# เนื้อหมู 123
# หมูบด 76
# หมูสามชั้น 36
# หมู 23
# เนื้อหมูสับ 22
# หมูหมัก 22
# หมูสันใน 20
# สันคอหมู 20
# หมูสไลด์ 14
# เนื้อหมูบด 14
# หมูชิ้น 13
# หมูหั่นชิ้น 8
# สันในหมู 8
# เนื้อหมูสามชั้น 8
# หมูเด้ง 7
# สันคอหมูสไลด์ 7
# หมูสามชั้นสไลด์ 6
# หมูสันนอก 6
# เนื้อหมูสันใน 5
# เนื้อหมูสันนอก 5
# หมูสันคอ 5
# หมูหั่น 4
# สันนอกหมู 4
# เนื้อหมูหั่น 4
# หมูบดติดมัน 3
# เนื้อหมูสไลด์ 3
# คอหมูย่าง 3
# เนื้อหมูหั่นชิ้น 3
# หมูนุ่ม 3
# หมูสับลวก 2
# เนื้อหมูส่วนสันคอ 2
# หมูหมักพริกไทยดำ 2
# หมูปิ้ง 2
# เนื้อหมูหมัก 2
# หมูหวาน 2
# สามชั้นสไลซ์ 2
# หมูสับปรุงรส 2
# หมูสับหยาบ 2
# สันคอ 2
# หมูเนื้อแดง 2
# เนื้อสันคอหมู 2

# %%
ch_regex = "^(?!.*เส้น)(.*ข้าวสวย|^ข้าว$|ข้าวกล้อง.*|ข้าวสาร|ข้าวเปล่า|ข้าวหอมมะลิ|ข้าวเย็น|ข้าวหุงสุก|ข้าวญี่ปุ่น|ข้าวสุก|ข้าวแช่เย็น|ข้าวหอม|ข้าวเสาไห้|ข้าวบาสมาติ)"
name = "ข้าวสวย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวสวย 197
# ข้าว 35
# ข้าวกล้อง 14
# ข้าวสาร 10
# ข้าวเปล่า 9
# ข้าวหอมมะลิ 8
# ข้าวกล้องหุงสุก 7
# ข้าวสวยแช่เย็น 7
# ข้าวสวยหอมมะลิ 6
# ข้าวสวยเก่า 5
# ข้าวเย็น 5
# ข้าวหุงสุก 5
# ข้าวญี่ปุ่น 5
# ข้าวสุก 4
# ข้าวสวยหุงสุก 4
# ข้าวสวยญี่ปุ่น 4
# ข้าวสวยหุงค้างคืน 4
# ข้าวสวยร้อนๆ 3
# ข้าวเสาไห้ 3
# ข้าวสารหอมมะลิ 3
# ข้าวสวยเย็น 3
# ข้าวบาสมาติ 3
# ข้าวหอมมะลิหุงสุก 3
# ข้าวแช่เย็น 2
# ข้าวเปล่าหุงสุก 2
# ข้าวสวยหอมมะลิหุงค้างคืน 2
# ข้าวสวยหุงแห้ง 2
# ข้าวหอมมะลิเก่า 2
# ข้าวหอม 2
# ข้าวสวย มากน้อยตามชอบค่ะ 2
# ข้าวญี่ปุ่นหุงสุก 2
# ข้าวสวยเย็นๆ 2

# %%
ch_regex = "มะนาว"
name = "น้ำมะนาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะนาว 191
# น้ำมะนาว 67
# มะนาวแป้น 7
# มะนาวฝาน 3
# น้ำมะนาวสด 2
# มะนาวผ่าซีก 2
# น้ำจิ้ม มะนาว 2

# %%
ch_regex = "พริกขี้หนู"
name = "พริกขี้หนู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกขี้หนู 158
# พริกขี้หนูสวน 39
# พริกขี้หนูซอย 24
# พริกขี้หนูแดง 15
# พริกขี้หนูตำ 13
# พริกขี้หนูสด 12
# พริกขี้หนูสับ 11
# พริกขี้หนูแห้ง 5
# พริกขี้หนูตำละเอียด 3
# พริกขี้หนูบุบ 3
# พริกขี้หนูแห้งซอย 2
# พริกขี้หนูสับหยาบ 2
# พริกขี้หนูหั่น 2
# พริกขี้หนูแห้งทอด 2
# พริกขี้หนูทอด 2

# %%
ch_regex = "^(?!.*ไข่|มัน|มาม่า).*กุ้ง(?!แห้ง).*"
name = "กุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุ้ง 152
# กุ้งสด 48
# กุ้งแม่น้ำ 8
# กุ้งขาว 8
# กุ้งสับ 6
# กุ้งลายเสือ 4
# กุ้งสดแกะเปลือก 4
# กุ้ง ปลาหมึก 3
# กุ้งแกะเปลือก 3
# กุ้งกุลาดำ 3
# กุ้งขาวขนาดกลาง 2
# กุ้งสดปอกเปลือกผ่าหลัง 2
# กุ้งก้ามกราม 2
# น้ำพริกมันกุ้ง 2
# เนื้อกุ้ง 2
# กุ้งแกะเปลือกผ่าหลัง 2
# กุ้งแชบ๊วย 2

# %%
ch_regex = "^(?!.*ซอส|ซ้อส).*มะเขือเทศ.*"
name = "มะเขือเทศ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือเทศ 139
# มะเขือเทศราชินี 18
# มะเขือเทศหั่นเต๋า 10
# มะเขือเทศสีดา 9
# มะเขือเทศลูกเล็ก 7
# มะเขือเทศลูกใหญ่ 5
# มะเขือเทศเชอร์รี่ 4
# มะเขือเทศสับละเอียด 2
# มะเขือเทศหั่นลูกเต๋า 2
# มะเขือเทศสับ 2
# มะเขือเทศหั่น 2
# มะเขือเทศเข้มข้น 2
# มะเขือเทศราชินีผ่าครึ่ง 2

# %%
ch_regex = "หอมใหญ่|หอมหัวใหญ่|หัวหอม|หอมแขก|หอมซอย|หอมเล็กเจียว|^หอม$|หัวใหญ่"
name = "หอมใหญ่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หอมใหญ่ 135
# ต้นหอมซอย 88
# หอมหัวใหญ่ 83
# หัวหอมใหญ่ 49
# หัวหอม 22
# หอมแขก 10
# หอมใหญ่สับ 10
# หัวหอมแดง 9
# หอมใหญ่หั่นเต๋า 9
# หอมใหญ่หั่นเสี้ยว 5
# หอมหัวใหญ่สับละเอียด 4
# หัวหอมใหญ่สับ 4
# หอมหัวใหญ่สับ 4
# หอมหัวใหญ่หั่นเต๋า 3
# หัวหอมสับ 3
# หัวหอมซอย 3
# หอมหัวใหญ่สับหยาบ 3
# หอมใหญ่ซอย 3
# หอมหัวใหญ่ซอย 3
# หอมใหญ่ซอยบางๆ 2
# หอมใหญ่หั่นชิ้นเล็ก 2
# หอมใหญ่หั่น 2
# หอม 2
# หัวหอมหั่น 2
# ต้มหอมซอย 2
# หัวหอมใหญ่หั่น 2
# หอมใหญ่สับละเอียด 2
# หัวหอมแดงสับ 2
# กระเทียมหัวใหญ่ 2
# หัวหอมใหญ่หั่นเต๋า 2
# หอมหัวใหญ่ หั่น 2
# เห็ดหอมซอย 2
# หอมเล็กเจียว 2
# หอมซอย 2

# %%
ch_regex = "รากผักชี"
name = "รากผักชี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# รากผักชี 111
# รากผักชีสับ 4
# รากผักชีทุบ 3
# รากผักชี+กระเทียม+พริกไทย 2

# %%
ch_regex = "หอมแดง|หอมเจียว|หอมเเดง"
name = "หอมแดง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หอมแดง 100
# หอมแดงซอย 45
# หอมเจียว 14
# หัวหอมแดง 9
# หอมแดงเจียว 3
# หอมแดงสับละเอียด 3
# หอมแดงเล็กซอย 2
# หอมแดงสับ 2
# หอมแดง 2
# หัวหอมแดงสับ 2
# หอมแดงเผา 2

# %%
ch_regex = "พริกแห้ง"
name = "พริกแห้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกแห้ง 100
# พริกแห้งทอด 8
# พริกแห้งจินดา 2
# พริกแห้งคั่ว 2
# พริกแห้งเม็ดเล็ก 2

# %%
ch_regex = "พริกป่น"
name = "พริกป่น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกป่น 99
# พริกป่นตามชอบ 3
# พริกป่นเกาหลี 3
# พริกป่นละเอียด 2

# %%
ch_regex = "^(?!.*ราก|ลูก).*ผักชี.*|ผง coriander"
name = "ผักชี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักชี 97
# ผักชีฝรั่ง 30
# ผักชีซอย 15
# ต้นหอมผักชี 15
# ผักชีต้นหอม 9
# ต้นหอม ผักชี 6
# ผักชีฝรั่งซอย 5
# ต้นหอมผักชีซอย 5
# ต้นหอม ผักชีซอย 5
# ผักชีใบเลื่อย 4
# ใบผักชี 4
# ผักชีหั่น 3
# ผักชีสับ 3
# ต้นหอม ผักชี ซอย 3
# ต้นหอมผักชีหั่น 3
# ผักชี/ต้นหอม 3
# ต้นหอม-ผักชีซอย 2
# ผักชีลาว 2
# เม็ดผักชี 2
# ผักชี ต้นหอม 2
# ผง coriander 2
# ต้นหอม/ผักชี 2

# %%
ch_regex = "ซอสมะเขือเทศ|ซ้อสมะเขือเทศ"
name = "ซอสมะเขือเทศ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสมะเขือเทศ 103
# ซอสมะเขือเทศเข้มข้น 3
# ซอสมะเขือเทศโรซ่า 3
# ซ้อสมะเขือเทศ 2

# %%
ch_regex = "ใบมะกรูด|ใบมะกูด|มะกรูด"
name = "ใบมะกรูด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบมะกรูด 94
# ใบมะกรูดซอย 22
# ใบมะกรูดฉีก 16
# ใบมะกูด 6
# ใบมะกรูดหั่นฝอย 6
# มะกรูด 2
# ผิวมะกรูด 2
# ใบมะกรูดฝอย 2

# %%
ch_regex = "น้ำมันงา"
name = "น้ำมันงา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมันงา 93
# น้ำมันงาเกาหลี 3
# น้ำมันงาลีกุมกี่ 2

# %%
ch_regex = "^พริก$|พริกสด|พริกจินดา|พริกแดง|พริกใหญ่|พริกสับ|พริกอ่อน|พริกตำ|พริกซอย|พริกทอด|พริกสีแดง|พริกหั่น|พริกคั่ว|พริก+|พริกหั่นเฉียง"
name = "พริก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกไทย 274
# พริกไทยป่น 163
# พริกขี้หนู 158
# พริกแห้ง 100
# พริกป่น 99
# พริก 89
# พริกไทยดำ 75
# น้ำพริกเผา 67
# ซอสพริก 48
# พริกชี้ฟ้าแดง 43
# พริกสด 42
# พริกแกงเผ็ด 39
# พริกขี้หนูสวน 39
# พริกจินดา 35
# พริกไท 32
# พริกแกง 28
# พริกชี้ฟ้า 26
# พริกไทยอ่อน 26
# พริกไทยดำป่น 25
# พริกแดง 25
# พริกขี้หนูซอย 24
# พริกไทป่น 23
# พริกจินดาแดง 19
# พริกไทยเม็ด 19
# พริกหยวก 18
# พริกเผา 17
# พริกไทยขาวป่น 16
# พริกขี้หนูแดง 15
# พริกใหญ่ 14
# พริกไทยขาว 14
# พริกขี้หนูตำ 13
# พริกแดงจินดา 12
# พริกขี้หนูสด 12
# พริกขี้หนูสับ 11
# พริกไทยดำบด 11
# พริกแกงใต้ 9
# พริกจินดาสีแดง 9
# น้ำพริกกะปิ 9
# พริกแกงเขียวหวาน 9
# พริกไทยสด 9
# พริกสับ 9
# พริกแห้งทอด 8
# น้ำพริกตาแดง 8
# พริกชี้ฟ้าซอย 7
# พริกอ่อน 7
# น้ำมันพริกเผา 6
# ซอสพริกศรีราชา 6
# พริกหวาน 6
# พริกชี้ฟ้าแห้ง 6
# ซอสพริกไทยดำ 5
# พริกหยวกหั่น 5
# พริกขี้หนูแห้ง 5
# พริกเหลือง 5
# เม็ดพริกไทย 5
# พริกแกงแดง 5
# พริกหวานหั่นเต๋า 4
# พริกหนุ่ม 4
# เกลือ พริกไทย 4
# พริกซอย 4
# พริกตำ 4
# พริกชี้ฟ้าแดงหั่นแฉลบ 3
# พริกทอด 3
# พริกไทยดำเม็ด 3
# พริกแกงพะแนง 3
# พริกขี้หนูตำละเอียด 3
# พริกไทเม็ด 3
# พริกขี้หนูบุบ 3
# พริกไทยป่นเล็กน้อย 3
# พริกสดหั่น 3
# พริกแกงน้ำยา 3
# พริกไทย ป่น 3
# พริกแกงส้ม 3
# พริกป่นตามชอบ 3
# พริกแกงคั่ว 3
# พริกป่นเกาหลี 3
# พริกไทดำ 3
# เกลือพริกไทย 2
# พริกแดงซอย 2
# พริกสดซอย 2
# พริกชี้ฟ้าเหลือง 2
# น้ำพริกหนุ่ม 2
# พริกไทยนิดหน่อย 2
# พริกหยวกสีเหลือง 2
# พริกน้ำส้ม 2
# พริกแกงเผ็ดใต้ 2
# พริกแดงสับ 2
# กระเทียม+พริก 2
# พริกหวานสีแดง 2
# พริกแดง-พริกเขียว 2
# พริกแห้งจินดา 2
# พริกขี้หนูแห้งซอย 2
# หมูหมักพริกไทยดำ 2
# พริกไทยขาวเม็ด 2
# พริกสีแดง 2
# พริกหยวกแดง 2
# น้ำพริกเผาผัด 2
# พริกขี้หนูสับหยาบ 2
# ผงพริกแดง 2
# พริกแกงมัสมั่น 2
# พริกชี้ฟ้าแดง เขียว 2
# พริกชี้ฟ้าหั่นเฉียง 2
# พริกไทยดำบดหยาบ 2
# น้ำพริก 2
# น้ำปลาพริก 2
# พริกหั่น 2
# พริกชี้ฟ้าเขียว แดง 2
# พริกคั่ว 2
# พริกชี้ฟ้าส้ม 2
# พริกขี้หนูหั่น 2
# พริกชี้ฟ้าตำละเอียด 2
# พริกใหญ่แดง 2
# พริก+กระเทียม 2
# เกลือและพริกไทย สำหรับปรุงรส 2
# พริกแห้งคั่ว 2
# พริกแกงกะทิ 2
# น้ำพริกมันกุ้ง 2
# พริกป่นละเอียด 2
# พริกชี้ฟ้าแดงซอย 2
# พริกแห้งเม็ดเล็ก 2
# พริกแกงฉู่ฉี่ 2
# น้ำพริกเผาต้มยำ 2
# พริกขี้หนูแห้งทอด 2
# พริกไทยบด 2
# พริกไทยเม็ดตำละเอียด 2
# เกลือ/พริกไทย 2
# โบโลน่าพริก 2
# พริกไทยป่นสำหรับโรยหน้า 2
# พริกไทขาวเม็ด 2
# พริกแกงคั่วกลิ้ง 2
# พริกหั่นเฉียง 2
# พริกสามสี 2
# รากผักชี+กระเทียม+พริกไทย 2
# พริกไทยป่นตามชอบ 2
# พริกหยวกสีเขียว 2
# พริกขี้หนูทอด 2

# %%
ch_regex = "โหระพา|ใบโหรพา|โหรพา"
name = "ใบโหระพา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบโหระพา 89
# โหระพา 52
# ใบโหรพา 5
# ใบโหระพาสับ 3
# โหรพา 3
# ใบโหระพาเด็ด 2
# โหระพาเด็ด 2

# %%
ch_regex = "ถั่วฝักยาว|ถั่วฟักยาว|ถั่วผักยาว|ถัวฝักยาว"
name = "ถั่วฝักยาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วฝักยาว 84
# ถั่วฟักยาว 5
# ถั่วฝักยาวหั่น 3
# ถั่วฝักยาวซอย 3
# ถั่วผักยาว 2

# %%
ch_regex = "ใบกะเพรา|ใบกระเพรา|กระเพรา|กะเพรา|ใบกระเพา|ใบกระ เพรา แดง|กระเพา|Basil"
name = "ใบกะเพรา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบกะเพรา 82
# ใบกระเพรา 82
# กระเพรา 19
# กะเพรา 11
# ใบกระเพา 5
# ใบกระเพราแดง 5
# กระเพาะปลา 4
# ใบกระเพราเด็ด 4
# กะเพราแดง 3
# กระเพา 2
# กระเพราขาว 2
# ใบกระ เพรา แดง 2

# %%
ch_regex = "^(?!.*ไส้กรอก|ไข่|เลือด|น้ำ|ผง|โครง|ตีน|เครื่องใน|เต้าหู้|ซี่โครง|ขา|ซอส|ตับ).*ไก่(?!จ๊อ|ไข่).*|chicken"
name = "เนื้อไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# อกไก่ 81
# เนื้อไก่ 54
# เนื้ออกไก่ 24
# สันในไก่ 21
# สะโพกไก่ 17
# ไก่ 13
# ไก่สับ 12
# อกไก่สับ 11
# น่องไก่ 11
# ไก่น่องสะโพก 8
# ปีกไก่ 8
# อกไก่หั่น 7
# เนื้อสะโพกไก่ 6
# น่องไก่ติดสะโพก 4
# อกไก่หั่นชิ้น 4
# เนื้ออกไก่สับ 3
# ไก่หมัก 3
# ปีกบนไก่ 3
# สะโพกไก่เลาะกระดูก 3
# เนื้ออกไก่ลอกหนัง 2
# ไก่หั่น 2
# ปีกกลางไก่ 2
# ปีกไก่บน 2
# ปีกไก่กลาง 2
# น่องไก่เล็ก 2
# อกไก่ลอกหนัง 2
# อกไก่ ไม่ติดหนัง 2
# เนื้อสันในไก่ 2
# ไก่บด 2
# เนื้ออกไก่หั่น 2
# เนื้อไก่บด 2
# อกไก่หมัก 2
# เนื้อไก่สับ 2
# ไก่ทอด 2
# ไก่สับละเอียด 2
# ไก่ชิ้น 2
# chicken 2
# เนื้อไก่หั่นเต๋า 2
# อกไก่ต้ม 2
# อกไก่บด 2

# %%
ch_regex = "^ซีอิ๊วดำ$|^ซีอิ้วดำ$|ซีอิ๋วดำ(?!หวาน)|สี่อิ๋วดำสูตรเค็ม"
name = "ซีอิ๊วดำ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ๊วดำ 77
# ซีอิ้วดำ 62
# ซีอิ๋วดำ 8
# สี่อิ๋วดำสูตรเค็ม 3

# %%
ch_regex = "ถั่วงอก"
name = "ถั่วงอก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วงอก 76
# ถั่วงอกลวก 4
# ถั่วงอกหัวโต 3
# ถั่วงอกดิบ 2
# ถั่วงอกเด็ดหาง 2

# %%
ch_regex = "คะน้า"
name = "คะน้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# คะน้า 74
# ผักคะน้า 33
# คะน้าฮ่องกง 19
# ยอดคะน้า 16
# คะน้ายอด 2
# ก้านคะน้าฮ่องกง 2

# %%
ch_regex = "ข้าวโพดอ่อน"
name = "ข้าวโพดอ่อน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวโพดอ่อน 74
# ยอดข้าวโพดอ่อน 3
# ข้าวโพดอ่อนหั่นแฉลบ 2
# ข้าวโพดอ่อนผ่าครึ่ง 2
# ข้าวโพดอ่อนแพคเล็ก 2
# ข้าวโพดอ่อนซอย 2
# ข้าวโพดอ่อนหั่น 2

# %%
ch_regex = "เนย"
name = "เนย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เนย 70
# เนยจืด 22
# เนยเค็ม 19
# เนยสด 16
# เนยแท้ 3
# เนยสดเค็ม 3
# เนยละลาย 2
# เนยสดจืด 2
# เนยรสจืด 2
# เนยมาการีน 2

# %%
ch_regex = "แป้งทอดกรอบ|แป้งชุบทอด|แป้งโกกิ|แป้งทอด|แป้งสำหรับทอด|แป้งทอดกรอบคนอร์"
name = "แป้งทอดกรอบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งทอดกรอบ 59
# แป้งชุบทอด 6
# แป้งโกกิ 5
# แป้งทอดกรอบคนอร์ 3
# แป้งสำหรับทอด 2
# แป้งทอด 2

# %%
ch_regex = "แป้งมัน"
name = "แป้งมัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งมัน 56
# แป้งมันฮ่องกง 8
# แป้งมันละลายน้ำ 4

# %%
ch_regex = "^(?!.*ซอส|ซีอิ๊ว|ผงปรุงรส|ซีอิ้ว|คนอร์).*เห็ด.*"
name = "เห็ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เห็ดหอม 56
# เห็ดเข็มทอง 34
# เห็ดออรินจิ 19
# เห็ดหอมสด 18
# เห็ดฟาง 16
# เห็ด 16
# เห็ดหูหนู 12
# เห็ดชิเมจิ 11
# เห็ดหอมแห้ง 10
# เห็ดแชมปิญอง 9
# เห็ดนางฟ้า 7
# เห็ดหูหนูดำ 7
# เห็ดหอมแช่น้ำ 5
# เห็ดนางรมหลวง 5
# เห็ดออริจิน 4
# เห็ดโคนญี่ปุ่น 3
# เห็ดหอมแห้งแช่น้ำจนนิ่ม 3
# เห็ดหูหนูขาว 3
# เห็ดหอมดอกใหญ่ 2
# เห็ดออริจิ 2
# เห็ดแชมปิยอง 2
# เห็ดหอมซอย 2

# %%
ch_regex = "เส้นสปาเก็ตตี้|เส้นสปาเกตตี้|สปาเก็ตตี้|สปาเกตตี้|เส้นสปาเกตตี|สปาเกตตี"
name = "เส้นสปาเก็ตตี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นสปาเก็ตตี้ 55
# เส้นสปาเกตตี้ 34
# สปาเก็ตตี้ 9
# เส้นสปาเก็ตตี้ต้มสุก 7
# สปาเกตตี้ 7
# เส้นสปาเกตตี 7
# เส้นสปาเก็ตตี้โฮลวีท 3
# เส้นสปาเกตตี้ ต้มสุก 2
# เส้นสปาเกตตี้ลวก 2
# สปาเกตตี 2

# %%
ch_regex = "เต้าเจี้ยว|เต้าเจี๊ยว|เต้าเจียว"
name = "เต้าเจี้ยว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เต้าเจี้ยว 53
# เต้าเจี๊ยว 3
# เต้าเจียว 3

# %%
ch_regex = "โชยุ|ซีอิ๊วญี่ปุ่น|โชวยุ|Soba tsuyu"
name = "โชยุ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โชยุ 53
# ซอสโชยุ 5
# ซีอิ๊วญี่ปุ่น 4
# โชวยุ 2
# Soba tsuyu 2
# โชยุญี่ปุ่น 2

# %%
ch_regex = "ตะไคร้|ตะใคร้"
name = "ตะไคร้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตะไคร้ 52
# ตะไคร้ซอย 22
# ตะใคร้ 5
# ตะไคร้หั่นฝอย 2
# ตะไคร้ ซอย 2

# %%
ch_regex = "^(?!.*ไข่).*ปลาหมึก.*|^หมึก|หมึกกล้วย"
name = "หมึก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาหมึก 52
# ปลาหมึกสด 8
# ปลาหมึกกรอบ 5
# ปลาหมึกแห้ง 4
# กุ้ง ปลาหมึก 3
# ปลาหมึกกล้วย 3
# หมึก 3
# ปลาหมึกหั่นแว่น 2
# หมึกกล้วย 2

# %%
ch_regex = "น้ำพริกเผา"
name = "น้ำพริกเผา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำพริกเผา 67
# น้ำพริกเผาผัด 2
# น้ำพริกเผาต้มยำ 2

# %%
ch_regex = "เบคอน"
name = "เบคอน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เบคอน 52
# เบคอนหั่น 4

# %%
ch_regex = "ไส้กรอก"
name = "ไส้กรอก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไส้กรอก 50
# ไส้กรอกรมควัน 7
# ไส้กรอกไก่ 6
# ไส้กรอกหมู 3
# ไส้กรอกหมูรมควัน 2
# ไส้กรอกหั่นชิ้น 2
# ไส้กรอกหั่นแว่น 2
# ไส้กรอกมินิคอกเทล 2
# ไส้กรอกไก่รมควัน 2

# %%
ch_regex = "^นม(?!ข้น)"
name = "นม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# นมสด 49
# นมจืด 18
# นมสดจืด 6
# นม 6
# นมสดรสจืด 3

# %%
ch_regex = "ซอสพริก"
name = "ซอสพริก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสพริก 48
# ซอสพริกศรีราชา 6
# ซอสพริกไทยดำ 5

# %%
ch_regex = "วุ้นเส้น|^เส้น$"
name = "วุ้นเส้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# วุ้นเส้น 47
# วุ้นเส้นสด 10
# วุ้นเส้นห่อเล็ก 3
# เส้น 2
# วุ้นเส้นแช่น้ำ 2
# วุ้นเส้นเกาหลี 2

# %%
ch_regex = "น้ำซุป|น้ำซุบ"
name = "น้ำซุป"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำซุป 46
# น้ำซุปไก่ 4
# น้ำซุปหรือน้ำเปล่า 3
# น้ำซุปดาชิ 3
# น้ำเปล่าหรือน้ำซุป 3
# น้ำซุบ 2
# น้ำซุปกระดูกหมู 2
# ส่วนผสมน้ำซุป 2
# น้ำเปล่า/น้ำซุป 2

# %%
ch_regex = "ผักกาด|ผัดกาดขาว|ผักคอส"
name = "ผักกาด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักกาดขาว 43
# ผักกาดหอม 17
# ผักกาดแก้ว 6
# ผักกาดดอง 6
# ผักกาด 3
# ผักคอส 3
# ผัดกาดขาว 3
# ผักกาดดองเค็ม 2
# ใบผักกาดขาว 2

# %%
ch_regex = "^กะปิ"
name = "กะปิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กะปิ 43
# กะปิดี 4
# กะปิอย่างดี 2

# %%
ch_regex = "พริกชี้ฟ้า|พริกเหลือง"
name = "พริกชี้ฟ้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกชี้ฟ้าแดง 43
# พริกชี้ฟ้า 26
# พริกชี้ฟ้าซอย 7
# พริกชี้ฟ้าแห้ง 6
# พริกเหลือง 5
# พริกชี้ฟ้าแดงหั่นแฉลบ 3
# พริกชี้ฟ้าเหลือง 2
# พริกชี้ฟ้าแดง เขียว 2
# พริกชี้ฟ้าหั่นเฉียง 2
# พริกชี้ฟ้าเขียว แดง 2
# พริกชี้ฟ้าส้ม 2
# พริกชี้ฟ้าตำละเอียด 2
# พริกชี้ฟ้าแดงซอย 2

# %%
ch_regex = "กะทิ|กระทิ"
name = "กะทิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กะทิ 42
# หัวกะทิ 12
# หางกะทิ 6
# น้ำกะทิ 6
# กะทิกล่อง 3
# กระทิ 2
# กะทิสด 2
# พริกแกงกะทิ 2

# %%
ch_regex = "เส้นใหญ่|เส้นไหญ่|^เส้น$"
name = "เส้นใหญ่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นใหญ่ 42
# ก๋วยเตี๋ยวเส้นใหญ่ 4
# เส้น 2

# %%
ch_regex = "^(?!.*ดอก)กะหล่ำ(?!.*ดอก.*)|กะหล่ำปลี|กระหล่ำปลี"
name = "กะหล่ำปลี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กะหล่ำปลี 40
# กระหล่ำปลี 21
# กะหล่ำปลีหั่น 4
# กะหล่ำ 3
# กระหล่ำปลีซอย 3
# กะหล่ำปลีซอย 3
# กระหล่ำปลีหั่น 2
# กะหล่ำปลีม่วงซอย 2
# กะหล่ำปลีฝอย 2
# กะหล่ำปลีหั่นฝอย 2

# %%
ch_regex = "ผักบุ้ง"
name = "ผักบุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักบุ้ง 39
# ผักบุ้งจีน 4
# ผักบุ้งไทย 2

# %%
ch_regex = "แฮม"
name = "แฮม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แฮม 39
# แฮมหมู 2
# แฮมหั่นเต๋า 2
# หมูแฮม 2

# %%
ch_regex = "หมูยอ"
name = "หมูยอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูยอ 37

# %%
ch_regex = "แตงกวา"
name = "แตงกวา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แตงกวา 36
# แตงกวาเล็ก 2
# แตงกวาญี่ปุ่น 2
# แตงกวาหั่น 2

# %%
ch_regex = "กุ้งแห้ง"
name = "กุ้งแห้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุ้งแห้ง 35
# กุ้งแห้งฝอย 4
# กุ้งแห้งป่น 4

# %%
ch_regex = "มิริน"
name = "มิริน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มิริน 35

# %%
ch_regex = "น้ำมะขามเปียก|น้ำมะขาวเปียก|น้ำมะขาม"
name = "น้ำมะขามเปียก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมะขามเปียก 35
# น้ำมะขาวเปียก 2
# น้ำมะขาม 2

# %%
ch_regex = "ต้นกระเทียม"
name = "ต้นกระเทียม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ต้นกระเทียม 2

# %%
ch_regex = "ถั่วเน่า"
name = "ถั่วเน่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วเน่า 2

# %%
ch_regex = "หญ้าหวาน"
name = "หญ้าหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำตาลหญ้าหวาน 9
# หญ้าหวาน 2

# %%
ch_regex = "ขึ้นฉ่าย|คื่นช่าย|คึ่นช่าย|ขึ้นช่าย|คื่นไช้|คื่นไฉ่|ตั้งโอ๋"
name = "ขึ้นฉ่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขึ้นฉ่าย 34
# คื่นช่าย 12
# คึ่นช่าย 7
# ตั้งโอ๋ 5
# ขึ้นช่าย 4
# ขึ้นฉ่ายซอย 4
# คื่นไช้ 3
# คื่นไฉ่ 3
# คื่นช่ายหั่น 2
# ขึ้นฉ่ายหั่น 2
# ตั้งโอ๋หั่นท่อน 2

# %%
ch_regex = "มันฝรั่ง"
name = "มันฝรั่ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มันฝรั่ง 33
# มันฝรั่งหั่นเต๋า 3

# %%
ch_regex = "น้ำส้มสายชู|น้ำส้ม"
name = "น้ำส้มสายชู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำส้มสายชู 31
# น้ำส้มสายชูข้าว 3
# พริกน้ำส้ม 2
# น้ำส้ม 2

# %%
ch_regex = "ใบบัวบก"
name = "ใบบัวบก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบบัวบก 2

# %%
ch_regex = "แป้งขนมปัง"
name = "แป้งขนมปัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งขนมปัง 2

# %%
ch_regex = "ซีรัป"
name = "ไซรัป"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีรัป 2

# %%
ch_regex = "เส้นเฟตตูชินี"
name = "เส้นเฟตตูชินี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นเฟตตูชินี 2

# %%
ch_regex = "ข่า"
name = "ข่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข่า 31
# ข่าซอย 4
# ข่าสับละเอียด 2
# ข่าอ่อนหั่นแว่น 2
# ข่าหั่น 2
# ข่าอ่อน 2
# ข่าหั่นแว่น 2

# %%
ch_regex = "มาม่า|บะหมี่กึ่งสำเร็จรูป|เส้นหมี่ไวไว|ไวไว|หมี่กึง"
name = "บะหมี่กึ่งสำเร็จรูป"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มาม่า 29
# บะหมี่กึ่งสำเร็จรูป 21
# มาม่าเกาหลี 5
# เส้นมาม่า 4
# เส้นบะหมี่กึ่งสำเร็จรูป 4
# เส้นมาม่าลวก 3
# ไวไว 3
# เส้นหมี่ไวไว 3
# หมี่กึง 3
# บะหมี่กึ่งสำเร็จรูปรสต้มยำ 2
# มาม่าลวก 2
# มาม่าต้มยำเจ 2
# ไวไวรสหอยลายผัดฉ่า 2
# มาม่ารสต้มยำ 2
# มาม่าต้มยำกุ้งน้ำใส 2
# บะหมี่กึ่งสำเร็จรูปรสหมูสับ 2
# มาม่าลวกสุก 2
# มาม่าต้มยำกุ้งน้ำข้น 2
# หมี่ขาวไวไว 2
# มาม่าต้มยำ 2

# %%
ch_regex = "น้ำผึ้ง"
name = "น้ำผึ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำผึ้ง 28

# %%
ch_regex = "^(?!.*ซอส|แป้งทอด).*(คนอร์|รสดี).*|อร่อยชัวร์|ผงปรุงรส|เครื่องปรุงรส|ซุปก้อน|ผงซุปหมูก้อน|ชูรส|ผงซุป|ผงเติมทิพ|ผงดาชิ|ผงปาปริก้า|ดาชิ|ปาปริก้า|เครื่องปรุง|ผงปาปริกา|italian seasoning|ผงนัว|ผงหม่าล่า|ซุปหมูก้อน|ผงหมาล่า|ผงโรยข้าว"
name = "ผงปรุงรส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงปรุงรส 193
# ผงปรุงรสคนอร์ 34
# รสดี 28
# คนอร์ 27
# ผงปรุงรสหมู 24
# ผงชูรส 19
# คนอร์อร่อยชัวร์ 16
# ผงคนอร์ 14
# อร่อยชัวร์ 13
# เครื่องปรุงรส 10
# ผงปรุงรสไก่ 7
# ผงปรุงรสรสหมู 7
# คนอร์ผงรสหมู 7
# ผงปรุงรสเห็ดหอม 6
# คนอร์ผง 6
# คนอร์รสหมู 6
# ซุปก้อน 6
# ผงซุปก้อนหมู 6
# ผงซุปหมูก้อน 5
# ชูรส 5
# ผงปรุงรสตราคนอร์ 5
# คนอร์ก้อน 5
# ผงปรุงรสคนอร์อร่อยชัวร์ 5
# ผงซุป 5
# ผงเติมทิพ 5
# ผงดาชิ 4
# ผงปาปริก้า 4
# คนอร์ผง รสหมู 4
# คนอร์ซุปก้อนรสหมู 4
# ดาชิ 4
# รสดีเมนู 4
# ปาปริก้า 4
# ผงปรุงรส คนอร์ 3
# รสดีหมู 3
# คนอร์ขวดสูตรเข้มข้น 3
# เครื่องปรุง 3
# ผงเติมทิพ. 3
# คนอร์อร่อยชัว 3
# ผงปาปริกา 3
# น้ำซุปดาชิ 3
# คนอร์ต้มยำ 3
# คนอร์เห็ดหอม 3
# ผงปรุงรสผัดคนอร์ 2
# italian seasoning 2
# คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส 2
# รสดีรสหมู 2
# คนอร์อร่อยชัวร์รสหมู 2
# ซุปหมูก้อน 2
# ผงชูรสเจ 2
# คนอร์ซุปก้อน 2
# ผงหมาล่า 2
# ซุปหมูก้อนคนอร์ 2
# ซุปก้อนรสหมู 2
# ผงคนอร์รสหมู 2
# ส่วนผสมเครื่องปรุง 2
# คนอร์ต้มยำก้อน 2
# ผงนัว 2
# ผงโรยข้าว 2
# ผงหม่าล่า 2
# คนอร์ขวดรสหมู 2

# %%
ch_regex = "ซอสเห็ดหอม|ซอสเห็ด หอม"
name = "ซอสเห็ดหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสเห็ดหอม 26
# ซอสเห็ด หอม 4

# %%
ch_regex = "ไชเท้า"
name = "หัวไชเท้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หัวไชเท้า 24
# ไชเท้า 5

# %%
ch_regex = "พริกแกง"
name = "พริกแกง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกแกงเผ็ด 39
# พริกแกง 28
# พริกแกงใต้ 9
# พริกแกงเขียวหวาน 9
# พริกแกงแดง 5
# พริกแกงพะแนง 3
# พริกแกงน้ำยา 3
# พริกแกงส้ม 3
# พริกแกงคั่ว 3
# พริกแกงเผ็ดใต้ 2
# พริกแกงมัสมั่น 2
# พริกแกงกะทิ 2
# พริกแกงฉู่ฉี่ 2
# พริกแกงคั่วกลิ้ง 2

# %%
ch_regex = "แป้งข้าวโพด"
name = "แป้งข้าวโพด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งข้าวโพด 32

# %%
ch_regex = "ซีอิ้วดำหวาน|ซีอิ๊วดำหวาน|ซีอิ๊วหวาน|สี่อิ๋วหวาน|สี่อิ๋วดำสูตรหวาน|ซี๊อิ๋วดำหวาน"
name = "ซีอิ๊วหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ้วดำหวาน 26
# ซีอิ๊วดำหวาน 16
# ซีอิ๊วหวาน 8
# สี่อิ๋วหวาน 3
# สี่อิ๋วดำสูตรหวาน 3
# ซี๊อิ๋วดำหวาน 2

# %%
ch_regex = "กุนเชียง"
name = "กุนเชียง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุนเชียง 24
# กุนเชียงหมู 5
# กุนเชียงทอด 3
# กุนเชียงอย่างดี 2

# %%
ch_regex = "ข้าวคั่ว"
name = "ข้าวคั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวคั่ว 24

# %%
ch_regex = "กวางตุ้ง"
name = "ผักกวางตุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักกวางตุ้ง 24
# กวางตุ้ง 10

# %%
ch_regex = "ลูกชิ้น"
name = "ลูกชิ้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ลูกชิ้นปลา 24
# ลูกชิ้นหมู 17
# ลูกชิ้น 16
# ลูกชิ้นปลากราย 2
# ลูกชิ้นเอ็นหมู 2
# ลูกชิ้นเนื้อ 2

# %%
ch_regex = "ไข่เป็ด"
name = "ไข่เป็ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่เป็ด 24

# %%
ch_regex = "ปลากระป๋อง"
name = "ปลากระป๋อง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลากระป๋อง 23

# %%
ch_regex = "ผักสลัด"
name = "ผักสลัด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักสลัด 23
# ผักสลัดตามชอบ 4

# %%
ch_regex = "^กระดูกหมู$|กระดูกเล้ง|เล้ง"
name = "กระดูกหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระดูกหมู 23
# กระดูกเล้ง 5
# เล้ง 2

# %%
ch_regex = "ปูอัด"
name = "ปูอัด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปูอัด 23

# %%
ch_regex = "เกล็ดขนมปัง|เกร็ดขนมปัง"
name = "เกล็ดขนมปัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เกล็ดขนมปัง 22
# เกร็ดขนมปัง 2

# %%
ch_regex = "เส้นโซบะ"
name = "เส้นโซบะ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นโซบะ 2

# %%
ch_regex = "น้ำหวานดอกมะพร้าว"
name = "น้ำหวานดอกมะพร้าว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำหวานดอกมะพร้าว 2

# %%
ch_regex = "น้ำจิ้มหมูหัน"
name = "น้ำจิ้มหมูหัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มหมูหัน 2

# %%
ch_regex = "ถั่วแระญี่ปุ่น"
name = "ถั่วแระญี่ปุ่น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วแระญี่ปุ่น 2

# %%
ch_regex = "เต้าหู้ไข่"
name = "เต้าหู้ไข่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เต้าหู้ไข่ 22
# เต้าหู้ไข่ไก่ 3

# %%
ch_regex = "ปลาร้า"
name = "น้ำปลาร้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำปลาร้า 20
# ปลาร้าต้มสุก 4
# น้ำปลาร้าต้มสุก 3

# %%
ch_regex = "^(?!.*น้ำ).*งา.*"
name = "งา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# งาขาว 20
# งาขาวคั่ว 20
# งาคั่ว 5
# งาดำ 3

# %%
ch_regex = "ถั่วลันเตา|ผักสามสี"
name = "ถั่วลันเตา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วลันเตา 20
# ผักสามสี 9

# %%
ch_regex = "ถั่วลันเตา"
name = "ถั่วลันเตา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วลันเตา 20

# %%
ch_regex = "กระชาย"
name = "กระชาย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระชาย 20
# กระชายซอย 10
# กระชายหั่นฝอย 2
# กระชายหั่นเส้น 2

# %%
ch_regex = "ผงชูรส"
name = "ผงชูรส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงชูรส 19
# คนอร์ผงปรุงรสหมูสูตรไม่ใส่ผงชูรส 2
# ผงชูรสเจ 2

# %%
ch_regex = "ขนมจีน"
name = "ขนมจีน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขนมจีน 19
# เส้นขนมจีน 2

# %%
ch_regex = "^(?!.*ผัก).*ชีส.*|Mozzarella cheese"
name = "ชีส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ชีส 19
# เชดด้าชีส 9
# มอสซาเรลล่าชีส 8
# ชีสแผ่น 8
# พาร์เมซานชีส 5
# มอสซาเรลลาชีส 4
# พาเมซานชีส 4
# Mozzarella cheese 3
# ชีสขูด 2

# %%
ch_regex = "พริกหยวก|พริกสามสี"
name = "พริกหยวก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกหยวก 18
# พริกหยวกหั่น 5
# พริกหยวกสีเหลือง 2
# พริกหยวกแดง 2
# พริกสามสี 2
# พริกหยวกสีเขียว 2

# %%
ch_regex = "เส้นหมี่(?!ซั่ว|ฮกเกี้ยน|เหลือง|ไวไว|หมี่ขาว)|หมี่ขาว|^เส้น$"
name = "เส้นหมี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นหมี่ 18
# เส้นหมี่ขาว 15
# เส้นหมี่ข้าวกล้อง 8
# เส้น 2
# เส้นหมี่แช่น้ำ 2
# หมี่ขาว 2
# เส้นหมี่สด 2
# หมี่ขาวไวไว 2

# %%
ch_regex = "มะเขือเปราะ"
name = "มะเขือเปราะ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือเปราะ 17

# %%
ch_regex = "พริกเผา"
name = "พริกเผา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำพริกเผา 67
# พริกเผา 17
# น้ำมันพริกเผา 6
# น้ำพริกเผาผัด 2
# น้ำพริกเผาต้มยำ 2

# %%
ch_regex = "ซี่โครงหมู"
name = "ซี่โครงหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซี่โครงหมู 17

# %%
ch_regex = "เหล้า|สาเก"
name = "เหล้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เหล้าจีน 16
# สาเก 9

# %%
ch_regex = "กิมจิ"
name = "กิมจิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กิมจิ 16
# กิมจิสับละเอียด 2

# %%
ch_regex = "ออริกาโน่|อาริกาโน|ออริกาโน|oregano"
name = "ออริกาโน่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ออริกาโน่ 16
# อาริกาโน 6
# ออริกาโน 5
# ออริกาโน่แห้ง 3
# ออริกาโนป่น 2
# oregano 2
# ออริกาโน่อบแห้ง 2

# %%
ch_regex = "มายองเนส"
name = "มายองเนส"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มายองเนส 15
# คิวพี มายองเนส ศรีราชา 2

# %%
ch_regex = "น้ำจิ้มสุกี้"
name = "น้ำจิ้มสุกี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มสุกี้ 15

# %%
ch_regex = "ขิง"
name = "ขิง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขิงซอย 15
# ขิง 9
# ขิงแก่ 6
# ขิงอ่อน 6
# ขิงสับละเอียด 4
# ขิงสับ 4
# ขิงอ่อนซอย 4
# ขิงขูด 3
# ขิงขูดละเอียด 2
# ขิงแก่ซอย 2
# ขิงหั่นแว่น 2

# %%
ch_regex = "ชะอม"
name = "ชะอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ชะอม 14

# %%
ch_regex = "^ผัก$|ผักที่ชอบ"
name = "ผัก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผัก 14
# ผักที่ชอบ 2

# %%
ch_regex = "^ผัก$|ผักต่างๆ|ผักสด|ผักเครื่องเคียง|ผักตามชอบ"
name = "ผัก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผัก 14
# ผักต่างๆ 4
# ผักสด 4
# ผักตามชอบ 2
# ผักเครื่องเคียง 2

# %%
ch_regex = "แหนม|เเหนม"
name = "แหนม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แหนม 16
# แหนมหมู 6
# แหนมตุ้มจิ๋ว 2
# แหนมสด 2

# %%
ch_regex = "นมข้น"
name = "นมข้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# นมข้นจืด 14

# %%
ch_regex = "มักกะโรนี|มะกะโรนีต้มสุก|มะกะโรนี"
name = "มักกะโรนี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มักกะโรนี 14
# เส้นมักกะโรนี 4
# มะกะโรนีต้มสุก 3
# มักกะโรนีต้มสุก 3
# มะกะโรนี 3
# เส้นมักกะโรนีต้มสุก 2
# เส้นมะกะโรนี 2

# %%
ch_regex = "อบเชย"
name = "อบเชย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# อบเชย 14

# %%
ch_regex = "ตับ"
name = "ตับ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตับหมู 13
# ตับ 4
# ตับไก่ 4

# %%
ch_regex = "หมูกรอบ"
name = "หมูกรอบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูกรอบ 13

# %%
ch_regex = "ผักโขม|ผักขม"
name = "ผักโขม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักโขม 13
# ผักขม 2

# %%
ch_regex = "เส้นจันทน์"
name = "เส้นจันทน์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นจันทน์ 2

# %%
ch_regex = "ใบเบย์"
name = "ใบเบย์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบเบย์ 2

# %%
ch_regex = "ปลาแผ่น"
name = "ปลาแผ่น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาแผ่น 2

# %%
ch_regex = "^มันหมู$"
name = "มันหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มันหมู 2

# %%
ch_regex = "ขาไก่"
name = "ขาไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขาไก่ 2

# %%
ch_regex = "แปะก๊วย"
name = "แปะก๊วย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แปะก๊วย 2

# %%
ch_regex = "วาซาบิ"
name = "วาซาบิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# วาซาบิ 2

# %%
ch_regex = "^ฟัก$"
name = "ฟัก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ฟัก 2

# %%
ch_regex = "ไทม์"
name = "ไทม์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไทม์ 2

# %%
ch_regex = "โคชูจัง"
name = "โคชูจัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โคชูจัง 12
# ซอสโคชูจัง 5

# %%
ch_regex = "ซีอิ๊วเห็ดหอม|ซีอิ้วเห็ดหอม"
name = "ซีอิ๊วเห็ดหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซีอิ๊วเห็ดหอม 12
# ซีอิ้วเห็ดหอม 5

# %%
ch_regex = "ไข่กุ้ง"
name = "ไข่กุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่กุ้ง 12

# %%
ch_regex = "^(?!.*น้ำพริก).*มันกุ้ง.*"
name = "มันกุ้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มันกุ้ง 12
# มันกุ้งเสวย 5

# %%
ch_regex = "^เต้าหู้(?!ไข่)"
name = "เต้าหู้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เต้าหู้ 12
# เต้าหู้เหลือง 9
# เต้าหู้ทอด 8
# เต้าหู้ขาว 7
# เต้าหู้แข็ง 4
# เต้าหู้หลอด 4
# เต้าหู้พวง 3
# เต้าหู้นิ่ม 3
# เต้าหู้อ่อน 3
# เต้าหู้ปลา 3
# เต้าหู้ขาวแข็ง 2
# เต้าหู้โมเมน 2

# %%
ch_regex = "ทูน่า"
name = "ทูน่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ทูน่าในน้ำแร่ 12
# ทูน่ากระป๋อง 6
# ปลาทูน่าในน้ำแร่ 6
# ทูน่า 5
# ทูน่ากระป๋องในน้ำแร่ 4
# ปลาทูน่า 2

# %%
ch_regex = "เบค่อน"
name = "เบค่อน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เบค่อน 12
# เบค่อนตามชอบ 2

# %%
ch_regex = "กระเฉด|ผักกะเฉด"
name = "ผักกระเฉด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักกระเฉด 11
# ผักกะเฉด 4

# %%
ch_regex = "เกี๊ยว"
name = "เกี๊ยว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แผ่นเกี๊ยว 11
# เกี๊ยวปลา 2

# %%
ch_regex = "สะตอ|สตอ"
name = "สะตอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# สะตอ 11
# สตอ 7

# %%
ch_regex = "ถั่วลิสง"
name = "ถั่วลิสง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วลิสงคั่ว 11
# ถั่วลิสง 9
# ถั่วลิสงป่น 6
# ถั่วลิสงบด 4
# ถั่วลิสงตำ 2
# ถั่วลิสงคั่วบด 2
# ถั่วลิสงคั่วป่น 2

# %%
ch_regex = "เส้นเล็ก|เส้นผัดไท"
name = "เส้นเล็ก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นเล็ก 11

# %%
ch_regex = "ซอสเทริยากิ|ซอสเทอริยากิ"
name = "ซอสเทริยากิ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสเทริยากิ 11
# ซอสเทอริยากิ 10

# %%
ch_regex = "เลือด"
name = "เลือด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เลือดไก่ 10
# เลือดหมู 3

# %%
ch_regex = "ฟักทอง"
name = "ฟักทอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ฟักทอง 10

# %%
ch_regex = "ใบกระวาน"
name = "ใบกระวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบกระวาน 10

# %%
ch_regex = "กุยช่าย|กุ้ยช่าย|กุ่ยช่าย|ใบกุ้ยฉ่าย"
name = "กุยช่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กุยช่าย 10
# กุ้ยช่าย 3
# ใบกุยช่าย 3
# กุ่ยช่าย 3
# ต้นกุยช่าย 2
# ใบกุ้ยฉ่าย 2
# ใบกุยช่ายหั่นท่อน 2
# ใบกุ่ยช่าย 2

# %%
ch_regex = "ผงกะหรี่|ผงกระหรี่"
name = "ผงกะหรี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงกะหรี่ 10
# ผงกระหรี่ 8

# %%
ch_regex = "มะเขือพวง"
name = "มะเขือพวง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือพวง 10

# %%
ch_regex = "มะเขือยาว"
name = "มะเขือยาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือยาว 10

# %%
ch_regex = "เส้นก๋วยเตี๋ยว"
name = "เส้นก๋วยเตี๋ยว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นก๋วยเตี๋ยว 9
# เส้นก๋วยเตี๋ยวหลอด 2
# เส้นก๋วยเตี๋ยวเล็ก 2

# %%
ch_regex = "น้ำพริก(?!เผา)|พริกหนุ่ม"
name = "น้ำพริก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำพริกกะปิ 9
# น้ำพริกตาแดง 8
# พริกหนุ่ม 4
# น้ำพริกหนุ่ม 2
# น้ำพริก 2
# น้ำพริกมันกุ้ง 2

# %%
ch_regex = "เม็ดมะม่วง"
name = "เม็ดมะม่วงหิมพานต์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เม็ดมะม่วงหิมพานต์ 8
# เม็ดมะม่วงหิมพานต์อบ 2
# เม็ดมะม่วงหิมพาน 2
# เม็ดมะม่วง 2

# %%
ch_regex = "^ข้าวโพด(?!อ่อน)|ผักสามสี"
name = "ข้าวโพด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักสามสี 9
# ข้าวโพด 8
# ข้าวโพดหวาน 7
# ข้าวโพดต้ม 4
# ข้าวโพดต้มสุก 4

# %%
ch_regex = "เส้นเซี่ยงไฮ้"
name = "เส้นเซี่ยงไฮ้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นเซี่ยงไฮ้ 2

# %%
ch_regex = "เส้นปลา|ปลาเส้น"
name = "ปลาเส้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นปลา 2
# ปลาเส้น 2

# %%
ch_regex = "บะหมี่(?!กึ่ง)|หมี่เหลือง|เส้นหมี่ฮกเกี้ยน|เส้นหมี่เหลือง|หมี่ฮ่องกง|เส้นเหลือง|หมี่หยก|หมี่เบตง|หมี่ฮกเกี้ยน|^เส้น$"
name = "บะหมี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นหมี่เหลือง 9
# บะหมี่ 8
# บะหมี่ผัก 8
# หมี่เหลือง 7
# บะหมี่ไข่ 6
# หมี่ฮ่องกง 4
# เส้นเหลือง 3
# เส้นหมี่ฮกเกี้ยน 3
# เส้นบะหมี่ 3
# เส้น 2
# บะหมี่ลวก 2
# หมี่หยก 2
# หมี่เบตง 2
# บะหมี่หยก 2
# บะหมี่เหลือง 2
# หมี่ฮกเกี้ยน 2

# %%
ch_regex = "หน่อไม้"
name = "หน่อไม้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หน่อไม้ดอง 8
# หน่อไม้ 7
# หน่อไม้ฝรั่ง 6
# หน่อไม้ต้ม 3
# หน่อไม้ฝอย 2
# หน่อไม้สด 2

# %%
ch_regex = "มะขามเปียก"
name = "มะขามเปียก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำมะขามเปียก 35
# มะขามเปียก 8

# %%
ch_regex = "แป้งอเนกประสงค์|แป้งสาลีอเนกประสงค์|แป้งสาลี|แป้งเอนกประสงค์"
name = "แป้งอเนกประสงค์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งอเนกประสงค์ 8
# แป้งสาลีอเนกประสงค์ 7
# แป้งสาลี 6
# แป้งเอนกประสงค์ 4
# แป้งสาลีเอนกประสงค์ 3

# %%
ch_regex = "ตั้งฉ่าย|ตังฉ่าย"
name = "ตั้งฉ่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตั้งฉ่าย 8
# ตังฉ่าย 4

# %%
ch_regex = "ดอกกะหล่ำ|กะหล่ำดอก|ดอกกระหล่ำ"
name = "ดอกกะหล่ำ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดอกกะหล่ำ 8
# กะหล่ำดอก 4
# ดอกกระหล่ำ 4

# %%
ch_regex = "พาสต้า|pasta"
name = "เส้นพาสต้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นพาสต้า 8
# พาสต้าดิบ 5
# พาสต้า 4
# pasta 2
# พาสต้าเอลิเก 2

# %%
ch_regex = "^ขนมปัง"
name = "ขนมปัง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ขนมปัง 8

# %%
ch_regex = "บล็อคโคลี่|บล๊อคโคลี่|บล็อคโครี่|บล๊อกโคลี่|บรอคคอลลี่|บร็อคโคลี่|บร๊อคโคลี่|บล็อกโคลี่"
name = "บล็อคโคลี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# บล็อคโคลี่ 8
# บล๊อคโคลี่ 5
# บล็อคโครี่ 2
# บล๊อกโคลี่ 2
# บรอคคอลลี่ 2
# บร็อคโคลี่ 2

# %%
ch_regex = "น้ำเชื่อม"
name = "น้ำเชื่อม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำเชื่อม 8

# %%
ch_regex = "น้ำจิ้มไก่"
name = "น้ำจิ้มไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มไก่ 8

# %%
ch_regex = "น้ำจิ้มไก่"
name = "น้ำจิ้มไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มไก่ 8

# %%
ch_regex = "หมี่ซั่ว"
name = "หมี่ซั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมี่ซั่ว 7
# เส้นหมี่ซั่ว 4

# %%
ch_regex = "โป๊ยกั๊ก"
name = "โป๊ยกั๊ก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โป๊ยกั๊ก 7

# %%
ch_regex = "น้ำกระเทียมดอง"
name = "น้ำกระเทียมดอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำกระเทียมดอง 7

# %%
ch_regex = "มะละกอ"
name = "มะละกอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะละกอ 7
# มะละกอสับ 3
# มะละกอขูด 2

# %%
ch_regex = "^(?!.*น้ำ).*มะพร้าว.*"
name = "มะพร้าว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะพร้าวคั่ว 7
# ยอดมะพร้าวอ่อน 3
# ยอดมะพร้าว 3

# %%
ch_regex = "ปู(?!อัด)"
name = "เนื้อปู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เนื้อปู 7
# ปูม้า 4
# ปูม้าสด 2
# เนื้อปูก้อน 2

# %%
ch_regex = "^(?!.*เป็ด).*พะโล้"
name = "เครื่องพะโล้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงพะโล้ 7
# เครื่องพะโล้ 4

# %%
ch_regex = "น้ำสต๊อก|น้ำสต็อก|น้ำสต้อค"
name = "น้ำสต๊อก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำสต๊อกหมู 7
# น้ำสต๊อก 5
# น้ำสต็อก 3
# น้ำสต้อค 2

# %%
ch_regex = "หมูหยอง"
name = "หมูหยอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูหยอง 7

# %%
ch_regex = "ตีนไก่"
name = "ตีนไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตีนไก่ 7

# %%
ch_regex = "สับปะรด|สัปปะรด"
name = "สับปะรด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# สับปะรด 7
# สัปปะรด 3

# %%
ch_regex = "ฟองเต้าหู้"
name = "ฟองเต้าหู้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ฟองเต้าหู้ 6
# ฟองเต้าหู้ทอดกรอบ 2

# %%
ch_regex = "น้ำสลัด"
name = "น้ำสลัด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำสลัด 6
# น้ำสลัดงาญี่ปุ่น 3
# น้ำสลัดงาคั่วญี่ปุ่น 2
# น้ำสลัดญี่ปุ่น 2

# %%
ch_regex = "มัสตาร์ด"
name = "มัสตาร์ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มัสตาร์ด 6

# %%
ch_regex = "พริกหวาน"
name = "พริกหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พริกหวาน 6
# พริกหวานหั่นเต๋า 4
# พริกหวานสีแดง 2

# %%
ch_regex = "มะระ"
name = "มะระ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะระ 6

# %%
ch_regex = "แครรอท"
name = "แครรอท"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แครรอท 6

# %%
ch_regex = "เก๋ากี้"
name = "เก๋ากี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เก๋ากี้ 6

# %%
ch_regex = "^(?!.*น้ำ|ซอส|ซอย|นำ้|ซอล|ไวไว|นํ้ามัน).*หอย.*"
name = "หอย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หอยเชลล์ 6
# หอยลาย 5
# หอยแมลงภู่ 5
# เนื้อหอยแมลงภู่ 3
# เนื้อหอยลาย 3
# หอยแมลงภู่นิวซีแลนด์ 3
# หอยแมลงภู่ต้มสุก 2
# หอยลายกระป๋อง 2
# หอยแครงลวก 2

# %%
ch_regex = "อุด้ง"
name = "เส้นอุด้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นอุด้ง 6

# %%
ch_regex = "^มะม่วง"
name = "มะม่วงดิบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะม่วงเปรี้ยว 6
# มะม่วงเบา 4
# มะม่วงแก้วขมิ้น 2
# มะม่วงสับ 2

# %%
ch_regex = "โครงไก่"
name = "โครงไก่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โครงไก่ 6
# ซี่โครงไก่ 2

# %%
ch_regex = "ข้าวไรซ์เบอรี่|ข้าวไรซ์เบอร์รี่"
name = "ข้าวไรซ์เบอรี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวไรซ์เบอรี่ 5
# ข้าวไรซ์เบอร์รี่ 4
# ข้าวไรซ์เบอร์รี่หุงสุก 3

# %%
ch_regex = "หมูแดง"
name = "หมูแดง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมูแดง 5

# %%
ch_regex = "โรสแมรี่"
name = "โรสแมรี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โรสแมรี่ 5
# โรสแมรี่อบแห้ง 2
# โรสแมรี่แห้ง 2

# %%
ch_regex = "ต้นอ่อนทานตะวัน|ยอดอ่อนทานตะวัน"
name = "ต้นอ่อนทานตะวัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ต้นอ่อนทานตะวัน 5
# ยอดอ่อนทานตะวัน 2

# %%
ch_regex = "เส้นยากิโซบะ"
name = "เส้นยากิโซบะ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นยากิโซบะ 5

# %%
ch_regex = "ลูกผักชี"
name = "ลูกผักชี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ลูกผักชี 5
# ลูกผักชีป่น 2

# %%
ch_regex = "ไส้อั่ว"
name = "ไส้อั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไส้อั่ว 5

# %%
ch_regex = "สะระแหน่|ใบสาระแหน่"
name = "ใบสะระแหน่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบสะระแหน่ 5
# สะระแหน่ 2
# ใบสาระแหน่ 2

# %%
ch_regex = "เส้นก๋วยจั๊บ"
name = "เส้นก๋วยจั๊บ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นก๋วยจั๊บ 5

# %%
ch_regex = "ผงฟู"
name = "ผงฟู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงฟู 5

# %%
ch_regex = "ฮอตดอก"
name = "ฮอตดอก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ฮอตดอก 5

# %%
ch_regex = "^(?!.*ลูกชิ้น|หมู).*เนื้อ(?!.*หมู|.*ไก่|กุ้ง|ปลา|ปู|หอย|เป็ด)"
name = "เนื้อ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เนื้อสับ 4
# เนื้อ 4
# เนื้อสัตว์ 4
# เนื้อวัว 4
# เนื้อวัวสับ 3
# เนื้อบด 3
# เนื้อวัวบด 2

# %%
ch_regex = "^แป้ง$|แป้งชุปทอด"
name = "แป้ง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้ง 4

# %%
ch_regex = "ซอสเย็นตาโฟ"
name = "ซอสเย็นตาโฟ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสเย็นตาโฟ 4
# น้ำซอสเย็นตาโฟ 2

# %%
ch_regex = "น้ำจิ้มซีฟู้ด"
name = "น้ำจิ้มซีฟู้ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำจิ้มซีฟู้ด 4

# %%
ch_regex = "แตงร้าน"
name = "แตงร้าน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แตงร้าน 4

# %%
ch_regex = "มะเขือม่วง"
name = "มะเขือม่วง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือม่วง 4

# %%
ch_regex = "กระดูกอ่อน"
name = "กระดูกอ่อน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระดูกอ่อน 4

# %%
ch_regex = "แป้งข้าวเจ้า"
name = "แป้งข้าวเจ้า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งข้าวเจ้า 4

# %%
ch_regex = "สาหร่าย"
name = "สาหร่าย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# สาหร่าย 4
# สาหร่ายแผ่น 2
# สาหร่ายแผ่นใหญ่ 2

# %%
ch_regex = "โยเกิร์ต"
name = "โยเกิร์ต"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โยเกิร์ตรสธรรมชาติ 4
# โยเกิร์ต 2

# %%
ch_regex = "(^ปลา(?!หมึก|กระป๋อง|ร้า|แผ่น|เส้น))|แซลมอน|เนื้อปลา"
name = "เนื้อปลา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ปลาทู 12
# ปลาทูน่าในน้ำแร่ 6
# ปลาสลิด 6
# ปลาทูนึ่ง 6
# ปลาอินทรีย์เค็ม 5
# ปลากระพง 5
# ปลาแซลมอน 4
# เนื้อปลา 4
# ปลาเค็ม 4
# ปลาซาบะ 4
# แซลมอน 4
# ปลานิล 4
# เนื้อปลาแซลมอน 4
# เนื้อปลาดอลลี่ 3
# ปลาสลิดทอด 3
# ปลากรอบ 3
# ปลาไข่ 3
# เนื้อปลาอินทรีย์ 3
# ปลาซุกิ 3
# ปลาช่อนหั่น 2
# ปลาทูทอด 2
# ปลาทูมัน 2
# ปลาทอด 2
# ปลาดอลลี่ 2
# ปลาแซลม่อน 2
# ปลาดุกย่าง 2
# เนื้อปลาทับทิม 2
# ปลาสลิดแดดเดียว 2
# ปลาทูน่า 2

# %%
ch_regex = "ผงขมิ้น|^ขมิ้น$"
name = "ผงขมิ้น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผงขมิ้น 4
# ขมิ้น 2

# %%
ch_regex = "ก้านพลู"
name = "ก้านพลู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ก้านพลู 4

# %%
ch_regex = "เส้นบุก"
name = "เส้นบุก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นบุก 4

# %%
ch_regex = "แขนง"
name = "ผักแขนง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักแขนง 4
# แขนง 2

# %%
ch_regex = "ซอสภูเขา"
name = "ซอสภูเขา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสภูเขา 4
# ซอสภูเขาทอง 3
# ซอสภูเขาฝาเขียว 3
# ซอสภูเขาทองฝาเขียว 2

# %%
ch_regex = "เครื่องใน"
name = "เครื่องใน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เครื่องในไก่ 4

# %%
ch_regex = "ยี่หร่า|ผง cumin"
name = "ยี่หร่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ยี่หร่าป่น 4
# ยี่หร่า 4
# ใบยี่หร่า 3
# ผง cumin 2

# %%
ch_regex = "โบโลน่า"
name = "โบโลน่า"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โบโลน่า 4
# โบโลน่าพริก 2

# %%
ch_regex = "หัวปลี"
name = "หัวปลี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หัวปลี 4

# %%
ch_regex = "ครีม"
name = "ครีม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ครีม 4
# วิปครีม 3
# วิปปิ้งครีม 3

# %%
ch_regex = "^กากหมู$"
name = "กากหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กากหมู 4

# %%
ch_regex = "กระเพาะปลา"
name = "กระเพาะปลา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# กระเพาะปลา 4

# %%
ch_regex = "ไวน์ขาว"
name = "ไวน์ขาว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไวน์ขาว 4

# %%
ch_regex = "ถั่วหวาน"
name = "ถั่วหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วหวาน 3

# %%
ch_regex = "แป้งท้าวยายม่อม|แป้งท้าว|แป้งเท้า"
name = "แป้งท้าวยายม่อม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งท้าวยายม่อม 4
# แป้งท้าว 3
# แป้งเท้า 2

# %%
ch_regex = "หมี่กรอบ"
name = "หมี่กรอบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หมี่กรอบ 3

# %%
ch_regex = "ตำลึง"
name = "ตำลึง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ตำลึง 3

# %%
ch_regex = "ซอสเพสโต้"
name = "ซอสเพสโต้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซอสเพสโต้ 3

# %%
ch_regex = "เครื่องแกงเขียวหวาน"
name = "เครื่องแกงเขียวหวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เครื่องแกงเขียวหวาน 3

# %%
ch_regex = "หนำเลี๊ยบ"
name = "หนำเลี๊ยบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# หนำเลี๊ยบ 3

# %%
ch_regex = "ข้าวเหนียว"
name = "ข้าวเหนียว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวเหนียว 3

# %%
ch_regex = "ดอกหอม"
name = "ดอกหอม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดอกหอม 3

# %%
ch_regex = "^(?!เบคกิ้ง)โซดา|น้ำโซดา"
name = "โซดา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โซดา 3
# น้ำโซดา 2

# %%
ch_regex = "ถั่วพู"
name = "ถั่วพู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วพู 3

# %%
ch_regex = "เส้นแก้ว"
name = "เส้นแก้ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เส้นแก้ว 3

# %%
ch_regex = "เครื่องต้มยำ"
name = "เครื่องต้มยำ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เครื่องต้มยำ 3

# %%
ch_regex = "เผือก"
name = "เผือก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เผือก 3

# %%
ch_regex = "ก้อนแกงกะหรี่ญี่ปุ่น"
name = "ก้อนแกงกะหรี่ญี่ปุ่น"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ก้อนแกงกะหรี่ญี่ปุ่น 3

# %%
ch_regex = "โปรตีนเกษตร"
name = "โปรตีนเกษตร"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# โปรตีนเกษตร 3

# %%
ch_regex = "บ๊วยดอง"
name = "บ๊วยดอง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# บ๊วยดอง 3

# %%
ch_regex = "ไชโป๊ว"
name = "หัวไชโป้ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไชโป๊ว 3
# หัวไชโป๊ว 2
# ไชโป๊วสับ 2

# %%
ch_regex = "แคปหมู"
name = "แคปหมู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แคปหมู 3

# %%
ch_regex = "พาร์สลีย์|พาสลี่|พาสลีย์|parsley"
name = "พาร์สลีย์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# พาร์สลีย์ 3
# พาสลี่ 2
# พาสลีย์ 2
# parsley 2
# พาสลีย์สับ 2
# พาสลีย์แห้ง 2

# %%
ch_regex = "บวบ"
name = "บวบ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# บวบ 3
# บวบเหลี่ยม 2

# %%
ch_regex = "ใบเตย"
name = "ใบเตย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบเตย 3

# %%
ch_regex = "ใบเหลียง"
name = "ใบเหลียง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบเหลียง 3

# %%
ch_regex = "เบคกิ้งโซดา"
name = "เบคกิ้งโซดา"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เบคกิ้งโซดา 3

# %%
ch_regex = "^(?!ไข่)เป็ด|เนื้อเป็ด|อกเป็ด"
name = "เนื้อเป็ด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เป็ดย่าง 3
# เป็ด 2
# เป็ดพะโล้ 2
# เนื้อเป็ด 2
# อกเป็ด 2

# %%
ch_regex = "แมงลัก"
name = "ใบแมงลัก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบแมงลัก 3

# %%
ch_regex = "^ถั่ว$|ถั่วป่น|ถั่วคั่ว"
name = "ถั่ว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วป่น 3
# ถั่ว 2
# ถั่วคั่ว 2

# %%
ch_regex = "^มะเขือ$"
name = "มะเขือ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะเขือ 3

# %%
ch_regex = "ไก่จ๊อ"
name = "ไก่จ๊อ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไก่จ๊อ 2

# %%
ch_regex = "ถั่วแดง"
name = "ถั่วแดง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วแดง 2

# %%
ch_regex = "ดอกไม้กวาด"
name = "ดอกไม้กวาด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดอกไม้กวาด 2

# %%
ch_regex = "Angel Hair|เส้นแองเจิลแฮร์|เส้น angel hair"
name = "แคปเปลลินี"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# Angel Hair 2
# เส้น angel hair 2
# เส้นแองเจิลแฮร์ 2

# %%
ch_regex = "แป้งพิซซ่าสำเร็จ"
name = "แป้งพิซซ่าสำเร็จ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งพิซซ่าสำเร็จ 2

# %%
ch_regex = "ควินัว|คีนัว"
name = "ควินัว"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ควินัวหุงสุก 2
# คีนัว 2

# %%
ch_regex = "น้ำเลม่อน"
name = "น้ำเลม่อน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำเลม่อน 2

# %%
ch_regex = "เครื่องยาจีน"
name = "เครื่องยาจีน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เครื่องยาจีน 2

# %%
ch_regex = "ข้าวโอ๊ต"
name = "ข้าวโอ๊ต"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ข้าวโอ๊ต 2

# %%
ch_regex = "ดอกชมจันทร์"
name = "ดอกชมจันทร์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดอกชมจันทร์ 2

# %%
ch_regex = "เยื่อไผ่"
name = "เยื่อไผ่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เยื่อไผ่ 2

# %%
ch_regex = "แป้งต็อก"
name = "แป้งต็อก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แป้งต็อก 2

# %%
ch_regex = "^มะกอก"
name = "มะกอก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มะกอกดำ 2
# มะกอก 2

# %%
ch_regex = "เครื่องแกงใต้"
name = "เครื่องแกงใต้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เครื่องแกงใต้ 2

# %%
ch_regex = "ใบชะพลู"
name = "ใบชะพลู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบชะพลู 2

# %%
ch_regex = "มาการีน"
name = "มาการีน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# มาการีน 2
# เนยมาการีน 2

# %%
ch_regex = "^แกงกะหรี่|กะหรี่แกง"
name = "แกงกะหรี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# แกงกะหรี่ 2

# %%
ch_regex = "ใบยอ"
name = "ใบยอ"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ใบยอ 2

# %%
ch_regex = "น้ำบูดู"
name = "น้ำบูดู"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำบูดู 2

# %%
ch_regex = "ไข่ปลาหมึก"
name = "ไข่ปลาหมึก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ไข่ปลาหมึก 2

# %%
ch_regex = "ดีปลีผง"
name = "ดีปลีผง"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดีปลีผง 2

# %%
ch_regex = "เครื่องตุ๋นยาจีน"
name = "เครื่องตุ๋นยาจีน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เครื่องตุ๋นยาจีน 2

# %%
ch_regex = "เซี่ยงจี้"
name = "เซี่ยงจี้"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เซี่ยงจี้ 2

# %%
ch_regex = "น้ำอ้อย"
name = "น้ำอ้อย"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# น้ำอ้อย 2

# %%
ch_regex = "เพนเน่"
name = "เพนเน่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# เพนเน่ 2
# เส้นเพนเน่ 2

# %%
ch_regex = "ดอกโสน"
name = "ดอกโสน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ดอกโสน 2

# %%
ch_regex = "ซุคคีนี"
name = "ซูกินี่"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ซุคคีนี 2

# %%
ch_regex = "ยีสต์"
name = "ยีสต์"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ยีสต์ 2

# %%
ch_regex = "ผักขม"
name = "ผักขม"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ผักขม 2

# %%
ch_regex = "ถั่วแขก"
name = "ถั่วแขก"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)
# Out:
# ถั่วแขก 2

# %%
ch_regex = "ลูกกระวาน"
name = "ลูกกระวาน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)

# %%
ch_regex = "น้ำอาจาด"
name = "น้ำอาจาด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)

# %%
ch_regex = "ข้าวมัน"
name = "ข้าวมัน"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)

# %%
ch_regex = "มันบด"
name = "มันบด"
all_facility_unique,example = search_fsc(all_facility_unique,ch_regex)
make_table(name,ch_regex,example)

# %%
print(sum([1 for i in all_facility_unique if i[2] == 0]))
for i in all_facility_unique:
    if i[2] == 0 and i[1] > 1:
        print(i[0],i[1])
# Out:
# 780
# แผ่นเกี้ยว 2
# ผักกะหล่ำ 2
# เครื่องเคียง 2
# เครื่องแกง 2
# ต้น 2

# %%
d = {'Type_fcs': df_name, 'RegEx': df_ch_regex, 'Example':df_example}
df = pd.DataFrame(data=d)
# df.to_excel('FCS_RegEx.xlsx' ,index=False)
df
# Out:
#       Type_fcs                                              RegEx  \
# 0       น้ำปลา                                      น้ำปลา(?!ร้า)
# 1     กระเทียม  ^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม|กระเท...
# 2       ไข่ไก่                 ^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))|ไก่ไข่
# 3       น้ำตาล                      น้ำตาล(?!หญ้าหวาน)|นำ้ตาลทราย
# 4        เกลือ                                    เกลือ|salt|เกลอ
# ..         ...                                                ...
# 290    ถั่วแขก                                            ถั่วแขก
# 291  ลูกกระวาน                                          ลูกกระวาน
# 292   น้ำอาจาด                                           น้ำอาจาด
# 293    ข้าวมัน                                            ข้าวมัน
# 294      มันบด                                              มันบด
#
#                                                Example
# 0    น้ำปลา, น้ำปลาอย่างดี, น้ำปลาดี, น้ำปลาไส้ตัน,...
# 1    กระเทียม, กระเทียมสับ, กระเทียมเจียว, กระเทียม...
# 2    ไข่ไก่, ไข่, ไข่ต้ม, ไข่เค็ม, ไข่แดง, ไข่ขาว, ...
# 3    น้ำตาลทราย, น้ำตาล, น้ำตาลปี๊บ, น้ำตาลทรายแดง,...
# 4    เกลือ, เกลือป่น, เกลือเม็ด, เกลือชมพู, เกลือแก...
# ..                                                 ...
# 290                                            ถั่วแขก
# 291
# 292
# 293
# 294
#
# [295 rows x 3 columns]

# %%
import sys
from pathlib import Path

# in jupyter (lab / notebook), based on notebook path
module_path = str(Path.cwd().parents[0])

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from dictionary.all_ingredients_unit_map import all_ingredients_unit_map

# %%
tmp_dict = {}

if __name__ == '__main__':
  for i,regex in enumerate(df_ch_regex):
    for key in all_ingredients_unit_map.keys():
      if not re.search(regex,key):
        continue
      if regex not in tmp_dict:
        tmp_dict[regex] = set()
      tmp_dict[regex].update(all_ingredients_unit_map[key])

for k in tmp_dict:
  tmp_dict[k] = list(tmp_dict[k])

tmp_dict
# Out:
# {'น้ำปลา(?!ร้า)': ['',
#   'เหยาะๆลงไป',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'มิลลิกรัม',
#   'ช.ต',
#   'เหยาะ',
#   'ตามใจ',
#   'ชช.',
#   'ช้อนทานข้าว',
#   'นิดนึง',
#   'ช้อนโต๊ะ',
#   'ซ้อนชา',
#   'tbs ตามชอบ',
#   'กรัม',
#   'กระบวย',
#   'tbs',
#   'ml.',
#   'ปรุงรสตามชอบ',
#   'ทัพพี',
#   'ขะยอก',
#   'ช.ต.',
#   'ตามใจชอบ',
#   'ชต.',
#   'ปรุงรส',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ช่อนชา',
#   'พอ',
#   'ขยอก',
#   'ชต',
#   'ขวด',
#   'ช้อนโต็ะ',
#   'ปรุงรสเล็กน้อย',
#   'ช็อนโต๊ะ',
#   'ช้อยชา',
#   'แล้วแต่ชอบ',
#   'นิดหน่อย',
#   'ปรุงรสตามใจชอบ',
#   'ถ้วย',
#   'ช้อรโต๊ะ',
#   'ช้อนชา /  ช้อนโต๊ะ',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'ช้อนใหญ่',
#   'เล็กน้อย',
#   'ลต',
#   'ชช',
#   'ชิมตามชอบ',
#   'ช้อน',
#   'ช้อนชา'],
#  '^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม|กระเทียวเจียว|กระเทียบ|กระทียมสับ|garlic|^น้ำจิ้ม กระเทียม$': ['',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'ช.ต',
#   'กลีบใหญ่',
#   'กลีบเล็ก',
#   'กรัมมือ',
#   'ชัอนโต๊ะ',
#   'ตามชอบใจ',
#   'ชช.',
#   'ถ้าชอบ',
#   'บาท',
#   'ช้อนแกง',
#   'กลีบกลาง',
#   'ช้อนโต๊ะ',
#   'Cloves',
#   'กรัม',
#   'กลับ',
#   'กระบวย',
#   'นิด',
#   'ช้อนดต๊ะ',
#   'ซีก',
#   'ทัพพี',
#   'กลีบ',
#   'ช.ต.',
#   'กีบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'กลีบกลางๆ',
#   'โรยหน้า',
#   'หัว',
#   'กลีบบุบ',
#   'ช้อนโต๊',
#   'ตามต้องการ',
#   'ชต',
#   'กำมือใหญ่ๆ ตามชอบ',
#   'ช็อนโต๊ะ',
#   'แพ็คเล็ก',
#   'แล้วแต่ชอบ',
#   'หัวใหญ่',
#   'นิดหน่อย',
#   'กีบใหญ่',
#   'pieces',
#   'หยิบมือ',
#   'ถ้วย เล็ก',
#   'กำ',
#   'ถ้วย',
#   'ตามความชอบ',
#   'แก้ว',
#   'ปริมาณตามชอบ',
#   'เม็ด',
#   'ตามชอบ',
#   'g',
#   'หัวเล็ก',
#   'ขีด',
#   'หัวทุบ',
#   'เล็กน้อย',
#   'ช้อนโต๊ะขึ้นไป',
#   'กรีบ',
#   'กำมือ',
#   'ชช',
#   'ช้อน',
#   'ช้อนชา'],
#  '^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))|ไก่ไข่': ['',
#   'บาท',
#   'ฟอง ผ่าซีก',
#   'kg',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ฟ.',
#   'มล',
#   'ตามใจชอบ',
#   'ชต.',
#   'ลูก',
#   'พวง',
#   '. ฟอง',
#   'จากไข่ไก่  ฟอง',
#   'ฟอง',
#   'ใบ',
#   'คลึ่งลูก',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ตามชอบ',
#   'ฟองต่อชาม',
#   'เม็ด',
#   'g.',
#   'ฟองใหญ่'],
#  'น้ำตาล(?!หญ้าหวาน)|นำ้ตาลทราย': ['',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'ช.ต',
#   'tbsp',
#   '. ช้อนชา',
#   'ชัอนชา',
#   'ตามใจ',
#   'ช.ช.',
#   'ชช.',
#   'ชช. พูน',
#   'ข้อนโต๊ะ',
#   'ช้อนทานข้าว',
#   'นิดนึง',
#   'kg',
#   'กระบวน',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'ใช้ปรุงรส',
#   'ชิ้นเล็กๆ',
#   'กรัม',
#   'ปรุงรสตามชอบ',
#   'ทัพพี',
#   'เหยาะนิดหน่อย',
#   'น้ำตาลปิ้บ  ถ้วย',
#   'ช.ต.',
#   '. ชต',
#   'ชต.',
#   'tsp',
#   'ช้อนช้า',
#   'ตามใจชอบ',
#   'ช.',
#   'หยิบเล็ก',
#   'ปลายช้อนชา',
#   'ช่อนชา',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ช้อนชาพูน',
#   'ปลายช้อน',
#   'ชต',
#   'ชต. ชช.',
#   'ช้อนโต็ะ',
#   'ใส่แค่ปลายช้อน',
#   'ช้อน โต๊ะ',
#   'ช็อนโต๊ะ',
#   'ช้อนโตผ๊ะ',
#   'นิดหน่อย',
#   'ถต.',
#   'ปรุงรสตามใจชอบ',
#   'หยิบมือ',
#   'ปรุงรส',
#   'ถ้วย',
#   'ช.ช',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ปลายหยิบมือ',
#   'เม็ด',
#   'ความชอบ',
#   'ช้อนใหญ่',
#   'ขีด',
#   'เล็กน้อย',
#   'ก้อน',
#   'ชช',
#   'โต๊ะ',
#   'ชิมตามชอบ',
#   'ช้อน',
#   'ช้อนชา'],
#  'เกลือ|salt|เกลอ': ['ประมาน  ช้อน',
#   '',
#   'ช้อนโต้ะ',
#   'ช้นชา',
#   'กระป๋อง',
#   'ช.ช.',
#   'กระจับมือ',
#   './ช้อนชา',
#   'ชช.',
#   'ชต ชช',
#   'นิดนึง',
#   'กะเอา',
#   'ช้อนโต๊ะ',
#   'ชุด',
#   'กรัม',
#   'นิด',
#   'tbs',
#   'ไม่ช้อนชา',
#   'ปรุงรสตามชอบ',
#   'ทัพพี',
#   'tps',
#   'ปรุงรส',
#   'ชต.',
#   'ตามใจชอบ',
#   'ปลายช้อนชา',
#   'ts',
#   'พอ',
#   'ตามต้องการ',
#   'ปลายช้อน',
#   'ชต',
#   'ถุง',
#   'หยิบนิ้วมือ',
#   'หยิบ',
#   'ปรุงรสเล็กน้อย',
#   'สำหรับปรุงรส',
#   'นิดหน่อย',
#   'ชช',
#   'หนึ่งหยิบมือ',
#   'ดอก',
#   'ชข.',
#   'หยิบมือ',
#   'ตามความชอบ',
#   'ช.ช',
#   'ถ้วย',
#   'กิโลกรัม',
#   'ช้อนชา /  ช้อนโต๊ะ',
#   'ปลายหยิบมือ',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'grams',
#   'โรยบางๆพอค็มปะเเล่ม',
#   'เล็กน้อย',
#   'กำมือ',
#   'หยิมมือ',
#   'ช้อน',
#   'ช้อนชา'],
#  'ซอสปรุงรส|ซอสฝาเขียว|ซอสฝาเหลือง|ซอสแมคกี้|ซอสแม็กกี้|ซอสข้นปรุงรสคนอร์|แม๊กกี้|ซอส|แม็กกี้|คนอร์ซอสข้นปรุงรสหมู|ซอสข้นคนอร์|ซอลปรุงรส|แมกกี้|ซ้อสปรุงรส': ['',
#   'เหยาะๆลงไป',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'mm',
#   'tbsp',
#   'กระป๋อง',
#   'เหยาะ',
#   'หมดขวด/รูป',
#   'ตามใจ',
#   'ช้ินชา',
#   'ชช.',
#   'ข้อนโต๊ะ',
#   'โรงรถไซให้ได้รถตามชอบ',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'กรัม',
#   'กระบวย',
#   'tbs',
#   'กป.',
#   'ทัพพี',
#   'หยด',
#   'ช.ต.',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช.',
#   'ช้อนโต๊',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ซอง',
#   'ตามต้องการ',
#   'ชต',
#   'ขวดเล็ก',
#   'ช้อร',
#   'ขวด',
#   'ถุง',
#   'เหยาะเพิ่มความหอม',
#   'ซ้อนโต๊ะ',
#   'แล้วแต่ชอบ',
#   'ห่อ',
#   'นิดหน่อย',
#   'mL',
#   'ช้อนา',
#   'ถ้วย',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'ความชอบ',
#   'เล็กน้อย',
#   'ชช',
#   'โต๊ะ',
#   'ช้อน',
#   'ช้อนชา'],
#  'น้ำมันหอย|ซอสหอย|ซอยหอยนางรม|นำ้มันหอย|ซอลหอยนางรม|นํ้ามันหอย': ['',
#   'เหยาะๆลงไป',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'ช.ต',
#   'tbsp',
#   'เหยาะ',
#   'ตามใจ',
#   'ชช.',
#   'ข้อนโต๊ะ',
#   'โรงรถไซให้ได้รถตามชอบ',
#   'ช้อนโต๊ะ',
#   'ใช้ปรุงรส',
#   'กรัม',
#   'กระบวย',
#   'tbs',
#   'ปรุงรสตามชอบ',
#   'ทัพพี',
#   'ช.ต.',
#   'ชต.',
#   'ชอนโต๊ะ',
#   'ช้อนโต๊',
#   'ช่อนชา',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ช้อยโต๊ะ',
#   'ชต',
#   'ช้อนโต',
#   'ซ้อนโต๊ะ',
#   'นิดหน่อย',
#   'ถต.',
#   'ช้อนา',
#   'อย่างละ  ช้อนชา',
#   'ข้อนชา',
#   'ถ้วย',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'เล็กน้อย',
#   'ชช',
#   'ช้อน',
#   'ช้อนชา'],
#  'น้ำมัน(?!(หอย|พริกเผา|งา))|olive oil|oil': ['',
#   'กะให้พอท่วมหนังปลา',
#   'มิลลิกรัม',
#   'มล.',
#   'กระฉอกใหญ่',
#   'สำหรับผัด',
#   'ชช.',
#   'ถ้วย   ชต',
#   'กรัม',
#   'ใช้ผัด',
#   'ทัพพีเล็ก',
#   'ขวดเล็ก',
#   'ช้อยชา',
#   'กะทะ',
#   'ช้อนชา',
#   'ถ้วยตวง',
#   'กระทะ',
#   'พอท่วม',
#   'สำหรับทอด',
#   'ml.',
#   'ชต.',
#   'ถต',
#   'กระปุก',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'เล็กน้อยสำหรับทอด',
#   'พอ',
#   'ซอง',
#   'ชต',
#   'กระฉอกเล็ก',
#   'ถ้วย   ช้อนโต๊ะ',
#   'ช้อนกินข้าว',
#   'mL',
#   'ถ้วย',
#   'ตามเหมาะสม',
#   'g',
#   'ตามชอบ',
#   'cc',
#   'เล็กน้อย',
#   'ช้อนโตีะ',
#   'กะเองนะ',
#   'ชช',
#   'พอท่วมกระเทียม',
#   'ตามชอบค่ะ',
#   'ช้อนโต๊ะ',
#   'แค่พอเคลือบกระทะ',
#   'กระบวย',
#   'tbs',
#   'กะให้ท่วมหมูขึ้นมาหน่อย',
#   'ใส่พอท่วมไข่',
#   'ทัพพี',
#   'tps',
#   'ช.ต.',
#   'มิลลิลิตร',
#   'ขวด',
#   'ฉีด',
#   'ช็อนโต๊ะ',
#   'ช้อโต๊ะ',
#   'ช้อนโต๊ะสำหรับเจียวกระเทียมและทอดปลาหมึกฝอย',
#   'นิดหน่อย',
#   'ถต.',
#   'ช้อนโต้ะ',
#   'ช.ต',
#   'ถ้วยเล็ก',
#   '. ช้อนชา',
#   'กระป๋อง',
#   'tbsp',
#   'ปริมาณแล้วแต่ชิ้นหมู ถ้าหมูชิ้นใหญ่ควรท่วมเนื้อหมู',
#   'ช้อนช้า',
#   'ช้อนโต๊',
#   'ช้อนโต๊ะ   ช้อนโต๊ะ',
#   'ml',
#   'คลุกเส้นหลังลวก',
#   'ของกระทะ',
#   'ใช้ทอด',
#   'oz',
#   'ลิตร',
#   'สเปรย์',
#   'ช้อน'],
#  'น้ำเปล่า|น้ำสะอาด|น้ำต้มสุก|^น้ำ$|น้ำเย็น|น้ำร้อน|น้ำดื่ม|น้ำอุ่น|น้ำสำหรับต้มเส้น': ['',
#   'แก้วเล็ก',
#   'ถ้วยตวง',
#   'มล.',
#   'ถ้วยเล็ก',
#   'กระทะ',
#   'ท่วมหมู',
#   'ขวดน้ำใหญ่',
#   'ถ้วย ช้อนโต๊ะ',
#   'สำหรับต้ม',
#   'สำหรับต้มเส้น',
#   'ถ้วยตวงข้าว',
#   'มิลลิเมตร',
#   'กรัม   กรัม',
#   'ช้อนโต๊ะ',
#   'พอท่วม',
#   'กะเอา',
#   'กรัม',
#   'กระบวย',
#   'tbs',
#   'ml.',
#   ',มิลลิลิตร',
#   'ทัพพี',
#   'พอเหมาะ',
#   'ถ้วน',
#   'มล',
#   'ช.ต.',
#   'มิลลิลิตร',
#   'ตามใจชอบ',
#   'ชต.',
#   'สำหรับลวกเส้น',
#   'แก้วกาแฟ',
#   'ถต',
#   'ต้มเส้น',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ml',
#   'สำหรับ',
#   'พอ',
#   'ชต',
#   'ทัพพีเล็ก',
#   'ขวด',
#   'ถ้วยน้ำจิ้ม',
#   'หม้อ',
#   'ใส่ท่วมหมู',
#   'ม.ล',
#   'ช้อน',
#   'นิดหน่อย',
#   'ถต.',
#   'ข้อนิ้ว',
#   'มิลลิลตร',
#   'ใส่/ซอส',
#   'ถ้าย',
#   'ก้อน',
#   'ข้อนชา',
#   'ถ้วย',
#   'กิโลกรัม',
#   'แก้ว',
#   'ลิตร',
#   'ตามชอบ',
#   'ชาม',
#   'ตามความเหมาะสม',
#   'cc',
#   'ขัน',
#   'พอท่วมไก่',
#   'เล็กน้อย',
#   'ขวดใหญ่',
#   'g.',
#   'ช้อนชา'],
#  'ซีอิ๊วขาว|ซีอิ้วขาว|ซอสถั่วเหลือง|ซีอิ๋วขาว|สี่อิ๋วขาวสูตร1|ซีอิ้วปรุงรส|^ซีอิ๊ว$|ซี๊อิ๋วขาว|ซีอิ้ว ขาว|ซีอิ้ว|ชีอิ้วขาว|ซี้อิ้วขาว|ซีอี๊วขาว|ชีอิ๊วขาว|ซีอิ๋ว|ซี่อิ๋วขาวสูตร1|สี่อิ๋วขาวสูตร 2|soy sauce|ซีอี้วขาว|ซีอี๋วขาว|สี่อิ๋วขาวสูตร|สี่อิ่ว': ['',
#   'เหยาะๆลงไป',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'tbsp',
#   'เหยาะ',
#   'ตามใจ',
#   'ขาว',
#   'นิดนึง  หยด',
#   'ช้วนโต๊ะ',
#   'ชช.',
#   'ช้อนโต๊ะ ตามชอบ',
#   'ข้อนโต๊ะ',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'พอให้หมูมีสี',
#   'ใช้ปรุงรส',
#   'กรัม',
#   'กระบวย',
#   'tbs',
#   'ปรุงรสตามชอบ',
#   'ทัพพี',
#   'ช.ต.',
#   'ชต.',
#   'ช้อนช้า',
#   'ช้อนโต๊',
#   'พอ',
#   'ชต',
#   'ปรุงรสเล็กน้อย',
#   'แล้วแต่ชอบ',
#   'ห่อ',
#   'นิดหน่อย',
#   'ถต.',
#   'นิดหน่อยเพิ่มสีสัน',
#   'ซ้อนโต้ะ',
#   'อย่างละ  ช้อนชา',
#   'ข้อนชา',
#   'ถ้วย',
#   'ช่อนโต๊ะ',
#   'ช้อนขาว',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'ตามชอบเพิ่มสีสัน',
#   'เล็กน้อย',
#   'ช',
#   'ชช',
#   'โต๊ะ',
#   'ช้อน',
#   'ช้อนชา'],
#  '^(?!.*ซอส|หมู).*พริกไทย.*|พริกไท|black pepper|Red Pepper Flakes': ['',
#   'หนึ่งช้อนโต๊ะ',
#   'ช้อนโต้ะ',
#   'กก',
#   'ส.',
#   'ใส่ตามชอบ',
#   'เหยาะ',
#   'ช.ช.',
#   'บด',
#   'ชช.',
#   'สำหรับโรย',
#   'หน่อย',
#   'ท่อนใบตอง',
#   'พวงเล็ก',
#   'โรงรถไซให้ได้รถตามชอบ',
#   'อก',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'กรัม',
#   'เล็กน้อย ตามชอบ',
#   'ปรุงรสตามชอบ',
#   'ฟัก',
#   'ฝัก',
#   'โรยหน้า',
#   'ตามสะดวก',
#   'ปรุงรส',
#   'ชต.',
#   'ตามใจชอบ',
#   'ช้อนช้า',
#   'หัว',
#   'ตามชอบใจกับปริมาณให้เหมาะสมกับเนื้อสัตว์',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ts',
#   'ตามใจฉัน',
#   'ก้าน',
#   'ช่อนชา',
#   'พอ',
#   'ซอง',
#   'ปลายช้อน',
#   'ชต',
#   'ห่อเล็ก',
#   'ปรุงรสเล็กน้อย',
#   'หยิบ',
#   'พวง',
#   '/ช้อนชา',
#   'ช่อ',
#   'แล้วแต่ชอบ',
#   'ห่อ',
#   'สำหรับปรุงรส',
#   'นิดหน่อย',
#   'เหยาะหน้าก๋วยเตี๋ยว',
#   'หยิบมือ',
#   'ตามความชอบ',
#   'ถ้วย',
#   'เสี้ยวช้อนโต๊ะ',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'เม็ด',
#   'ขีด',
#   'เล็กน้อย',
#   'หลายๆเหยาะ',
#   'แพ็ก',
#   'นิดหน่อย แล้วแต่ชอบ',
#   'ตามชอ',
#   'กิ่ง',
#   'กำมือ',
#   'ชช',
#   'ช้อน',
#   'ช้อนชา'],
#  'ต้นหอม|ต้มหอม|ตันหอม': ['',
#   'ตามชอบค่ะ',
#   'ส.',
#   'ถ้วยเล็ก',
#   'ชช.',
#   'ถ้าชอบ',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'ตกแต่ง',
#   'ซอย',
#   'กรัม',
#   'ต้น',
#   'ถ้า',
#   'ไว้แต่งจาน',
#   'โรยหน้า',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'ตามต้องการ',
#   'อย่างละ ต้น',
#   'ชต',
#   'ต้น ตามชอบ',
#   'สำหรับโรยหน้า',
#   'แล้วแต่ชอบ',
#   'กำเล็ก',
#   'นิดหน่อย',
#   'ถต.',
#   'ไม่ต้องใส่เยอะมาก',
#   'นิ้ว',
#   'หยิบมือ',
#   'ใบ',
#   'ต้น หั่นท่อน',
#   'กำ',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ตามชอบ',
#   'ถ้ากิน',
#   'ท่อน',
#   'ขีด',
#   'เล็กน้อย',
#   'มัด',
#   'กำมือ',
#   'ช้อนชา'],
#  'แครอท|แคร์รอต|แครท|ผักสามสี': ['',
#   'ถ้วยตวง',
#   'มล.',
#   'ถ้วยเล็ก',
#   'ต้นเล็ก',
#   'ชิ้น',
#   'ผล',
#   'แท่ง',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม',
#   'ต้น',
#   'อย่างละ ช้อน',
#   'แผ่น',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'อัน',
#   'พอ',
#   'ตามต้องการ',
#   'ลูก',
#   'ชต',
#   'ขึด',
#   'หยิบ',
#   'นึง',
#   'หัวใหญ่',
#   'นิดหน่อย',
#   'นิ้ว',
#   'หยิบมือ',
#   'เหลืออยู่ก็กินต่อให้หมด',
#   'กำ',
#   'ถ้วย',
#   'แว่น',
#   'ตามชอบ ไม่ขอบไม่ใส่ก็ได้',
#   'g',
#   'ตามชอบ',
#   'ท่อน',
#   'ชค.',
#   'นิดนึงตามชอบ',
#   'หัวเล็ก',
#   'ขีด',
#   'ชตใ',
#   'เล็กน้อย',
#   'กำมือ',
#   'ช้อนชา'],
#  '^(?!.*บะหมี่|ผง|กระดูก|ลูกชิ้น|ซี่โครง|ตับ|น้ำมัน|น้ำสต๊อก|คนอร์|แหนม|กุนเชียง|กาก|รสดี|ซุป|น้ำ|แคป|ซอส|มัน|กระเทียม|ไส้กรอก|เลือด|แฮม).*หมู(?!ยอ|กรอบ|หยอง|แดง|แฮม).*|สามชั้นสไลซ์|สันคอ': ['',
#   'KG',
#   'กก',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'ตามใจขอบเลยจ้า',
#   'ไม้',
#   'กรัม ตามชอบ',
#   'ชช.',
#   'ก.ก.',
#   'ข้อนโต๊ะ',
#   'แพ๊ค',
#   'นิดนึง',
#   'บาท',
#   'kg.',
#   'แล้วแต่ปริมาณชิ้นที่ทำ',
#   'kg',
#   'ชิ้น',
#   'กรัม /  ถ้วยตวง',
#   'ช้อนโต๊ะ',
#   'กร้ม',
#   'เส้น',
#   'ลิ้น',
#   'กรัม',
#   'โครง',
#   'ทัพพี',
#   '.  กรัม',
#   'สำหรับจาน',
#   'แพค',
#   'แผ่น',
#   'ขา',
#   'ตามใจชอบ',
#   'ชต.',
#   'ถ้วยซุป',
#   'ใส่จานละ แผ่น',
#   'หาง',
#   'พอ',
#   'ตามต้องการ',
#   'ชต',
#   'กิโล',
#   'ขึด',
#   'สำหรับ  จาน',
#   'ก.',
#   'ห่อ',
#   'Kg',
#   'ช้ินโต๊ะ',
#   'ช้อน',
#   'ขีเ',
#   'ฟอง',
#   'ชิ้นใหญ่',
#   'ไข่ กก.',
#   'Kg.',
#   'กก.',
#   'ถ้วย',
#   'กิโลกรัม',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'g',
#   'ก้อนเล็ก',
#   'ชีด',
#   'แพ็ค',
#   'ขีด',
#   'เล็กน้อย',
#   'โล',
#   'ก้อน',
#   'g.',
#   'ช้อนชา'],
#  '^(?!.*เส้น)(.*ข้าวสวย|^ข้าว$|ข้าวกล้อง.*|ข้าวสาร|ข้าวเปล่า|ข้าวหอมมะลิ|ข้าวเย็น|ข้าวหุงสุก|ข้าวญี่ปุ่น|ข้าวสุก|ข้าวแช่เย็น|ข้าวหอม|ข้าวเสาไห้|ข้าวบาสมาติ)': ['',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'ถวย',
#   'คนทาน',
#   'หม้อหุงข้าว',
#   'ถ้วยตวงข้าว',
#   'ทับพี',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'กป.',
#   'cup',
#   'ทัพพี',
#   'ถ้วน',
#   'ถ้วยซุป',
#   'ที่',
#   'กระป๋องตวงช',
#   'ตามต้องการ',
#   'จานพูนๆ',
#   'ถุง',
#   'ถ้วยชามสำหรับ  ท่าน',
#   'ก.',
#   'หม้อ',
#   'ถ้วย/จาน',
#   'ถ้วยตวงเล็ก',
#   'ถ้วยพูน',
#   'ถต.',
#   'จาน',
#   'สำหรับ  ท่าน',
#   'สำหรับ  คน',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ตามความชอบ',
#   'ทัฟพี',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'ชาม',
#   'ชามใหญ่',
#   'กำมือ',
#   '/'],
#  'มะนาว': ['',
#   'ลูกใหญ่',
#   'ช้อนทานข้าว',
#   'ชิ้น',
#   'ผล',
#   'ช้อนโต๊ะ',
#   'ml.',
#   'ปรุงรสตามชอบ',
#   'ซีก',
#   'ทัพพี',
#   'แผ่น',
#   'กลีบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช้อนช้า',
#   'ชีก',
#   'ช่อนชา',
#   'ซอง',
#   'ลูก',
#   'ชต',
#   'ใบ',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ตามชอบ',
#   'เล็กน้อย',
#   'ช้อมโต๊ะ',
#   'ช้อนโต๊ะ   ช้อนชา',
#   'ชิมตามชอบ',
#   'ช้อน',
#   'ช้อนชา'],
#  'พริกขี้หนู': ['',
#   'กรัมมือ',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'กลีบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'ตามชอบเผ็ด',
#   'เม็ด เม็ดเล็ก',
#   'ชต',
#   'แล้วแต่ความชอบ',
#   'สีละ  เม็ด',
#   'พริก',
#   'แล้วแต่ชอบ',
#   'กำเล็ก',
#   'เผ็ดตามความชอบ',
#   'ดอก',
#   'ถ้วย',
#   'เม็ดโรยหน้า',
#   'g',
#   'เม็ด',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'เมล็ด',
#   'ขีด',
#   'เล็กน้อย',
#   'กำมือ',
#   'ชช',
#   'ช่อนโต๊ะ',
#   'ช้อนชา'],
#  '^(?!.*ไข่|มัน|มาม่า).*กุ้ง(?!แห้ง).*': ['',
#   'กก',
#   'ถ้วยตวง',
#   'kg.',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'ตามที่มี',
#   'ทั้งซอง',
#   'กรัม',
#   'กำมือ',
#   'ตัว ตามชอบ',
#   'ช.ต.',
#   'ชต.',
#   'ตามฐานะ รวยมากใส่มาก',
#   'ตัว/ตามใจชอบ',
#   'ตัวใหญ่',
#   'ชต',
#   'ซอง',
#   'ขึด',
#   'กิโล',
#   'ห่อ',
#   'Kg',
#   'ตัว',
#   'กก.',
#   'ถ้วย',
#   'กิโลกรัม',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'g',
#   'ขีด',
#   'เล็กน้อย',
#   'โล',
#   'เยอะๆ',
#   'g.',
#   'ช้อนชา'],
#  '^(?!.*ซอส|ซ้อส).*มะเขือเทศ.*': ['',
#   'กก',
#   'ถ้วยตวง',
#   'mm',
#   'กระป๋อง',
#   'ลูกใหญ่',
#   'ก.ก.',
#   'กล่อง',
#   'ชิ้น',
#   'ผล',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ไว้แต่งจาน',
#   'แพค',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'ซอง',
#   'ลูก',
#   'ชต',
#   'ลุก',
#   'ลูกเล็ก',
#   'หัวใหญ่',
#   'ถ้วย',
#   'กรั',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ถ้ากิน',
#   'ขีด',
#   'เยอะๆ',
#   'g.'],
#  'หอมใหญ่|หอมหัวใหญ่|หัวหอม|หอมแขก|หอมซอย|หอมเล็กเจียว|^หอม$|หัวใหญ่': ['',
#   'กก',
#   'ถ้วยตวง',
#   'ตามชอบค่ะ',
#   'mm',
#   'ส.',
#   'ลูกใหญ่',
#   'บาท',
#   'ผล',
#   'ช้อนโต๊ะ',
#   'ตกแต่ง',
#   'กรัม',
#   'ต้น',
#   'ซีก',
#   'กลีบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'ซอง',
#   'ลูก',
#   'ชต',
#   'ก.',
#   'สำหรับโรยหน้า',
#   'ลูกเล็ก',
#   'หัวใหญ่',
#   'นิดหน่อย',
#   'ถต.',
#   'ดอก',
#   'หยิบมือ',
#   'กำ',
#   'สำหรับเสิร์ฟ',
#   'กก.',
#   'ถ้วย',
#   'ซอยหัว',
#   'g',
#   'ตามชอบ',
#   'ถ้ากิน',
#   'ท่อน',
#   'หัวเล็ก',
#   'ขีด',
#   'เล็กน้อย',
#   'กรีบ',
#   'ใส่ไม่ใส่ก็ได้ตามชอบ'],
#  'รากผักชี': ['',
#   'หนึ่งช้อนโต๊ะ',
#   'ต้น',
#   ',ราก',
#   'ราก',
#   'ตามชอบ',
#   'ชต.',
#   'ช้อนชา',
#   'หัว',
#   'เล็กน้อย',
#   'ตามชอบใจกับปริมาณให้เหมาะสมกับเนื้อสัตว์',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'หอมแดง|หอมเจียว|หอมเเดง': ['',
#   'ถ้วยตวง',
#   'กลีบใหญ่',
#   'ชช.',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'กลีบ',
#   'โรยหน้า',
#   'ชต.',
#   'หัว',
#   'ลูก',
#   'ชต',
#   'ช้อนโต็ะ',
#   'ลูกเล็ก',
#   'หัวใหญ่',
#   'หยิบมือ',
#   'ถ้วย',
#   'ซอยหัว',
#   'g',
#   'ตามชอบ',
#   'เม็ด',
#   'หัวเล็ก',
#   'ขีด',
#   'กำมือ',
#   'ช้อนชา'],
#  'พริกแห้ง': ['',
#   'กำ',
#   'ตามความชอบ',
#   'กำมือ',
#   'ทัพพี',
#   'ถ้วยเล็ก',
#   'ตามชอบ',
#   'เม็ด',
#   'แล้วแต่ชอบ',
#   'โรยหน้า',
#   'นิดหน่อย',
#   'ช้อนโตีะ',
#   'กรัม',
#   'ดอก',
#   'ช้อนโต๊ะ',
#   'ลูก',
#   'ช้อน',
#   'เม็ด /ตามชอบ'],
#  'พริกป่น': ['',
#   'ชช.',
#   'นิดนึง',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ปรุงรสตามชอบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช้อนโต๊',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ช้อนชาพูน',
#   'ชต',
#   'นิดหน่อย',
#   'ถ้วย',
#   'ตามชอบ',
#   'เล็กน้อย',
#   'ชช',
#   'ช้อน',
#   'ช้อนชา'],
#  '^(?!.*ราก|ลูก).*ผักชี.*|ผง coriander': ['',
#   'ถ้วยตวง',
#   'ก้่าน',
#   'ถ้วยเล็ก',
#   'ตามใจ',
#   'ชช.',
#   'สำหรับโรย',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ต้น',
#   'ถ้า',
#   'แพค',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'เอาไว้ตกแต่ง',
#   'ก้าน',
#   'อย่างละ ต้น',
#   'ชต',
#   'หยิบ',
#   'ราก',
#   'สำหรับโรยหน้า',
#   'แล้วแต่ชอบ',
#   'ต้ร',
#   'กำเล็ก',
#   'นิดหน่อย',
#   'หยิบมือ',
#   'ใบ',
#   'กำ',
#   'ถ้วย',
#   'ตามชอบ',
#   'ถ้ากิน',
#   'สำหรับตกแต่ง',
#   'ขีด',
#   'เล็กน้อย',
#   'มัด',
#   'กิ่ง',
#   'กำมือ',
#   'ชช',
#   'ตามชอบ ใส่ไม่ใส่ได้หมด',
#   'ช้อนชา'],
#  'ซอสมะเขือเทศ|ซ้อสมะเขือเทศ': ['',
#   'ถ้วยตวง',
#   'หมดขวด/รูป',
#   'กะเอา',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'tbs',
#   'ทัพพี',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช้อนโต๊',
#   'ซอง',
#   'ชต',
#   'ขวด',
#   'ถ้วย',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'ช้อน',
#   'ช้อนชา'],
#  'ใบมะกรูด|ใบมะกูด|มะกรูด': ['',
#   'ชช.',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ต้น',
#   'พอเหมาะ',
#   'ลูก',
#   'หยิบ',
#   'นิดหน่อย',
#   'หยิบมือ',
#   'ใบ',
#   'ใบ โรยหน้า',
#   'กำ',
#   'สำหรับเสิร์ฟ',
#   'ตามชอบ',
#   'ขีด',
#   'เล็กน้อย',
#   'กิ่ง',
#   'อย่างละนิด'],
#  'น้ำมันงา': ['',
#   'ถ้วยตวง',
#   'tbsp',
#   'ช.ช',
#   'เหยาะๆ ลงไป',
#   'ตามชอบ',
#   'สำหรับทอด',
#   'ชช.',
#   'ชต.',
#   'โรงรถไซให้ได้รถตามชอบ',
#   'ชต',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'ช้อน',
#   'ช้อนชา'],
#  '^พริก$|พริกสด|พริกจินดา|พริกแดง|พริกใหญ่|พริกสับ|พริกอ่อน|พริกตำ|พริกซอย|พริกทอด|พริกสีแดง|พริกหั่น|พริกคั่ว|พริก+|พริกหั่นเฉียง': ['',
#   'มล.',
#   'ช้อนโต๊ะ ตามชอบ',
#   'ชช.',
#   'ถ้าชอบ',
#   'กรัม',
#   'แผ่น',
#   'ห่อเล็ก',
#   'ตามต้องการ',
#   'ปลายช้อน',
#   'ปรุงรสเล็กน้อย',
#   'แล้วแต่ความชอบ',
#   '/ช้อนชา',
#   'ช่อ',
#   'กำเล็ก',
#   'ชต พูนๆ',
#   'เหยาะหน้าก๋วยเตี๋ยว',
#   'เผ็ดตามความชอบ',
#   'ช้อน/ถ้วย',
#   'เม็ดโรยหน้า',
#   'กิ่ง',
#   'ช่อนโต๊ะ',
#   'ช้อนชา',
#   'เม็ด /ตามชอบ',
#   'ถ้วยตวง',
#   'ใส่ตามชอบ',
#   'หมดขวด/รูป',
#   'บด',
#   'เม็ดใหญ่',
#   'ข้อนโต๊ะ',
#   'อก',
#   'ตามที่มี',
#   'ปรุงรสตามชอบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'กระปุก',
#   'เครื่องปรุงใส่ตามความชอบ',
#   'ช่อนชา',
#   'อัน',
#   'พอ',
#   'ซอง',
#   'ช้อนชาพูน',
#   'ชต',
#   'พวง',
#   'พริก',
#   'ช้อนชา/ตามใจชอบ',
#   'ห่อ',
#   'ชข.',
#   'ตามความชอบ',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ช้อนใหญ่',
#   'เล็กน้อย',
#   'โล',
#   'ช้อนโตีะ',
#   'นิดหน่อย แล้วแต่ชอบ',
#   'ชช',
#   'ส.',
#   'ช.ช.',
#   'สำหรับโรย',
#   'หน่อย',
#   'นิดนึง',
#   'บาท',
#   'โรงรถไซให้ได้รถตามชอบ',
#   'kg',
#   'ผล',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'เม็ด/ตามชอบ',
#   'กระบวย',
#   'ทัพพี',
#   'ฝัก',
#   'กลีบ',
#   'โรยหน้า',
#   'ตามสะดวก',
#   'ปรุงรส',
#   'ตามชอบเผ็ด',
#   'ช.ต.',
#   'ตามชอบใจกับปริมาณให้เหมาะสมกับเนื้อสัตว์',
#   'ถุง',
#   'อย่างละ  ลูก',
#   'ช้อนโต๊ะพูนๆ',
#   'ลูกเล็ก',
#   'แล้วแต่ชอบ',
#   'สำหรับปรุงรส',
#   'นิดหน่อย',
#   'ดอก',
#   'หยิบมือ',
#   'เสี้ยวช้อนโต๊ะ',
#   'ปริมาณตามชอบ',
#   'เหยาะๆ ลงไป',
#   'เมล็ด',
#   'ขีด',
#   'หลายๆเหยาะ',
#   'กำมือ',
#   'ท่อนใบตอง',
#   'อย่างละนิด',
#   'หนึ่งช้อนโต๊ะ',
#   'ช้อนโต้ะ',
#   'กก',
#   'mm',
#   'tbsp',
#   'ถ้วยเล็ก',
#   'กระป๋อง',
#   'เหยาะ',
#   'กรัมมือ',
#   'พวงเล็ก',
#   'ชิ้น',
#   'ซองเล็ก',
#   'ช้อนโโต๊ะ',
#   'เล็กน้อย ตามชอบ',
#   'ต้น',
#   'แล้วแต่ขอบ',
#   'ฟัก',
#   'ช้อนพูน',
#   'กป',
#   'ช้อนช้า',
#   'เม็ด เม็ดเล็ก',
#   'ช้อนโต๊',
#   'ปลายช้อนชา',
#   'ตามใจฉัน',
#   'ก้าน',
#   'ลูก',
#   'กิโล',
#   'หยิบ',
#   'สีละ  เม็ด',
#   'เพื่อปรุงรส',
#   'กำ',
#   'ดอด',
#   'เม็ด',
#   'แพ็ก',
#   'ตามชอ',
#   'โต๊ะ',
#   'ช้อน',
#   'ts'],
#  'โหระพา|ใบโหรพา|โหรพา': ['',
#   'ถ้วยตวง',
#   'ตามใจ',
#   'บาท',
#   'กรัม',
#   'กำใหญ่',
#   'ต้น',
#   'ตามใจชอบ',
#   'ถ้วยเล้ก',
#   'ชต.',
#   'ก้าน',
#   'กำใหญ่ๆ',
#   'ตามต้องการ',
#   'หยิบ',
#   'ช่อ',
#   'เยอะๆ',
#   'แล้วแต่ชอบ',
#   'นิดหน่อย',
#   'ถต.',
#   'หยิบมือ',
#   'ใบ',
#   'กำ',
#   'ถ้วย',
#   'ยอด',
#   'ตามชอบ',
#   'ขีด',
#   'มัด',
#   'กิ่ง',
#   'กำมือ',
#   'เยอะตามสะดวก',
#   'ช้อนชา'],
#  'ถั่วฝักยาว|ถั่วฟักยาว|ถั่วผักยาว|ถัวฝักยาว': ['',
#   'กำ',
#   'สำหรับเสิร์ฟ',
#   'ต้น',
#   'ถ้วย',
#   'ถ้วยตวง',
#   'ฟัก',
#   'ฝัก',
#   'ตามชอบ',
#   'ขีด',
#   'เล็กน้อย',
#   'อัน',
#   'เยอะน้อยตามชอบ',
#   'พอ',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม'],
#  'ใบกะเพรา|ใบกระเพรา|กระเพรา|กะเพรา|ใบกระเพา|ใบกระ เพรา แดง|กระเพา|Basil': ['',
#   'ถ้วยตวง',
#   'ใส่ตามชอบ',
#   'หากชอบ',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'ช้อนชา',
#   'กรัม',
#   'กำใหญ่',
#   'ต้น',
#   'แพค',
#   'ตามสะดวก',
#   'ตามใจชอบ',
#   'ก้าน',
#   'พอ',
#   'แล้วแต่ความชอบ',
#   'แล้วแต่ชอบ',
#   'แล้วแต่',
#   'กำเล็ก',
#   'นิดหน่อย',
#   'ถต.',
#   'ใบ',
#   'หยิบมือ',
#   'กำ',
#   'ถ้วย',
#   'ขยุ้ม',
#   'ตามชอบ',
#   'แพ็ค',
#   'ขีด',
#   'มัด',
#   'โล',
#   'เล็กน้อย',
#   'กิ่ง',
#   'กำมือ',
#   'หยิบมือแล้วแต่ชอบ',
#   'กำ,'],
#  '^(?!.*ไส้กรอก|ไข่|เลือด|น้ำ|ผง|โครง|ตีน|เครื่องใน|เต้าหู้|ซี่โครง|ขา|ซอส|ตับ).*ไก่(?!จ๊อ|ไข่).*|chicken': ['',
#   'กก',
#   'ถ้วยตวง',
#   'น่อง',
#   'ชช.',
#   'บาท',
#   'kg.',
#   'อก',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม',
#   'สำหรับหมัก',
#   'กลีบ',
#   'น่องเนื้อไก่ตามชอบ',
#   'ตามใจชอบ',
#   'กล่องนึง',
#   'อัน',
#   'อกใหญ',
#   'พอ',
#   'ซอง',
#   'ตามต้องการ',
#   'ลูก',
#   'กิโล',
#   'ดวง',
#   'พอทาน',
#   'ห่อ',
#   'Kg',
#   'ช้อน',
#   'ฟอง',
#   'ชิ้น/ ชิ้น',
#   'ตัว',
#   'ขิ้น',
#   'ก้อน',
#   'ชิ้นใหญ่',
#   'กก.',
#   'ถ้วย',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'ปีก',
#   'แพ็ค',
#   'ขีด',
#   'เล็กน้อย',
#   'โล',
#   'กระม',
#   'g.',
#   'ช้อนชา'],
#  '^ซีอิ๊วดำ$|^ซีอิ้วดำ$|ซีอิ๋วดำ(?!หวาน)|สี่อิ๋วดำสูตรเค็ม': ['',
#   'เหยาะ',
#   'นิดนึง  หยด',
#   'ชช.',
#   'ช้อนโต๊ะ',
#   'พอให้หมูมีสี',
#   'กรัม',
#   'ชต.',
#   'ช้อนโต๊',
#   'ปลายช้อน',
#   'ชต',
#   'แล้วแต่ชอบ',
#   'นิดหน่อย',
#   'ชช',
#   'ข้อนชา',
#   'ถ้วย',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'เล็กน้อย',
#   'นิดหน่อยเพิ่มสีสัน',
#   'ตามชอบเพิ่มสีสัน',
#   'ช้อน',
#   'ช้อนชา'],
#  'ถั่วงอก': ['',
#   'กก',
#   'ถ้วยตวง',
#   'ถุงเล็ก',
#   'ตามใจ',
#   'บาท',
#   'kg',
#   'กรัม',
#   'ตามใจชอบ',
#   'ตามขนาดชอบ',
#   'กิโล',
#   'ถุง',
#   'หยิบมือ',
#   'กำ',
#   'กก.',
#   'ถ้วย',
#   'ถั่วตวง',
#   'เพ็ค',
#   'ตามชอบ',
#   'ขีด',
#   'กำมือ',
#   'ช้อน'],
#  'คะน้า': ['',
#   'กก',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'kg',
#   'กร้ม',
#   'กรัม',
#   'ต้น',
#   'ก้าน',
#   'กิโล',
#   'แล้วแต่ชอบ',
#   'กำเล็ก',
#   'ใบ',
#   'กำ',
#   'กก.',
#   'ถ้วย',
#   'ยอด',
#   'g',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'ขีด',
#   'มัด',
#   'กำมือ',
#   'กัาน'],
#  'ข้าวโพดอ่อน': ['',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'ชิ้น',
#   'แท่ง',
#   'กรัม',
#   'ต้น',
#   'ฝัก',
#   'ฟัก',
#   'แพค',
#   'ตามใจชอบ',
#   'หัว',
#   'อัน',
#   'ตามต้องการ',
#   'นิดหน่อย',
#   'ผัก',
#   'ถ้วย',
#   'ฝักเล็ก',
#   'ตามชอบ',
#   'ท่อน',
#   'แพ็ค',
#   'ช้อนชา'],
#  'เนย': ['',
#   'ช้อนโต้ะ',
#   'ถ้วยตวง',
#   'tbsp',
#   'ชช.',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ชต.',
#   'ช้อนโต๊',
#   'ตามต้องการ',
#   'ชต',
#   'ก.',
#   'แล้วแต่ชอบ',
#   'นิดหน่อย',
#   'ถ้วย',
#   'ก้อนเล็ก',
#   'ตามชอบ',
#   'g',
#   'เล็กน้อย',
#   'ใช้ทากะทะ',
#   'ก้อน',
#   'ชช',
#   'ช้อนชา'],
#  'แป้งทอดกรอบ|แป้งชุบทอด|แป้งโกกิ|แป้งทอด|แป้งสำหรับทอด|แป้งทอดกรอบคนอร์': ['',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ทัพพี',
#   'ตามสะดวก',
#   'ชต.',
#   'ถต',
#   'พอ',
#   'ซอง',
#   'ชต',
#   'ถุง',
#   'ห่อ',
#   'ถต.',
#   'ถ้วย',
#   'ตามชอบ',
#   'ชาม',
#   'ชุบไก่'],
#  'แป้งมัน': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'tbsp',
#   'ชค',
#   'มิลลิลิตร',
#   'ชช.',
#   'ชต.',
#   'ถต.',
#   'ml',
#   'กรัม',
#   'ชช',
#   'พอ',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'ช้อน',
#   'ช้อนชา'],
#  '^(?!.*ซอส|ซีอิ๊ว|ผงปรุงรส|ซีอิ้ว|คนอร์).*เห็ด.*': ['',
#   'ดอกใหญ่',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'กระป๋อง',
#   'ดอก ใหญ่',
#   'ใส่ตามใจชอบ',
#   'ชช.',
#   'กล่อง',
#   'kg',
#   'ชิ้น',
#   'ถ้วยใหญ่',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ต้น',
#   'แพค',
#   'ตามใจชอบ',
#   'ชต.',
#   'หัว',
#   'อัน',
#   'ห่อเล็ก',
#   'โคนใหญ่',
#   'ลูก',
#   'กิโล',
#   'กอด',
#   'ถุง',
#   'ตามใจชอบได้เลยจ้า',
#   'ห่อ',
#   'ดิก',
#   'ถต.',
#   'ดอก',
#   'ใบ',
#   'กำ',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'แพ็ค',
#   'ชาม',
#   'ขีด',
#   'ก้อน',
#   'กำมือ',
#   'ช้อนชา'],
#  'เส้นสปาเก็ตตี้|เส้นสปาเกตตี้|สปาเก็ตตี้|สปาเกตตี้|เส้นสปาเกตตี|สปาเกตตี': ['',
#   'กก',
#   'ถ้วยตวง',
#   'ถุงเล็ก',
#   'หนึ่งกำมือ',
#   'เเล้วเเต่ทาน',
#   'kg',
#   'แท่ง',
#   'ซองเล็ก',
#   'กรัม',
#   'ตามใจชอบ',
#   'ห่อเล็ก',
#   'ซอง',
#   'ตามต้องการ',
#   'สำหรับคน',
#   'ถุง',
#   'ก.',
#   'แล้วแต่ชอบ',
#   'ห่อ',
#   'โอเค',
#   'หยิบมือ',
#   'จาน',
#   'กำ',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ชาม',
#   'มัด',
#   'กำมือ',
#   'g.'],
#  'เต้าเจี้ยว|เต้าเจี๊ยว|เต้าเจียว': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ทัพพี',
#   'เหยาะๆ ลงไป',
#   'ตามชอบ',
#   'แล้วแต่ชอบ',
#   'ชต.',
#   'ช้อนชา',
#   'ช้อน',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'กรัม'],
#  'โชยุ|ซีอิ๊วญี่ปุ่น|โชวยุ|Soba tsuyu': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ตามชอบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'เล็กน้อย',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'ชต',
#   'ช้อนชา'],
#  'ตะไคร้|ตะใคร้': ['',
#   'ถ้วยตวง',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'ช้อนชา',
#   'กรัม',
#   'ต้น',
#   'ชต.',
#   'หัว',
#   'ก้าน',
#   'ต้า',
#   'กำ',
#   'ถ้วย',
#   'แว่น',
#   'g',
#   'ตามชอบ',
#   'ท่อน',
#   'กำมือ',
#   'ชช',
#   'อย่างละนิด'],
#  '^(?!.*ไข่).*ปลาหมึก.*|^หมึก|หมึกกล้วย': ['',
#   'ตัวเล็ก',
#   'ชิ้น',
#   'ตามที่มี',
#   'กรัม',
#   'ตัวใหญ่',
#   'ลูก',
#   'กิโล',
#   'ตัว',
#   'ชิ้นใหญ่',
#   'ตัวขนาดกลาง',
#   'กก.',
#   'ถ้วย',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ขีด',
#   'เล็กน้อย',
#   'ต้ว'],
#  'น้ำพริกเผา': ['ช้อนโต้ะ',
#   'ถ้วย',
#   'กระป๋อง',
#   'g',
#   'ตามชอบ',
#   'ช้อนโต๊ะพูนๆ',
#   'ชช.',
#   'ชต.',
#   'กป',
#   'ชต พูนๆ',
#   'ช่อนชา',
#   'ชต',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'ตามที่มี',
#   'ช้อน',
#   'ช้อนชา',
#   'ช้อน/ถ้วย'],
#  'เบคอน': ['',
#   'แผ่นอวบๆ',
#   'ถ้วย',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'แผ่นยาว',
#   'แผ่น',
#   'ห่อ',
#   'ตามใจชอบ',
#   'ขีด',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม'],
#  'ไส้กรอก': ['',
#   'ชิ้น',
#   'แท่ง',
#   'เส้น',
#   'กรัม',
#   'ดุ้น',
#   'อัน',
#   'ห่อเล็ก',
#   'ตามต้องการ',
#   'ถุง',
#   'แพคเล็ก',
#   'แล้วแต่ชอบ',
#   'ห่อ',
#   'กก.',
#   'ตามความชอบ',
#   'ถ้วย',
#   'ตามชอบ',
#   'ท่อน',
#   'แพ็ค',
#   'ขีด'],
#  '^นม(?!ข้น)': ['ขวดกลาง  ขวด',
#   'ถ้วยตวง',
#   'มล.',
#   'ถ้วยเล็ก',
#   'กล่อง',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ml.',
#   'มิลลิลิตร',
#   'ml',
#   'ชต',
#   'ขวด',
#   'กล่่อง',
#   'กล่องเล็ก',
#   'oz',
#   'นิดหน่อย',
#   'ถต.',
#   'ถ้วย',
#   'แก้ว',
#   'g',
#   'ตามชอบ',
#   'ขวดกลาง',
#   'cc',
#   'ซีซี',
#   'ช้อน',
#   'ช้อนชา'],
#  'ซอสพริก': ['',
#   'โต๊ะ',
#   'ถ้วย',
#   'mm',
#   'ทัพพี',
#   'เหยาะๆ ลงไป',
#   'ตามชอบ',
#   'หมดขวด/รูป',
#   'ห่อ',
#   'ชต.',
#   'กรัม',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'ชต',
#   'ช้อน',
#   'ช้อนชา',
#   'กระบวย'],
#  'วุ้นเส้น|^เส้น$': ['',
#   'ถุง',
#   'หยิบ',
#   'ถ้วย',
#   'ถุงเล็ก',
#   'ตามชอบ',
#   'หอ',
#   'ห่อ',
#   'ห่อกลาง',
#   'นิดหน่อย',
#   'ต่อถุง',
#   'ซองเล็ก',
#   'กำมือ',
#   'ห่อเล็ก',
#   'ซอง',
#   'g.',
#   'กรัม'],
#  'น้ำซุป|น้ำซุบ': ['',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'มิลลิเมตร',
#   'ช้อนโต๊ะ',
#   'ชุด',
#   'กระบวย',
#   'ทัพพี',
#   'มิลลิตร',
#   'มิลลิลิตร',
#   'ชต.',
#   'ml',
#   'สำหรับ',
#   'ซอง',
#   'ถุง',
#   'oz',
#   'นิดหน่อย',
#   'ถต.',
#   'ถ้วย',
#   'ลิตร',
#   'ตามชอบ',
#   'ชาม',
#   'cc',
#   'เล็กน้อย',
#   'ออนซ์',
#   'ช้อนชา'],
#  'ผักกาด|ผัดกาดขาว|ผักคอส': ['',
#   'กระป๋อง',
#   'ตามใจ',
#   'กระป๋องเล็ก',
#   'หัวเล็ก  หัว',
#   'ถ้วยใหญ่',
#   'ชิ้น',
#   'กรัม',
#   'ต้น',
#   'กลีบ',
#   'ตามใจชอบ',
#   'หัว',
#   'กิโล',
#   'หัวใหญ่',
#   'ใบ',
#   'ถ้วย',
#   'ใบใหญ่',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'หัวเล็ก',
#   'ก้อน',
#   'กำมือ'],
#  '^กะปิ': ['',
#   'กรัม',
#   'ช้อนตักแกง',
#   'ตามชอบ',
#   'ช้อนพูนๆ',
#   'ชช.',
#   'ชต.',
#   'นิดหน่อย',
#   'ชต',
#   'ช้อนโต๊ะ',
#   'ช้อน',
#   'ช้อนชา'],
#  'พริกชี้ฟ้า|พริกเหลือง': ['',
#   'ต้น',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'หยิบ',
#   'เม็ด',
#   'ตามชอบ',
#   'อัน',
#   'ตามใจชอบ',
#   'เล็กน้อย',
#   'หยิบมือ',
#   'ดอก',
#   'ช้อนโต๊ะ',
#   'ลูก',
#   'ชต',
#   'กรัม'],
#  'กะทิ|กระทิ': ['',
#   'มิลลิกรัม',
#   'กก',
#   'ถ้วยตวง',
#   'มล.',
#   'ถ้วยเล็ก',
#   'กระป๋อง',
#   'กล่อง',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ml.',
#   'มิลิกรัม',
#   'ทัพพี',
#   'มล',
#   'มิลลิลิตร',
#   'ชต.',
#   'ml',
#   'ขวดเล็ก',
#   'กิโล',
#   'มิล.',
#   'กล่องเล็ก',
#   'Ml',
#   'ถ้วย',
#   'กิโลกรัม',
#   'g',
#   'ลิตร',
#   'โล',
#   'ช้อนชา'],
#  'เส้นใหญ่|เส้นไหญ่|^เส้น$': ['',
#   'กก',
#   'kg.',
#   'kg',
#   'ก.ก',
#   'กรัม',
#   'แพค',
#   'กิโล',
#   'ถุง',
#   'ก.',
#   'ห่อ',
#   'หยิบมือ',
#   'กก.',
#   'ถ้วย',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ขีด',
#   'โล',
#   'กรัมม'],
#  '^(?!.*ดอก)กะหล่ำ(?!.*ดอก.*)|กะหล่ำปลี|กระหล่ำปลี': ['',
#   'ถ้วยตวง',
#   'ถ้วยเล็ก',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ปริมาณตามต้องการ',
#   'หัว',
#   'ลูก',
#   'หัวใหญ่',
#   'ใข',
#   'ใบ',
#   'ซีกเล็ก',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ตามชอบ',
#   'ชาม',
#   'หัวเล็ก',
#   'ขีด',
#   'เล็กน้อย',
#   'กำมือ'],
#  'ผักบุ้ง': ['',
#   'กำ',
#   'ต้น',
#   'ถาด',
#   'ถ้วย',
#   'g',
#   'กัม',
#   'ตามชอบ',
#   'กำเล็ก',
#   'ขีด',
#   'มัด',
#   'นิดหน่อย',
#   'แพ็ก',
#   'ชามใหญ่',
#   'กำมือ',
#   'หยิบมือ',
#   'กรัม'],
#  'แฮม': ['ตามชอบ', 'แผ่น', 'แล้วแต่ชอบ', 'อัน', 'ชิ้น', 'ชิ้นใหญ่', 'กรัม'],
#  'หมูยอ': ['แถว',
#   'ชิ้น',
#   'แท่ง',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม',
#   'อันเล็ก',
#   'อัน',
#   'แท่งกลาง',
#   'ห่อ',
#   'แท่งเล็ก',
#   'กก.',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ท่อน',
#   'ก้อนเล็ก',
#   'ขีด',
#   'ท่อนใบตอง'],
#  'แตงกวา': ['',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'ลูกเล็ก',
#   'ลูกใหญ่',
#   'ผักเครื่องเคียง',
#   'หัว',
#   'ชิ้น',
#   'ผล',
#   'ลูก',
#   'g.'],
#  'กุ้งแห้ง': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'tbsp',
#   'ตามชอบ',
#   'ตัว',
#   'ขีด',
#   'ชต.',
#   'ช้อนชา',
#   'เล็กน้อย',
#   'ช้อนโตีะ',
#   'บาท',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'หยิบมือ',
#   'ชต',
#   'กรัม'],
#  'มิริน': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ช.ต',
#   'ทัพพี',
#   'อย่างละ  ช้อนโต๊ะ',
#   'ตามชอบ',
#   ', ช้อนชา',
#   'ชต.',
#   'นิดหน่อย',
#   'ชต',
#   'ช้อนโต๊ะ',
#   'ช้อน',
#   'ช้อนชา'],
#  'น้ำมะขามเปียก|น้ำมะขาวเปียก|น้ำมะขาม': ['',
#   'ปรุงรสตามชอบ',
#   'ถ้วย',
#   'ทัพพี',
#   'ตามชอบ',
#   'ชต.',
#   'ช้อน',
#   'กรัม',
#   'ช้อนโต๊ะ',
#   'ช่้อนโต๊ะ',
#   'ชต',
#   'ช้อนชา',
#   'กระบวย'],
#  'ต้นกระเทียม': ['ต้น', 'ตามใจชอบ', 'กรัม'],
#  'ถั่วเน่า': ['ช้อนโต๊ะ', 'แผ่น', 'กล่อง'],
#  'หญ้าหวาน': ['', 'ตามชอบ', 'ชช.', 'ปลายช้อนชา', 'ช้อนชา', 'ซองเล็ก', 'กรัม'],
#  'ขึ้นฉ่าย|คื่นช่าย|คึ่นช่าย|ขึ้นช่าย|คื่นไช้|คื่นไฉ่|ตั้งโอ๋': ['',
#   'ถ้วยตวง',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ต้น',
#   'ชต',
#   'ราก',
#   'กำเล็ก',
#   'นิดหน่อย',
#   'กำ',
#   'ถ้วย',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'ท่อน',
#   'เล็กน้อย',
#   'มัด',
#   'กำมือ',
#   'พอโรยหน้า'],
#  'มันฝรั่ง': ['',
#   'กิโลกรัม',
#   'แล้วแต่ชอบ',
#   'หัวเล็ก',
#   'ชช.',
#   'หัวใหญ่',
#   'หัว',
#   'ถต.',
#   'ลูกกลาง',
#   'ลูก',
#   'กรัม'],
#  'น้ำส้มสายชู|น้ำส้ม': ['',
#   'ถ้วยตวง',
#   'ชช.',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'กรัม',
#   'กระบวย',
#   'ทัพพี',
#   'กลีบ',
#   'ชต.',
#   'ชต',
#   'ขวด',
#   'แล้วแต่ชอบ',
#   'ถ้วย',
#   'ตามความชอบ',
#   'ตามชอบ',
#   'เม็ด',
#   'ช้อน',
#   'ช้อนชา'],
#  'ใบบัวบก': ['สำหรับเสิร์ฟ', 'กรัม'],
#  'แป้งขนมปัง': ['กรัม'],
#  'ซีรัป': ['ช้อนโต๊ะ'],
#  'เส้นเฟตตูชินี': ['กำเล็ก', 'กรัม', 'ปริมาณตามหน้าซองบรรจุ'],
#  'ข่า': ['',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'ช้อชา',
#   'ชต.',
#   'หัว',
#   'แง่ง',
#   'หัวใหญ่',
#   'นิดเดียว',
#   'สำหรับเสิร์ฟ',
#   'แว่น',
#   'g',
#   'ท่อน',
#   'หัวเล็ก',
#   'ขีด',
#   'กำมือ',
#   'ชช',
#   'ช้อน',
#   'อย่างละนิด'],
#  'มาม่า|บะหมี่กึ่งสำเร็จรูป|เส้นหมี่ไวไว|ไวไว|หมี่กึง': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'มล.',
#   'ห่อตามภาพ ต้มได้  คน',
#   'ตามชอบ',
#   'ชอง',
#   'ซอง/กระป๋อง',
#   'ห่อ',
#   'ชาม',
#   'ทั้งหมด',
#   'ก้อน',
#   'ห่อเล็ก',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'เส้น',
#   'ทั้งซอง',
#   'กรัม'],
#  'น้ำผึ้ง': ['ถ้วยตวง',
#   'ถ้วย',
#   'ทัพพี',
#   'ตามชอบ',
#   'ชต.',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'ช้อนชา'],
#  '^(?!.*ซอส|แป้งทอด).*(คนอร์|รสดี).*|อร่อยชัวร์|ผงปรุงรส|เครื่องปรุงรส|ซุปก้อน|ผงซุปหมูก้อน|ชูรส|ผงซุป|ผงเติมทิพ|ผงดาชิ|ผงปาปริก้า|ดาชิ|ปาปริก้า|เครื่องปรุง|ผงปาปริกา|italian seasoning|ผงนัว|ผงหม่าล่า|ซุปหมูก้อน|ผงหมาล่า|ผงโรยข้าว': ['',
#   'ถ้วยตวง',
#   'เเล้วเเต่ชอบ',
#   'ช.ช.',
#   'ชช.',
#   'teaspoon',
#   'ช้อนโต๊ะ',
#   'ช้อนชา',
#   'ซองเล็ก',
#   'ชุด',
#   'กรัม',
#   'ปรุงรสตามชอบ',
#   'สำหรับหมัก',
#   'ใส่ไม่ใส่ก็ได้',
#   'มิลลิลิตร',
#   'ปรุงรส',
#   'ชต.',
#   'ตามใจชอบ',
#   'ปลายช้อนชา',
#   'ปลายชช.',
#   'ซอง',
#   'ปลายช้อน',
#   'ชต',
#   'ก.',
#   'แล้วแต่ชอบ',
#   'ห่อ',
#   'ช้อน',
#   'นิดหน่อย',
#   'กัอน',
#   'ข้อนชา',
#   'ถ้วย',
#   'ช.ช',
#   'ก้อนเล็ก',
#   'ตามชอบ',
#   'ทั้งหมด',
#   'ช้านชา',
#   'เล็กน้อย',
#   'ก้อน',
#   'ชช',
#   'ช่อนโต๊ะ',
#   'ช้นโต๊ะ',
#   'ชุบไก่'],
#  'ซอสเห็ดหอม|ซอสเห็ด หอม': ['', 'ชช.', 'ชต.', 'ช้อนโต๊ะ', 'ชต'],
#  'ไชเท้า': ['', 'หัวกลาง', 'หัวเล็ก', 'หัว', 'อัน', 'ลูก'],
#  'พริกแกง': ['',
#   'ช้อนโต๊ะ ตามชอบ',
#   'ข้อนโต๊ะ',
#   'บาท',
#   'kg',
#   'ช้อนโต๊ะ',
#   'ซองเล็ก',
#   'กรัม',
#   'ทัพพี',
#   'ตามสะดวก',
#   'ชต.',
#   'ชต',
#   'ห่อ',
#   'ช้อน',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ขีด',
#   'ช้อนใหญ่',
#   'โล',
#   'ช่อนโต๊ะ',
#   'ช้อนชา'],
#  'แป้งข้าวโพด': ['ถ้วยตวง',
#   'ถ้วย',
#   'ให้พอเหนียว',
#   'ทัพพี',
#   'ชต.',
#   'ช้อน',
#   'เล็กน้อย',
#   'ถต.',
#   'กรัม',
#   'ช้อนโต๊ะ',
#   'กะเอา',
#   'ชต',
#   'ช้อนชา'],
#  'ซีอิ้วดำหวาน|ซีอิ๊วดำหวาน|ซีอิ๊วหวาน|สี่อิ๋วหวาน|สี่อิ๋วดำสูตรหวาน|ซี๊อิ๋วดำหวาน': ['',
#   'ถ้วย',
#   'ช.ต',
#   'ทัพพี',
#   'ตามชอบ',
#   'ห่อ',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'ช้อนชา'],
#  'กุนเชียง': ['',
#   'เส้นกลาง',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ถ้ามี',
#   'ตามชอบ',
#   'ท่อน',
#   'แท่งยาว',
#   'แท่ง',
#   'เส้นยาว',
#   'ชิ้นโต',
#   'แท่งเล็ก',
#   'อัน',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม'],
#  'ข้าวคั่ว': ['ตามชอบ', 'ชช.', 'ชต.', 'ช้อนโต๊ะ', 'ชต', 'ช้อนชา'],
#  'กวางตุ้ง': ['',
#   'กำ',
#   'ต้น',
#   'กก',
#   'กำมือ',
#   'ก้าน',
#   'กิโลกรัม',
#   'ตามชอบ',
#   'บาท',
#   'ต้นใหญ่',
#   'กรัม'],
#  'ลูกชิ้น': ['',
#   'ถุง',
#   'กก',
#   'กก.',
#   'ถ้วย',
#   'ไม้',
#   'กิโลกรัม',
#   'ตามชอบ',
#   'ถุงเล็ก',
#   'แล้วแต่ชอบ',
#   'แพ็ค',
#   'ห่อ',
#   'ขีด',
#   'เล็กน้อย',
#   'โล',
#   'ชิ้น',
#   'ลูก',
#   'กรัม'],
#  'ไข่เป็ด': ['', 'ใบ', 'ฟอง'],
#  'ปลากระป๋อง': ['กะป๋อง', 'กระปุก', 'กป.', 'กระป๋อง'],
#  'ผักสลัด': ['',
#   'ปริมาณตามต้องการ',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ตามความชอบ',
#   'ก้าน',
#   'กำมือ',
#   'ตามชอบ',
#   'ชาม',
#   'ห่อ',
#   'ขีด',
#   'กรัม',
#   'ต้นใหญ่',
#   'จาน',
#   'ใบ',
#   'กอง'],
#  '^กระดูกหมู$|กระดูกเล้ง|เล้ง': ['ถุง',
#   'กก',
#   'กก.',
#   'กิโลกรัม',
#   'ก.ก.',
#   'ขีด',
#   'โล',
#   'kg',
#   'ชิ้น',
#   'ตามชอบไม่ชอบไม่ใส่',
#   'เส้น',
#   'กรัม',
#   'กิโล'],
#  'ปูอัด': ['',
#   'กำมือ',
#   'ตามชอบ',
#   'แพค',
#   'แล้วแต่ชอบ',
#   'ขีด',
#   'ก่อเล็ก',
#   'อัน',
#   'ชิ้น',
#   'แท่ง',
#   'กรัม'],
#  'เกล็ดขนมปัง|เกร็ดขนมปัง': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ตามชอบ',
#   'โรยหน้า',
#   'ชต.',
#   'พอ',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'กรัม'],
#  'เส้นโซบะ': ['ห่อ', 'มัดเล็ก', 'กรัม'],
#  'น้ำหวานดอกมะพร้าว': ['ช้อนชา', 'ชช.'],
#  'น้ำจิ้มหมูหัน': ['ช้อนโต๊ะ', 'ช้อนชา'],
#  'ถั่วแระญี่ปุ่น': ['ถ้วย', 'g.'],
#  'เต้าหู้ไข่': ['ถุง', 'อัน', 'หลอด', 'ก้อน', 'ชิ้น'],
#  'ปลาร้า': ['ขวด',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ถ้วยเล็ก',
#   'ทัพพี',
#   'กิโลกรัม',
#   'ซ้อนโต๊ะ',
#   'แล้วแต่ชอบ',
#   'ชต.',
#   'ช้อน',
#   'พับพี',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'ช้อนชา',
#   'กระบวย'],
#  '^(?!.*น้ำ).*งา.*': ['',
#   'โรยนิดหน่อย',
#   'สำหรับเสิร์ฟ',
#   'ทัพพี',
#   'ตามชอบ',
#   'สำหรับโรยหน้า',
#   'แล้วแต่ชอบ',
#   'สำหรับตกแต่ง',
#   'ชช.',
#   'ชต.',
#   'ช้อนชา',
#   'ขีด',
#   'เล็กน้อย',
#   'kg',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'กรัม'],
#  'ถั่วลันเตา|ผักสามสี': ['',
#   'แพ็กเล็ก',
#   'ถุง',
#   'กำ',
#   'ถ้วย',
#   'อย่างละ ช้อน',
#   'ถ้วยเล็ก',
#   'ฝัก',
#   'ตามชอบ',
#   'ขีด',
#   'kg',
#   'ชิ้น',
#   'จาน',
#   'กรัม'],
#  'ถั่วลันเตา': ['',
#   'แพ็กเล็ก',
#   'ถุง',
#   'กำ',
#   'ถ้วย',
#   'ฝัก',
#   'ตามชอบ',
#   'ขีด',
#   'kg',
#   'ชิ้น',
#   'จาน',
#   'กรัม'],
#  'กระชาย': ['ถ้วย',
#   'ถ้วยเล็ก',
#   'ก้าน',
#   'ตามชอบ',
#   'กลีบ',
#   'แง่ง',
#   'ขีด',
#   'แท่ง',
#   'หัว',
#   'บาท',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'ตามต้องการ',
#   'หยิบมือ',
#   'เหง้า',
#   'กรัม'],
#  'ผงชูรส': ['',
#   'ปรุงรสตามชอบ',
#   'แล้วแต่ชอบ',
#   'ชช.',
#   'ช้อนชา',
#   'เล็กน้อย',
#   'นิดหน่อย',
#   'ปลายช้อนชา',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'ขนมจีน': ['',
#   'กก',
#   'ถ้วย',
#   'ตามชอบ',
#   'จับ',
#   'ห่อ',
#   'ตะกร้า',
#   'ก.ก.',
#   'โล',
#   'บาท',
#   'kg',
#   'ชุด',
#   'กรัม',
#   'กิโล'],
#  '^(?!.*ผัก).*ชีส.*|Mozzarella cheese': ['',
#   'ถุง',
#   'ถ้วย',
#   'กำมือ',
#   'กระป๋อง',
#   'g',
#   'ตามชอบ',
#   'ปริมาณตามชอบ',
#   'แผ่น',
#   'โรยหน้า',
#   'แล้วแต่ชอบ',
#   'ขีด',
#   'as desire',
#   'ชิ้น',
#   'แท่ง',
#   'ช้อนโต๊ะ',
#   'เส้น',
#   'กรัม'],
#  'พริกหยวก|พริกสามสี': ['',
#   'กรัม',
#   'ถ้วย',
#   'ดอด',
#   'เม็ด',
#   'ตามใจชอบ',
#   'เม็ดใหญ่',
#   'เล็กน้อย',
#   'หัว',
#   'ดอก',
#   'อัน',
#   'ผล',
#   'ลูก',
#   'อย่างละนิด'],
#  'เส้นหมี่(?!ซั่ว|ฮกเกี้ยน|เหลือง|ไวไว|หมี่ขาว)|หมี่ขาว|^เส้น$': ['',
#   'กก',
#   'กรัม',
#   'ห่อเล็ก',
#   'พอ',
#   'ซอง',
#   'ห่อใหญ่',
#   'ถุง',
#   'แล้วแต่',
#   'ห่อ',
#   'กรับ',
#   'จาน',
#   'กำ',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'g',
#   'ชาม',
#   'ขีด',
#   'เล็กน้อย',
#   'ก้อน',
#   'กำมือ'],
#  'มะเขือเปราะ': ['', 'ตามชอบ', 'ผล', 'ลูก', 'กรัม'],
#  'พริกเผา': ['ช้อนโต้ะ',
#   'มล.',
#   'กระป๋อง',
#   'ชช.',
#   'ช้อนโต๊ะ',
#   'ช้อนโโต๊ะ',
#   'ตามที่มี',
#   'กป',
#   'ชต.',
#   'ช่อนชา',
#   'ซอง',
#   'ชต',
#   'ช้อนโต๊ะพูนๆ',
#   'ชต พูนๆ',
#   'ช้อน/ถ้วย',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ช้อน',
#   'ช้อนชา'],
#  'ซี่โครงหมู': ['KG',
#   'กก',
#   'กก.',
#   'g',
#   'แผ่น',
#   'ขีด',
#   'kg',
#   'ชิ้น',
#   'เส้น',
#   'ชิ้นใหญ่',
#   'กรัม',
#   'กิโล'],
#  'เหล้า|สาเก': ['ถ้วย', 'tbsp', 'ชช.', 'ชช', 'ช้อนโต๊ะ', 'ฝา', 'ชต', 'ช้อนชา'],
#  'กิมจิ': ['ถุง',
#   'ถ้วย',
#   'ตามชอบ',
#   'ถุงเล็ก',
#   'ห่อ',
#   'ถต.',
#   'ช้อนโต๊ะ',
#   'ช้อน',
#   'กรัม'],
#  'ออริกาโน่|อาริกาโน|ออริกาโน|oregano': ['',
#   'ตามชอบ',
#   'ก็แล้วแต่ชอบ',
#   'ชช.',
#   'ช้อน',
#   'นิดหน่อย',
#   'เล็กน้อย',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'ช้อนชา'],
#  'มายองเนส': ['',
#   'ถุง',
#   'mm',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'ชช.',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช้อนโต๊ะ',
#   'g.',
#   'ช้อนชา'],
#  'น้ำจิ้มสุกี้': ['',
#   'ขวด',
#   'ช้อนโต้ะ',
#   'ถ้วย',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'เหยาะๆ ลงไป',
#   'ชต.',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'ขิง': ['',
#   'tbsp',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ตามใจชอบ',
#   'หัว',
#   'ชต',
#   'แง่ง',
#   'ข้อนิ้ว',
#   'นิดหน่อย',
#   'ถ้วย',
#   'แว่น',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'หนึ่งเสี้ยวเล็ก',
#   'ขีด',
#   'กำมือ',
#   'ชช',
#   'ช้อนชา'],
#  'ชะอม': ['กำ',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'แพ',
#   'ตามชอบ',
#   'แล้วแต่ชอบ',
#   'มัด',
#   'กำมือ',
#   'กรัม'],
#  '^ผัก$|ผักที่ชอบ': ['',
#   'ตามความชอบ',
#   'ตามชอบ',
#   'ตามใจชอบ',
#   'ตามต้องการ',
#   'กรัม'],
#  '^ผัก$|ผักต่างๆ|ผักสด|ผักเครื่องเคียง|ผักตามชอบ': ['',
#   'ตามความชอบ',
#   'ตามชอบ',
#   'ตามชอบใจ',
#   'ตามใจชอบ',
#   'แล้วแต่เราใส่',
#   'จาน',
#   'กรัม'],
#  'แหนม|เเหนม': ['',
#   'กรัม',
#   'แพ๊คเล็ก',
#   'ท่อนเล็ก',
#   'g',
#   'เม็ด',
#   'ท่อน',
#   'ห่อ',
#   'ท่อนยาว',
#   'ขีด',
#   'แท่งเล็ก',
#   'อัน',
#   'ชิ้น',
#   'แท่ง',
#   'ช้อนโต๊ะ',
#   'ลูก',
#   'ช้อนชา'],
#  'นมข้น': ['ถ้วยตวง', 'ถ้วย', 'มล.', 'กระป๋อง', 'ชต', 'ช้อนโต๊ะ', 'ช้อน'],
#  'มักกะโรนี|มะกะโรนีต้มสุก|มะกะโรนี': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'ถ้วย สำหรับ  ท่าน',
#   'ชาม',
#   'ห่อ',
#   'ตามใจชอบ',
#   'ฟอง',
#   'กำมือ',
#   'เส้น',
#   'จาน',
#   'g.',
#   'กรัม'],
#  'อบเชย': ['ท่อน', 'ช้อนชา', 'อัน', 'ชิ้น', 'แท่ง', '/', 'กรัม'],
#  'ตับ': ['',
#   'กก',
#   'ไม้',
#   'บาท',
#   'ตับ',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ตามใจชอบ',
#   'กิโล',
#   'พวง',
#   'ชิ้นฝ่ามือ',
#   'Kg.',
#   'กก.',
#   'ถ้วย',
#   'ขีด',
#   'โล',
#   'ก้อน'],
#  'หมูกรอบ': ['ถ้วย', 'ตามชอบ', 'ขีด', 'เส้น', 'กรัม', 'กิโล'],
#  'ผักโขม|ผักขม': ['ถุง',
#   'ต้น',
#   'ถ้วย',
#   'g',
#   'ตามชอบ',
#   'แล้วแต่',
#   'แพ็ค',
#   'เล็กน้อย',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'ตามต้องการ',
#   'กรัม'],
#  'เส้นจันทน์': ['กำ', 'กิโลกรัม'],
#  'ใบเบย์': ['ใบ'],
#  'ปลาแผ่น': ['ชิ้น', 'แท่ง', 'เส้น'],
#  '^มันหมู$': ['ช้อนโต๊ะ', 'ขีด'],
#  'ขาไก่': ['กก', 'ขา', 'ก.ก.'],
#  'แปะก๊วย': ['เมล็ด', 'กรัม', 'ขีด'],
#  'วาซาบิ': ['', 'ช้อนชา'],
#  '^ฟัก$': ['ลูก', 'ขีด'],
#  'ไทม์': ['', 'ต้น', 'tps', 'tsp', 'ก้าน', 'หยิบมือ'],
#  'โคชูจัง': ['ถ้วยตวง', 'ถ้วย', 'ชต.', 'กรัม', 'ช้อนโต๊ะ', 'ช้อนชา'],
#  'ซีอิ๊วเห็ดหอม|ซีอิ้วเห็ดหอม': ['ถ้วยตวง',
#   'แล้วแต่ชอบ',
#   'นิดหน่อย',
#   'ช้อนโต๊ะ',
#   'ตามต้องการ',
#   'ช้อนชา'],
#  'ไข่กุ้ง': ['ตามชอบ',
#   'แล้วแต่ชอบ',
#   'ชต.',
#   'เล็กน้อย',
#   'กรัม',
#   'ชต',
#   'ช้อนชา'],
#  '^(?!.*น้ำพริก).*มันกุ้ง.*': ['ช้อนโต้ะ',
#   'ขีด',
#   'โล',
#   'ตัว',
#   'ช้อนโต๊ะ',
#   'ชต'],
#  '^เต้าหู้(?!ไข่)': ['หั่นชิ้น',
#   'ถ้วยตวง',
#   'กล่อง',
#   'หลอด',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'แพค',
#   'แผ่น',
#   'ตามใจชอบ',
#   'ชต.',
#   'อัน',
#   'ลูก',
#   'ช้อนโต็ะ',
#   'ก้อนสี่เหลี่ยม',
#   'พวง',
#   'แล้วแต่ชอบ',
#   'ถ้วย',
#   'ตามชอบ',
#   'ก้อน'],
#  'ทูน่า': ['',
#   'กระป๋อง',
#   'กป',
#   'ตัว/กระป๋อง',
#   'ถต.',
#   'กระป๋องเล็ก',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'เบค่อน': ['', 'ตามชอบ', 'แพค', 'ห่อ', 'เส้น', 'กรัม'],
#  'กระเฉด|ผักกะเฉด': ['',
#   'กำ',
#   'ต้น',
#   'ถ้วย',
#   'ตามชอบ',
#   'กำเล็ก',
#   'ขีด',
#   'เล็กน้อย',
#   'กำมือ',
#   'จาน',
#   'กรัม'],
#  'เกี๊ยว': ['',
#   'ถุง',
#   'ถ้วย',
#   'ตามชอบ',
#   'แผ่น',
#   'แพ็ค',
#   'ห่อ',
#   'ชิ้น',
#   'ลูก',
#   'กรัม'],
#  'สะตอ|สตอ': ['',
#   'ต้น',
#   'ถ้วย',
#   'มล.',
#   'ฝัก',
#   'ฟัก',
#   'ตามชอบ',
#   'เม็ด',
#   'แพ็ค',
#   'ตามใจชอบ',
#   'กรัม'],
#  'ถั่วลิสง': ['',
#   'กำ',
#   'ช้อนโต็ะ',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'ถ้วยตวง',
#   'ถุง',
#   'ตามชอบ',
#   'ตามใจชอบ',
#   'ขีด',
#   'สำหรับโรย',
#   'ชต.',
#   'กรัม',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'ช้อนชา'],
#  'เส้นเล็ก|เส้นผัดไท': ['',
#   'กำ',
#   'ตามชอบ',
#   'ห่อ',
#   'ถ้วยใหญ่',
#   'หัว',
#   'กำมือ',
#   'หยิบมือ',
#   'กรัม'],
#  'ซอสเทริยากิ|ซอสเทอริยากิ': ['', 'ถ้วย', 'ช.ต.', 'ช้อนโต๊ะ', 'ชต'],
#  'เลือด': ['หลอด', 'ขีด', 'กรัม', 'ก้อน'],
#  'ฟักทอง': ['',
#   'ถ้วยตวง',
#   'g',
#   'ชิ้นเล็ก',
#   'ลูกเล็ก',
#   'ตามชอบ',
#   'ชิ้น',
#   'พอ',
#   'ลูก',
#   'กรัม'],
#  'ใบกระวาน': ['ใบ'],
#  'กุยช่าย|กุ้ยช่าย|กุ่ยช่าย|ใบกุ้ยฉ่าย': ['',
#   'กำ',
#   'ต้น',
#   'ช้อนโต็ะ',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'ขีด',
#   'เล็กน้อย',
#   'นิ้ว',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  'ผงกะหรี่|ผงกระหรี่': ['tbs',
#   'ถุงเล็ก',
#   'ชต.',
#   'กล่อง',
#   'นิดหน่อย',
#   'ก้อน',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'ช้อน',
#   'ช้อนชา'],
#  'มะเขือพวง': ['ถ้วย',
#   'ตามชอบ',
#   'ตามใจชอบ',
#   'หยิบมือ',
#   'กำมือ',
#   'ลูก',
#   'กรัม'],
#  'มะเขือยาว': ['กก', 'อัน', 'ผล', 'ขีด   ลูก', 'ลูก', 'กิโล'],
#  'เส้นก๋วยเตี๋ยว': ['',
#   'ถุง',
#   'กก',
#   'กำ',
#   'ถ้วย',
#   'กิโลกรัม',
#   'ตามชอบ',
#   'กำมือ',
#   'ห่อเล็ก',
#   'กรัม',
#   'กิโล'],
#  'น้ำพริก(?!เผา)|พริกหนุ่ม': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ตามชอบ',
#   'เม็ด',
#   'ช.ต.',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช้อนชา',
#   'ขีด',
#   'ช้อน',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'กรัม',
#   'กิโล'],
#  'เม็ดมะม่วง': ['',
#   'กำ',
#   'ถ้วย',
#   'g',
#   'ถุงเล็ก',
#   'ตามชอบ',
#   'ตามใจชอบ',
#   'สำหรับโรย',
#   'ช้อนชา',
#   'กรัม/ตามชอบ',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  '^ข้าวโพด(?!อ่อน)|ผักสามสี': ['',
#   'อย่างละ ช้อน',
#   'ถ้วย',
#   'ถ้วยเล็ก',
#   'ฝัก',
#   'ฟัก',
#   'ตามชอบ',
#   'ชต.',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'ตามต้องการ',
#   'ชต',
#   'กรัม'],
#  'เส้นเซี่ยงไฮ้': ['ห่อ', 'กรัม'],
#  'เส้นปลา|ปลาเส้น': ['ชิ้น', 'ห่อ', 'เส้น'],
#  'บะหมี่(?!กึ่ง)|หมี่เหลือง|เส้นหมี่ฮกเกี้ยน|เส้นหมี่เหลือง|หมี่ฮ่องกง|เส้นเหลือง|หมี่หยก|หมี่เบตง|หมี่ฮกเกี้ยน|^เส้น$': ['',
#   'ถ้วยตวง',
#   'มล.',
#   'คนทาน',
#   'ก.ก.',
#   'kg',
#   'กรัม',
#   'แพ',
#   'หัว',
#   'ซอง',
#   'กิโล',
#   'ถุง',
#   'ขวด',
#   'ห่อ',
#   'หยิบมือ',
#   'กิโลกรัม',
#   'ตามชอบ',
#   'ก้อน/ที่',
#   'ก้อน',
#   'กำมือ'],
#  'หน่อไม้': ['',
#   'กก',
#   'ถ้วยเล็ก',
#   'kg.',
#   'แท่ง',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'ต้น',
#   'ทัพพี',
#   'กิโล',
#   'ถุง',
#   'หน่อ',
#   'ถ้วย',
#   'กก.',
#   'กิโลกรัม',
#   'ตามชอบ',
#   'แพ็ค',
#   'ขีด',
#   'กำมือ',
#   'g.'],
#  'มะขามเปียก': ['',
#   'ปั้น',
#   'ปรุงรสตามชอบ',
#   'ถ้วย',
#   'ทัพพี',
#   'ฝัก',
#   'พอ',
#   'ตามชอบ',
#   'ช้อนตักแกง',
#   'ชต.',
#   'นิดหน่อย',
#   'กรัม',
#   'ช้อนโต๊ะ',
#   'ช่้อนโต๊ะ',
#   'ชต',
#   'ช้อนชา',
#   'กระบวย'],
#  'แป้งอเนกประสงค์|แป้งสาลีอเนกประสงค์|แป้งสาลี|แป้งเอนกประสงค์': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ชต.',
#   'ถต.',
#   'ช้อนโต๊ะ',
#   'ช้อน',
#   'กรัม'],
#  'ตั้งฉ่าย|ตังฉ่าย': ['ถ้วย',
#   'ตามชอบ',
#   'เล็กน้อย',
#   'ช้อนโต๊ะ',
#   'หยิบมือ',
#   'ช้อนชา'],
#  'ดอกกะหล่ำ|กะหล่ำดอก|ดอกกระหล่ำ': ['',
#   'กำมือ',
#   'g',
#   'หัวเล็ก',
#   'หัวใหญ่',
#   'หัว',
#   'ชิ้น',
#   'ตามต้องการ',
#   'กรัม'],
#  'พาสต้า|pasta': ['',
#   'ก.',
#   'ถ้วย',
#   'กระป๋อง',
#   'g',
#   'เล็กน้อย',
#   'กำมือ',
#   'ซอง',
#   'กรัม'],
#  '^ขนมปัง': ['', 'g', 'แผ่น', 'ห่อ', 'แพ็ค', 'ก้อน', 'ชิ้น'],
#  'บล็อคโคลี่|บล๊อคโคลี่|บล็อคโครี่|บล๊อกโคลี่|บรอคคอลลี่|บร็อคโคลี่|บร๊อคโคลี่|บล็อกโคลี่': ['',
#   'ต้น',
#   'ถ้วยตวง',
#   'g',
#   'ตามชอบ',
#   'พอ',
#   'ตามใจชอบ',
#   'หัว',
#   'ก้าน',
#   'ช้อนโต๊ะ',
#   'ตามต้องการ',
#   'กรัม'],
#  'น้ำเชื่อม': ['',
#   'ml.',
#   'ทัพพี',
#   'ตามชอบ',
#   'ชต.',
#   'กรัม',
#   'ช้อนโต๊ะ',
#   'ช้อน',
#   'ช้อนชา'],
#  'น้ำจิ้มไก่': ['', 'ขวด', 'ช้อนโต๊ะ', 'ช้อน'],
#  'หมี่ซั่ว': ['กำ', 'แพค', 'ห่อ', 'ก้อน', 'กำมือ', 'ใจ', 'กรัม'],
#  'โป๊ยกั๊ก': ['ชิ้น', 'ดอก', 'อัน'],
#  'น้ำกระเทียมดอง': ['ม.ล', 'ช้อนโต๊ะ', 'กรัม'],
#  'มะละกอ': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ตามชอบ',
#   'ลูก',
#   'ตามใจชอบ',
#   'กำมือ',
#   'หยิบมือ',
#   'กรัม'],
#  '^(?!.*น้ำ).*มะพร้าว.*': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ชต.',
#   'ขีด',
#   'หัว',
#   'โล',
#   'กรัม',
#   'กำมือ',
#   'ช้อนโต๊ะ',
#   'ช้อนชา'],
#  'ปู(?!อัด)': ['กก.',
#   'ตามใจเรา',
#   'ถ้วย',
#   'มล.',
#   'ปริมาณตามชอบ',
#   'g',
#   'ขีด',
#   'ถ้วยเล็กๆ',
#   'ตัวเล็ก',
#   'โล',
#   'kg',
#   'ตัว',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'กิโล'],
#  '^(?!.*เป็ด).*พะโล้': ['ชุด',
#   'ตามชอบ',
#   'ห่อ',
#   'ชาม',
#   'ขีด',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'เส้น',
#   'กรัม'],
#  'น้ำสต๊อก|น้ำสต็อก|น้ำสต้อค': ['',
#   'ถ้วยตวง',
#   'ถ้วย',
#   'ชาม',
#   'เล็กน้อย',
#   'นิดหน่อย',
#   'ก้อน',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'กระบวย'],
#  'หมูหยอง': ['', 'ตามชอบ', 'ขีด', 'ช้อนโต๊ะ', 'หยิบมือ'],
#  'ตีนไก่': ['กก', 'ตีน', 'Kg', 'โล', 'กรัม', 'กิโล'],
#  'สับปะรด|สัปปะรด': ['ถ้วย',
#   'ชิ้นเล็ก',
#   'หัว',
#   'ชิ้น',
#   'ml',
#   'ผล',
#   'ชช',
#   'ช้อนชา',
#   'ลูก',
#   'ชต',
#   'กรัม'],
#  'ฟองเต้าหู้': ['ถุง', 'ถ้วย', 'แพ', 'แผ่น', 'ห่อ', 'ช้อนโต๊ะ', 'กรัม'],
#  'น้ำสลัด': ['',
#   'ml.',
#   'ถ้วย',
#   'ตามชอบ',
#   'ตามใจชอบ',
#   'ชต.',
#   'ช้อนโต๊ะ',
#   'ซอง',
#   'ขวดเล็ก'],
#  'มัสตาร์ด': ['', 'ตามชอบ', 'ช้อนโต๊ะ', 'ช้อน', 'ช้อนชา'],
#  'พริกหวาน': ['ถ้วย',
#   'เม็ด',
#   'ลูกเล็ก',
#   'ตามชอบ',
#   'ชต.',
#   'ขีด',
#   'หัว',
#   'นิดหน่อย',
#   'ตามต้องการ',
#   'ลูก',
#   'กรัม'],
#  'มะระ': ['', 'ลูก', 'กรัม', 'อัน'],
#  'แครรอท': ['เส้น', 'หัว', 'ถ้วย', 'กรัม'],
#  'เก๋ากี้': ['เม็ด', 'ช้อนโต๊ะ', 'ถ้วย'],
#  '^(?!.*น้ำ|ซอส|ซอย|นำ้|ซอล|ไวไว|นํ้ามัน).*หอย.*': ['',
#   'KG',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'แพค',
#   'ซอง',
#   'กิโล',
#   'ก.',
#   'ห่อ',
#   'ตัว',
#   'กแ',
#   'ถ้วย',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ขีด',
#   'โล'],
#  'อุด้ง': ['ถุง', 'ตามช', 'มัด', 'ช้อนโต๊ะ', 'กรัม'],
#  '^มะม่วง': ['',
#   'สำหรับเสิร์ฟ',
#   'ถ้วย',
#   'หยิบมือ',
#   'ผล',
#   'ช้อนโต๊ะ',
#   'ลูก',
#   'กรัม'],
#  'โครงไก่': ['ชิ้น', 'ตัว', 'โครง'],
#  'ข้าวไรซ์เบอรี่|ข้าวไรซ์เบอร์รี่': ['ถ้วย',
#   'ทัพพี',
#   'ทัฟพี',
#   'ห่อ',
#   'กรัม',
#   'เสิร์ฟ'],
#  'หมูแดง': ['ถ้วยตวง', 'ทั้งหมด', 'แผ่น', 'ขีด', 'เส้น', 'ซอง', 'จาน', 'กรัม'],
#  'โรสแมรี่': ['tps',
#   'ตามชอบ',
#   'ชช.',
#   'ก้าน',
#   'ชช',
#   'ช้อนโต๊ะ',
#   'หยิบมือ',
#   'ช้อนชา'],
#  'ต้นอ่อนทานตะวัน|ยอดอ่อนทานตะวัน': ['',
#   'ถุง',
#   'ต้น',
#   'ถ้วย',
#   'ตามชอบ',
#   'ขีด',
#   'กรัม'],
#  'เส้นยากิโซบะ': ['ถ้วย', 'กรัม'],
#  'ลูกผักชี': ['หยิบ', 'ตามชอบ', 'ช้อนโต๊ะ', 'ลูก', 'ช้อนชา'],
#  'ไส้อั่ว': ['ชิ้นเล็ก', 'กก', 'ชิ้น', 'กรัม'],
#  'สะระแหน่|ใบสาระแหน่': ['', 'หยิบ', 'ต้น', 'ถ้วย', 'ตามชอบ', 'กำมือ', 'กรัม'],
#  'เส้นก๋วยจั๊บ': ['กก.', 'ห่อ', 'ขีด', 'ถ้วยใหญ่', 'กำมือ', 'กรัม'],
#  'ผงฟู': ['ชช', 'ช้อนโต๊ะ', 'ช้อน', 'ช้อนชา'],
#  'ฮอตดอก': ['ชิ้น', 'แท่ง', 'อัน'],
#  '^(?!.*ลูกชิ้น|หมู).*เนื้อ(?!.*หมู|.*ไก่|กุ้ง|ปลา|ปู|หอย|เป็ด)': ['',
#   'กระป๋อง',
#   'ก.ก.',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'โครง',
#   'tbs',
#   'ใส่/ไม่ใส่',
#   'ตัว',
#   'กก.',
#   'ถ้วย',
#   'ตามความชอบ',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ก้อนเล็ก',
#   'ขีด',
#   'โล',
#   'ช้อนชา'],
#  '^แป้ง$|แป้งชุปทอด': ['ถุง', 'ช้อนโต๊ะ', 'ชต.'],
#  'ซอสเย็นตาโฟ': ['', 'ถ้วยตวง', 'ถ้วย', 'ช้อนโต๊ะ', 'กรัม'],
#  'น้ำจิ้มซีฟู้ด': ['ตามชอบ', 'ช้อนโต๊ะ', 'ถ้วย', 'ถ้วยน้ำจิ้ม'],
#  'แตงร้าน': ['ผล', 'ลูก'],
#  'มะเขือม่วง': ['หัว', 'ลูก'],
#  'กระดูกอ่อน': ['กก', 'กก.', 'กิโลกรัม', 'kg', 'กรัม', 'กิโล'],
#  'แป้งข้าวเจ้า': ['ช้อนโต๊ะ', 'ถ้วยตวง', 'กรัม'],
#  'สาหร่าย': ['',
#   'โรยตามชอบ',
#   'ถ้วย',
#   'กำมือ',
#   'ตามชอบ',
#   'แผ่น',
#   'ชต.',
#   'ชิ้น',
#   'ตามจำนวนข้าวที่ปั้นได้'],
#  'โยเกิร์ต': ['ถ้วย', 'แก้ว', 'ชต.', 'ช้อนโต๊ะ', 'กรัม'],
#  '(^ปลา(?!หมึก|กระป๋อง|ร้า|แผ่น|เส้น))|แซลมอน|เนื้อปลา': ['',
#   'กก',
#   'ถ้วยตวง',
#   'กระป๋อง',
#   'ชื้น',
#   'กระป๋องเล็ก',
#   'kg',
#   'ชิ้น',
#   'ช้อนโต๊ะ',
#   'กรัม',
#   'แพค',
#   'ตามสะดวก',
#   'ป๋อง',
#   'ตามต้องการ',
#   'ตัวใหญ่',
#   'ขึด',
#   'กิโล',
#   'ชิ้นเล็ก',
#   'ตัว/กระป๋อง',
#   'ถต.',
#   'ตัว',
#   'จาน',
#   'ชิ้นใหญ่',
#   'ชิ้นขนาดกลาง',
#   'ถ้วย',
#   'กก.',
#   'กิโลกรัม',
#   'g',
#   'ตามชอบ',
#   'ท่อน',
#   'ขีด',
#   'โล',
#   'ต้ว',
#   'g.',
#   'ช้อนชา'],
#  'ผงขมิ้น|^ขมิ้น$': ['แง่ง', 'หัว', 'ชช', 'ช้อนโต๊ะ', 'ช้อนชา'],
#  'ก้านพลู': ['ก้าน', 'ช้อนโต๊ะ'],
#  'เส้นบุก': ['ถุง', 'ห่อ', 'ตามชอบ', 'กรัม'],
#  'แขนง': ['ถุง', 'ต้น', 'หัว', 'บาท', 'กรัม'],
#  'ซอสภูเขา': ['', 'ช.ต.', 'ช้อนโต๊ะ', 'ช้อน', 'ช้อนชา'],
#  'เครื่องใน': ['ชุด', 'ตามใจชอบ', 'กรัม'],
#  'ยี่หร่า|ผง cumin': ['', 'กำ', 'หยิบ', 'ช้อนโต๊ะ', 'ใบ', 'ช้อนชา'],
#  'โบโลน่า': ['', 'แผ่น', 'ห่อ', 'กรัม'],
#  'หัวปลี': ['', 'หัว', 'สำหรับเสิร์ฟ', 'กรัม'],
#  'ครีม': ['mL',
#   'มิลลิลิตรึ',
#   'ถ้วย',
#   'มล.',
#   'กระป๋อง',
#   'ตามชอบ',
#   'มิลลิลิตร',
#   'ml',
#   'ช้อนโต๊ะ',
#   'ชต',
#   'กรัม'],
#  '^กากหมู$': ['ตามชอบ', 'นิดหน่อย', 'ถ้วย', 'กรัม'],
#  'กระเพาะปลา': ['โล', 'กรัม', 'ขีด'],
#  'ไวน์ขาว': ['mL', 'ช้อนโต๊ะ', 'ถ้วย'],
#  'ถั่วหวาน': ['', 'ตามใจชอบ', 'ขีด', 'เหลืออยู่ก็กินต่อให้หมด', 'กรัม'],
#  'แป้งท้าวยายม่อม|แป้งท้าว|แป้งเท้า': ['', 'ช้อนโต๊ะ', 'ชต', 'กรัม'],
#  'หมี่กรอบ': ['ถุง', 'ถ้วย', 'ก้อน'],
#  'ตำลึง': ['', 'กำ', 'ต้น', 'กำมือ', 'กรัม'],
#  'ซอสเพสโต้': ['ตามชอบ', 'ช้อนโต๊ะ', 'ชต'],
#  'เครื่องแกงเขียวหวาน': ['ช้อนโต๊ะ', 'ขีด'],
#  'หนำเลี๊ยบ': ['เม็ด', 'เมล็ด'],
#  'ข้าวเหนียว': ['ก้อน', 'ถ้วยตวง', 'ถ้วย', 'kg'],
#  'ดอกหอม': ['ต้น', 'กรัม', 'ขีด'],
#  '^(?!เบคกิ้ง)โซดา|น้ำโซดา': ['ขวด', 'ถ้วย'],
#  'ถั่วพู': ['ฝัก', 'กรัม', 'ฟัก'],
#  'เส้นแก้ว': ['กำมือ', 'กรัม'],
#  'เครื่องต้มยำ': ['ซอยตามใจชอบ', 'ชุด', 'ช้อนชา'],
#  'เผือก': ['หัว', 'ถ้วยเล็ก', 'กรัม'],
#  'ก้อนแกงกะหรี่ญี่ปุ่น': ['กล่อง', 'แพ็ค', 'ก้อน'],
#  'โปรตีนเกษตร': ['ตามชอบ', 'ถ้วยตวง', 'ถ้วย'],
#  'บ๊วยดอง': ['เม็ด', 'ลูก'],
#  'ไชโป๊ว': ['ชต.', 'กำมือ', 'เส้น', 'ช้อนโต๊ะ', 'หยิบมือ', 'กรัม'],
#  'แคปหมู': ['สำหรับเสิร์ฟ', 'ถ้วย'],
#  'พาร์สลีย์|พาสลี่|พาสลีย์|parsley': ['',
#   'cup',
#   'ถ้วย',
#   'ปริมาณตามชอบ',
#   'ตามชอบ',
#   'สำหรับตกแต่ง',
#   'เล็กน้อย',
#   'กิ่ง',
#   'ช้อนโต๊ะ',
#   'ตามต้องการ',
#   'ตกแต่ง',
#   'ช้อนชา'],
#  'บวบ': ['', 'ถ้วยตวง', 'ลูก', 'อัน'],
#  'ใบเตย': ['ตามชอบ', 'ช้อนโต๊ะ', 'ใบ', 'ช้อนชา'],
#  'ใบเหลียง': ['กำ', 'แพ็ค', 'จานพูนๆ'],
#  'เบคกิ้งโซดา': ['ชช', 'ช้อนชา', 'ชช.'],
#  '^(?!ไข่)เป็ด|เนื้อเป็ด|อกเป็ด': ['น่อง',
#   'ถ้วย',
#   'กิโลกรัม',
#   'ขีด',
#   'ชิ้น',
#   'อก',
#   'ตัว',
#   'กรัม'],
#  'แมงลัก': ['', 'กำ', 'ต้น', 'ตามชอบ', 'กรัม'],
#  '^ถั่ว$|ถั่วป่น|ถั่วคั่ว': ['ถ้วย',
#   'ตามชอบ',
#   'ชต.',
#   'บาท',
#   'ช้อนโต๊ะ',
#   'กรัม'],
#  '^มะเขือ$': ['', 'ลูก'],
#  'ไก่จ๊อ': ['ชิ้น', 'ลูก'],
#  'ถั่วแดง': ['ตามชอบ', 'เมล็ด'],
#  'ดอกไม้กวาด': ['กำ'],
#  'Angel Hair|เส้นแองเจิลแฮร์|เส้น angel hair': ['grams', 'ห่อ', 'กรัม'],
#  'แป้งพิซซ่าสำเร็จ': ['แผ่น'],
#  'ควินัว|คีนัว': ['ถต.', 'ถ้วย', 'กรัม'],
#  'น้ำเลม่อน': ['ช้อนโต๊ะ', 'tbsp'],
#  'เครื่องยาจีน': ['ชุด', 'ซอง', 'กรัม'],
#  'ข้าวโอ๊ต': ['ถ้วยตวง', 'มิลลิลิตร', 'กรัม'],
#  'ดอกชมจันทร์': ['ถุง', 'กรัม'],
#  'เยื่อไผ่': ['ถุง', 'ถ้วย'],
#  'แป้งต็อก': ['กรัม'],
#  '^มะกอก': ['เม็ด', 'ลูก', 'กรัม'],
#  'เครื่องแกงใต้': ['ช้อนโต๊ะ'],
#  'ใบชะพลู': ['ตามชอบ', 'สำหรับเสิร์ฟ'],
#  'มาการีน': ['ช้อนชา', 'ก้อน'],
#  '^แกงกะหรี่|กะหรี่แกง': ['ถาด', 'นึงของกล่อง', 'g', 'กล่อง', 'ก้อน', 'ซอง'],
#  'ใบยอ': ['ใบ', 'กรัม'],
#  'น้ำบูดู': ['ช้อนโต๊ะ', 'ถ้วย'],
#  'ไข่ปลาหมึก': ['ตามชอบ', 'กรัม'],
#  'ดีปลีผง': ['ช้อนชา'],
#  'เครื่องตุ๋นยาจีน': ['ตามชอบ', 'ซอง'],
#  'เซี่ยงจี้': ['โล', 'ขีด'],
#  'น้ำอ้อย': ['ช้อนโต๊ะ', 'กิโลกรัม'],
#  'เพนเน่': ['ก.', 'ถ้วย', 'ห่อ', 'กำมือ', 'กรัม'],
#  'ดอกโสน': ['ขีด'],
#  'ซุคคีนี': ['ผล', 'ถ้วย'],
#  'ยีสต์': ['ช้อนชา', 'กรัม'],
#  'ผักขม': ['ตามต้องการ', 'แล้วแต่', 'ถ้วย'],
#  'ถั่วแขก': ['', 'กก.', 'กรัม'],
#  'ลูกกระวาน': ['ลูก'],
#  'น้ำอาจาด': ['ขวด'],
#  'ข้าวมัน': ['ช้อนโต๊ะ', 'กลีบ', 'ถ้วย', 'แว่น'],
#  'มันบด': ['ชิ้น']}

# %%
import json

with open('../dictionary/ingredient_dict_reqex.json','w',encoding='utf8')as file:
  json.dump(tmp_dict,file,ensure_ascii=False)

# %%
dict_name= {}
for i in range(len(df_name)):
  dict_name[df_ch_regex[i]] =  df_name[i]

# %%
dict_name
# Out:
# {'น้ำปลา': 'น้ำปลา(?!ร้า)',
#  'กระเทียม': '^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม|กระเทียวเจียว|กระเทียบ|กระทียมสับ|garlic|^น้ำจิ้ม กระเทียม$',
#  'ไข่ไก่': '^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))|ไก่ไข่',
#  'น้ำตาล': 'น้ำตาล(?!หญ้าหวาน)|นำ้ตาลทราย',
#  'เกลือ': 'เกลือ|salt|เกลอ',
#  'ซอสปรุงรส': 'ซอสปรุงรส|ซอสฝาเขียว|ซอสฝาเหลือง|ซอสแมคกี้|ซอสแม็กกี้|ซอสข้นปรุงรสคนอร์|แม๊กกี้|ซอส|แม็กกี้|คนอร์ซอสข้นปรุงรสหมู|ซอสข้นคนอร์|ซอลปรุงรส|แมกกี้|ซ้อสปรุงรส',
#  'น้ำมันหอย': 'น้ำมันหอย|ซอสหอย|ซอยหอยนางรม|นำ้มันหอย|ซอลหอยนางรม|นํ้ามันหอย',
#  'น้ำมัน': 'น้ำมัน(?!(หอย|พริกเผา|งา))|olive oil|oil',
#  'น้ำเปล่า': 'น้ำเปล่า|น้ำสะอาด|น้ำต้มสุก|^น้ำ$|น้ำเย็น|น้ำร้อน|น้ำดื่ม|น้ำอุ่น|น้ำสำหรับต้มเส้น',
#  'ซีอิ๊วขาว': 'ซีอิ๊วขาว|ซีอิ้วขาว|ซอสถั่วเหลือง|ซีอิ๋วขาว|สี่อิ๋วขาวสูตร1|ซีอิ้วปรุงรส|^ซีอิ๊ว$|ซี๊อิ๋วขาว|ซีอิ้ว ขาว|ซีอิ้ว|ชีอิ้วขาว|ซี้อิ้วขาว|ซีอี๊วขาว|ชีอิ๊วขาว|ซีอิ๋ว|ซี่อิ๋วขาวสูตร1|สี่อิ๋วขาวสูตร 2|soy sauce|ซีอี้วขาว|ซีอี๋วขาว|สี่อิ๋วขาวสูตร|สี่อิ่ว',
#  'พริกไทย': '^(?!.*ซอส|หมู).*พริกไทย.*|พริกไท|black pepper|Red Pepper Flakes',
#  'ต้นหอม': 'ต้นหอม|ต้มหอม|ตันหอม',
#  'แครอท': 'แครอท|แคร์รอต|แครท|ผักสามสี',
#  'เนื้อหมู': '^(?!.*บะหมี่|ผง|กระดูก|ลูกชิ้น|ซี่โครง|ตับ|น้ำมัน|น้ำสต๊อก|คนอร์|แหนม|กุนเชียง|กาก|รสดี|ซุป|น้ำ|แคป|ซอส|มัน|กระเทียม|ไส้กรอก|เลือด|แฮม).*หมู(?!ยอ|กรอบ|หยอง|แดง|แฮม).*|สามชั้นสไลซ์|สันคอ',
#  'ข้าวสวย': '^(?!.*เส้น)(.*ข้าวสวย|^ข้าว$|ข้าวกล้อง.*|ข้าวสาร|ข้าวเปล่า|ข้าวหอมมะลิ|ข้าวเย็น|ข้าวหุงสุก|ข้าวญี่ปุ่น|ข้าวสุก|ข้าวแช่เย็น|ข้าวหอม|ข้าวเสาไห้|ข้าวบาสมาติ)',
#  'น้ำมะนาว': 'มะนาว',
#  'พริกขี้หนู': 'พริกขี้หนู',
#  'กุ้ง': '^(?!.*ไข่|มัน|มาม่า).*กุ้ง(?!แห้ง).*',
#  'มะเขือเทศ': '^(?!.*ซอส|ซ้อส).*มะเขือเทศ.*',
#  'หอมใหญ่': 'หอมใหญ่|หอมหัวใหญ่|หัวหอม|หอมแขก|หอมซอย|หอมเล็กเจียว|^หอม$|หัวใหญ่',
#  'รากผักชี': 'รากผักชี',
#  'หอมแดง': 'หอมแดง|หอมเจียว|หอมเเดง',
#  'พริกแห้ง': 'พริกแห้ง',
#  'พริกป่น': 'พริกป่น',
#  'ผักชี': '^(?!.*ราก|ลูก).*ผักชี.*|ผง coriander',
#  'ซอสมะเขือเทศ': 'ซอสมะเขือเทศ|ซ้อสมะเขือเทศ',
#  'ใบมะกรูด': 'ใบมะกรูด|ใบมะกูด|มะกรูด',
#  'น้ำมันงา': 'น้ำมันงา',
#  'พริก': '^พริก$|พริกสด|พริกจินดา|พริกแดง|พริกใหญ่|พริกสับ|พริกอ่อน|พริกตำ|พริกซอย|พริกทอด|พริกสีแดง|พริกหั่น|พริกคั่ว|พริก+|พริกหั่นเฉียง',
#  'ใบโหระพา': 'โหระพา|ใบโหรพา|โหรพา',
#  'ถั่วฝักยาว': 'ถั่วฝักยาว|ถั่วฟักยาว|ถั่วผักยาว|ถัวฝักยาว',
#  'ใบกะเพรา': 'ใบกะเพรา|ใบกระเพรา|กระเพรา|กะเพรา|ใบกระเพา|ใบกระ เพรา แดง|กระเพา|Basil',
#  'เนื้อไก่': '^(?!.*ไส้กรอก|ไข่|เลือด|น้ำ|ผง|โครง|ตีน|เครื่องใน|เต้าหู้|ซี่โครง|ขา|ซอส|ตับ).*ไก่(?!จ๊อ|ไข่).*|chicken',
#  'ซีอิ๊วดำ': '^ซีอิ๊วดำ$|^ซีอิ้วดำ$|ซีอิ๋วดำ(?!หวาน)|สี่อิ๋วดำสูตรเค็ม',
#  'ถั่วงอก': 'ถั่วงอก',
#  'คะน้า': 'คะน้า',
#  'ข้าวโพดอ่อน': 'ข้าวโพดอ่อน',
#  'เนย': 'เนย',
#  'แป้งทอดกรอบ': 'แป้งทอดกรอบ|แป้งชุบทอด|แป้งโกกิ|แป้งทอด|แป้งสำหรับทอด|แป้งทอดกรอบคนอร์',
#  'แป้งมัน': 'แป้งมัน',
#  'เห็ด': '^(?!.*ซอส|ซีอิ๊ว|ผงปรุงรส|ซีอิ้ว|คนอร์).*เห็ด.*',
#  'เส้นสปาเก็ตตี้': 'เส้นสปาเก็ตตี้|เส้นสปาเกตตี้|สปาเก็ตตี้|สปาเกตตี้|เส้นสปาเกตตี|สปาเกตตี',
#  'เต้าเจี้ยว': 'เต้าเจี้ยว|เต้าเจี๊ยว|เต้าเจียว',
#  'โชยุ': 'โชยุ|ซีอิ๊วญี่ปุ่น|โชวยุ|Soba tsuyu',
#  'ตะไคร้': 'ตะไคร้|ตะใคร้',
#  'หมึก': '^(?!.*ไข่).*ปลาหมึก.*|^หมึก|หมึกกล้วย',
#  'น้ำพริกเผา': 'น้ำพริกเผา',
#  'เบคอน': 'เบคอน',
#  'ไส้กรอก': 'ไส้กรอก',
#  'นม': '^นม(?!ข้น)',
#  'ซอสพริก': 'ซอสพริก',
#  'วุ้นเส้น': 'วุ้นเส้น|^เส้น$',
#  'น้ำซุป': 'น้ำซุป|น้ำซุบ',
#  'ผักกาด': 'ผักกาด|ผัดกาดขาว|ผักคอส',
#  'กะปิ': '^กะปิ',
#  'พริกชี้ฟ้า': 'พริกชี้ฟ้า|พริกเหลือง',
#  'กะทิ': 'กะทิ|กระทิ',
#  'เส้นใหญ่': 'เส้นใหญ่|เส้นไหญ่|^เส้น$',
#  'กะหล่ำปลี': '^(?!.*ดอก)กะหล่ำ(?!.*ดอก.*)|กะหล่ำปลี|กระหล่ำปลี',
#  'ผักบุ้ง': 'ผักบุ้ง',
#  'แฮม': 'แฮม',
#  'หมูยอ': 'หมูยอ',
#  'แตงกวา': 'แตงกวา',
#  'กุ้งแห้ง': 'กุ้งแห้ง',
#  'มิริน': 'มิริน',
#  'น้ำมะขามเปียก': 'น้ำมะขามเปียก|น้ำมะขาวเปียก|น้ำมะขาม',
#  'ต้นกระเทียม': 'ต้นกระเทียม',
#  'ถั่วเน่า': 'ถั่วเน่า',
#  'หญ้าหวาน': 'หญ้าหวาน',
#  'ขึ้นฉ่าย': 'ขึ้นฉ่าย|คื่นช่าย|คึ่นช่าย|ขึ้นช่าย|คื่นไช้|คื่นไฉ่|ตั้งโอ๋',
#  'มันฝรั่ง': 'มันฝรั่ง',
#  'น้ำส้มสายชู': 'น้ำส้มสายชู|น้ำส้ม',
#  'ใบบัวบก': 'ใบบัวบก',
#  'แป้งขนมปัง': 'แป้งขนมปัง',
#  'ไซรัป': 'ซีรัป',
#  'เส้นเฟตตูชินี': 'เส้นเฟตตูชินี',
#  'ข่า': 'ข่า',
#  'บะหมี่กึ่งสำเร็จรูป': 'มาม่า|บะหมี่กึ่งสำเร็จรูป|เส้นหมี่ไวไว|ไวไว|หมี่กึง',
#  'น้ำผึ้ง': 'น้ำผึ้ง',
#  'ผงปรุงรส': '^(?!.*ซอส|แป้งทอด).*(คนอร์|รสดี).*|อร่อยชัวร์|ผงปรุงรส|เครื่องปรุงรส|ซุปก้อน|ผงซุปหมูก้อน|ชูรส|ผงซุป|ผงเติมทิพ|ผงดาชิ|ผงปาปริก้า|ดาชิ|ปาปริก้า|เครื่องปรุง|ผงปาปริกา|italian seasoning|ผงนัว|ผงหม่าล่า|ซุปหมูก้อน|ผงหมาล่า|ผงโรยข้าว',
#  'ซอสเห็ดหอม': 'ซอสเห็ดหอม|ซอสเห็ด หอม',
#  'หัวไชเท้า': 'ไชเท้า',
#  'พริกแกง': 'พริกแกง',
#  'แป้งข้าวโพด': 'แป้งข้าวโพด',
#  'ซีอิ๊วหวาน': 'ซีอิ้วดำหวาน|ซีอิ๊วดำหวาน|ซีอิ๊วหวาน|สี่อิ๋วหวาน|สี่อิ๋วดำสูตรหวาน|ซี๊อิ๋วดำหวาน',
#  'กุนเชียง': 'กุนเชียง',
#  'ข้าวคั่ว': 'ข้าวคั่ว',
#  'ผักกวางตุ้ง': 'กวางตุ้ง',
#  'ลูกชิ้น': 'ลูกชิ้น',
#  'ไข่เป็ด': 'ไข่เป็ด',
#  'ปลากระป๋อง': 'ปลากระป๋อง',
#  'ผักสลัด': 'ผักสลัด',
#  'กระดูกหมู': '^กระดูกหมู$|กระดูกเล้ง|เล้ง',
#  'ปูอัด': 'ปูอัด',
#  'เกล็ดขนมปัง': 'เกล็ดขนมปัง|เกร็ดขนมปัง',
#  'เส้นโซบะ': 'เส้นโซบะ',
#  'น้ำหวานดอกมะพร้าว': 'น้ำหวานดอกมะพร้าว',
#  'น้ำจิ้มหมูหัน': 'น้ำจิ้มหมูหัน',
#  'ถั่วแระญี่ปุ่น': 'ถั่วแระญี่ปุ่น',
#  'เต้าหู้ไข่': 'เต้าหู้ไข่',
#  'น้ำปลาร้า': 'ปลาร้า',
#  'งา': '^(?!.*น้ำ).*งา.*',
#  'ถั่วลันเตา': 'ถั่วลันเตา',
#  'กระชาย': 'กระชาย',
#  'ผงชูรส': 'ผงชูรส',
#  'ขนมจีน': 'ขนมจีน',
#  'ชีส': '^(?!.*ผัก).*ชีส.*|Mozzarella cheese',
#  'พริกหยวก': 'พริกหยวก|พริกสามสี',
#  'เส้นหมี่': 'เส้นหมี่(?!ซั่ว|ฮกเกี้ยน|เหลือง|ไวไว|หมี่ขาว)|หมี่ขาว|^เส้น$',
#  'มะเขือเปราะ': 'มะเขือเปราะ',
#  'พริกเผา': 'พริกเผา',
#  'ซี่โครงหมู': 'ซี่โครงหมู',
#  'เหล้า': 'เหล้า|สาเก',
#  'กิมจิ': 'กิมจิ',
#  'ออริกาโน่': 'ออริกาโน่|อาริกาโน|ออริกาโน|oregano',
#  'มายองเนส': 'มายองเนส',
#  'น้ำจิ้มสุกี้': 'น้ำจิ้มสุกี้',
#  'ขิง': 'ขิง',
#  'ชะอม': 'ชะอม',
#  'ผัก': '^ผัก$|ผักต่างๆ|ผักสด|ผักเครื่องเคียง|ผักตามชอบ',
#  'แหนม': 'แหนม|เเหนม',
#  'นมข้น': 'นมข้น',
#  'มักกะโรนี': 'มักกะโรนี|มะกะโรนีต้มสุก|มะกะโรนี',
#  'อบเชย': 'อบเชย',
#  'ตับ': 'ตับ',
#  'หมูกรอบ': 'หมูกรอบ',
#  'ผักโขม': 'ผักโขม|ผักขม',
#  'เส้นจันทน์': 'เส้นจันทน์',
#  'ใบเบย์': 'ใบเบย์',
#  'ปลาแผ่น': 'ปลาแผ่น',
#  'มันหมู': '^มันหมู$',
#  'ขาไก่': 'ขาไก่',
#  'แปะก๊วย': 'แปะก๊วย',
#  'วาซาบิ': 'วาซาบิ',
#  'ฟัก': '^ฟัก$',
#  'ไทม์': 'ไทม์',
#  'โคชูจัง': 'โคชูจัง',
#  'ซีอิ๊วเห็ดหอม': 'ซีอิ๊วเห็ดหอม|ซีอิ้วเห็ดหอม',
#  'ไข่กุ้ง': 'ไข่กุ้ง',
#  'มันกุ้ง': '^(?!.*น้ำพริก).*มันกุ้ง.*',
#  'เต้าหู้': '^เต้าหู้(?!ไข่)',
#  'ทูน่า': 'ทูน่า',
#  'เบค่อน': 'เบค่อน',
#  'ผักกระเฉด': 'กระเฉด|ผักกะเฉด',
#  'เกี๊ยว': 'เกี๊ยว',
#  'สะตอ': 'สะตอ|สตอ',
#  'ถั่วลิสง': 'ถั่วลิสง',
#  'เส้นเล็ก': 'เส้นเล็ก|เส้นผัดไท',
#  'ซอสเทริยากิ': 'ซอสเทริยากิ|ซอสเทอริยากิ',
#  'เลือด': 'เลือด',
#  'ฟักทอง': 'ฟักทอง',
#  'ใบกระวาน': 'ใบกระวาน',
#  'กุยช่าย': 'กุยช่าย|กุ้ยช่าย|กุ่ยช่าย|ใบกุ้ยฉ่าย',
#  'ผงกะหรี่': 'ผงกะหรี่|ผงกระหรี่',
#  'มะเขือพวง': 'มะเขือพวง',
#  'มะเขือยาว': 'มะเขือยาว',
#  'เส้นก๋วยเตี๋ยว': 'เส้นก๋วยเตี๋ยว',
#  'น้ำพริก': 'น้ำพริก(?!เผา)|พริกหนุ่ม',
#  'เม็ดมะม่วงหิมพานต์': 'เม็ดมะม่วง',
#  'ข้าวโพด': '^ข้าวโพด(?!อ่อน)|ผักสามสี',
#  'เส้นเซี่ยงไฮ้': 'เส้นเซี่ยงไฮ้',
#  'ปลาเส้น': 'เส้นปลา|ปลาเส้น',
#  'บะหมี่': 'บะหมี่(?!กึ่ง)|หมี่เหลือง|เส้นหมี่ฮกเกี้ยน|เส้นหมี่เหลือง|หมี่ฮ่องกง|เส้นเหลือง|หมี่หยก|หมี่เบตง|หมี่ฮกเกี้ยน|^เส้น$',
#  'หน่อไม้': 'หน่อไม้',
#  'มะขามเปียก': 'มะขามเปียก',
#  'แป้งอเนกประสงค์': 'แป้งอเนกประสงค์|แป้งสาลีอเนกประสงค์|แป้งสาลี|แป้งเอนกประสงค์',
#  'ตั้งฉ่าย': 'ตั้งฉ่าย|ตังฉ่าย',
#  'ดอกกะหล่ำ': 'ดอกกะหล่ำ|กะหล่ำดอก|ดอกกระหล่ำ',
#  'เส้นพาสต้า': 'พาสต้า|pasta',
#  'ขนมปัง': '^ขนมปัง',
#  'บล็อคโคลี่': 'บล็อคโคลี่|บล๊อคโคลี่|บล็อคโครี่|บล๊อกโคลี่|บรอคคอลลี่|บร็อคโคลี่|บร๊อคโคลี่|บล็อกโคลี่',
#  'น้ำเชื่อม': 'น้ำเชื่อม',
#  'น้ำจิ้มไก่': 'น้ำจิ้มไก่',
#  'หมี่ซั่ว': 'หมี่ซั่ว',
#  'โป๊ยกั๊ก': 'โป๊ยกั๊ก',
#  'น้ำกระเทียมดอง': 'น้ำกระเทียมดอง',
#  'มะละกอ': 'มะละกอ',
#  'มะพร้าว': '^(?!.*น้ำ).*มะพร้าว.*',
#  'เนื้อปู': 'ปู(?!อัด)',
#  'เครื่องพะโล้': '^(?!.*เป็ด).*พะโล้',
#  'น้ำสต๊อก': 'น้ำสต๊อก|น้ำสต็อก|น้ำสต้อค',
#  'หมูหยอง': 'หมูหยอง',
#  'ตีนไก่': 'ตีนไก่',
#  'สับปะรด': 'สับปะรด|สัปปะรด',
#  'ฟองเต้าหู้': 'ฟองเต้าหู้',
#  'น้ำสลัด': 'น้ำสลัด',
#  'มัสตาร์ด': 'มัสตาร์ด',
#  'พริกหวาน': 'พริกหวาน',
#  'มะระ': 'มะระ',
#  'แครรอท': 'แครรอท',
#  'เก๋ากี้': 'เก๋ากี้',
#  'หอย': '^(?!.*น้ำ|ซอส|ซอย|นำ้|ซอล|ไวไว|นํ้ามัน).*หอย.*',
#  'เส้นอุด้ง': 'อุด้ง',
#  'มะม่วงดิบ': '^มะม่วง',
#  'โครงไก่': 'โครงไก่',
#  'ข้าวไรซ์เบอรี่': 'ข้าวไรซ์เบอรี่|ข้าวไรซ์เบอร์รี่',
#  'หมูแดง': 'หมูแดง',
#  'โรสแมรี': 'โรสแมรี่',
#  'ต้นอ่อนทานตะวัน': 'ต้นอ่อนทานตะวัน|ยอดอ่อนทานตะวัน',
#  'เส้นยากิโซบะ': 'เส้นยากิโซบะ',
#  'ลูกผักชี': 'ลูกผักชี',
#  'ไส้อั่ว': 'ไส้อั่ว',
#  'ใบสะระแหน่': 'สะระแหน่|ใบสาระแหน่',
#  'เส้นก๋วยจั๊บ': 'เส้นก๋วยจั๊บ',
#  'ผงฟู': 'ผงฟู',
#  'ฮอตดอก': 'ฮอตดอก',
#  'เนื้อ': '^(?!.*ลูกชิ้น|หมู).*เนื้อ(?!.*หมู|.*ไก่|กุ้ง|ปลา|ปู|หอย|เป็ด)',
#  'แป้ง': '^แป้ง$|แป้งชุปทอด',
#  'ซอสเย็นตาโฟ': 'ซอสเย็นตาโฟ',
#  'น้ำจิ้มซีฟู้ด': 'น้ำจิ้มซีฟู้ด',
#  'แตงร้าน': 'แตงร้าน',
#  'มะเขือม่วง': 'มะเขือม่วง',
#  'กระดูกอ่อน': 'กระดูกอ่อน',
#  'แป้งข้าวเจ้า': 'แป้งข้าวเจ้า',
#  'สาหร่าย': 'สาหร่าย',
#  'โยเกิร์ต': 'โยเกิร์ต',
#  'เนื้อปลา': '(^ปลา(?!หมึก|กระป๋อง|ร้า|แผ่น|เส้น))|แซลมอน|เนื้อปลา',
#  'ผงขมิ้น': 'ผงขมิ้น|^ขมิ้น$',
#  'ก้านพลู': 'ก้านพลู',
#  'เส้นบุก': 'เส้นบุก',
#  'ผักแขนง': 'แขนง',
#  'ซอสภูเขา': 'ซอสภูเขา',
#  'เครื่องใน': 'เครื่องใน',
#  'ยี่หร่า': 'ยี่หร่า|ผง cumin',
#  'โบโลน่า': 'โบโลน่า',
#  'หัวปลี': 'หัวปลี',
#  'ครีม': 'ครีม',
#  'กากหมู': '^กากหมู$',
#  'กระเพาะปลา': 'กระเพาะปลา',
#  'ไวน์ขาว': 'ไวน์ขาว',
#  'ถั่วหวาน': 'ถั่วหวาน',
#  'แป้งท้าวยายม่อม': 'แป้งท้าวยายม่อม|แป้งท้าว|แป้งเท้า',
#  'หมี่กรอบ': 'หมี่กรอบ',
#  'ตำลึง': 'ตำลึง',
#  'ซอสเพสโต้': 'ซอสเพสโต้',
#  'เครื่องแกงเขียวหวาน': 'เครื่องแกงเขียวหวาน',
#  'หนำเลี๊ยบ': 'หนำเลี๊ยบ',
#  'ข้าวเหนียว': 'ข้าวเหนียว',
#  'ดอกหอม': 'ดอกหอม',
#  'โซดา': '^(?!เบคกิ้ง)โซดา|น้ำโซดา',
#  'ถั่วพู': 'ถั่วพู',
#  'เส้นแก้ว': 'เส้นแก้ว',
#  'เครื่องต้มยำ': 'เครื่องต้มยำ',
#  'เผือก': 'เผือก',
#  'ก้อนแกงกะหรี่ญี่ปุ่น': 'ก้อนแกงกะหรี่ญี่ปุ่น',
#  'โปรตีนเกษตร': 'โปรตีนเกษตร',
#  'บ๊วยดอง': 'บ๊วยดอง',
#  'หัวไชโป้ว': 'ไชโป๊ว',
#  'แคปหมู': 'แคปหมู',
#  'พาร์สลีย์': 'พาร์สลีย์|พาสลี่|พาสลีย์|parsley',
#  'บวบ': 'บวบ',
#  'ใบเตย': 'ใบเตย',
#  'ใบเหลียง': 'ใบเหลียง',
#  'เบคกิ้งโซดา': 'เบคกิ้งโซดา',
#  'เนื้อเป็ด': '^(?!ไข่)เป็ด|เนื้อเป็ด|อกเป็ด',
#  'ใบแมงลัก': 'แมงลัก',
#  'ถั่ว': '^ถั่ว$|ถั่วป่น|ถั่วคั่ว',
#  'มะเขือ': '^มะเขือ$',
#  'ไก่จ๊อ': 'ไก่จ๊อ',
#  'ถั่วแดง': 'ถั่วแดง',
#  'ดอกไม้กวาด': 'ดอกไม้กวาด',
#  'แคปเปลลินี': 'Angel Hair|เส้นแองเจิลแฮร์|เส้น angel hair',
#  'แป้งพิซซ่าสำเร็จ': 'แป้งพิซซ่าสำเร็จ',
#  'ควินัว': 'ควินัว|คีนัว',
#  'น้ำเลม่อน': 'น้ำเลม่อน',
#  'เครื่องยาจีน': 'เครื่องยาจีน',
#  'ข้าวโอ๊ต': 'ข้าวโอ๊ต',
#  'ดอกชมจันทร์': 'ดอกชมจันทร์',
#  'เยื่อไผ่': 'เยื่อไผ่',
#  'แป้งต็อก': 'แป้งต็อก',
#  'มะกอก': '^มะกอก',
#  'เครื่องแกงใต้': 'เครื่องแกงใต้',
#  'ใบชะพลู': 'ใบชะพลู',
#  'มาการีน': 'มาการีน',
#  'แกงกะหรี่': '^แกงกะหรี่|กะหรี่แกง',
#  'ใบยอ': 'ใบยอ',
#  'น้ำบูดู': 'น้ำบูดู',
#  'ไข่ปลาหมึก': 'ไข่ปลาหมึก',
#  'ดีปลีผง': 'ดีปลีผง',
#  'เครื่องตุ๋นยาจีน': 'เครื่องตุ๋นยาจีน',
#  'เซี่ยงจี้': 'เซี่ยงจี้',
#  'น้ำอ้อย': 'น้ำอ้อย',
#  'เพนเน่': 'เพนเน่',
#  'ดอกโสน': 'ดอกโสน',
#  'ซูกินี่': 'ซุคคีนี',
#  'ยีสต์': 'ยีสต์',
#  'ผักขม': 'ผักขม',
#  'ถั่วแขก': 'ถั่วแขก',
#  'ลูกกระวาน': 'ลูกกระวาน',
#  'น้ำอาจาด': 'น้ำอาจาด',
#  'ข้าวมัน': 'ข้าวมัน',
#  'มันบด': 'มันบด'}

# %%
with open('../dictionary/ingredient_dict.json','w',encoding='utf8')as file:
  json.dump(dict_name,file,ensure_ascii=False)

# %%
for x in dict_name.keys():
  print(x)
# Out:
# น้ำปลา(?!ร้า)
# ^กระเทียม|กะเทียม|กระเทียบสับ|ผงกระเทียม|กระเทียวเจียว|กระเทียบ|กระทียมสับ|garlic|^น้ำจิ้ม กระเทียม$
# ^ไข่(?!(เป็ด|กุ้ง|ปลาหมึก))|ไก่ไข่
# น้ำตาล(?!หญ้าหวาน)|นำ้ตาลทราย
# เกลือ|salt|เกลอ
# ซอสปรุงรส|ซอสฝาเขียว|ซอสฝาเหลือง|ซอสแมคกี้|ซอสแม็กกี้|ซอสข้นปรุงรสคนอร์|แม๊กกี้|ซอส|แม็กกี้|คนอร์ซอสข้นปรุงรสหมู|ซอสข้นคนอร์|ซอลปรุงรส|แมกกี้|ซ้อสปรุงรส
# น้ำมันหอย|ซอสหอย|ซอยหอยนางรม|นำ้มันหอย|ซอลหอยนางรม|นํ้ามันหอย
# น้ำมัน(?!(หอย|พริกเผา|งา))|olive oil|oil
# น้ำเปล่า|น้ำสะอาด|น้ำต้มสุก|^น้ำ$|น้ำเย็น|น้ำร้อน|น้ำดื่ม|น้ำอุ่น|น้ำสำหรับต้มเส้น
# ซีอิ๊วขาว|ซีอิ้วขาว|ซอสถั่วเหลือง|ซีอิ๋วขาว|สี่อิ๋วขาวสูตร1|ซีอิ้วปรุงรส|^ซีอิ๊ว$|ซี๊อิ๋วขาว|ซีอิ้ว ขาว|ซีอิ้ว|ชีอิ้วขาว|ซี้อิ้วขาว|ซีอี๊วขาว|ชีอิ๊วขาว|ซีอิ๋ว|ซี่อิ๋วขาวสูตร1|สี่อิ๋วขาวสูตร 2|soy sauce|ซีอี้วขาว|ซีอี๋วขาว|สี่อิ๋วขาวสูตร|สี่อิ่ว
# ^(?!.*ซอส|หมู).*พริกไทย.*|พริกไท|black pepper|Red Pepper Flakes
# ต้นหอม|ต้มหอม|ตันหอม
# แครอท|แคร์รอต|แครท|ผักสามสี
# ^(?!.*บะหมี่|ผง|กระดูก|ลูกชิ้น|ซี่โครง|ตับ|น้ำมัน|น้ำสต๊อก|คนอร์|แหนม|กุนเชียง|กาก|รสดี|ซุป|น้ำ|แคป|ซอส|มัน|กระเทียม|ไส้กรอก|เลือด|แฮม).*หมู(?!ยอ|กรอบ|หยอง|แดง|แฮม).*|สามชั้นสไลซ์|สันคอ
# ^(?!.*เส้น)(.*ข้าวสวย|^ข้าว$|ข้าวกล้อง.*|ข้าวสาร|ข้าวเปล่า|ข้าวหอมมะลิ|ข้าวเย็น|ข้าวหุงสุก|ข้าวญี่ปุ่น|ข้าวสุก|ข้าวแช่เย็น|ข้าวหอม|ข้าวเสาไห้|ข้าวบาสมาติ)
# มะนาว
# พริกขี้หนู
# ^(?!.*ไข่|มัน|มาม่า).*กุ้ง(?!แห้ง).*
# ^(?!.*ซอส|ซ้อส).*มะเขือเทศ.*
# หอมใหญ่|หอมหัวใหญ่|หัวหอม|หอมแขก|หอมซอย|หอมเล็กเจียว|^หอม$|หัวใหญ่
# รากผักชี
# หอมแดง|หอมเจียว|หอมเเดง
# พริกแห้ง
# พริกป่น
# ^(?!.*ราก|ลูก).*ผักชี.*|ผง coriander
# ซอสมะเขือเทศ|ซ้อสมะเขือเทศ
# ใบมะกรูด|ใบมะกูด|มะกรูด
# น้ำมันงา
# ^พริก$|พริกสด|พริกจินดา|พริกแดง|พริกใหญ่|พริกสับ|พริกอ่อน|พริกตำ|พริกซอย|พริกทอด|พริกสีแดง|พริกหั่น|พริกคั่ว|พริก+|พริกหั่นเฉียง
# โหระพา|ใบโหรพา|โหรพา
# ถั่วฝักยาว|ถั่วฟักยาว|ถั่วผักยาว|ถัวฝักยาว
# ใบกะเพรา|ใบกระเพรา|กระเพรา|กะเพรา|ใบกระเพา|ใบกระ เพรา แดง|กระเพา|Basil
# ^(?!.*ไส้กรอก|ไข่|เลือด|น้ำ|ผง|โครง|ตีน|เครื่องใน|เต้าหู้|ซี่โครง|ขา|ซอส|ตับ).*ไก่(?!จ๊อ|ไข่).*|chicken
# ^ซีอิ๊วดำ$|^ซีอิ้วดำ$|ซีอิ๋วดำ(?!หวาน)|สี่อิ๋วดำสูตรเค็ม
# ถั่วงอก
# คะน้า
# ข้าวโพดอ่อน
# เนย
# แป้งทอดกรอบ|แป้งชุบทอด|แป้งโกกิ|แป้งทอด|แป้งสำหรับทอด|แป้งทอดกรอบคนอร์
# แป้งมัน
# ^(?!.*ซอส|ซีอิ๊ว|ผงปรุงรส|ซีอิ้ว|คนอร์).*เห็ด.*
# เส้นสปาเก็ตตี้|เส้นสปาเกตตี้|สปาเก็ตตี้|สปาเกตตี้|เส้นสปาเกตตี|สปาเกตตี
# เต้าเจี้ยว|เต้าเจี๊ยว|เต้าเจียว
# โชยุ|ซีอิ๊วญี่ปุ่น|โชวยุ|Soba tsuyu
# ตะไคร้|ตะใคร้
# ^(?!.*ไข่).*ปลาหมึก.*|^หมึก|หมึกกล้วย
# น้ำพริกเผา
# เบคอน
# ไส้กรอก
# ^นม(?!ข้น)
# ซอสพริก
# วุ้นเส้น|^เส้น$
# น้ำซุป|น้ำซุบ
# ผักกาด|ผัดกาดขาว|ผักคอส
# ^กะปิ
# พริกชี้ฟ้า|พริกเหลือง
# กะทิ|กระทิ
# เส้นใหญ่|เส้นไหญ่|^เส้น$
# ^(?!.*ดอก)กะหล่ำ(?!.*ดอก.*)|กะหล่ำปลี|กระหล่ำปลี
# ผักบุ้ง
# แฮม
# หมูยอ
# แตงกวา
# กุ้งแห้ง
# มิริน
# น้ำมะขามเปียก|น้ำมะขาวเปียก|น้ำมะขาม
# ต้นกระเทียม
# ถั่วเน่า
# หญ้าหวาน
# ขึ้นฉ่าย|คื่นช่าย|คึ่นช่าย|ขึ้นช่าย|คื่นไช้|คื่นไฉ่|ตั้งโอ๋
# มันฝรั่ง
# น้ำส้มสายชู|น้ำส้ม
# ใบบัวบก
# แป้งขนมปัง
# ซีรัป
# เส้นเฟตตูชินี
# ข่า
# มาม่า|บะหมี่กึ่งสำเร็จรูป|เส้นหมี่ไวไว|ไวไว|หมี่กึง
# น้ำผึ้ง
# ^(?!.*ซอส|แป้งทอด).*(คนอร์|รสดี).*|อร่อยชัวร์|ผงปรุงรส|เครื่องปรุงรส|ซุปก้อน|ผงซุปหมูก้อน|ชูรส|ผงซุป|ผงเติมทิพ|ผงดาชิ|ผงปาปริก้า|ดาชิ|ปาปริก้า|เครื่องปรุง|ผงปาปริกา|italian seasoning|ผงนัว|ผงหม่าล่า|ซุปหมูก้อน|ผงหมาล่า|ผงโรยข้าว
# ซอสเห็ดหอม|ซอสเห็ด หอม
# ไชเท้า
# พริกแกง
# แป้งข้าวโพด
# ซีอิ้วดำหวาน|ซีอิ๊วดำหวาน|ซีอิ๊วหวาน|สี่อิ๋วหวาน|สี่อิ๋วดำสูตรหวาน|ซี๊อิ๋วดำหวาน
# กุนเชียง
# ข้าวคั่ว
# กวางตุ้ง
# ลูกชิ้น
# ไข่เป็ด
# ปลากระป๋อง
# ผักสลัด
# ^กระดูกหมู$|กระดูกเล้ง|เล้ง
# ปูอัด
# เกล็ดขนมปัง|เกร็ดขนมปัง
# เส้นโซบะ
# น้ำหวานดอกมะพร้าว
# น้ำจิ้มหมูหัน
# ถั่วแระญี่ปุ่น
# เต้าหู้ไข่
# ปลาร้า
# ^(?!.*น้ำ).*งา.*
# ถั่วลันเตา|ผักสามสี
# ถั่วลันเตา
# กระชาย
# ผงชูรส
# ขนมจีน
# ^(?!.*ผัก).*ชีส.*|Mozzarella cheese
# พริกหยวก|พริกสามสี
# เส้นหมี่(?!ซั่ว|ฮกเกี้ยน|เหลือง|ไวไว|หมี่ขาว)|หมี่ขาว|^เส้น$
# มะเขือเปราะ
# พริกเผา
# ซี่โครงหมู
# เหล้า|สาเก
# กิมจิ
# ออริกาโน่|อาริกาโน|ออริกาโน|oregano
# มายองเนส
# น้ำจิ้มสุกี้
# ขิง
# ชะอม
# ^ผัก$|ผักที่ชอบ
# ^ผัก$|ผักต่างๆ|ผักสด|ผักเครื่องเคียง|ผักตามชอบ
# แหนม|เเหนม
# นมข้น
# มักกะโรนี|มะกะโรนีต้มสุก|มะกะโรนี
# อบเชย
# ตับ
# หมูกรอบ
# ผักโขม|ผักขม
# เส้นจันทน์
# ใบเบย์
# ปลาแผ่น
# ^มันหมู$
# ขาไก่
# แปะก๊วย
# วาซาบิ
# ^ฟัก$
# ไทม์
# โคชูจัง
# ซีอิ๊วเห็ดหอม|ซีอิ้วเห็ดหอม
# ไข่กุ้ง
# ^(?!.*น้ำพริก).*มันกุ้ง.*
# ^เต้าหู้(?!ไข่)
# ทูน่า
# เบค่อน
# กระเฉด|ผักกะเฉด
# เกี๊ยว
# สะตอ|สตอ
# ถั่วลิสง
# เส้นเล็ก|เส้นผัดไท
# ซอสเทริยากิ|ซอสเทอริยากิ
# เลือด
# ฟักทอง
# ใบกระวาน
# กุยช่าย|กุ้ยช่าย|กุ่ยช่าย|ใบกุ้ยฉ่าย
# ผงกะหรี่|ผงกระหรี่
# มะเขือพวง
# มะเขือยาว
# เส้นก๋วยเตี๋ยว
# น้ำพริก(?!เผา)|พริกหนุ่ม
# เม็ดมะม่วง
# ^ข้าวโพด(?!อ่อน)|ผักสามสี
# เส้นเซี่ยงไฮ้
# เส้นปลา|ปลาเส้น
# บะหมี่(?!กึ่ง)|หมี่เหลือง|เส้นหมี่ฮกเกี้ยน|เส้นหมี่เหลือง|หมี่ฮ่องกง|เส้นเหลือง|หมี่หยก|หมี่เบตง|หมี่ฮกเกี้ยน|^เส้น$
# หน่อไม้
# มะขามเปียก
# แป้งอเนกประสงค์|แป้งสาลีอเนกประสงค์|แป้งสาลี|แป้งเอนกประสงค์
# ตั้งฉ่าย|ตังฉ่าย
# ดอกกะหล่ำ|กะหล่ำดอก|ดอกกระหล่ำ
# พาสต้า|pasta
# ^ขนมปัง
# บล็อคโคลี่|บล๊อคโคลี่|บล็อคโครี่|บล๊อกโคลี่|บรอคคอลลี่|บร็อคโคลี่|บร๊อคโคลี่|บล็อกโคลี่
# น้ำเชื่อม
# น้ำจิ้มไก่
# หมี่ซั่ว
# โป๊ยกั๊ก
# น้ำกระเทียมดอง
# มะละกอ
# ^(?!.*น้ำ).*มะพร้าว.*
# ปู(?!อัด)
# ^(?!.*เป็ด).*พะโล้
# น้ำสต๊อก|น้ำสต็อก|น้ำสต้อค
# หมูหยอง
# ตีนไก่
# สับปะรด|สัปปะรด
# ฟองเต้าหู้
# น้ำสลัด
# มัสตาร์ด
# พริกหวาน
# มะระ
# แครรอท
# เก๋ากี้
# ^(?!.*น้ำ|ซอส|ซอย|นำ้|ซอล|ไวไว|นํ้ามัน).*หอย.*
# อุด้ง
# ^มะม่วง
# โครงไก่
# ข้าวไรซ์เบอรี่|ข้าวไรซ์เบอร์รี่
# หมูแดง
# โรสแมรี่
# ต้นอ่อนทานตะวัน|ยอดอ่อนทานตะวัน
# เส้นยากิโซบะ
# ลูกผักชี
# ไส้อั่ว
# สะระแหน่|ใบสาระแหน่
# เส้นก๋วยจั๊บ
# ผงฟู
# ฮอตดอก
# ^(?!.*ลูกชิ้น|หมู).*เนื้อ(?!.*หมู|.*ไก่|กุ้ง|ปลา|ปู|หอย|เป็ด)
# ^แป้ง$|แป้งชุปทอด
# ซอสเย็นตาโฟ
# น้ำจิ้มซีฟู้ด
# แตงร้าน
# มะเขือม่วง
# กระดูกอ่อน
# แป้งข้าวเจ้า
# สาหร่าย
# โยเกิร์ต
# (^ปลา(?!หมึก|กระป๋อง|ร้า|แผ่น|เส้น))|แซลมอน|เนื้อปลา
# ผงขมิ้น|^ขมิ้น$
# ก้านพลู
# เส้นบุก
# แขนง
# ซอสภูเขา
# เครื่องใน
# ยี่หร่า|ผง cumin
# โบโลน่า
# หัวปลี
# ครีม
# ^กากหมู$
# กระเพาะปลา
# ไวน์ขาว
# ถั่วหวาน
# แป้งท้าวยายม่อม|แป้งท้าว|แป้งเท้า
# หมี่กรอบ
# ตำลึง
# ซอสเพสโต้
# เครื่องแกงเขียวหวาน
# หนำเลี๊ยบ
# ข้าวเหนียว
# ดอกหอม
# ^(?!เบคกิ้ง)โซดา|น้ำโซดา
# ถั่วพู
# เส้นแก้ว
# เครื่องต้มยำ
# เผือก
# ก้อนแกงกะหรี่ญี่ปุ่น
# โปรตีนเกษตร
# บ๊วยดอง
# ไชโป๊ว
# แคปหมู
# พาร์สลีย์|พาสลี่|พาสลีย์|parsley
# บวบ
# ใบเตย
# ใบเหลียง
# เบคกิ้งโซดา
# ^(?!ไข่)เป็ด|เนื้อเป็ด|อกเป็ด
# แมงลัก
# ^ถั่ว$|ถั่วป่น|ถั่วคั่ว
# ^มะเขือ$
# ไก่จ๊อ
# ถั่วแดง
# ดอกไม้กวาด
# Angel Hair|เส้นแองเจิลแฮร์|เส้น angel hair
# แป้งพิซซ่าสำเร็จ
# ควินัว|คีนัว
# น้ำเลม่อน
# เครื่องยาจีน
# ข้าวโอ๊ต
# ดอกชมจันทร์
# เยื่อไผ่
# แป้งต็อก
# ^มะกอก
# เครื่องแกงใต้
# ใบชะพลู
# มาการีน
# ^แกงกะหรี่|กะหรี่แกง
# ใบยอ
# น้ำบูดู
# ไข่ปลาหมึก
# ดีปลีผง
# เครื่องตุ๋นยาจีน
# เซี่ยงจี้
# น้ำอ้อย
# เพนเน่
# ดอกโสน
# ซุคคีนี
# ยีสต์
# ผักขม
# ถั่วแขก
# ลูกกระวาน
# น้ำอาจาด
# ข้าวมัน
# มันบด
